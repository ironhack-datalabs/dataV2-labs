# %%
import feedparser
from pprint import pprint 
import requests

# %%
centreinffo1 = requests.get("http://rss.cnn.com/rss/edition_meast.rss")
centreinffo = feedparser.parse(centreinffo1.text)

# %%
centreinffo.entries
# Out:
# [{'title': "Jordan's royal family drama sends shudders around the region. Here's what we know",
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': '',
#    'value': "Jordan's royal family drama sends shudders around the region. Here's what we know"},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://rss.cnn.com/~r/rss/edition_meast/~3/EKbutClCJnw/index.html'}],
#   'link': 'http://rss.cnn.com/~r/rss/edition_meast/~3/EKbutClCJnw/index.html',
#   'id': 'https://www.cnn.com/2021/04/05/middleeast/jordan-arrests-royal-family-explainer-intl/index.html',
#   'guidislink': False,
#   'published': 'Tue, 06 Apr 2021 05:57:14 GMT',
#   'published_parsed': time.struct_time(tm_year=2021, tm_mon=4, tm_mday=6, tm_hour=5, tm_min=57, tm_sec=14, tm_wday=1, tm_yday=96, tm_isdst=0),
#   'media_content': [{'medium': 'image',
# ...
