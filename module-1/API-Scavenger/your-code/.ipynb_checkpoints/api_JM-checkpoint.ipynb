# %%
import requests
import json
import pandas as pd

# %%
response = requests.get('https://api.github.com/events', headers={'Accept': 'application/vnd.github.v3+json'})

# %%
response.request.url
# Out:
# 'https://api.github.com/events'

# %%
from pandas import json_normalize

# %%
data = json_normalize(response.json())

# %%
f = open('../github_token.txt', 'r')

# %%
github_token = f.read()
f.close()

# %%
response = requests.get('https://api.github.com/user', 
                        headers={'Accept': 'application/vnd.github.v3+json',
                                 'Authorization': f'token {github_token}'})

# %%
from pprint import pprint

# %%
pprint(response.json())
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/1613530?v=4',
#  'bio': None,
#  'blog': '',
#  'collaborators': 1,
#  'company': None,
#  'created_at': '2012-04-04T22:27:38Z',
#  'disk_usage': 91602,
#  'email': None,
#  'events_url': 'https://api.github.com/users/jmomarty/events{/privacy}',
#  'followers': 4,
#  'followers_url': 'https://api.github.com/users/jmomarty/followers',
#  'following': 8,
#  'following_url': 'https://api.github.com/users/jmomarty/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jmomarty/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/jmomarty',
#  'id': 1613530,
#  'location': None,
#  'login': 'jmomarty',
#  'name': None,
#  'node_id': 'MDQ6VXNlcjE2MTM1MzA=',
#  'organizations_url': 'https://api.github.com/users/jmomarty/orgs',
#  'owned_private_repos': 2,
#  'plan': {'collaborators': 0,
#           'name': 'free',
#           'private_repos': 10000,
# ...

# %%
response = requests.get('https://api.github.com/user/emails', 
                        headers={'Accept': 'application/vnd.github.v3+json',
                                 'Authorization': f'token {github_token}'},
                        data=json.dumps({"emails": ["jmomarty@gmail.com"]}))

# %%
response.json()
# Out:
# [{'email': 'jmomarty@gmail.com',
#   'primary': True,
#   'verified': True,
#   'visibility': 'public'}]

# %%
response = requests.delete('https://api.github.com/user/emails', 
                        headers={'Accept': 'application/vnd.github.v3+json',
                                 'Authorization': f'token {github_token}'},
                        data=json.dumps({"emails": ["jm@devlens.ai"]}))

# %%
response.content
# Out:
# b''

# %%
from github import Github

# First create a Github instance:

# using an access token
g = Github(github_token)

# %%
g.get_user()
# Out:
# 'jmomarty'

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(adata[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
data.head(1)['payload']
# Out:
# 0    {'action': 'started'}
# Name: payload, dtype: object

# %%
data_flat = flatten(data, ['actor', 'repo', 'payload', 'org'])

# %%
data_flat
# Out:
#              id               type  public            created_at  actor_id  \
# 0   12944733292         WatchEvent    True  2020-07-18T12:24:28Z   1410997
# 1   12944733289          PushEvent    True  2020-07-18T12:24:28Z  55109545
# 2   12944733287          PushEvent    True  2020-07-18T12:24:28Z  24551379
# 3   12944733288        CreateEvent    True  2020-07-18T12:24:28Z  49699333
# 4   12944733278   PullRequestEvent    True  2020-07-18T12:24:28Z  50907924
# 5   12944733281        CreateEvent    True  2020-07-18T12:24:28Z  67676458
# 6   12944733279         WatchEvent    True  2020-07-18T12:24:28Z  19967403
# 7   12944733276  IssueCommentEvent    True  2020-07-18T12:24:28Z   7312456
# 8   12944733272   PullRequestEvent    True  2020-07-18T12:24:28Z  62996553
# 9   12944733271          PushEvent    True  2020-07-18T12:24:28Z  59916393
# 10  12944733264        CreateEvent    True  2020-07-18T12:24:28Z  49699333
# ...

# %%
flattened = pd.DataFrame(dict(data['actor'])).transpose()

# %%
flattened
# Out:
#           id                      login              display_login  \
# 0   46473241                     Rostux                     Rostux
# 1   49699333            dependabot[bot]                 dependabot
# 2   43522559              FreeBirdsCrew              FreeBirdsCrew
# 3   49699333            dependabot[bot]                 dependabot
# 4   66284035              andremenezees              andremenezees
# 5   10461665                    jishnub                    jishnub
# 6   49699333            dependabot[bot]                 dependabot
# 7   49699333            dependabot[bot]                 dependabot
# 8   61357822               justinm0rgan               justinm0rgan
# 9   10430134                      axlwe                      axlwe
# 10  22845496                      Jozeb                      Jozeb
# 11  12855915           SteveCharlesYang           SteveCharlesYang
# 12    262545                 proffalken                 proffalken
# ...

# %%
columns = [str(col) for col in flattened.columns]
flattened.columns = ['actor' + '_' + colname for colname in columns]

# %%
flattened
# Out:
#     actor_id                actor_login        actor_display_login  \
# 0   46473241                     Rostux                     Rostux
# 1   49699333            dependabot[bot]                 dependabot
# 2   43522559              FreeBirdsCrew              FreeBirdsCrew
# 3   49699333            dependabot[bot]                 dependabot
# 4   66284035              andremenezees              andremenezees
# 5   10461665                    jishnub                    jishnub
# 6   49699333            dependabot[bot]                 dependabot
# 7   49699333            dependabot[bot]                 dependabot
# 8   61357822               justinm0rgan               justinm0rgan
# 9   10430134                      axlwe                      axlwe
# 10  22845496                      Jozeb                      Jozeb
# 11  12855915           SteveCharlesYang           SteveCharlesYang
# 12    262545                 proffalken                 proffalken
# ...

# %%
data = pd.concat([data, flattened], axis=1)
data = data.drop('actor', axis=1)

# %%
data
# Out:
#              id              type  \
# 0   12944700722         PushEvent
# 1   12944700723  PullRequestEvent
# 2   12944700719         PushEvent
# 3   12944700721  PullRequestEvent
# 4   12944700712         PushEvent
# 5   12944700713         PushEvent
# 6   12944700714  PullRequestEvent
# 7   12944700708  PullRequestEvent
# 8   12944700709         PushEvent
# 9   12944700710         PushEvent
# 10  12944700699         PushEvent
# 11  12944700702         PushEvent
# 12  12944700700         PushEvent
# 13  12944700697  PullRequestEvent
# 14  12944700706       CreateEvent
# 15  12944700691         PushEvent
# 16  12944700696  PullRequestEvent
# 17  12944700694       CreateEvent
# 18  12944700695         PushEvent
# 19  12944700690         PushEvent
# 20  12944700688         PushEvent
# 21  12944700686       CreateEvent
# 22  12944700685  PullRequestEvent
# 23  12944700680         PushEvent
# 24  12944700675         PushEvent
# 25  12944700669         PushEvent
# ...

# %%
# ?requests.get

# %%
res = requests.get('https://api.github.com', headers={'Authorization': 'token f4f7c97ea1bdec080dd56163d543bae537d421a4'})

# %%
res.content
# Out:
# b'{"message":"Bad credentials","documentation_url":"https://developer.github.com/v3"}'

# %%
data["type"].value_counts()
# Out:
# CreateEvent          10
# PullRequestEvent      8
# WatchEvent            4
# IssueCommentEvent     4
# PushEvent             4
# Name: type, dtype: int64
