# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %%
from datetime import date
from datetime import datetime
from datetime import timedelta
delta = timedelta(days=30)
today = date.today()

# %%
questions = SITE.fetch('questions', fromdate=datetime.today() - timedelta(days=31),
                       todate=datetime.now(), min=20)
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 233,
#  'total': 0,
#  'items': [{'tags': ['docker',
#     'docker-compose',
#     'phpstorm',
#     'php-7.4',
#     'xdebug-3'],
#    'owner': {'reputation': 677,
#     'user_id': 1829368,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://www.gravatar.com/avatar/0fb28a45315f355ba7bc71d822a60e2f?s=128&d=identicon&r=PG',
#     'display_name': 'TomaszKane',
#     'link': 'https://stackoverflow.com/users/1829368/tomaszkane'},
#    'is_answered': True,
#    'view_count': 15,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1616850908,
#    'creation_date': 1616843017,
#    'last_edit_date': 1616850164,
#    'question_id': 66830577,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/66830577/xdebug-cannot-connect-to-client-from-docker-container',
# ...

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
import json
questions = SITE.fetch('questions', fromdate=datetime.today() - timedelta(days=2), todate=datetime.today(),
    min=5, tagged='python', sort='votes')

questions['items'][0]
# Out:
# {'tags': ['python', 'pandas', 'dataframe'],
#  'owner': {'reputation': 133,
#   'user_id': 15479264,
#   'user_type': 'registered',
#   'profile_image': 'https://www.gravatar.com/avatar/445535c7b005e1a42a628256f8465118?s=128&d=identicon&r=PG&f=1',
#   'display_name': 'mkoeck',
#   'link': 'https://stackoverflow.com/users/15479264/mkoeck'},
#  'is_answered': True,
#  'view_count': 242,
#  'accepted_answer_id': 66802384,
#  'answer_count': 4,
#  'score': 13,
#  'last_activity_date': 1616687207,
#  'creation_date': 1616684128,
#  'question_id': 66802094,
#  'content_license': 'CC BY-SA 4.0',
#  'link': 'https://stackoverflow.com/questions/66802094/pandas-check-if-value-in-one-multiindex-column-is-in-any-column-same-row-of-dif',
#  'title': 'Pandas check if value in one multiindex column is in any column, same row of different multiindex'}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answers = SITE.fetch('answers', ids=[6784, 6786])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 242,
#  'total': 0,
#  'items': [{'owner': {'reputation': 67921,
#     'user_id': 383,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/b3b929eac30b663d37bad00f2061403b?s=128&d=identicon&r=PG',
#     'display_name': 'GateKiller',
#     'link': 'https://stackoverflow.com/users/383/gatekiller'},
#    'is_accepted': False,
#    'score': -1,
#    'last_activity_date': 1410851980,
#    'last_edit_date': 1410851980,
#    'creation_date': 1218292127,
#    'answer_id': 6786,
#    'question_id': 6785,
#    'content_license': 'CC BY-SA 3.0'},
#   {'owner': {'reputation': 29473,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
# ...
