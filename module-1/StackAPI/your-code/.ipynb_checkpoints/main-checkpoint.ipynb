# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import sys
# !{sys.executable} -m pip install stackapi
from stackapi import StackAPI
from datetime import datetime
import pandas as pd

SITE = StackAPI('stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# Last month is April, dates converted to Unix Timestamp.

questions = SITE.fetch('questions', fromdate=1585699200, todate=1588291199)

questions_df = pd.DataFrame(questions)
questions_df
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                                  items
# 0    {'tags': ['reactjs', 'react-context', 'storybo...
# 1    {'tags': ['scala.js'], 'owner': {'reputation':...
# ...

# %%
# An alternative is to use datetime instead of Unix time:
# answers = SITE.fetch('answers', fromdate=datetime(2020,4,1), todate=datetime(2020,4,30))

answers = SITE.fetch('answers', fromdate=1585699200, todate=1588291199)
answers_df = pd.DataFrame(answers)
answers_df
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                                  items
# 0    {'owner': {'reputation': 116, 'user_id': 10985...
# 1    {'owner': {'reputation': 1, 'user_id': 1340392...
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
most_voted_question = SITE.fetch('questions', fromdate=1589932800, todate=1590019199, min=5, tagged='python', sort='votes')
most_voted_question
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'pandas'],
#    'owner': {'reputation': 103,
#     'user_id': 7740692,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/GbSfv.jpg?s=128&g=1',
#     'display_name': 'Andy Wilson',
#     'link': 'https://stackoverflow.com/users/7740692/andy-wilson'},
#    'is_answered': True,
#    'view_count': 59,
#    'answer_count': 3,
#    'score': 6,
#    'last_activity_date': 1589967702,
#    'creation_date': 1589965546,
#    'last_edit_date': 1589966099,
#    'question_id': 61909187,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61909187/selecting-rows-with-multi-index-columns',
#    'title': 'Selecting rows with multi-index columns'}]}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here

answer_id_6784_6473 = SITE.fetch('answers', ids=[6473, 6784])

# %%
answer_id_6784_6473
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 28815,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}
