# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
from stackapi import StackAPI
import json
import pandas as pd

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1585699200, todate=1588291200)
answers = SITE.fetch('answers', fromdate=1585699200, todate=1588291200)
#qadf = pd.json_normalize(q_and_a)
questions
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['nginx', 'nginx-config'],
#    'owner': {'reputation': 1,
#     'user_id': 5020431,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-QQyf5719_K4/AAAAAAAAAAI/AAAAAAAAAB8/GkHBQP4UoVI/photo.jpg?sz=128',
#     'display_name': 'Sweetie Panav',
#     'link': 'https://stackoverflow.com/users/5020431/sweetie-panav'},
#    'is_answered': False,
#    'view_count': 19,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1589970870,
#    'creation_date': 1586090399,
#    'question_id': 61042727,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61042727/how-to-include-multiple-js-include-tags-in-nginx',
#    'title': 'How to include multiple js_include tags in Nginx'},
#   {'tags': ['python-3.x', 'tensorflow', 'deep-learning', 'q-learning'],
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
topvote = SITE.fetch('questions', fromdate=1589932800, todate=1589979600,
    min=5, tagged='python', sort='votes')
topvote
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'pandas'],
#    'owner': {'reputation': 103,
#     'user_id': 7740692,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/GbSfv.jpg?s=128&g=1',
#     'display_name': 'Andy Wilson',
#     'link': 'https://stackoverflow.com/users/7740692/andy-wilson'},
#    'is_answered': True,
#    'view_count': 54,
#    'answer_count': 3,
#    'score': 6,
#    'last_activity_date': 1589967702,
#    'creation_date': 1589965546,
#    'last_edit_date': 1589966099,
#    'question_id': 61909187,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61909187/selecting-rows-with-multi-index-columns',
#    'title': 'Selecting rows with multi-index columns'}]}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
print ('Looked like 6473 was empty, so I searched 6437 and found another just to make sure I found two IDs')
specific_answers = SITE.fetch('answers',ids=[6784,6437])
specific_answers
# Out:
# Looked like 6473 was empty, so I searched 6437 and found another just to make sure I found two IDs
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 28815,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'},
#   {'owner': {'reputation': 12762,
#     'user_id': 214,
#     'user_type': 'registered',
#     'accept_rate': 72,
# ...
