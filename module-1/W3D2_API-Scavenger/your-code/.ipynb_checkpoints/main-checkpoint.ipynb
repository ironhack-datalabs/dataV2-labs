# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

username = 'vpavandijk'
token = '********'

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# # your code here

response_1 = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks?page=1&per_page=100', auth=(username,token))
results_1 = response_1.json()
data_1 = pd.DataFrame(results_1)

response_2 = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks?page=2&per_page=100', auth=(username,token))
results_2 = response_2.json()
data_2 = pd.DataFrame(results_2)

data_complete_forks = pd.concat([data_1, data_2])
data_complete_forks
# Out:
#            id                           node_id         name  \
# 0   261791698  MDEwOlJlcG9zaXRvcnkyNjE3OTE2OTg=  dataV2-labs
# 1   261162998  MDEwOlJlcG9zaXRvcnkyNjExNjI5OTg=  dataV2-labs
# 2   261150300  MDEwOlJlcG9zaXRvcnkyNjExNTAzMDA=  dataV2-labs
# 3   261144946  MDEwOlJlcG9zaXRvcnkyNjExNDQ5NDY=  dataV2-labs
# 4   261144477  MDEwOlJlcG9zaXRvcnkyNjExNDQ0Nzc=  dataV2-labs
# ..        ...                               ...          ...
# 1   215970459  MDEwOlJlcG9zaXRvcnkyMTU5NzA0NTk=  dataV2-labs
# 2   215567399  MDEwOlJlcG9zaXRvcnkyMTU1NjczOTk=  dataV2-labs
# 3   215323533  MDEwOlJlcG9zaXRvcnkyMTUzMjM1MzM=  dataV2-labs
# 4   215323405  MDEwOlJlcG9zaXRvcnkyMTUzMjM0MDU=  dataV2-labs
# 5   215267431  MDEwOlJlcG9zaXRvcnkyMTUyNjc0MzE=  dataV2-labs
#
#                     full_name  private  \
# 0     llopisaleix/dataV2-labs    False
# 1       Mingiziem/dataV2-labs    False
# 2     rosealcolea/dataV2-labs    False
# 3    erin-berardi/dataV2-labs    False
# 4       vivaveeka/dataV2-labs    False
# ..                        ...      ...
# 1       Slavulyaa/dataV2-labs    False
# 2         MelineM/dataV2-labs    False
# 3          CLeila/dataV2-labs    False
# 4   Deepika-Vijay/dataV2-labs    False
# 5       archanaVi/dataV2-labs    False
#
#                                                 owner  \
# 0   {'login': 'llopisaleix', 'id': 45939551, 'node...
# 1   {'login': 'Mingiziem', 'id': 62057304, 'node_i...
# 2   {'login': 'rosealcolea', 'id': 64498985, 'node...
# 3   {'login': 'erin-berardi', 'id': 63595191, 'nod...
# 4   {'login': 'vivaveeka', 'id': 61741579, 'node_i...
# ..                                                ...
# 1   {'login': 'Slavulyaa', 'id': 53147209, 'node_i...
# 2   {'login': 'MelineM', 'id': 55245104, 'node_id'...
# 3   {'login': 'CLeila', 'id': 17428590, 'node_id':...
# 4   {'login': 'Deepika-Vijay', 'id': 56197190, 'no...
# 5   {'login': 'archanaVi', 'id': 20680580, 'node_i...
#
#                                         html_url description  fork  \
# 0     https://github.com/llopisaleix/dataV2-labs        None  True
# 1       https://github.com/Mingiziem/dataV2-labs        None  True
# 2     https://github.com/rosealcolea/dataV2-labs        None  True
# 3    https://github.com/erin-berardi/dataV2-labs        None  True
# 4       https://github.com/vivaveeka/dataV2-labs        None  True
# ..                                           ...         ...   ...
# 1       https://github.com/Slavulyaa/dataV2-labs        None  True
# 2         https://github.com/MelineM/dataV2-labs        None  True
# 3          https://github.com/CLeila/dataV2-labs        None  True
# 4   https://github.com/Deepika-Vijay/dataV2-labs        None  True
# 5       https://github.com/archanaVi/dataV2-labs        None  True
#
#                                                   url  ... mirror_url  \
# 0   https://api.github.com/repos/llopisaleix/dataV...  ...       None
# 1   https://api.github.com/repos/Mingiziem/dataV2-...  ...       None
# 2   https://api.github.com/repos/rosealcolea/dataV...  ...       None
# 3   https://api.github.com/repos/erin-berardi/data...  ...       None
# 4   https://api.github.com/repos/vivaveeka/dataV2-...  ...       None
# ..                                                ...  ...        ...
# 1   https://api.github.com/repos/Slavulyaa/dataV2-...  ...       None
# 2    https://api.github.com/repos/MelineM/dataV2-labs  ...       None
# 3     https://api.github.com/repos/CLeila/dataV2-labs  ...       None
# 4   https://api.github.com/repos/Deepika-Vijay/dat...  ...       None
# 5   https://api.github.com/repos/archanaVi/dataV2-...  ...       None
#
#    archived disabled open_issues_count license forks open_issues watchers  \
# 0     False    False                 0    None     0           0        0
# 1     False    False                 0    None     0           0        0
# 2     False    False                 0    None     0           0        0
# 3     False    False                 0    None     0           0        0
# 4     False    False                 0    None     0           0        0
# ..      ...      ...               ...     ...   ...         ...      ...
# 1     False    False                 0    None     0           0        0
# 2     False    False                 0    None     0           0        0
# 3     False    False                 0    None     0           0        0
# 4     False    False                 0    None     0           0        0
# 5     False    False                 0    None     0           0        0
#
#    default_branch                                    permissions
# 0          master  {'admin': False, 'push': False, 'pull': True}
# 1          master  {'admin': False, 'push': False, 'pull': True}
# 2          master  {'admin': False, 'push': False, 'pull': True}
# 3          master  {'admin': False, 'push': False, 'pull': True}
# 4          master  {'admin': False, 'push': False, 'pull': True}
# ..            ...                                            ...
# 1          master  {'admin': False, 'push': False, 'pull': True}
# 2          master  {'admin': False, 'push': False, 'pull': True}
# 3          master  {'admin': False, 'push': False, 'pull': True}
# 4          master  {'admin': False, 'push': False, 'pull': True}
# 5          master  {'admin': False, 'push': False, 'pull': True}
#
# [106 rows x 74 columns]

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
# your code here

# data_complete_forks.columns

unique_arr = data_complete_forks["language"].unique()
print(f'The languages used are: {list(unique_arr)}.')
# Out:
# The languages used are: ['Jupyter Notebook', None, 'AGS Script'].

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here

response_3 = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?page=1&per_page=100', auth=(username,token))
results_3 = response_3.json()
flattened_data_3 = json_normalize(results_3)

response_4 = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?page=2&per_page=100', auth=(username,token))
results_4 = response_4.json()
flattened_data_4 = json_normalize(results_4)

data_complete_commits = pd.concat([flattened_data_3, flattened_data_4])
data_complete_commits
# Out:
#                                          sha  \
# 0   3050baad4bdf4ee65be7b6d56ee4902abf59d5fb
# 1   680a9ca1cebd77383a8a104ab48c868d1600790f
# 2   1421d2b97b1e250bbd1c321e7c38a1ef87fd2c49
# 3   023a27f4c4bb515a77bfda08f9309c1b1e333e72
# 4   574666b2fc86a71f60f334545fe4d16ab61ab28f
# ..                                       ...
# 43  14a5e391ed75af39a77ddaee8709f56c2477742b
# 44  b76981fcbd5353a81f1a6ff8167aaf0f7db6281a
# 45  07c5db0ea09dc8d3b817e7a73e67c7d183590f53
# 46  601c36d033364b0b98d2cf59c7e47be0961c9db5
# 47  4d5a0bc47433d02d5568a399162d45b5ff4420ac
#
#                                               node_id  \
# 0   MDY6Q29tbWl0MjEzNjQxMTcwOjMwNTBiYWFkNGJkZjRlZT...
# 1   MDY6Q29tbWl0MjEzNjQxMTcwOjY4MGE5Y2ExY2ViZDc3Mz...
# 2   MDY6Q29tbWl0MjEzNjQxMTcwOjE0MjFkMmI5N2IxZTI1MG...
# 3   MDY6Q29tbWl0MjEzNjQxMTcwOjAyM2EyN2Y0YzRiYjUxNW...
# 4   MDY6Q29tbWl0MjEzNjQxMTcwOjU3NDY2NmIyZmM4NmE3MW...
# ..                                                ...
# 43  MDY6Q29tbWl0MjEzNjQxMTcwOjE0YTVlMzkxZWQ3NWFmMz...
# 44  MDY6Q29tbWl0MjEzNjQxMTcwOmI3Njk4MWZjYmQ1MzUzYT...
# 45  MDY6Q29tbWl0MjEzNjQxMTcwOjA3YzVkYjBlYTA5ZGM4ZD...
# 46  MDY6Q29tbWl0MjEzNjQxMTcwOjYwMWMzNmQwMzMzNjRiMG...
# 47  MDY6Q29tbWl0MjEzNjQxMTcwOjRkNWEwYmM0NzQzM2QwMm...
#
#                                                   url  \
# 0   https://api.github.com/repos/ironhack-datalabs...
# 1   https://api.github.com/repos/ironhack-datalabs...
# 2   https://api.github.com/repos/ironhack-datalabs...
# 3   https://api.github.com/repos/ironhack-datalabs...
# 4   https://api.github.com/repos/ironhack-datalabs...
# ..                                                ...
# 43  https://api.github.com/repos/ironhack-datalabs...
# 44  https://api.github.com/repos/ironhack-datalabs...
# 45  https://api.github.com/repos/ironhack-datalabs...
# 46  https://api.github.com/repos/ironhack-datalabs...
# 47  https://api.github.com/repos/ironhack-datalabs...
#
#                                              html_url  \
# 0   https://github.com/ironhack-datalabs/dataV2-la...
# 1   https://github.com/ironhack-datalabs/dataV2-la...
# 2   https://github.com/ironhack-datalabs/dataV2-la...
# 3   https://github.com/ironhack-datalabs/dataV2-la...
# 4   https://github.com/ironhack-datalabs/dataV2-la...
# ..                                                ...
# 43  https://github.com/ironhack-datalabs/dataV2-la...
# 44  https://github.com/ironhack-datalabs/dataV2-la...
# 45  https://github.com/ironhack-datalabs/dataV2-la...
# 46  https://github.com/ironhack-datalabs/dataV2-la...
# 47  https://github.com/ironhack-datalabs/dataV2-la...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/ironhack-datalabs...
# 1   https://api.github.com/repos/ironhack-datalabs...
# 2   https://api.github.com/repos/ironhack-datalabs...
# 3   https://api.github.com/repos/ironhack-datalabs...
# 4   https://api.github.com/repos/ironhack-datalabs...
# ..                                                ...
# 43  https://api.github.com/repos/ironhack-datalabs...
# 44  https://api.github.com/repos/ironhack-datalabs...
# 45  https://api.github.com/repos/ironhack-datalabs...
# 46  https://api.github.com/repos/ironhack-datalabs...
# 47  https://api.github.com/repos/ironhack-datalabs...
#
#                                               parents commit.author.name  \
# 0   [{'sha': '680a9ca1cebd77383a8a104ab48c868d1600...    kelsey-ironhack
# 1   [{'sha': '1421d2b97b1e250bbd1c321e7c38a1ef87fd...    kelsey-ironhack
# 2   [{'sha': '023a27f4c4bb515a77bfda08f9309c1b1e33...    kelsey-ironhack
# 3   [{'sha': '574666b2fc86a71f60f334545fe4d16ab61a...       kbartonhenry
# 4   [{'sha': '6f83d1446dbb6bd600a2082e8147b79e420f...       kbartonhenry
# ..                                                ...                ...
# 43  [{'sha': 'b76981fcbd5353a81f1a6ff8167aaf0f7db6...             kelsey
# 44  [{'sha': '07c5db0ea09dc8d3b817e7a73e67c7d18359...             kelsey
# 45  [{'sha': '601c36d033364b0b98d2cf59c7e47be0961c...    kelsey-ironhack
# 46  [{'sha': '4d5a0bc47433d02d5568a399162d45b5ff44...    kelsey-ironhack
# 47                                                 []    kelsey-ironhack
#
#                                   commit.author.email    commit.author.date  \
# 0   52278191+kelsey-ironhack@users.noreply.github.com  2020-03-19T11:51:21Z
# 1   52278191+kelsey-ironhack@users.noreply.github.com  2020-02-28T11:07:41Z
# 2   52278191+kelsey-ironhack@users.noreply.github.com  2020-02-20T09:29:30Z
# 3                             k.bartonhenry@gmail.com  2020-01-16T13:47:50Z
# 4                             k.bartonhenry@gmail.com  2020-01-16T11:58:50Z
# ..                                                ...                   ...
# 43                            k.bartonhenry@gmail.com  2019-10-08T13:20:35Z
# 44                            k.bartonhenry@gmail.com  2019-10-08T13:16:40Z
# 45  52278191+kelsey-ironhack@users.noreply.github.com  2019-10-08T12:56:52Z
# 46  52278191+kelsey-ironhack@users.noreply.github.com  2019-10-08T12:56:35Z
# 47  52278191+kelsey-ironhack@users.noreply.github.com  2019-10-08T12:56:18Z
#
#    commit.committer.name  ...  \
# 0                 GitHub  ...
# 1                 GitHub  ...
# 2                 GitHub  ...
# 3                 GitHub  ...
# 4                 GitHub  ...
# ..                   ...  ...
# 43                kelsey  ...
# 44                kelsey  ...
# 45                GitHub  ...
# 46                GitHub  ...
# 47                GitHub  ...
#
#                               committer.following_url  \
# 0   https://api.github.com/users/web-flow/followin...
# 1   https://api.github.com/users/web-flow/followin...
# 2   https://api.github.com/users/web-flow/followin...
# 3   https://api.github.com/users/web-flow/followin...
# 4   https://api.github.com/users/web-flow/followin...
# ..                                                ...
# 43  https://api.github.com/users/kbartonhenry/foll...
# 44  https://api.github.com/users/kbartonhenry/foll...
# 45  https://api.github.com/users/web-flow/followin...
# 46  https://api.github.com/users/web-flow/followin...
# 47  https://api.github.com/users/web-flow/followin...
#
#                                   committer.gists_url  \
# 0   https://api.github.com/users/web-flow/gists{/g...
# 1   https://api.github.com/users/web-flow/gists{/g...
# 2   https://api.github.com/users/web-flow/gists{/g...
# 3   https://api.github.com/users/web-flow/gists{/g...
# 4   https://api.github.com/users/web-flow/gists{/g...
# ..                                                ...
# 43  https://api.github.com/users/kbartonhenry/gist...
# 44  https://api.github.com/users/kbartonhenry/gist...
# 45  https://api.github.com/users/web-flow/gists{/g...
# 46  https://api.github.com/users/web-flow/gists{/g...
# 47  https://api.github.com/users/web-flow/gists{/g...
#
#                                 committer.starred_url  \
# 0   https://api.github.com/users/web-flow/starred{...
# 1   https://api.github.com/users/web-flow/starred{...
# 2   https://api.github.com/users/web-flow/starred{...
# 3   https://api.github.com/users/web-flow/starred{...
# 4   https://api.github.com/users/web-flow/starred{...
# ..                                                ...
# 43  https://api.github.com/users/kbartonhenry/star...
# 44  https://api.github.com/users/kbartonhenry/star...
# 45  https://api.github.com/users/web-flow/starred{...
# 46  https://api.github.com/users/web-flow/starred{...
# 47  https://api.github.com/users/web-flow/starred{...
#
#                           committer.subscriptions_url  \
# 0   https://api.github.com/users/web-flow/subscrip...
# 1   https://api.github.com/users/web-flow/subscrip...
# 2   https://api.github.com/users/web-flow/subscrip...
# 3   https://api.github.com/users/web-flow/subscrip...
# 4   https://api.github.com/users/web-flow/subscrip...
# ..                                                ...
# 43  https://api.github.com/users/kbartonhenry/subs...
# 44  https://api.github.com/users/kbartonhenry/subs...
# 45  https://api.github.com/users/web-flow/subscrip...
# 46  https://api.github.com/users/web-flow/subscrip...
# 47  https://api.github.com/users/web-flow/subscrip...
#
#                        committer.organizations_url  \
# 0       https://api.github.com/users/web-flow/orgs
# 1       https://api.github.com/users/web-flow/orgs
# 2       https://api.github.com/users/web-flow/orgs
# 3       https://api.github.com/users/web-flow/orgs
# 4       https://api.github.com/users/web-flow/orgs
# ..                                             ...
# 43  https://api.github.com/users/kbartonhenry/orgs
# 44  https://api.github.com/users/kbartonhenry/orgs
# 45      https://api.github.com/users/web-flow/orgs
# 46      https://api.github.com/users/web-flow/orgs
# 47      https://api.github.com/users/web-flow/orgs
#
#                                 committer.repos_url  \
# 0       https://api.github.com/users/web-flow/repos
# 1       https://api.github.com/users/web-flow/repos
# 2       https://api.github.com/users/web-flow/repos
# 3       https://api.github.com/users/web-flow/repos
# 4       https://api.github.com/users/web-flow/repos
# ..                                              ...
# 43  https://api.github.com/users/kbartonhenry/repos
# 44  https://api.github.com/users/kbartonhenry/repos
# 45      https://api.github.com/users/web-flow/repos
# 46      https://api.github.com/users/web-flow/repos
# 47      https://api.github.com/users/web-flow/repos
#
#                                  committer.events_url  \
# 0   https://api.github.com/users/web-flow/events{/...
# 1   https://api.github.com/users/web-flow/events{/...
# 2   https://api.github.com/users/web-flow/events{/...
# 3   https://api.github.com/users/web-flow/events{/...
# 4   https://api.github.com/users/web-flow/events{/...
# ..                                                ...
# 43  https://api.github.com/users/kbartonhenry/even...
# 44  https://api.github.com/users/kbartonhenry/even...
# 45  https://api.github.com/users/web-flow/events{/...
# 46  https://api.github.com/users/web-flow/events{/...
# 47  https://api.github.com/users/web-flow/events{/...
#
#                         committer.received_events_url committer.type  \
# 0   https://api.github.com/users/web-flow/received...           User
# 1   https://api.github.com/users/web-flow/received...           User
# 2   https://api.github.com/users/web-flow/received...           User
# 3   https://api.github.com/users/web-flow/received...           User
# 4   https://api.github.com/users/web-flow/received...           User
# ..                                                ...            ...
# 43  https://api.github.com/users/kbartonhenry/rece...           User
# 44  https://api.github.com/users/kbartonhenry/rece...           User
# 45  https://api.github.com/users/web-flow/received...           User
# 46  https://api.github.com/users/web-flow/received...           User
# 47  https://api.github.com/users/web-flow/received...           User
#
#    committer.site_admin
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ..                  ...
# 43                False
# 44                False
# 45                False
# 46                False
# 47                False
#
# [148 rows x 57 columns]

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here


# data_complete_commits.columns

check_date = data_complete_commits['commit.author.date']

yd_list = [i[:7] for i in list(check_date) if i[:7] == '2019-10']
print(f'The number of commits made in October 2019 is: {len(yd_list)}.')
# Out:
# The number of commits made in October 2019 is: 142.

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
response_5 = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger', auth=(username,token))
results_5 = response_5.json()
data_5 = pd.DataFrame(results_5)
data_5
# Out:
#                             id                           node_id       name  \
# login                162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# id                   162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# node_id              162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# avatar_url           162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# gravatar_id          162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# url                  162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# html_url             162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# followers_url        162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# following_url        162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# gists_url            162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# starred_url          162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# subscriptions_url    162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# organizations_url    162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# repos_url            162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# events_url           162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# received_events_url  162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# type                 162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# site_admin           162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# admin                162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# push                 162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
# pull                 162375181  MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=  scavenger
#
#                                        full_name  private  \
# login                ironhack-datalabs/scavenger    False
# id                   ironhack-datalabs/scavenger    False
# node_id              ironhack-datalabs/scavenger    False
# avatar_url           ironhack-datalabs/scavenger    False
# gravatar_id          ironhack-datalabs/scavenger    False
# url                  ironhack-datalabs/scavenger    False
# html_url             ironhack-datalabs/scavenger    False
# followers_url        ironhack-datalabs/scavenger    False
# following_url        ironhack-datalabs/scavenger    False
# gists_url            ironhack-datalabs/scavenger    False
# starred_url          ironhack-datalabs/scavenger    False
# subscriptions_url    ironhack-datalabs/scavenger    False
# organizations_url    ironhack-datalabs/scavenger    False
# repos_url            ironhack-datalabs/scavenger    False
# events_url           ironhack-datalabs/scavenger    False
# received_events_url  ironhack-datalabs/scavenger    False
# type                 ironhack-datalabs/scavenger    False
# site_admin           ironhack-datalabs/scavenger    False
# admin                ironhack-datalabs/scavenger    False
# push                 ironhack-datalabs/scavenger    False
# pull                 ironhack-datalabs/scavenger    False
#
#                                                                  owner  \
# login                                                ironhack-datalabs
# id                                                            44225188
# node_id                               MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4
# avatar_url           https://avatars2.githubusercontent.com/u/44225...
# gravatar_id
# url                     https://api.github.com/users/ironhack-datalabs
# html_url                          https://github.com/ironhack-datalabs
# followers_url        https://api.github.com/users/ironhack-datalabs...
# following_url        https://api.github.com/users/ironhack-datalabs...
# gists_url            https://api.github.com/users/ironhack-datalabs...
# starred_url          https://api.github.com/users/ironhack-datalabs...
# subscriptions_url    https://api.github.com/users/ironhack-datalabs...
# organizations_url    https://api.github.com/users/ironhack-datalabs...
# repos_url            https://api.github.com/users/ironhack-datalabs...
# events_url           https://api.github.com/users/ironhack-datalabs...
# received_events_url  https://api.github.com/users/ironhack-datalabs...
# type                                                      Organization
# site_admin                                                       False
# admin                                                              NaN
# push                                                               NaN
# pull                                                               NaN
#
#                                                            html_url  \
# login                https://github.com/ironhack-datalabs/scavenger
# id                   https://github.com/ironhack-datalabs/scavenger
# node_id              https://github.com/ironhack-datalabs/scavenger
# avatar_url           https://github.com/ironhack-datalabs/scavenger
# gravatar_id          https://github.com/ironhack-datalabs/scavenger
# url                  https://github.com/ironhack-datalabs/scavenger
# html_url             https://github.com/ironhack-datalabs/scavenger
# followers_url        https://github.com/ironhack-datalabs/scavenger
# following_url        https://github.com/ironhack-datalabs/scavenger
# gists_url            https://github.com/ironhack-datalabs/scavenger
# starred_url          https://github.com/ironhack-datalabs/scavenger
# subscriptions_url    https://github.com/ironhack-datalabs/scavenger
# organizations_url    https://github.com/ironhack-datalabs/scavenger
# repos_url            https://github.com/ironhack-datalabs/scavenger
# events_url           https://github.com/ironhack-datalabs/scavenger
# received_events_url  https://github.com/ironhack-datalabs/scavenger
# type                 https://github.com/ironhack-datalabs/scavenger
# site_admin           https://github.com/ironhack-datalabs/scavenger
# admin                https://github.com/ironhack-datalabs/scavenger
# push                 https://github.com/ironhack-datalabs/scavenger
# pull                 https://github.com/ironhack-datalabs/scavenger
#
#                     description   fork  \
# login                      None  False
# id                         None  False
# node_id                    None  False
# avatar_url                 None  False
# gravatar_id                None  False
# url                        None  False
# html_url                   None  False
# followers_url              None  False
# following_url              None  False
# gists_url                  None  False
# starred_url                None  False
# subscriptions_url          None  False
# organizations_url          None  False
# repos_url                  None  False
# events_url                 None  False
# received_events_url        None  False
# type                       None  False
# site_admin                 None  False
# admin                      None  False
# push                       None  False
# pull                       None  False
#
#                                                                    url  ...  \
# login                https://api.github.com/repos/ironhack-datalabs...  ...
# id                   https://api.github.com/repos/ironhack-datalabs...  ...
# node_id              https://api.github.com/repos/ironhack-datalabs...  ...
# avatar_url           https://api.github.com/repos/ironhack-datalabs...  ...
# gravatar_id          https://api.github.com/repos/ironhack-datalabs...  ...
# url                  https://api.github.com/repos/ironhack-datalabs...  ...
# html_url             https://api.github.com/repos/ironhack-datalabs...  ...
# followers_url        https://api.github.com/repos/ironhack-datalabs...  ...
# following_url        https://api.github.com/repos/ironhack-datalabs...  ...
# gists_url            https://api.github.com/repos/ironhack-datalabs...  ...
# starred_url          https://api.github.com/repos/ironhack-datalabs...  ...
# subscriptions_url    https://api.github.com/repos/ironhack-datalabs...  ...
# organizations_url    https://api.github.com/repos/ironhack-datalabs...  ...
# repos_url            https://api.github.com/repos/ironhack-datalabs...  ...
# events_url           https://api.github.com/repos/ironhack-datalabs...  ...
# received_events_url  https://api.github.com/repos/ironhack-datalabs...  ...
# type                 https://api.github.com/repos/ironhack-datalabs...  ...
# site_admin           https://api.github.com/repos/ironhack-datalabs...  ...
# admin                https://api.github.com/repos/ironhack-datalabs...  ...
# push                 https://api.github.com/repos/ironhack-datalabs...  ...
# pull                 https://api.github.com/repos/ironhack-datalabs...  ...
#
#                     license forks open_issues watchers default_branch  \
# login                  None     4           0        0         master
# id                     None     4           0        0         master
# node_id                None     4           0        0         master
# avatar_url             None     4           0        0         master
# gravatar_id            None     4           0        0         master
# url                    None     4           0        0         master
# html_url               None     4           0        0         master
# followers_url          None     4           0        0         master
# following_url          None     4           0        0         master
# gists_url              None     4           0        0         master
# starred_url            None     4           0        0         master
# subscriptions_url      None     4           0        0         master
# organizations_url      None     4           0        0         master
# repos_url              None     4           0        0         master
# events_url             None     4           0        0         master
# received_events_url    None     4           0        0         master
# type                   None     4           0        0         master
# site_admin             None     4           0        0         master
# admin                  None     4           0        0         master
# push                   None     4           0        0         master
# pull                   None     4           0        0         master
#
#                     permissions temp_clone_token  \
# login                       NaN
# id                          NaN
# node_id                     NaN
# avatar_url                  NaN
# gravatar_id                 NaN
# url                         NaN
# html_url                    NaN
# followers_url               NaN
# following_url               NaN
# gists_url                   NaN
# starred_url                 NaN
# subscriptions_url           NaN
# organizations_url           NaN
# repos_url                   NaN
# events_url                  NaN
# received_events_url         NaN
# type                        NaN
# site_admin                  NaN
# admin                     False
# push                      False
# pull                       True
#
#                                                           organization  \
# login                                                ironhack-datalabs
# id                                                            44225188
# node_id                               MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4
# avatar_url           https://avatars2.githubusercontent.com/u/44225...
# gravatar_id
# url                     https://api.github.com/users/ironhack-datalabs
# html_url                          https://github.com/ironhack-datalabs
# followers_url        https://api.github.com/users/ironhack-datalabs...
# following_url        https://api.github.com/users/ironhack-datalabs...
# gists_url            https://api.github.com/users/ironhack-datalabs...
# starred_url          https://api.github.com/users/ironhack-datalabs...
# subscriptions_url    https://api.github.com/users/ironhack-datalabs...
# organizations_url    https://api.github.com/users/ironhack-datalabs...
# repos_url            https://api.github.com/users/ironhack-datalabs...
# events_url           https://api.github.com/users/ironhack-datalabs...
# received_events_url  https://api.github.com/users/ironhack-datalabs...
# type                                                      Organization
# site_admin                                                       False
# admin                                                              NaN
# push                                                               NaN
# pull                                                               NaN
#
#                     network_count subscribers_count
# login                           4                 2
# id                              4                 2
# node_id                         4                 2
# avatar_url                      4                 2
# gravatar_id                     4                 2
# url                             4                 2
# html_url                        4                 2
# followers_url                   4                 2
# following_url                   4                 2
# gists_url                       4                 2
# starred_url                     4                 2
# subscriptions_url               4                 2
# organizations_url               4                 2
# repos_url                       4                 2
# events_url                      4                 2
# received_events_url             4                 2
# type                            4                 2
# site_admin                      4                 2
# admin                           4                 2
# push                            4                 2
# pull                            4                 2
#
# [21 rows x 78 columns]

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
