# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
pip install bs4
# Out:
# ...
#      |████████████████████████████████| 115 kB 6.3 MB/s eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=200bcb06a06976c35a350d06efa58501c453b7fbcaba9cbca09441c5d91823ed
#   Stored in directory: /Users/par-philippine-breuil/Library/Caches/pip/wheels/75/78/21/68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.1.1/libexec/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here
html = requests.get(url).content
html
# Out:
# b'\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-YR0i2ZAJ3fFf7L2CvMny+FWH76iHZNNIcD1YX57o4cdBHev8ffMXOfzy5F/lpBJpLttwPahk3zY/8XXaRH12ew==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-611d22d99009ddf15fecbd82bcc9f2f8.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-37pLQI8klDWPjWVVWFB9ITJLwVTTkp3Rt4bVf+yixrViURK9OoGHEJDbTLx
# ...

# %%
soup = BeautifulSoup(html, "html")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-611d22d99009ddf15fecbd82bcc9f2f8.css" integrity="sha512-YR0i2ZAJ3fFf7L2CvMny+FWH76iHZNNIcD1YX57o4cdBHev8ffMXOfzy5F/lpBJpLttwPahk3zY/8XXaRH12ew==" media="all" rel="stylesheet">
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
table_name = soup.find_all('h1',{'class':'h3 lh-condensed'})
table_name
# Out:
# [<h1 class="h3 lh-condensed">
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":1290234,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="342e533452e250a57c5bfa5d3e24cc48556211c5331b640106904086ea215b1a" href="/prologic">
#              James Mills
#  </a> </h1>,
#  <h1 class="h3 lh-condensed">
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":97088,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="f68e03dfcd3fbf1ca4517328fdcbaa2202f0eef2880f3d4e76f7ec2bdcbb6d7a" href="/mrdoob">
#              Mr.doob
#  </a> </h1>,
#  <h1 class="h3 lh-condensed">
# ...

# %%
table_company = soup.find_all('p',{'class':'f4 text-normal mb-1'})
table_company = [developpers.text.strip() for developpers in table_company]

# %%
#rows = table.find_all('h1')
table_name = [developpers.text.strip() for developpers in table_name]

# %%
[f'{name} ({company})' for name, company in zip(table_name, table_company)]
# Out:
# ['James Mills (prologic)',
#  'Mr.doob (mrdoob)',
#  'Franck Nijhof (frenck)',
#  'Dave Henderson (hairyhenderson)',
#  'Alex Ghiondea (AlexGhiondea)',
#  'Felix Angelov (felangel)',
#  'Robert Mosolgo (rmosolgo)',
#  'Liam DeBeasi (liamdebeasi)',
#  'Alon Zakai (kripken)',
#  'Julian Gruber (juliangruber)',
#  'Bernát Gábor (gaborbernat)',
#  'John Otander (johno)',
#  'Jason Miller (developit)',
#  'chriseth (youknowriad)',
#  'Riad Benguella (mars)',
#  'Mars Hall (caarlos0)',
#  'Carlos Alexandro Becker (benjamn)',
#  'Ben Newman (ai)',
#  'Andrey Sitnik (otaviojava)',
#  'Otávio Santana (geerlingguy)',
#  'Jeff Geerling (michalsnik)',
#  'Michał Sajnóg (Qqwy)',
#  'Qqwy / Wiebe-Marten (hathach)',
#  'Ha Thach (paulb777)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
html = requests.get(url).content
html
# Out:
# b'\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-YR0i2ZAJ3fFf7L2CvMny+FWH76iHZNNIcD1YX57o4cdBHev8ffMXOfzy5F/lpBJpLttwPahk3zY/8XXaRH12ew==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-611d22d99009ddf15fecbd82bcc9f2f8.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-37pLQI8klDWPjWVVWFB9ITJLwVTTkp3Rt4bVf+yixrViURK9OoGHEJDbTLx
# ...

# %%
# your code here
soup = BeautifulSoup(html, "html")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-611d22d99009ddf15fecbd82bcc9f2f8.css" integrity="sha512-YR0i2ZAJ3fFf7L2CvMny+FWH76iHZNNIcD1YX57o4cdBHev8ffMXOfzy5F/lpBJpLttwPahk3zY/8XXaRH12ew==" media="all" rel="stylesheet">
# ...

# %%
table = soup.find_all('h1',{'class':'h3 lh-condensed'})
rows = [row.text.strip().split(" ")[-1] for row in table]
rows
# Out:
# ['fawkes',
#  'rpi-power-monitor',
#  'stock',
#  'GitHub520',
#  'retinaface',
#  'BorderDet',
#  'Pytorch_Retinaface',
#  'ansible',
#  'fairseq',
#  'awesome-python',
#  'ansible-for-devops',
#  'zipline',
#  'PaddleDetection',
#  'kedro',
#  'azure-cli',
#  'public-apis',
#  'unicorn',
#  'yyg-seir-simulator',
#  'PyTorch_YOLOv4',
#  'Summer2021-Internships',
#  'skywater-pdk',
#  'nni',
#  'horovod',
#  'django',
#  'dagster']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")

# %%
table = soup.find_all('img')
rows = [row["src"] for row in table if row["src"] != ""]
rows
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "html")
table = soup.find_all('a')
table
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#searchInput">Jump to search</a>,
#  <a class="extiw" href="https://en.wiktionary.org/wiki/Python" title="wiktionary:Python">Python</a>,
#  <a class="extiw" href="https://en.wiktionary.org/wiki/python" title="wiktionary:python">python</a>,
#  <a href="#Snakes"><span class="tocnumber">1</span> <span class="toctext">Snakes</span></a>,
#  <a href="#Ancient_Greece"><span class="tocnumber">2</span> <span class="toctext">Ancient Greece</span></a>,
#  <a href="#Media_and_entertainment"><span class="tocnumber">3</span> <span class="toctext">Media and entertainment</span></a>,
#  <a href="#Computing"><span class="tocnumber">4</span> <span class="toctext">Computing</span></a>,
#  <a href="#Engineering"><span class="tocnumber">5</span> <span class="toctext">Engineering</span></a>,
# ...

# %%
rows = [row["href"] for row in table[1:]]
rows
# Out:
# ['#mw-head',
#  '#searchInput',
#  'https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  '#Snakes',
#  '#Ancient_Greece',
#  '#Media_and_entertainment',
#  '#Computing',
#  '#Engineering',
#  '#Roller_coasters',
#  '#Vehicles',
#  '#Weaponry',
#  '#People',
#  '#Other_uses',
#  '#See_also',
#  '/w/index.php?title=Python&action=edit&section=1',
#  '/wiki/Pythonidae',
#  '/wiki/Python_(genus)',
#  '/w/index.php?title=Python&action=edit&section=2',
#  '/wiki/Python_(mythology)',
#  '/wiki/Python_of_Aenus',
#  '/wiki/Python_(painter)',
#  '/wiki/Python_of_Byzantium',
#  '/wiki/Python_of_Catana',
#  '/w/index.php?title=Python&action=edit&section=3',
#  '/wiki/Python_(film)',
#  '/wiki/Pythons_2',
#  '/wiki/Monty_Python',
#  '/wiki/Python_(Monty)_Pictures',
#  '/w/index.php?title=Python&action=edit&section=4',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CPython',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/PERQ#PERQ_3',
# ...

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "html")
table = len(soup.find_all('div',{'class':'usctitlechanged'}))
table
# Out:
# 1

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "html")
table = soup.find_all('h3',{'class':'title'})
rows = [row.text.strip() for row in table]
rows
# Out:
# ['ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'JASON DEREK BROWN',
#  'YASER ABDEL SAID',
#  'ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "html")
#table = soup.find_all("td",{'class':['tabev1','tabev2','tabev6','tb_region']})
latitude_longitude = soup.find_all("td",{'class':['tabev1','tabev2']})
raw_date_hour = soup.find_all("td",{'class':'tabev6'})
raw_region = soup.find_all("td",{'class':'tb_region'})

# %%
table_lat_long = [elements.text.strip().split("</td>")for elements in latitude_longitude]

# %%
table_date_hour = [row.text.strip().split("</td>")for row in raw_date_hour]

# %%
table_regions = [row.text.strip().split("</td>")for row in raw_region]

# %%
# Assembler les élements ensemble
#[f'{name} ({company})' for name, company in zip(table_name, table_company)]
table = [f'{lat_long},{date_hour},{regions}' for latitutude_longitude, date_and_time, regions in zip(table_name, table_company, table_regions)]

# %%
table = [row.split(",")for row in table]

# %%
pd.DataFrame(table)
# Out:
#            0       1            2       3         4           5       6    \
# 0   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 1   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 2   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 3   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 4   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 5   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 6   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 7   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 8   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 9   [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 10  [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# 11  [['36.48']   ['N']   ['118.05']   ['W']   ['2.2']   ['51.44']   ['N']
# ...

# %%
url_earthquake = 'https://www.emsc-csem.org/Earthquake/'
html_earthquake = requests.get(url_earthquake).content
soup_earthquake = BeautifulSoup(html_earthquake, "html")
earthquakes_lines = soup_earthquake.find_all('tr',{"class":["ligne1 normal","ligne2 normal"]})
earthquakes_info = []
for earthquake in earthquakes_lines:
    datetime = earthquake.find_all('td',{"class": "tabev6"})[0].text.split()
    date = (datetime[0])[-10:]
    time = " ".join(datetime[1:])[:8]
    latitude = f"{earthquake.find_all('td',{'class': 'tabev1'})[0].text.strip()} {earthquake.find_all('td',{'class': 'tabev2'})[0].text.strip()}"
    longitude = f"{earthquake.find_all('td',{'class': 'tabev1'})[1].text.strip()} {earthquake.find_all('td',{'class': 'tabev2'})[1].text.strip()}"
    region = earthquake.find_all('td',{"class": "tb_region"})[0].text.strip()
    earthquakes_info.append({"date":date, "time": time, "latitude": latitude,"longitude": longitude,"region":region})
earthquakes_info[:20]
pd.DataFrame(earthquakes_info[:20])
# Out:
#           date      time latitude longitude                    region
# 0   2020-07-25  08:47:03  46.22 N    7.79 E               SWITZERLAND
# 1   2020-07-25  08:41:16  66.30 N   18.66 W            ICELAND REGION
# 2   2020-07-25  08:21:02  38.16 N  118.03 W                    NEVADA
# 3   2020-07-25  08:19:54  36.48 N  118.05 W        CENTRAL CALIFORNIA
# 4   2020-07-25  08:15:04  51.44 N   16.08 E                    POLAND
# 5   2020-07-25  07:49:40  36.44 N  117.99 W        CENTRAL CALIFORNIA
# 6   2020-07-25  07:32:16  43.07 N   78.39 E        EASTERN KAZAKHSTAN
# 7   2020-07-25  07:23:00   7.78 S  119.01 E                FLORES SEA
# 8   2020-07-25  07:07:04  56.25 N  148.69 W            GULF OF ALASKA
# 9   2020-07-25  07:02:30  55.10 N  158.45 W          ALASKA PENINSULA
# 10  2020-07-25  06:28:38  36.99 N    5.28 W       STRAIT OF GIBRALTAR
# 11  2020-07-25  06:09:01  38.78 N   27.82 E            WESTERN TURKEY
# ...

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url_twitter = 'https://mobile.twitter.com/thedailybeast'

# %% [markdown]
# # HERE WE DISSABLED JAVA SCRIPT IN THE CONSOLE -> COMMAND+SHIFT+P -> DISABLE JAVA

# %%
# your code here
html = requests.get(url_twitter ).content
soup_twitter = BeautifulSoup(html, "html")
user_infos = soup_twitter.find_all('div', {"class": "statnum"})
tweet_count = [elements.text.strip().split("</div>")for elements in user_infos][0]
tweet_count
# Out:
# ['320,813']

# %%
url_twitter2 = 'https://mobile.twitter.com/'
handle = input('Input your account name on Twitter: ') 
try:
    temp = requests.get(url_twitter2 + handle).content
    bs = BeautifulSoup(temp,'html.parser')
    bs
    tweet_count = bs.find_all('div',{'class':'statnum'})
    print(tweet_count)
    tweet = [element.text.strip().split("</div") for element in tweet_count][0]
    tweet
except:
    print('Account name not found')
# Out:
# Input your account name on Twitter: thedailybeast

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url_twitter = 'https://mobile.twitter.com/thedailybeast'
#input("tell me the @handle")
html = requests.get(url_twitter ).content
soup_twitter = BeautifulSoup(html, "html")
user_infos = soup_twitter.find_all('div', {"class": "statnum"})
follower_count = [elements.text.strip().split("</div>")for elements in user_infos][-1]
#table_regions = [row.text.strip().split("</td>")for row in raw_region]
#follower_count = soup.find_all('a',{'href':'/thedailybeast/followers'})
#follower_count = soup.find_all({'class':"css-901oao.css-16my406.r-1qd0xha.r-ad9z0x.r-bcqeeo.r-qvutc0"})

print(follower_count)
# Out:
# ['1,286,173']

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
wiki_url = 'https://www.wikipedia.org/'

# %%
# your code here
html = requests.get(wiki_url).content
soup_wiki = BeautifulSoup(html, "html")
res = []
for language in soup_wiki.find_all('div', {'class':'central-featured-lang'}):
    title = language.a.strong.text
    article = "".join(filter(str.isdigit,language.a.small.text))
    res.append([title,article])
res_df = pd.DataFrame(res)
res_df
# Out:
#            0        1
# 0    English  6125000
# 1        日本語  1218000
# 2    Español  1612000
# 3    Deutsch  2458000
# 4    Русский  1644000
# 5   Français  2236000
# 6   Italiano  1623000
# 7         中文  1130000
# 8  Português  1039000
# 9     Polski  1420000

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "html")
res = []
for book in soup.find_all('li', {'class': 'col-xs-6 col-sm-4 col-md-3 col-lg-3'}):
    title = book.h3.a['title']
    div_prodprice = book.find('div', {'class': 'product_price'})
    price = div_prodprice.find_all('p')[0].text
    stock = div_prodprice.find_all('p')[1].text.strip()
    res.append([title, price, stock])
res_df = pd.DataFrame(res)

# %%
res_df
# Out:
#                                                     0       1         2
# 0                                A Light in the Attic  £51.77  In stock
# 1                                  Tipping the Velvet  £53.74  In stock
# 2                                          Soumission  £50.10  In stock
# 3                                       Sharp Objects  £47.82  In stock
# 4               Sapiens: A Brief History of Humankind  £54.23  In stock
# 5                                     The Requiem Red  £22.65  In stock
# 6   The Dirty Little Secrets of Getting Your Dream...  £33.34  In stock
# 7   The Coming Woman: A Novel Based on the Life of...  £17.93  In stock
# 8   The Boys in the Boat: Nine Americans and Their...  £22.60  In stock
# 9                                     The Black Maria  £52.15  In stock
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  £13.99  In stock
# 11                              Shakespeare's Sonnets  £20.66  In stock
# ...
