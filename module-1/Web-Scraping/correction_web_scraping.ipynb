# %%
# Understanding Web Content
    # Types : HTML, CSS, JS, Image, Audio, Video, Font, PDF, etc.
    # Structure of HTML
    # DevTools

# %%
# HTML = HyperText Markup Language
# DOM (Document Object Model) Tree
# Syntax

# %%
import requests
import pandas as pd

# %%
url = 'https://www.lemonde.fr/economie/article/2020/07/22/delphine-ernotte-reconduite-a-la-tete-de-france-televisions_6046981_3234.html'
html = requests.get(url).content

# %%
html

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html')

# %%
soup

# %%
tags = ['h1', 'h2', 'h3', 'h4', 'h6', 'h7', 'p']
text = [element.text for element in soup.find_all(tags)]
text
# Out:
# ['Consulterle journal',
#  'Pourquoi la vente de produits en vrac n’enthousiasme ni les hypermarchés ni les industriels',
#  'Slack, l’application devenue championne du télétravail qui n’y croyait guère',
#  '«\xa0Le bonheur a résisté au Covid-19, même si le virus nourrit un pessimisme momentané\xa0»',
#  '«\xa0Allons jusqu’à au moins un tiers d’administrateurs représentant les salariés dans les grandes entreprises\xa0»',
#  'Le Covid-19 est-il une bonne nouvelle\xa0pour le climat\xa0?',
#  'Pourquoi nos modes de vie sont à l’origine des pandémies',
#  'Enquête vidéo\xa0: comment des milices d’extrême droite américaines ont préparé l’invasion du Capitole',
#  'Les premières photos de la Commune de Paris ont-elles été manipulées\xa0?',
#  'Nathalie Iannetta, sur «\xa0Je ne suis pas une salope, je suis journaliste\xa0»\xa0: «\xa0On ne veut détruire personne. On veut juste déconstruire un système\xa0»',
# ...

# %%
url = 'https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy'
html = requests.get(url).content
soup = BeautifulSoup(html, "html")

# %%
table = soup.find_all('table', {'class': 'sortable wikitable'})[0]
table

# %%
for x in [row.text for row in table.find_all('tr')][1:]:
    print(x)
    break
# Out:
# 1
#
#  Monaco[3]
#
# 89.4

# %%
rows = table.find_all('tr')
res = []
for rowx in [row.text.strip().split("\n") for row in rows]:
    rowx = [elt.strip() for elt in rowx if elt != ''][1:]
    res.append(rowx)
print(res)
# Out:
# [['Country', 'Life expectancy[1]', 'Influenza vaccination rate, people aged 65 and over, 2016 (%)[2]'], ['Monaco[3]', '89.4'], ['San Marino[4]', '83.4'], ['Switzerland', '83.0'], ['Spain', '82.8', '56%'], ['Liechtenstein', '82.7', '28%'], ['Italy', '82.7', '50%'], ['Norway', '82.5', '38%'], ['Iceland', '82.5', '47%'], ['Luxembourg', '82.3', '38%'], ['France', '82.3', '50%'], ['Sweden', '82.2', '49%'], ['Malta', '81.8'], ['Finland', '81.8', '47%'], ['Ireland', '81.6', '55%'], ['Netherlands', '81.5', '65%'], ['Portugal', '81.1', '58%'], ['Greece', '81.0'], ['United Kingdom', '81.0', '71%'], ['Belgium', '81.0'], ['Austria', '80.9'], ['Slovenia', '80.8', '10%'], ['Denmark', '80.7', '41%'], ['Germany', '80.6', '35%'], ['Cyprus', '80.5'], ['Albania', '78.3'], ['Czech Republic', '78.3'], ['Croatia', '78.0', '21%'], ['Estonia', '77.7', '3%'], ['Poland', '77.5'], ['Montenegro', '77.1', '13%'], ['Bosnia and Herzegovina', '76.9'], ['Slovakia', '76.6', '10%'], ['Turkey', '75.8', '7%'], ['North M
# ...

# %%
colnames = res[0]
data = res[1:]
df = pd.DataFrame(data, columns=colnames)
df
# Out:
#                    Country Life expectancy[1]  \
# 0                Monaco[3]               89.4
# 1            San Marino[4]               83.4
# 2              Switzerland               83.0
# 3                    Spain               82.8
# 4            Liechtenstein               82.7
# 5                    Italy               82.7
# 6                   Norway               82.5
# 7                  Iceland               82.5
# 8               Luxembourg               82.3
# 9                   France               82.3
# 10                  Sweden               82.2
# 11                   Malta               81.8
# 12                 Finland               81.8
# 13                 Ireland               81.6
# 14             Netherlands               81.5
# 15                Portugal               81.1
# 16                  Greece               81.0
# 17          United Kingdom               81.0
# 18                 Belgium               81.0
# ...

# %%
res = requests.get("http://books.toscrape.com/")
soup = BeautifulSoup(res.content, 'html')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
res = []
for book in soup.find_all('li', {'class': 'col-xs-6 col-sm-4 col-md-3 col-lg-3'}):
    title = book.h3.a['title']
    div_prodprice = book.find('div', {'class': 'product_price'})
    price = div_prodprice.find_all('p')[0].text
    stock = div_prodprice.find_all('p')[1].text.strip()
    res.append([title, price, stock])
res_df = pd.DataFrame(res)

# %%
res_df
# Out:
#                                                     0       1         2
# 0                                A Light in the Attic  £51.77  In stock
# 1                                  Tipping the Velvet  £53.74  In stock
# 2                                          Soumission  £50.10  In stock
# 3                                       Sharp Objects  £47.82  In stock
# 4               Sapiens: A Brief History of Humankind  £54.23  In stock
# 5                                     The Requiem Red  £22.65  In stock
# 6   The Dirty Little Secrets of Getting Your Dream...  £33.34  In stock
# 7   The Coming Woman: A Novel Based on the Life of...  £17.93  In stock
# 8   The Boys in the Boat: Nine Americans and Their...  £22.60  In stock
# 9                                     The Black Maria  £52.15  In stock
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  £13.99  In stock
# 11                              Shakespeare's Sonnets  £20.66  In stock
# ...
