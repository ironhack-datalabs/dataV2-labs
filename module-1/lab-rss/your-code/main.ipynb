# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
feedburner = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
feedburner.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
feedburner.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
title = feedburner.feed.title
subtitle = feedburner.feed.subtitle
#author = feedburner.feed.author
link = feedburner.feed.link
print(f"TITLE: {title}, SUBTITLE: {subtitle}, LINK: {link}")
# Out:
# TITLE: Radar, SUBTITLE: Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology, LINK: https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(feedburner.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
feedburner.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [entry.title for entry in feedburner.entries]
titles
# Out:
# ['Four short links: 24 July 2020',
#  'Four short links: 26 July 2020',
#  'Four short links: 22 July 2020',
#  'AI, Protests, and Justice',
#  'Four short links: 21 July 2020',
#  'Four short links: 20 July 2020',
#  'Four short links: 17 July 2020',
#  'Four short links: 16 July 2020',
#  'Microservices Adoption in 2020',
#  'Four short links: 15 July 2020',
#  'Society-Centered Design',
#  'Four short links: 14 July 2020',
#  'Four short links: 13 July 2020',
#  'Four short links: 10 July 2020',
#  'Automated Coding and the Future of Programming',
#  'Four short links: 9 July 2020',
#  'Four short links: 8 July 2020',
#  'Four short links: 7 July 2020',
#  'Four short links: 6 July 2020',
#  'Four short links: 3 July 2020',
#  'Four short links: 2 July 2020',
#  'Radar trends to watch: July 2020',
#  'Four short links: 1 July 2020',
#  'Four short links: 30 June 2020',
#  'Four short links: 29 June 2020',
#  'Four short links: 28 June 2020',
#  'Four short links: 25 June 2020',
#  'COVID-19 and Complex Systems',
#  'Four short links: 24 June 2020',
#  'Four short links: 23 June 2020',
#  'Four short links: 22 June 2020',
#  'Four short links: June 19, 2020',
#  'Four short links: 17 June 2020',
#  'Decision-Making in a Time of Crisis',
#  'Four short links: 16 June 2020',
#  'Four short links: 15 June 2020',
#  'Four short links: 12 June 2020',
#  'Four short links: 11 June 2020',
#  'Four short links: 10 June 2020',
#  'Machine Learning and the Production Gap',
#  'Four short links: 9 June 2020',
#  'Radar trends to watch: June 2020',
#  'Four short links: 8 June 2020',
#  'Four short links: 5 June 2020',
#  'Four short links: 4 June 2020',
#  'The Business of Open Source',
#  'Four short links: 3 June 2020',
#  'Four short links: 2 June 2020',
#  'Four short links: 1 June 2020',
#  'Four short links: 29 May 2020',
#  'Four short links: 28 May 2020',
#  'Reclaiming the stories that algorithms tell',
#  'Four short links: 27 May 2020',
#  'Four short links: 26 May 2020',
#  'Four short links: 25 May 2020',
#  'Four short links: 22 May 2020',
#  'Four short links: 21 May 2020',
#  'Four short links: 20 May 2020',
#  'Cloud Adoption in 2020',
#  'Four short links: 19 May 2020']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
len([title for title in titles if title[:16] == "Four short links"])/len(titles)*100
# Out:
# 80.0

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(feedburner.entries)
df
# Out:
#                                              title  \
# 0                   Four short links: 24 July 2020
# 1                   Four short links: 26 July 2020
# 2                   Four short links: 22 July 2020
# 3                        AI, Protests, and Justice
# 4                   Four short links: 21 July 2020
# 5                   Four short links: 20 July 2020
# 6                   Four short links: 17 July 2020
# 7                   Four short links: 16 July 2020
# 8                   Microservices Adoption in 2020
# 9                   Four short links: 15 July 2020
# 10                         Society-Centered Design
# 11                  Four short links: 14 July 2020
# 12                  Four short links: 13 July 2020
# 13                  Four short links: 10 July 2020
# 14  Automated Coding and the Future of Programming
# 15                   Four short links: 9 July 2020
# 16                   Four short links: 8 July 2020
# 17                   Four short links: 7 July 2020
# 18                   Four short links: 6 July 2020
# 19                   Four short links: 3 July 2020
# 20                   Four short links: 2 July 2020
# 21                Radar trends to watch: July 2020
# 22                   Four short links: 1 July 2020
# 23                  Four short links: 30 June 2020
# 24                  Four short links: 29 June 2020
# 25                  Four short links: 28 June 2020
# 26                  Four short links: 25 June 2020
# 27                    COVID-19 and Complex Systems
# 28                  Four short links: 24 June 2020
# 29                  Four short links: 23 June 2020
# 30                  Four short links: 22 June 2020
# 31                 Four short links: June 19, 2020
# 32                  Four short links: 17 June 2020
# 33             Decision-Making in a Time of Crisis
# 34                  Four short links: 16 June 2020
# 35                  Four short links: 15 June 2020
# 36                  Four short links: 12 June 2020
# 37                  Four short links: 11 June 2020
# 38                  Four short links: 10 June 2020
# 39         Machine Learning and the Production Gap
# 40                   Four short links: 9 June 2020
# 41                Radar trends to watch: June 2020
# 42                   Four short links: 8 June 2020
# 43                   Four short links: 5 June 2020
# 44                   Four short links: 4 June 2020
# 45                     The Business of Open Source
# 46                   Four short links: 3 June 2020
# 47                   Four short links: 2 June 2020
# 48                   Four short links: 1 June 2020
# 49                   Four short links: 29 May 2020
# 50                   Four short links: 28 May 2020
# 51     Reclaiming the stories that algorithms tell
# 52                   Four short links: 27 May 2020
# 53                   Four short links: 26 May 2020
# 54                   Four short links: 25 May 2020
# 55                   Four short links: 22 May 2020
# 56                   Four short links: 21 May 2020
# 57                   Four short links: 20 May 2020
# 58                          Cloud Adoption in 2020
# 59                   Four short links: 19 May 2020
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
# 15  {'type': 'text/plain', 'language': None, 'base...
# 16  {'type': 'text/plain', 'language': None, 'base...
# 17  {'type': 'text/plain', 'language': None, 'base...
# 18  {'type': 'text/plain', 'language': None, 'base...
# 19  {'type': 'text/plain', 'language': None, 'base...
# 20  {'type': 'text/plain', 'language': None, 'base...
# 21  {'type': 'text/plain', 'language': None, 'base...
# 22  {'type': 'text/plain', 'language': None, 'base...
# 23  {'type': 'text/plain', 'language': None, 'base...
# 24  {'type': 'text/plain', 'language': None, 'base...
# 25  {'type': 'text/plain', 'language': None, 'base...
# 26  {'type': 'text/plain', 'language': None, 'base...
# 27  {'type': 'text/plain', 'language': None, 'base...
# 28  {'type': 'text/plain', 'language': None, 'base...
# 29  {'type': 'text/plain', 'language': None, 'base...
# 30  {'type': 'text/plain', 'language': None, 'base...
# 31  {'type': 'text/plain', 'language': None, 'base...
# 32  {'type': 'text/plain', 'language': None, 'base...
# 33  {'type': 'text/plain', 'language': None, 'base...
# 34  {'type': 'text/plain', 'language': None, 'base...
# 35  {'type': 'text/plain', 'language': None, 'base...
# 36  {'type': 'text/plain', 'language': None, 'base...
# 37  {'type': 'text/plain', 'language': None, 'base...
# 38  {'type': 'text/plain', 'language': None, 'base...
# 39  {'type': 'text/plain', 'language': None, 'base...
# 40  {'type': 'text/plain', 'language': None, 'base...
# 41  {'type': 'text/plain', 'language': None, 'base...
# 42  {'type': 'text/plain', 'language': None, 'base...
# 43  {'type': 'text/plain', 'language': None, 'base...
# 44  {'type': 'text/plain', 'language': None, 'base...
# 45  {'type': 'text/plain', 'language': None, 'base...
# 46  {'type': 'text/plain', 'language': None, 'base...
# 47  {'type': 'text/plain', 'language': None, 'base...
# 48  {'type': 'text/plain', 'language': None, 'base...
# 49  {'type': 'text/plain', 'language': None, 'base...
# 50  {'type': 'text/plain', 'language': None, 'base...
# 51  {'type': 'text/plain', 'language': None, 'base...
# 52  {'type': 'text/plain', 'language': None, 'base...
# 53  {'type': 'text/plain', 'language': None, 'base...
# 54  {'type': 'text/plain', 'language': None, 'base...
# 55  {'type': 'text/plain', 'language': None, 'base...
# 56  {'type': 'text/plain', 'language': None, 'base...
# 57  {'type': 'text/plain', 'language': None, 'base...
# 58  {'type': 'text/plain', 'language': None, 'base...
# 59  {'type': 'text/plain', 'language': None, 'base...
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 15  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 16  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 17  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 18  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 19  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 20  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 21  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 22  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 23  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 24  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 25  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 26  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 27  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 28  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 29  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 30  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 31  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 32  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 33  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 34  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 35  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 36  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 37  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 38  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 39  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 40  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 41  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 42  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 43  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 44  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 45  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 46  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 47  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 48  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 49  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 50  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 51  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 52  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 53  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 54  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 55  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 56  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 57  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 58  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 59  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                  link  \
# 0   http://feedproxy.google.com/~r/oreilly/radar/a...
# 1   http://feedproxy.google.com/~r/oreilly/radar/a...
# 2   http://feedproxy.google.com/~r/oreilly/radar/a...
# 3   http://feedproxy.google.com/~r/oreilly/radar/a...
# 4   http://feedproxy.google.com/~r/oreilly/radar/a...
# 5   http://feedproxy.google.com/~r/oreilly/radar/a...
# 6   http://feedproxy.google.com/~r/oreilly/radar/a...
# 7   http://feedproxy.google.com/~r/oreilly/radar/a...
# 8   http://feedproxy.google.com/~r/oreilly/radar/a...
# 9   http://feedproxy.google.com/~r/oreilly/radar/a...
# 10  http://feedproxy.google.com/~r/oreilly/radar/a...
# 11  http://feedproxy.google.com/~r/oreilly/radar/a...
# 12  http://feedproxy.google.com/~r/oreilly/radar/a...
# 13  http://feedproxy.google.com/~r/oreilly/radar/a...
# 14  http://feedproxy.google.com/~r/oreilly/radar/a...
# 15  http://feedproxy.google.com/~r/oreilly/radar/a...
# 16  http://feedproxy.google.com/~r/oreilly/radar/a...
# 17  http://feedproxy.google.com/~r/oreilly/radar/a...
# 18  http://feedproxy.google.com/~r/oreilly/radar/a...
# 19  http://feedproxy.google.com/~r/oreilly/radar/a...
# 20  http://feedproxy.google.com/~r/oreilly/radar/a...
# 21  http://feedproxy.google.com/~r/oreilly/radar/a...
# 22  http://feedproxy.google.com/~r/oreilly/radar/a...
# 23  http://feedproxy.google.com/~r/oreilly/radar/a...
# 24  http://feedproxy.google.com/~r/oreilly/radar/a...
# 25  http://feedproxy.google.com/~r/oreilly/radar/a...
# 26  http://feedproxy.google.com/~r/oreilly/radar/a...
# 27  http://feedproxy.google.com/~r/oreilly/radar/a...
# 28  http://feedproxy.google.com/~r/oreilly/radar/a...
# 29  http://feedproxy.google.com/~r/oreilly/radar/a...
# 30  http://feedproxy.google.com/~r/oreilly/radar/a...
# 31  http://feedproxy.google.com/~r/oreilly/radar/a...
# 32  http://feedproxy.google.com/~r/oreilly/radar/a...
# 33  http://feedproxy.google.com/~r/oreilly/radar/a...
# 34  http://feedproxy.google.com/~r/oreilly/radar/a...
# 35  http://feedproxy.google.com/~r/oreilly/radar/a...
# 36  http://feedproxy.google.com/~r/oreilly/radar/a...
# 37  http://feedproxy.google.com/~r/oreilly/radar/a...
# 38  http://feedproxy.google.com/~r/oreilly/radar/a...
# 39  http://feedproxy.google.com/~r/oreilly/radar/a...
# 40  http://feedproxy.google.com/~r/oreilly/radar/a...
# 41  http://feedproxy.google.com/~r/oreilly/radar/a...
# 42  http://feedproxy.google.com/~r/oreilly/radar/a...
# 43  http://feedproxy.google.com/~r/oreilly/radar/a...
# 44  http://feedproxy.google.com/~r/oreilly/radar/a...
# 45  http://feedproxy.google.com/~r/oreilly/radar/a...
# 46  http://feedproxy.google.com/~r/oreilly/radar/a...
# 47  http://feedproxy.google.com/~r/oreilly/radar/a...
# 48  http://feedproxy.google.com/~r/oreilly/radar/a...
# 49  http://feedproxy.google.com/~r/oreilly/radar/a...
# 50  http://feedproxy.google.com/~r/oreilly/radar/a...
# 51  http://feedproxy.google.com/~r/oreilly/radar/a...
# 52  http://feedproxy.google.com/~r/oreilly/radar/a...
# 53  http://feedproxy.google.com/~r/oreilly/radar/a...
# 54  http://feedproxy.google.com/~r/oreilly/radar/a...
# 55  http://feedproxy.google.com/~r/oreilly/radar/a...
# 56  http://feedproxy.google.com/~r/oreilly/radar/a...
# 57  http://feedproxy.google.com/~r/oreilly/radar/a...
# 58  http://feedproxy.google.com/~r/oreilly/radar/a...
# 59  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                              comments  \
# 0   https://www.oreilly.com/radar/four-short-links...
# 1   https://www.oreilly.com/radar/four-short-links...
# 2   https://www.oreilly.com/radar/four-short-links...
# 3   https://www.oreilly.com/radar/ai-protests-and-...
# 4   https://www.oreilly.com/radar/four-short-links...
# 5   https://www.oreilly.com/radar/four-short-links...
# 6   https://www.oreilly.com/radar/four-short-links...
# 7   https://www.oreilly.com/radar/four-short-links...
# 8   https://www.oreilly.com/radar/microservices-ad...
# 9   https://www.oreilly.com/radar/four-short-links...
# 10  https://www.oreilly.com/radar/society-centered...
# 11  https://www.oreilly.com/radar/four-short-links...
# 12  https://www.oreilly.com/radar/four-short-links...
# 13  https://www.oreilly.com/radar/four-short-links...
# 14  https://www.oreilly.com/radar/automated-coding...
# 15  https://www.oreilly.com/radar/four-short-links...
# 16  https://www.oreilly.com/radar/four-short-links...
# 17  https://www.oreilly.com/radar/four-short-links...
# 18  https://www.oreilly.com/radar/four-short-links...
# 19  https://www.oreilly.com/radar/four-short-links...
# 20  https://www.oreilly.com/radar/four-short-links...
# 21  https://www.oreilly.com/radar/radar-trends-to-...
# 22  https://www.oreilly.com/radar/four-short-links...
# 23  https://www.oreilly.com/radar/four-short-links...
# 24  https://www.oreilly.com/radar/four-short-links...
# 25  https://www.oreilly.com/radar/four-short-links...
# 26  https://www.oreilly.com/radar/four-short-links...
# 27  https://www.oreilly.com/radar/covid-19-and-com...
# 28  https://www.oreilly.com/radar/four-short-links...
# 29  https://www.oreilly.com/radar/four-short-links...
# 30  https://www.oreilly.com/radar/four-short-links...
# 31  https://www.oreilly.com/radar/four-short-links...
# 32  https://www.oreilly.com/radar/four-short-links...
# 33  https://www.oreilly.com/radar/decision-making-...
# 34  https://www.oreilly.com/radar/four-short-links...
# 35  https://www.oreilly.com/radar/four-short-links...
# 36  https://www.oreilly.com/radar/four-short-links...
# 37  https://www.oreilly.com/radar/four-short-links...
# 38  https://www.oreilly.com/radar/four-short-links...
# 39  https://www.oreilly.com/radar/machine-learning...
# 40  https://www.oreilly.com/radar/four-short-links...
# 41  https://www.oreilly.com/radar/radar-trends-to-...
# 42  https://www.oreilly.com/radar/four-short-links...
# 43  https://www.oreilly.com/radar/four-short-links...
# 44  https://www.oreilly.com/radar/four-short-links...
# 45  https://www.oreilly.com/radar/the-business-of-...
# 46  https://www.oreilly.com/radar/four-short-links...
# 47  https://www.oreilly.com/radar/four-short-links...
# 48  https://www.oreilly.com/radar/four-short-links...
# 49  https://www.oreilly.com/radar/four-short-links...
# 50  https://www.oreilly.com/radar/four-short-links...
# 51  https://www.oreilly.com/radar/reclaiming-the-s...
# 52  https://www.oreilly.com/radar/four-short-links...
# 53  https://www.oreilly.com/radar/four-short-links...
# 54  https://www.oreilly.com/radar/four-short-links...
# 55  https://www.oreilly.com/radar/four-short-links...
# 56  https://www.oreilly.com/radar/four-short-links...
# 57  https://www.oreilly.com/radar/four-short-links...
# 58  https://www.oreilly.com/radar/cloud-adoption-i...
# 59  https://www.oreilly.com/radar/four-short-links...
#
#                           published                      published_parsed  \
# 0   Fri, 24 Jul 2020 11:30:50 +0000  (2020, 7, 24, 11, 30, 50, 4, 206, 0)
# 1   Thu, 23 Jul 2020 11:18:39 +0000  (2020, 7, 23, 11, 18, 39, 3, 205, 0)
# 2   Wed, 22 Jul 2020 11:29:30 +0000  (2020, 7, 22, 11, 29, 30, 2, 204, 0)
# 3   Tue, 21 Jul 2020 11:42:29 +0000  (2020, 7, 21, 11, 42, 29, 1, 203, 0)
# 4   Tue, 21 Jul 2020 11:20:35 +0000  (2020, 7, 21, 11, 20, 35, 1, 203, 0)
# 5   Mon, 20 Jul 2020 11:14:44 +0000  (2020, 7, 20, 11, 14, 44, 0, 202, 0)
# 6   Fri, 17 Jul 2020 10:49:53 +0000  (2020, 7, 17, 10, 49, 53, 4, 199, 0)
# 7   Thu, 16 Jul 2020 11:18:37 +0000  (2020, 7, 16, 11, 18, 37, 3, 198, 0)
# 8   Wed, 15 Jul 2020 13:33:44 +0000  (2020, 7, 15, 13, 33, 44, 2, 197, 0)
# 9   Wed, 15 Jul 2020 11:19:45 +0000  (2020, 7, 15, 11, 19, 45, 2, 197, 0)
# 37  Thu, 11 Jun 2020 11:57:38 +0000  (2020, 6, 11, 11, 57, 38, 3, 163, 0)
# 38  Wed, 10 Jun 2020 11:33:31 +0000  (2020, 6, 10, 11, 33, 31, 2, 162, 0)
# 39  Tue, 09 Jun 2020 11:31:48 +0000   (2020, 6, 9, 11, 31, 48, 1, 161, 0)
# 40  Tue, 09 Jun 2020 10:58:27 +0000   (2020, 6, 9, 10, 58, 27, 1, 161, 0)
# 41  Mon, 08 Jun 2020 11:59:51 +0000   (2020, 6, 8, 11, 59, 51, 0, 160, 0)
# 42  Mon, 08 Jun 2020 11:07:38 +0000    (2020, 6, 8, 11, 7, 38, 0, 160, 0)
# 43  Fri, 05 Jun 2020 11:52:17 +0000   (2020, 6, 5, 11, 52, 17, 4, 157, 0)
# 44  Thu, 04 Jun 2020 11:27:10 +0000   (2020, 6, 4, 11, 27, 10, 3, 156, 0)
# 45  Wed, 03 Jun 2020 13:47:19 +0000   (2020, 6, 3, 13, 47, 19, 2, 155, 0)
# 46  Wed, 03 Jun 2020 11:42:00 +0000    (2020, 6, 3, 11, 42, 0, 2, 155, 0)
# 47  Tue, 02 Jun 2020 11:43:44 +0000   (2020, 6, 2, 11, 43, 44, 1, 154, 0)
# 48  Mon, 01 Jun 2020 11:33:37 +0000   (2020, 6, 1, 11, 33, 37, 0, 153, 0)
# 49  Fri, 29 May 2020 11:42:51 +0000  (2020, 5, 29, 11, 42, 51, 4, 150, 0)
# 50  Thu, 28 May 2020 11:18:21 +0000  (2020, 5, 28, 11, 18, 21, 3, 149, 0)
# 51  Wed, 27 May 2020 12:37:21 +0000  (2020, 5, 27, 12, 37, 21, 2, 148, 0)
# 52  Wed, 27 May 2020 11:42:16 +0000  (2020, 5, 27, 11, 42, 16, 2, 148, 0)
# 53  Tue, 26 May 2020 11:40:42 +0000  (2020, 5, 26, 11, 40, 42, 1, 147, 0)
# 54  Tue, 26 May 2020 11:39:26 +0000  (2020, 5, 26, 11, 39, 26, 1, 147, 0)
# 55  Fri, 22 May 2020 10:38:16 +0000  (2020, 5, 22, 10, 38, 16, 4, 143, 0)
# 56  Thu, 21 May 2020 11:57:44 +0000  (2020, 5, 21, 11, 57, 44, 3, 142, 0)
# 57  Wed, 20 May 2020 11:10:07 +0000   (2020, 5, 20, 11, 10, 7, 2, 141, 0)
# 58  Tue, 19 May 2020 18:40:09 +0000   (2020, 5, 19, 18, 40, 9, 1, 140, 0)
# 59  Tue, 19 May 2020 11:17:58 +0000  (2020, 5, 19, 11, 17, 58, 1, 140, 0)
#
#                                               authors  \
# 0                        [{'name': 'Nat Torkington'}]
# 1                        [{'name': 'Nat Torkington'}]
# 2                        [{'name': 'Nat Torkington'}]
# 3                         [{'name': 'Mike Loukides'}]
# 4                        [{'name': 'Nat Torkington'}]
# 5                        [{'name': 'Nat Torkington'}]
# 6                        [{'name': 'Nat Torkington'}]
# 7                        [{'name': 'Nat Torkington'}]
# 8        [{'name': 'Mike Loukides and Steve Swoyer'}]
# 9                        [{'name': 'Nat Torkington'}]
# 10                           [{'name': 'Sarah Gold'}]
# 11                       [{'name': 'Nat Torkington'}]
# 12                       [{'name': 'Nat Torkington'}]
# 13                       [{'name': 'Nat Torkington'}]
# 14                        [{'name': 'Mike Loukides'}]
# 15                       [{'name': 'Nat Torkington'}]
# 16                       [{'name': 'Nat Torkington'}]
# 17                       [{'name': 'Nat Torkington'}]
# 18                       [{'name': 'Nat Torkington'}]
# 19                       [{'name': 'Nat Torkington'}]
# 20                       [{'name': 'Nat Torkington'}]
# 21                        [{'name': 'Mike Loukides'}]
# 22                       [{'name': 'Nat Torkington'}]
# 23                       [{'name': 'Nat Torkington'}]
# 24                       [{'name': 'Nat Torkington'}]
# 25                       [{'name': 'Nat Torkington'}]
# 26                       [{'name': 'Nat Torkington'}]
# 27                        [{'name': 'Mike Loukides'}]
# 28                       [{'name': 'Nat Torkington'}]
# 29                       [{'name': 'Nat Torkington'}]
# 30                       [{'name': 'Nat Torkington'}]
# 31                       [{'name': 'Nat Torkington'}]
# 32                       [{'name': 'Nat Torkington'}]
# 33                  [{'name': 'Hugo Bowne-Anderson'}]
# 34                       [{'name': 'Nat Torkington'}]
# 35                       [{'name': 'Nat Torkington'}]
# 36                       [{'name': 'Nat Torkington'}]
# 37                       [{'name': 'Nat Torkington'}]
# 38                       [{'name': 'Nat Torkington'}]
# 39                        [{'name': 'Mike Loukides'}]
# 40                       [{'name': 'Nat Torkington'}]
# 41                        [{'name': 'Mike Loukides'}]
# 42                       [{'name': 'Nat Torkington'}]
# 43                       [{'name': 'Nat Torkington'}]
# 44                       [{'name': 'Nat Torkington'}]
# 45  [{'name': 'Adam Jacob, Nat Torkington and Mike...
# 46                       [{'name': 'Nat Torkington'}]
# 47                       [{'name': 'Nat Torkington'}]
# 48                       [{'name': 'Nat Torkington'}]
# 49                       [{'name': 'Nat Torkington'}]
# 50                       [{'name': 'Nat Torkington'}]
# 51                    [{'name': 'David G. Robinson'}]
# 52                       [{'name': 'Nat Torkington'}]
# 53                       [{'name': 'Nat Torkington'}]
# 54                       [{'name': 'Nat Torkington'}]
# 55                       [{'name': 'Nat Torkington'}]
# 56                       [{'name': 'Nat Torkington'}]
# 57                       [{'name': 'Nat Torkington'}]
# 58      [{'name': 'Roger Magoulas and Steve Swoyer'}]
# 59                       [{'name': 'Nat Torkington'}]
#
#                                           author  \
# 0                                 Nat Torkington
# 1                                 Nat Torkington
# 2                                 Nat Torkington
# 3                                  Mike Loukides
# 4                                 Nat Torkington
# 5                                 Nat Torkington
# 6                                 Nat Torkington
# 7                                 Nat Torkington
# 8                 Mike Loukides and Steve Swoyer
# 9                                 Nat Torkington
# 10                                    Sarah Gold
# 11                                Nat Torkington
# 12                                Nat Torkington
# 13                                Nat Torkington
# 14                                 Mike Loukides
# 15                                Nat Torkington
# 16                                Nat Torkington
# 17                                Nat Torkington
# 18                                Nat Torkington
# 19                                Nat Torkington
# 20                                Nat Torkington
# 21                                 Mike Loukides
# 22                                Nat Torkington
# 23                                Nat Torkington
# 24                                Nat Torkington
# 25                                Nat Torkington
# 26                                Nat Torkington
# 27                                 Mike Loukides
# 28                                Nat Torkington
# 29                                Nat Torkington
# 30                                Nat Torkington
# 31                                Nat Torkington
# 32                                Nat Torkington
# 33                           Hugo Bowne-Anderson
# 34                                Nat Torkington
# 35                                Nat Torkington
# 36                                Nat Torkington
# 37                                Nat Torkington
# 38                                Nat Torkington
# 39                                 Mike Loukides
# 40                                Nat Torkington
# 41                                 Mike Loukides
# 42                                Nat Torkington
# 43                                Nat Torkington
# 44                                Nat Torkington
# 45  Adam Jacob, Nat Torkington and Mike Loukides
# 46                                Nat Torkington
# 47                                Nat Torkington
# 48                                Nat Torkington
# 49                                Nat Torkington
# 50                                Nat Torkington
# 51                             David G. Robinson
# 52                                Nat Torkington
# 53                                Nat Torkington
# 54                                Nat Torkington
# 55                                Nat Torkington
# 56                                Nat Torkington
# 57                                Nat Torkington
# 58               Roger Magoulas and Steve Swoyer
# 59                                Nat Torkington
#
#                                         author_detail  \
# 0                          {'name': 'Nat Torkington'}
# 1                          {'name': 'Nat Torkington'}
# 2                          {'name': 'Nat Torkington'}
# 3                           {'name': 'Mike Loukides'}
# 4                          {'name': 'Nat Torkington'}
# 5                          {'name': 'Nat Torkington'}
# 6                          {'name': 'Nat Torkington'}
# 7                          {'name': 'Nat Torkington'}
# 8          {'name': 'Mike Loukides and Steve Swoyer'}
# 9                          {'name': 'Nat Torkington'}
# 10                             {'name': 'Sarah Gold'}
# 11                         {'name': 'Nat Torkington'}
# 12                         {'name': 'Nat Torkington'}
# 13                         {'name': 'Nat Torkington'}
# 14                          {'name': 'Mike Loukides'}
# 15                         {'name': 'Nat Torkington'}
# 16                         {'name': 'Nat Torkington'}
# 17                         {'name': 'Nat Torkington'}
# 18                         {'name': 'Nat Torkington'}
# 19                         {'name': 'Nat Torkington'}
# 20                         {'name': 'Nat Torkington'}
# 21                          {'name': 'Mike Loukides'}
# 22                         {'name': 'Nat Torkington'}
# 23                         {'name': 'Nat Torkington'}
# 24                         {'name': 'Nat Torkington'}
# 25                         {'name': 'Nat Torkington'}
# 26                         {'name': 'Nat Torkington'}
# 27                          {'name': 'Mike Loukides'}
# 28                         {'name': 'Nat Torkington'}
# 29                         {'name': 'Nat Torkington'}
# 30                         {'name': 'Nat Torkington'}
# 31                         {'name': 'Nat Torkington'}
# 32                         {'name': 'Nat Torkington'}
# 33                    {'name': 'Hugo Bowne-Anderson'}
# 34                         {'name': 'Nat Torkington'}
# 35                         {'name': 'Nat Torkington'}
# 36                         {'name': 'Nat Torkington'}
# 37                         {'name': 'Nat Torkington'}
# 38                         {'name': 'Nat Torkington'}
# 39                          {'name': 'Mike Loukides'}
# 40                         {'name': 'Nat Torkington'}
# 41                          {'name': 'Mike Loukides'}
# 42                         {'name': 'Nat Torkington'}
# 43                         {'name': 'Nat Torkington'}
# 44                         {'name': 'Nat Torkington'}
# 45  {'name': 'Adam Jacob, Nat Torkington and Mike ...
# 46                         {'name': 'Nat Torkington'}
# 47                         {'name': 'Nat Torkington'}
# 48                         {'name': 'Nat Torkington'}
# 49                         {'name': 'Nat Torkington'}
# 50                         {'name': 'Nat Torkington'}
# 51                      {'name': 'David G. Robinson'}
# 52                         {'name': 'Nat Torkington'}
# 53                         {'name': 'Nat Torkington'}
# 54                         {'name': 'Nat Torkington'}
# 55                         {'name': 'Nat Torkington'}
# 56                         {'name': 'Nat Torkington'}
# 57                         {'name': 'Nat Torkington'}
# 58        {'name': 'Roger Magoulas and Steve Swoyer'}
# 59                         {'name': 'Nat Torkington'}
#
#                                                  tags  \
# 0   [{'term': 'Four Short Links', 'scheme': None, ...
# 1   [{'term': 'Four Short Links', 'scheme': None, ...
# 2   [{'term': 'Four Short Links', 'scheme': None, ...
# 3   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 4   [{'term': 'Four Short Links', 'scheme': None, ...
# 5   [{'term': 'Four Short Links', 'scheme': None, ...
# 6   [{'term': 'Four Short Links', 'scheme': None, ...
# 7   [{'term': 'Four Short Links', 'scheme': None, ...
# 8   [{'term': 'Next Architecture', 'scheme': None,...
# 9   [{'term': 'Four Short Links', 'scheme': None, ...
# 10  [{'term': 'Design', 'scheme': None, 'label': N...
# 11  [{'term': 'Four Short Links', 'scheme': None, ...
# 12  [{'term': 'Four Short Links', 'scheme': None, ...
# 13  [{'term': 'Four Short Links', 'scheme': None, ...
# 14  [{'term': 'Software Engineering', 'scheme': No...
# 15  [{'term': 'Four Short Links', 'scheme': None, ...
# 16  [{'term': 'Four Short Links', 'scheme': None, ...
# 17  [{'term': 'Four Short Links', 'scheme': None, ...
# 18  [{'term': 'Four Short Links', 'scheme': None, ...
# 19  [{'term': 'Four Short Links', 'scheme': None, ...
# 20  [{'term': 'Four Short Links', 'scheme': None, ...
# 21  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 22  [{'term': 'Four Short Links', 'scheme': None, ...
# 23  [{'term': 'Four Short Links', 'scheme': None, ...
# 24  [{'term': 'Four Short Links', 'scheme': None, ...
# 25  [{'term': 'Four Short Links', 'scheme': None, ...
# 26  [{'term': 'Four Short Links', 'scheme': None, ...
# 27  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 28  [{'term': 'Four Short Links', 'scheme': None, ...
# 29  [{'term': 'Four Short Links', 'scheme': None, ...
# 30  [{'term': 'Four Short Links', 'scheme': None, ...
# 31  [{'term': 'Four Short Links', 'scheme': None, ...
# 32  [{'term': 'Four Short Links', 'scheme': None, ...
# 33  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 34  [{'term': 'Four Short Links', 'scheme': None, ...
# 35  [{'term': 'Four Short Links', 'scheme': None, ...
# 36  [{'term': 'Four Short Links', 'scheme': None, ...
# 37  [{'term': 'Four Short Links', 'scheme': None, ...
# 38  [{'term': 'Four Short Links', 'scheme': None, ...
# 39  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 40  [{'term': 'Four Short Links', 'scheme': None, ...
# 41  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 42  [{'term': 'Four Short Links', 'scheme': None, ...
# 43  [{'term': 'Four Short Links', 'scheme': None, ...
# 44  [{'term': 'Four Short Links', 'scheme': None, ...
# 45  [{'term': 'Open Source', 'scheme': None, 'labe...
# 46  [{'term': 'Four Short Links', 'scheme': None, ...
# 47  [{'term': 'Four Short Links', 'scheme': None, ...
# 48  [{'term': 'Four Short Links', 'scheme': None, ...
# 49  [{'term': 'Four Short Links', 'scheme': None, ...
# 50  [{'term': 'Four Short Links', 'scheme': None, ...
# 51  [{'term': 'AI & ML', 'scheme': None, 'label': ...
#
# 53  https://www.oreilly.com/radar/?p=12909       False
# 54  https://www.oreilly.com/radar/?p=12906       False
# 55  https://www.oreilly.com/radar/?p=12902       False
# 56  https://www.oreilly.com/radar/?p=12899       False
# 57  https://www.oreilly.com/radar/?p=12896       False
# 58  https://www.oreilly.com/radar/?p=12817       False
# 59  https://www.oreilly.com/radar/?p=12814       False
#
#                                               summary  \
# 0   How Taiwan&#8217;s Unlikely Digital Minister H...
# 1   As We May Code &#8212; why aren’t we — ostensi...
# 2   wiki.js &#8212; Portable open-source Javascrip...
# 3   Largely on the impetus of the Black Lives Matt...
# 4   22 Principles for Great Product Managers &#821...
# 5   A Bug-Sized Camera for Bug-Sized Robots and Bu...
# 6   Matters Computational: Ideas, Algorithms, Sour...
# 7   Pseudogen &#8212; [open source] tool to automa...
# 8   Microservices&#160;seem to be everywhere. Scra...
# 9   Fixing Bugs Properly &#8212; Why did a fix tha...
# 10  A World of Individuals Our world is on fire. F...
# 11  Neutralizing Misinformation through Inoculatio...
# 12  Too Efficiency &#8212; (Tim Bray) Think of eff...
# 13  Notes on Splicing CRDTs for Structured Hyperte...
# 14  At Microsoft&#8217;s Build conference, Microso...
# 15  Avoiding Fallback in Distributed Systems &#821...
# 16  When Data is Messy &#8212; I love stories that...
# 17  eDEX-ui &#8212; a fullscreen, cross-platform t...
# 18  Debubble &#8212; I like that people are trying...
# 19  Open Differential Privacy &#8212; Open source ...
# 20  Sweetviz &#8212; an open source Python library...
# 21  News of the past month is dominated by COVID-1...
# 22  PyLance &#8212; Python language server for VS ...
# 23  Durable Teams &#8212; Rael Dornfest called thi...
# 24  Why Does DARPA Work? &#8212; Absolutely the be...
# 25  timecraft &#8212; synthesizing time lapse vide...
# 26  Krita &#8212; a professional FREE and open sou...
# 27  In various mailing lists about the COVID-19 pa...
# 28  You&#8217;ve Been Referred Here Because You&#8...
# 29  Work From Home Cybersecurity Course &#8212; Se...
# 30  Root Causes &#8212; here are a set of “root ca...
# 31  Tsunami &#8212; a general purpose network secu...
# 32  Drive and Listen &#8212; Video of driving thro...
# 33  In the 1996 cult classic film Swingers, two fr...
# 34  The Global Implications of “Re-education” Tech...
# 35  Team Players: How Social Skills Improve Group ...
# 36  OpenSHC &#8212; Syropod High-level Controller ...
# 37  Testing the Automation Revolution Hypothesis &...
# 38  CapRover &#8212; an extremely easy to use app/...
# 39  The biggest problem facing machine learning to...
# 40  Anti-Monopoly Thinking &#8212; Tim Bray review...
# 41  Most of the technical news this month continue...
# 42  Privacy Threats in Intimate Relationships &#82...
# 43  Computers Barely Work &#8212; An interview wit...
# 44  Ears to Faces &#8212; our goal is to generate ...
# 45  In a recent Twitter thread, Adam Jacob (co-fou...
# 46  Undie Detector &#8212; Safe Meeting keeps an e...
# 47  Coders on Twitch &#8212; Currently, livestream...
# 48  Real-time Face Video Swapping From A Single Po...
# 49  Confidential Computing &#8212; Confidential co...
# 50  Living Computers Museum Closing &#8212; Since ...
# 51  Algorithms tell stories about who people are. ...
# 52  Facebook Reportedly Ignored Its Own Research S...
# 53  Habits of High-Performing Teams &#8212; instea...
# 54  NoTo Font &#8212; An elegant font with glyphs ...
# 55  COVID-19 Contact Tracing Data Standard &#8212;...
# 56  Fuzzing: On the Exponential Cost of Vulnerabil...
# 57  The Paradox of Source Code Secrecy &#8212; In ...
# 58  We wanted to discover what our readers were do...
# 59  This Service Helps Malware Authors Fix Flaws i...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
# 15  {'type': 'text/html', 'language': None, 'base'...
# 16  {'type': 'text/html', 'language': None, 'base'...
# 17  {'type': 'text/html', 'language': None, 'base'...
# 18  {'type': 'text/html', 'language': None, 'base'...
# 19  {'type': 'text/html', 'language': None, 'base'...
# 20  {'type': 'text/html', 'language': None, 'base'...
# 21  {'type': 'text/html', 'language': None, 'base'...
# 22  {'type': 'text/html', 'language': None, 'base'...
# 23  {'type': 'text/html', 'language': None, 'base'...
# 24  {'type': 'text/html', 'language': None, 'base'...
# 25  {'type': 'text/html', 'language': None, 'base'...
# 26  {'type': 'text/html', 'language': None, 'base'...
# 27  {'type': 'text/html', 'language': None, 'base'...
# 28  {'type': 'text/html', 'language': None, 'base'...
# 29  {'type': 'text/html', 'language': None, 'base'...
# 30  {'type': 'text/html', 'language': None, 'base'...
# 31  {'type': 'text/html', 'language': None, 'base'...
# 32  {'type': 'text/html', 'language': None, 'base'...
# 33  {'type': 'text/html', 'language': None, 'base'...
# 34  {'type': 'text/html', 'language': None, 'base'...
# 35  {'type': 'text/html', 'language': None, 'base'...
# 36  {'type': 'text/html', 'language': None, 'base'...
# 37  {'type': 'text/html', 'language': None, 'base'...
# 38  {'type': 'text/html', 'language': None, 'base'...
# 39  {'type': 'text/html', 'language': None, 'base'...
# 40  {'type': 'text/html', 'language': None, 'base'...
# 41  {'type': 'text/html', 'language': None, 'base'...
# 42  {'type': 'text/html', 'language': None, 'base'...
# 43  {'type': 'text/html', 'language': None, 'base'...
# 44  {'type': 'text/html', 'language': None, 'base'...
# 45  {'type': 'text/html', 'language': None, 'base'...
# 46  {'type': 'text/html', 'language': None, 'base'...
# 47  {'type': 'text/html', 'language': None, 'base'...
# 48  {'type': 'text/html', 'language': None, 'base'...
# 49  {'type': 'text/html', 'language': None, 'base'...
# 50  {'type': 'text/html', 'language': None, 'base'...
# 51  {'type': 'text/html', 'language': None, 'base'...
# 52  {'type': 'text/html', 'language': None, 'base'...
# 53  {'type': 'text/html', 'language': None, 'base'...
# 54  {'type': 'text/html', 'language': None, 'base'...
# 55  {'type': 'text/html', 'language': None, 'base'...
# 56  {'type': 'text/html', 'language': None, 'base'...
# 57  {'type': 'text/html', 'language': None, 'base'...
# 58  {'type': 'text/html', 'language': None, 'base'...
# 59  {'type': 'text/html', 'language': None, 'base'...
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 15  [{'type': 'text/html', 'language': None, 'base...
# 16  [{'type': 'text/html', 'language': None, 'base...
# 17  [{'type': 'text/html', 'language': None, 'base...
# 18  [{'type': 'text/html', 'language': None, 'base...
# 19  [{'type': 'text/html', 'language': None, 'base...
# 20  [{'type': 'text/html', 'language': None, 'base...
# 21  [{'type': 'text/html', 'language': None, 'base...
# 22  [{'type': 'text/html', 'language': None, 'base...
# 23  [{'type': 'text/html', 'language': None, 'base...
# 24  [{'type': 'text/html', 'language': None, 'base...
# 25  [{'type': 'text/html', 'language': None, 'base...
# 26  [{'type': 'text/html', 'language': None, 'base...
# 27  [{'type': 'text/html', 'language': None, 'base...
# 28  [{'type': 'text/html', 'language': None, 'base...
# 29  [{'type': 'text/html', 'language': None, 'base...
# 30  [{'type': 'text/html', 'language': None, 'base...
# 31  [{'type': 'text/html', 'language': None, 'base...
# 32  [{'type': 'text/html', 'language': None, 'base...
# 33  [{'type': 'text/html', 'language': None, 'base...
# 34  [{'type': 'text/html', 'language': None, 'base...
# 35  [{'type': 'text/html', 'language': None, 'base...
# 36  [{'type': 'text/html', 'language': None, 'base...
# 37  [{'type': 'text/html', 'language': None, 'base...
# 38  [{'type': 'text/html', 'language': None, 'base...
# 39  [{'type': 'text/html', 'language': None, 'base...
# 40  [{'type': 'text/html', 'language': None, 'base...
# 41  [{'type': 'text/html', 'language': None, 'base...
# 42  [{'type': 'text/html', 'language': None, 'base...
# 43  [{'type': 'text/html', 'language': None, 'base...
# 44  [{'type': 'text/html', 'language': None, 'base...
# 45  [{'type': 'text/html', 'language': None, 'base...
# 46  [{'type': 'text/html', 'language': None, 'base...
# 47  [{'type': 'text/html', 'language': None, 'base...
# 48  [{'type': 'text/html', 'language': None, 'base...
# 49  [{'type': 'text/html', 'language': None, 'base...
# 50  [{'type': 'text/html', 'language': None, 'base...
# 51  [{'type': 'text/html', 'language': None, 'base...
# 52  [{'type': 'text/html', 'language': None, 'base...
# 53  [{'type': 'text/html', 'language': None, 'base...
# 54  [{'type': 'text/html', 'language': None, 'base...
# 55  [{'type': 'text/html', 'language': None, 'base...
# 56  [{'type': 'text/html', 'language': None, 'base...
# 57  [{'type': 'text/html', 'language': None, 'base...
# 58  [{'type': 'text/html', 'language': None, 'base...
# 59  [{'type': 'text/html', 'language': None, 'base...
#
#                                        wfw_commentrss slash_comments  \
# 0   https://www.oreilly.com/radar/four-short-links...              0
# 1   https://www.oreilly.com/radar/four-short-links...              0
# 2   https://www.oreilly.com/radar/four-short-links...              0
# 3   https://www.oreilly.com/radar/ai-protests-and-...              0
# 4   https://www.oreilly.com/radar/four-short-links...              0
# 5   https://www.oreilly.com/radar/four-short-links...              0
# 6   https://www.oreilly.com/radar/four-short-links...              0
# 7   https://www.oreilly.com/radar/four-short-links...              0
# 8   https://www.oreilly.com/radar/microservices-ad...              0
# 9   https://www.oreilly.com/radar/four-short-links...              0
# 10  https://www.oreilly.com/radar/society-centered...              0
# 11  https://www.oreilly.com/radar/four-short-links...              0
# 12  https://www.oreilly.com/radar/four-short-links...              0
# 13  https://www.oreilly.com/radar/four-short-links...              0
# 14  https://www.oreilly.com/radar/automated-coding...              0
# 15  https://www.oreilly.com/radar/four-short-links...              0
# 16  https://www.oreilly.com/radar/four-short-links...              0
# 17  https://www.oreilly.com/radar/four-short-links...              0
# 18  https://www.oreilly.com/radar/four-short-links...              0
# 19  https://www.oreilly.com/radar/four-short-links...              0
# 20  https://www.oreilly.com/radar/four-short-links...              0
# 21  https://www.oreilly.com/radar/radar-trends-to-...              0
# 22  https://www.oreilly.com/radar/four-short-links...              0
# 23  https://www.oreilly.com/radar/four-short-links...              0
# 24  https://www.oreilly.com/radar/four-short-links...              0
# 25  https://www.oreilly.com/radar/four-short-links...              0
# 26  https://www.oreilly.com/radar/four-short-links...              0
# 27  https://www.oreilly.com/radar/covid-19-and-com...              0


# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df.title.str.len()
df_new = df

df_new[["title","author","title_length"]].head(10)
# Out:
#                             title                          author  \
# 0  Four short links: 24 July 2020                  Nat Torkington
# 1  Four short links: 26 July 2020                  Nat Torkington
# 2  Four short links: 22 July 2020                  Nat Torkington
# 3       AI, Protests, and Justice                   Mike Loukides
# 4  Four short links: 21 July 2020                  Nat Torkington
# 5  Four short links: 20 July 2020                  Nat Torkington
# 6  Four short links: 17 July 2020                  Nat Torkington
# 7  Four short links: 16 July 2020                  Nat Torkington
# 8  Microservices Adoption in 2020  Mike Loukides and Steve Swoyer
# 9  Four short links: 15 July 2020                  Nat Torkington
#
#    title_length
# 0            30
# 1            30
# 2            30
# 3            25
# 4            30
# 5            30
# 6            30
# 7            30
# 8            30
# 9            30

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
#df_new["machine learning" in df_new["summary"].str ]
df_new[df_new["summary"].str.contains("machine learning")]
# Out:
#                                       title  \
# 16            Four short links: 8 July 2020
# 39  Machine Learning and the Production Gap
#
#                                          title_detail  \
# 16  {'type': 'text/plain', 'language': None, 'base...
# 39  {'type': 'text/plain', 'language': None, 'base...
#
#                                                 links  \
# 16  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 39  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                  link  \
# 16  http://feedproxy.google.com/~r/oreilly/radar/a...
# 39  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                              comments  \
# 16  https://www.oreilly.com/radar/four-short-links...
# 39  https://www.oreilly.com/radar/machine-learning...
#
#                           published                     published_parsed  \
# 16  Wed, 08 Jul 2020 12:49:23 +0000  (2020, 7, 8, 12, 49, 23, 2, 190, 0)
# 39  Tue, 09 Jun 2020 11:31:48 +0000  (2020, 6, 9, 11, 31, 48, 1, 161, 0)
#
#                          authors          author               author_detail  \
# 16  [{'name': 'Nat Torkington'}]  Nat Torkington  {'name': 'Nat Torkington'}
# 39   [{'name': 'Mike Loukides'}]   Mike Loukides   {'name': 'Mike Loukides'}
#
#                                                  tags  \
# 16  [{'term': 'Four Short Links', 'scheme': None, ...
# 39  [{'term': 'AI & ML', 'scheme': None, 'label': ...
#
#                                         id  guidislink  \
# 16  https://www.oreilly.com/radar/?p=13100       False
# 39  https://www.oreilly.com/radar/?p=12965       False
#
#                                               summary  \
# 16  When Data is Messy &#8212; I love stories that...
# 39  The biggest problem facing machine learning to...
#
#                                        summary_detail  \
# 16  {'type': 'text/html', 'language': None, 'base'...
# 39  {'type': 'text/html', 'language': None, 'base'...
#
#                                               content  \
# 16  [{'type': 'text/html', 'language': None, 'base...
# 39  [{'type': 'text/html', 'language': None, 'base...
#
#                                        wfw_commentrss slash_comments  \
# 16  https://www.oreilly.com/radar/four-short-links...              0
# 39  https://www.oreilly.com/radar/machine-learning...              0
#
#                                   feedburner_origlink  title_length
# 16  https://www.oreilly.com/radar/four-short-links...            29
# 39  https://www.oreilly.com/radar/machine-learning...            39

# %%
df[df["title_length"]==25]
# Out:
#                        title  \
# 3  AI, Protests, and Justice
#
#                                         title_detail  \
# 3  {'type': 'text/plain', 'language': None, 'base...
#
#                                                links  \
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 3  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                             comments  \
# 3  https://www.oreilly.com/radar/ai-protests-and-...
#
#                          published                      published_parsed  \
# 3  Tue, 21 Jul 2020 11:42:29 +0000  (2020, 7, 21, 11, 42, 29, 1, 203, 0)
#
#                        authors         author              author_detail  \
# 3  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
#
#                                                 tags  \
# 3  [{'term': 'AI & ML', 'scheme': None, 'label': ...
#
#                                        id  guidislink  \
# 3  https://www.oreilly.com/radar/?p=13156       False
#
#                                              summary  \
# 3  Largely on the impetus of the Black Lives Matt...
#
#                                       summary_detail  \
# 3  {'type': 'text/html', 'language': None, 'base'...
#
#                                              content  \
# 3  [{'type': 'text/html', 'language': None, 'base...
#
#                                       wfw_commentrss slash_comments  \
# 3  https://www.oreilly.com/radar/ai-protests-and-...              0
#
#                                  feedburner_origlink  title_length
# 3  https://www.oreilly.com/radar/ai-protests-and-...            25
