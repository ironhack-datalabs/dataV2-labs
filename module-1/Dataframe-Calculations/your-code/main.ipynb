# %% [markdown]
# # Mandatory Challenge
# ## Context
# You work in the data analysis team of a very important company. On Monday, the company shares some good news with you: you just got hired by a major retail company! So, let's get prepared for a huge amount of work!
#
# Then you get to work with your team and define the following tasks to perform:
# 1. You need to start your analysis using data from the past.
# 2. You need to define a process that takes your daily data as an input and integrates it.
#
# You are in charge of the second part, so you are provided with a sample file that you will have to read daily. To complete you task, you need the following aggregates:
# * One aggregate per store that adds up the rest of the values.
# * One aggregate per item that adds up the rest of the values.
#
# You can import the dataset `warehouse_and_retail_sales` from Ironhack's database.
#
# ## Your task
# Therefore, your process will consist of the following steps:
# 1. Read the sample file that a daily process will save in your folder.
# 2. Clean up the data.
# 3. Create the aggregates.
# 4. Write three tables in your local database:
#     - A table for the cleaned data.
#     - A table for the aggregate per supplier.
#     - A table for the aggregate per item.
#
# ## Instructions
# * Read the csv you can find in Ironhack's database.
# * Clean the data and create the aggregates as you consider.
# * Create the tables in your local database.
# * Populate them with your process.

# %%
import pandas as pd
import numpy as np
ware_reta = pd.read_csv('Warehouse_and_Retail_Sales.csv')
ware_reta.head()
ware_reta
# Out:
#         YEAR  MONTH                      SUPPLIER ITEM CODE  \
# 0       2017      4               ROYAL WINE CORP    100200
# 1       2017      4      SANTA MARGHERITA USA INC    100749
# 2       2017      4            JIM BEAM BRANDS CO     10103
# 3       2017      4  HEAVEN HILL DISTILLERIES INC     10120
# 4       2017      4               ROYAL WINE CORP    101664
# ...      ...    ...                           ...       ...
# 128350  2018      2            ANHEUSER BUSCH INC      9997
# 128351  2018      2   COASTAL BREWING COMPANY LLC     99970
# 128352  2018      2       BOSTON BEER CORPORATION     99988
# 128353  2018      2                           NaN        BC
# 128354  2018      2                           NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                             GAMLA CAB - 750ML      WINE          0.00
# 1          SANTA MARGHERITA P/GRIG ALTO - 375ML      WINE          0.00
# 2         KNOB CREEK BOURBON 9YR - 100P - 375ML    LIQUOR          0.00
# 3                 J W DANT BOURBON 100P - 1.75L    LIQUOR          0.00
# 4                   RAMON CORDOVA RIOJA - 750ML      WINE          0.00
# ...                                         ...       ...           ...
# 128350                  HOEGAARDEN 4/6NR - 12OZ      BEER         66.46
# 128351  DOMINION OAK BARREL STOUT 4/6 NR - 12OZ      BEER          9.08
# 128352               SAM ADAMS COLD SNAP 1/6 KG      KEGS          0.00
# 128353                              BEER CREDIT       REF          0.00
# 128354                              WINE CREDIT       REF          0.00
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 0                    1.0              0.0
# 1                    1.0              0.0
# 2                    8.0              0.0
# 3                    2.0              0.0
# 4                    4.0              0.0
# ...                  ...              ...
# 128350              59.0            212.0
# 128351               7.0             35.0
# 128352               0.0             32.0
# 128353               0.0            -35.0
# 128354               0.0            -81.0
#
# [128355 rows x 9 columns]

# %%
null_cols = ware_reta.isnull().sum()
null_cols[null_cols > 0]
# Out:
# SUPPLIER     24
# ITEM TYPE     1
# dtype: int64

# %%
null_displ = ware_reta[(ware_reta['SUPPLIER'].isnull()==True)|(ware_reta['ITEM TYPE'].isnull()==True)]
null_displ = null_displ[['YEAR', 'MONTH', 'SUPPLIER', 'ITEM CODE', 'ITEM DESCRIPTION','ITEM TYPE','RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES']]
null_displ.head(24)
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 19483   2017      6                                NaN      1279
# 20056   2017      8                                NaN      1279
# 32282   2017      6                                NaN        BC
# 32283   2017      6                                NaN        WC
# 45871   2017      8                                NaN        BC
# 45872   2017      8                                NaN        WC
# 46518   2017      9                                NaN      1279
# 59259   2017      9                                NaN        BC
# 59260   2017      9                                NaN        WC
# 59920   2017     10                                NaN      1279
# 66439   2017     10  REPUBLIC NATIONAL DISTRIBUTING CO    347939
# 72878   2017     10                                NaN        BC
# 72879   2017     10                                NaN        WC
# 73546   2017     11                                NaN      1279
# 87410   2017     11                                NaN        BC
# 87411   2017     11                                NaN        WC
# 88078   2017     12                                NaN      1279
# 101909  2017     12                                NaN        BC
# 101910  2017     12                                NaN        WC
# 102542  2018      1                                NaN      1279
# 115254  2018      1                                NaN        BC
# 115255  2018      1                                NaN        WC
# 115874  2018      2                                NaN      1279
# 128353  2018      2                                NaN        BC
#
#                                 ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 19483                      EMPTY WINE KEG - KEGS   DUNNAGE           0.0
# 20056                      EMPTY WINE KEG - KEGS   DUNNAGE           0.0
# 32282                                BEER CREDIT       REF           0.0
# 32283                                WINE CREDIT       REF           0.0
# 45871                                BEER CREDIT       REF           0.0
# 45872                                WINE CREDIT       REF           0.0
# 46518                      EMPTY WINE KEG - KEGS   DUNNAGE           0.0
# 59259                                BEER CREDIT       REF           0.0
# 59260                                WINE CREDIT       REF           0.0
# 59920                      EMPTY WINE KEG - KEGS   DUNNAGE           0.0
# 66439   FONTANAFREDDA BAROLO SILVER LABEL 750 ML       NaN           0.0
# 72878                                BEER CREDIT       REF           0.0
# 72879                                WINE CREDIT       REF           0.0
# 73546                      EMPTY WINE KEG - KEGS   DUNNAGE           0.0
# 87410                                BEER CREDIT       REF           0.0
# 87411                                WINE CREDIT       REF           0.0
# 88078                      EMPTY WINE KEG - KEGS   DUNNAGE           0.0
# 101909                               BEER CREDIT       REF           0.0
# 101910                               WINE CREDIT       REF           0.0
# 102542                     EMPTY WINE KEG - KEGS   DUNNAGE           0.0
# 115254                               BEER CREDIT       REF           0.0
# 115255                               WINE CREDIT       REF           0.0
# 115874                     EMPTY WINE KEG - KEGS   DUNNAGE           0.0
# 128353                               BEER CREDIT       REF           0.0
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 19483                0.0             -9.0
# 20056                0.0             -5.0
# 32282                0.0            -58.0
# 32283                0.0             -8.0
# 45871                0.0           -699.0
# 45872                0.0             -5.0
# 46518                0.0             -9.0
# 59259                0.0           -502.0
# 59260                0.0            -15.0
# 59920                0.0             -6.0
# 66439                0.0              1.0
# 72878                0.0          -1308.0
# 72879                0.0            -21.0
# 73546                0.0             -5.0
# 87410                0.0          -1755.0
# 87411                0.0           -375.0
# 88078                0.0             -8.0
# 101909               0.0          -1644.0
# 101910               0.0           -156.0
# 102542               0.0            -11.0
# 115254               0.0            -21.0
# 115255               0.0            -71.0
# 115874               0.0             -3.0
# 128353               0.0            -35.0

# %%
ware_reta.dtypes
# Out:
# YEAR                  int64
# MONTH                 int64
# SUPPLIER             object
# ITEM CODE            object
# ITEM DESCRIPTION     object
# ITEM TYPE            object
# RETAIL SALES        float64
# RETAIL TRANSFERS    float64
# WAREHOUSE SALES     float64
# dtype: object

# %%
ware_reta['YEAR'] = ware_reta['YEAR'].astype('object')
ware_reta['YEAR'].dtype
# Out:
# dtype('O')

# %%
ware_reta['MONTH'] = ware_reta['MONTH'].astype('object')
ware_reta['MONTH'].dtype
# Out:
# dtype('O')

# %%
ware_reta.head(60)
# Out:
#     YEAR MONTH                              SUPPLIER ITEM CODE  \
# 0   2017     4                       ROYAL WINE CORP    100200
# 1   2017     4              SANTA MARGHERITA USA INC    100749
# 2   2017     4                    JIM BEAM BRANDS CO     10103
# 3   2017     4          HEAVEN HILL DISTILLERIES INC     10120
# 4   2017     4                       ROYAL WINE CORP    101664
# 5   2017     4     REPUBLIC NATIONAL DISTRIBUTING CO    101680
# 6   2017     4                       ROYAL WINE CORP    101753
# 7   2017     4                    JIM BEAM BRANDS CO     10197
# 8   2017     4             STE MICHELLE WINE ESTATES    101974
# 9   2017     4             MONSIEUR TOUTON SELECTION    102083
# 10  2017     4                    JIM BEAM BRANDS CO     10243
# 11  2017     4                 BACCHUS IMPORTERS LTD     10246
# 12  2017     4                               MHW LTD     10266
# 13  2017     4                               MHW LTD     10268
# 14  2017     4  CRAFT WINE & SPIRITS OF MARYLAND LLC     10269
# 15  2017     4  CRAFT WINE & SPIRITS OF MARYLAND LLC     10270
# 16  2017     4              ALLAGASH BREWING COMPANY     10271
# 17  2017     4     REPUBLIC NATIONAL DISTRIBUTING CO     10274
# 18  2017     4                 PERNOD RICARD USA LLC     10275
# 19  2017     4                   KATCEF BROTHERS INC     10306
# 20  2017     4                       BACARDI USA INC     10332
# 21  2017     4                 A VINTNERS SELECTIONS    103608
# 22  2017     4                           LEGENDS LTD     10370
# 23  2017     4                CASTLE BRANDS USA CORP     10375
# 24  2017     4                               Default       104
# 25  2017     4                  DIONYSOS IMPORTS INC    104060
# 26  2017     4        JACKSON FAMILY ENTERPRISES INC     10413
# 27  2017     4         BUCK DISTRIBUTING COMPANY INC     10430
# 28  2017     4                        PUNTO VINO LLC    104302
# 29  2017     4                   KATCEF BROTHERS INC     10431
# 30  2017     4                           LEGENDS LTD     10434
# 31  2017     4                           LEGENDS LTD     10435
# 32  2017     4                           LEGENDS LTD     10436
# 33  2017     4                           LEGENDS LTD     10437
# 34  2017     4                           LEGENDS LTD     10438
# 35  2017     4                        THE WINE GROUP     10439
# 36  2017     4                        THE WINE GROUP     10441
# 37  2017     4                 PERNOD RICARD USA LLC     10442
# 38  2017     4                 PERNOD RICARD USA LLC     10443
# 39  2017     4                 PERNOD RICARD USA LLC     10444
# 40  2017     4  CRAFT WINE & SPIRITS OF MARYLAND LLC     10445
# 41  2017     4                   ELITE WINES IMPORTS    104450
# 42  2017     4                 PERNOD RICARD USA LLC     10472
# 43  2017     4                    BARON FRANCOIS LTD     10480
# 44  2017     4                    BARON FRANCOIS LTD     10499
# 45  2017     4                   PROXIMO SPIRITS INC     10529
# 46  2017     4     PRESTIGE BEVERAGE GROUP OF MD LLC    105490
# 47  2017     4                   KATCEF BROTHERS INC      1058
# 48  2017     4                               Default       106
# 49  2017     4                           LEGENDS LTD     10609
# 50  2017     4                           LEGENDS LTD     10610
# 51  2017     4              DIAGEO NORTH AMERICA INC     10634
# 52  2017     4                    JIM BEAM BRANDS CO     10636
# 53  2017     4                        THE WINE GROUP     10637
# 54  2017     4                           LEGENDS LTD     10645
# 55  2017     4                    JIM BEAM BRANDS CO     10666
# 56  2017     4                    JIM BEAM BRANDS CO     10667
# 57  2017     4                    JIM BEAM BRANDS CO     10668
# 58  2017     4     PRESTIGE BEVERAGE GROUP OF MD LLC     10673
# 59  2017     4                     MOET HENNESSY USA    106739
#
#                                 ITEM DESCRIPTION     ITEM TYPE  RETAIL SALES  \
# 0                              GAMLA CAB - 750ML          WINE           0.0
# 1           SANTA MARGHERITA P/GRIG ALTO - 375ML          WINE           0.0
# 2          KNOB CREEK BOURBON 9YR - 100P - 375ML        LIQUOR           0.0
# 3                  J W DANT BOURBON 100P - 1.75L        LIQUOR           0.0
# 4                    RAMON CORDOVA RIOJA - 750ML          WINE           0.0
# 5           MANISCHEWITZ CREAM WH CONCORD - 1.5L          WINE           0.0
# 6                 BARKAN CLASSIC PET SYR - 750ML          WINE           0.0
# 7          KNOB CREEK BOURBON 9YR - 100P - 1.75L        LIQUOR           0.0
# 8                      CH ST MICH P/GRIS - 750ML          WINE           0.0
# 9             CH DE LA CHESNAIE MUSCADET - 750ML          WINE           0.0
# 10            OLD GRAND DAD BOURBON 100P - 750ML        LIQUOR           0.0
# 11              HILLROCK DOUBLE CASK RYE - 750ML        LIQUOR           0.0
# 12                          LA CHAYA MAL - 750ML          WINE           0.0
# 13                    LA CHAYA TORRONTES - 750ML          WINE           0.0
# 14                           FEW BOURBON - 750ML        LIQUOR           0.0
# 15                 KOPPER KETTLE WHISKEY - 750ML        LIQUOR           0.0
# 16                  ALLAGASH SAISON 6/4 NR 12.0Z          BEER           0.0
# 17                        KINSEY BOURBON - 750ML        LIQUOR           0.0
# 18                            LOT 40 RYE - 750ML        LIQUOR           0.0
# 19          TROEGS SOLID SENDER PALE ALE - 4/6NR          BEER           0.0
# 20                      GREY GOOSE VODKA - 375ML        LIQUOR           0.0
# 21             VAJRA LANGHE NEBBIOLO DOC - 750ML          WINE           0.0
# 22       BALTIMORE BEER WORKS DARK USHER - 4/6NR          BEER           0.0
# 23               PALLINI LIMONCELLO 6/CS - 750ML        LIQUOR           0.0
# 24                         FOUR BOTTLE WINE TOTE  STR_SUPPLIES           0.0
# 25        LES CHAILLOUX SANCERRE CHERRIE - 750ML          WINE           0.0
# 26                    MURPHY GOODE CHARD - 750ML          WINE           0.0
# 27                       STONE IPA 4/6 NR - 12OZ          BEER           0.0
# 28              EREDI LODALI BAROLO 6/CS - 750ML          WINE           0.0
# 29            VICTORY GOLDEN MONKEY 4/6NR - 12OZ          BEER           0.0
# 30                   LAGUNITAS IPA 4/6 NR - 12OZ          BEER           0.0
# 31         LAGUNITAS SUMPIN SUMPIN 4/6 NR - 12OZ          BEER           0.0
# 32      OSKAR BLUES DALES PALE ALE 12.OZ 4/6 CAN          BEER           0.0
# 33          CRISPIN CIDER ORIGINAL 4/6 NR - 12OZ          BEER           0.0
# 34     BRECKENRIDGE VANILLA PORTER 4/6 NR - 12OZ          BEER           0.0
# 35                CONCANNON FOUNDERS CAB - 750ML          WINE           0.0
# 36                           LOVE P/NOIR - 750ML          WINE           0.0
# 37              OLMECA ALTOS TEQ - PLATA - 750ML        LIQUOR           0.0
# 38           OLMECA ALTOS TEQ - REPOSADO - 750ML        LIQUOR           0.0
# 39       JAMESON IRISH WHISKY CASK MATES - 750ML        LIQUOR           0.0
# 40                  BRECKENRIDGE BOURBON - 750ML        LIQUOR           0.0
# 41                        SEIFRIED S/BLC - 750ML          WINE           0.0
# 42            MALIBU RUM - PASSION FRUIT - 750ML        LIQUOR           0.0
# 43         CHATEAU LAUBADE ARMAGNAC VSOP - 750ML        LIQUOR           0.0
# 44           CHATEAU LAUBADE ARMAGNAC XO - 750ML        LIQUOR           0.0
# 45          JOSE CUERVO GOLDEN MARGARITA - 1.75L        LIQUOR           0.0
# 46                        HAKUTSURU SAKE - 720ML          WINE           0.0
# 47              TROEGS HOPBACK ALE 4/6 NR - 12OZ          BEER           0.0
# 48                SIX BOTTLE WINE TOTE (NO LOGO)  STR_SUPPLIES           0.0
# 49  FIRESTONE LUPONIC DISTORTION - 4/6 CAN 12.0Z          BEER           0.0
# 50          LAGUNITAS LIL SUMPIN - 2/12 NR 12.0Z          BEER           0.0
# 51                  SMIRNOFF VODKA - CHERRY - 1L        LIQUOR           0.0
# 52                  HAKUSHU WHISKY 12 YR - 750ML        LIQUOR           0.0
# 53                    CUPCAKE PROSECCO - 187 3PK          WINE           0.0
# 54    OSKAR BLUES DEVIANT DALES - 4/6  CAN 12.OZ          BEER           0.0
# 55               SAUZA HORNITOS REPOSATO - 375ML        LIQUOR           0.0
# 56            EFFEN VODKA - BLACK CHERRY - 375ML        LIQUOR           0.0
# 57                   MAKERS MARK BOURBON - 375ML        LIQUOR           0.0
# 58           CINNABON CINNAMON CREAM LIQ - 750ML        LIQUOR           0.0
# 59               VEUVE CLICQUOT DEMI SEC - 375ML          WINE           0.0
#
#     RETAIL TRANSFERS  WAREHOUSE SALES
# 0                1.0              0.0
# 1                1.0              0.0
# 2                8.0              0.0
# 3                2.0              0.0
# 4                4.0              0.0
# 5                1.0              0.0
# 6                1.0              0.0
# 7               32.0              0.0
# 8               26.0              0.0
# 9                1.0              0.0
# 10               3.0              0.0
# 11               5.0              0.0
# 12               4.0              0.0
# 13               1.0              0.0
# 14               1.0              0.0
# 15               1.0              0.0
# 16               4.0              0.0
# 17               1.0              0.0
# 18               1.0              0.0
# 19               1.0              0.0
# 20              11.0              0.0
# 21               1.0              0.0
# 22               1.0              0.0
# 23               2.0              0.0
# 24               2.0              0.0
# 25               1.0              0.0
# 26              22.0              0.0
# 27              44.0              0.0
# 28               1.0              0.0
# 29              25.0              0.0
# 30              58.0              0.0
# 31              26.0              0.0
# 32              31.0              0.0
# 33               2.0              0.0
# 34               6.0              0.0
# 35               3.0              0.0
# 36              16.0              0.0
# 37              39.0              0.0
# 38              20.0              0.0
# 39               3.0              0.0
# 40               3.0              0.0
# 41               1.0              0.0
# 42               3.0              0.0
# 43               2.0              0.0
# 44               1.0              0.0
# 45              50.0              0.0
# 46               2.0              0.0
# 47               5.0              0.0
# 48               2.0              0.0
# 49               3.0              0.0
# 50               6.0              0.0
# 51               6.0              0.0
# 52               6.0              0.0
# 53               2.0              0.0
# 54               3.0              0.0
# 55               1.0              0.0
# 56               2.0              0.0
# 57              27.0              0.0
# 58               1.0              0.0
# 59               1.0              0.0

# %%
test = ware_reta[(ware_reta['SUPPLIER']=='Default') & (ware_reta['ITEM TYPE']=='WINE')]
test[['YEAR', 'MONTH', 'SUPPLIER', 'ITEM CODE', 'ITEM DESCRIPTION','ITEM TYPE','RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES']]
test.head()
# Out:
#        YEAR MONTH SUPPLIER ITEM CODE                     ITEM DESCRIPTION  \
# 28651  2017     6  Default     60453  LUNA DI LUNA P/GRIG P/BIANCO - 1.5L
# 55675  2017     9  Default     60453  LUNA DI LUNA P/GRIG P/BIANCO - 1.5L
# 69311  2017    10  Default     60453  LUNA DI LUNA P/GRIG P/BIANCO - 1.5L
#
#       ITEM TYPE  RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# 28651      WINE          0.00               0.5              0.0
# 55675      WINE          0.17               0.0              0.0
# 69311      WINE          0.17               0.0              0.0

# %%
ware_reta.loc[(ware_reta['SUPPLIER']=='Default') & (ware_reta['ITEM TYPE']=='WINE'), 'SUPPLIER'] = 'SOUTHERN GLAZERS WINE AND SPIRITS'
test1 = ware_reta[(ware_reta['SUPPLIER']=='Default') & (ware_reta['ITEM TYPE']=='WINE')]
#test1 = ware_reta[(ware_reta['SUPPLIER']=='SOUTHERN GLAZERS WINE AND SPIRITS')]
test1.head()
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, SUPPLIER, ITEM CODE, ITEM DESCRIPTION, ITEM TYPE, RETAIL SALES, RETAIL TRANSFERS, WAREHOUSE SALES]
# Index: []

# %%
low_variance = []
 
for col in ware_reta._get_numeric_data():
    minimum = min(ware_reta[col])
    ninety_perc = np.percentile(ware_reta[col], 90)
    if ninety_perc == minimum:
        low_variance.append(col)
 
print(low_variance)
# Out:
# []

# %%
stats = ware_reta.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                      count       mean         std      min  25%   50%   75%  \
# RETAIL SALES      128355.0   6.563037   28.924944    -6.49  0.0  0.33  3.25
# RETAIL TRANSFERS  128355.0   7.188161   30.640156   -27.66  0.0  0.00  4.00
# WAREHOUSE SALES   128355.0  22.624213  239.693277 -4996.00  0.0  1.00  4.00
#
#                        max   IQR
# RETAIL SALES       1616.60  3.25
# RETAIL TRANSFERS   1587.99  4.00
# WAREHOUSE SALES   16271.75  4.00

# %%
outliers = pd.DataFrame(columns=ware_reta.columns)

for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 3
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = ware_reta[(ware_reta[col] < lower) | (ware_reta[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)

outliers
# Out:
#         YEAR MONTH                        SUPPLIER ITEM CODE  \
# 5229    2017     5              JIM BEAM BRANDS CO     10197
# 5264    2017     5                 BACARDI USA INC     10332
# 5269    2017     5          CASTLE BRANDS USA CORP     10375
# 5278    2017     5  JACKSON FAMILY ENTERPRISES INC     10413
# 5280    2017     5   BUCK DISTRIBUTING COMPANY INC     10430
# ...      ...   ...                             ...       ...
# 128350  2018     2              ANHEUSER BUSCH INC      9997
# 128351  2018     2     COASTAL BREWING COMPANY LLC     99970
# 128352  2018     2         BOSTON BEER CORPORATION     99988
# 128353  2018     2                             NaN        BC
# 128354  2018     2                             NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 5229      KNOB CREEK BOURBON 9YR - 100P - 1.75L    LIQUOR         33.44
# 5264                   GREY GOOSE VODKA - 375ML    LIQUOR         16.12
# 5269            PALLINI LIMONCELLO 6/CS - 750ML    LIQUOR         13.38
# 5278                 MURPHY GOODE CHARD - 750ML      WINE         22.07
# 5280                    STONE IPA 4/6 NR - 12OZ      BEER         52.75
# ...                                         ...       ...           ...
# 128350                  HOEGAARDEN 4/6NR - 12OZ      BEER         66.46
# 128351  DOMINION OAK BARREL STOUT 4/6 NR - 12OZ      BEER          9.08
# 128352               SAM ADAMS COLD SNAP 1/6 KG      KEGS          0.00
# 128353                              BEER CREDIT       REF          0.00
# 128354                              WINE CREDIT       REF          0.00
#
#         RETAIL TRANSFERS  WAREHOUSE SALES          Outlier
# 5229                39.0              0.0     RETAIL SALES
# 5264                12.0              0.0     RETAIL SALES
# 5269                 0.0              0.0     RETAIL SALES
# 5278                18.0             39.0     RETAIL SALES
# 5280                61.0            154.0     RETAIL SALES
# ...                  ...              ...              ...
# 128350              59.0            212.0  WAREHOUSE SALES
# 128351               7.0             35.0  WAREHOUSE SALES
# 128352               0.0             32.0  WAREHOUSE SALES
# 128353               0.0            -35.0  WAREHOUSE SALES
# 128354               0.0            -81.0  WAREHOUSE SALES
#
# [39616 rows x 10 columns]

# %%
#print(set(ware_reta['SUPPLIER']))
ware_reta['SUPPLIER'] = ware_reta['SUPPLIER'].str.replace('WI,INC', 'WI INC')
set(ware_reta['SUPPLIER'])
# Out:
# {'8 VINI INC',
#  'A HARDY USA LTD',
#  'A I G WINE & SPIRITS',
#  'A VINTNERS SELECTIONS',
#  'A&E INC',
#  'A&W BORDERS LLC',
#  'ADAMBA IMPORTS INTL',
#  'AIKO IMPORTERS INC',
#  'ALLAGASH BREWING COMPANY',
#  'ALLIED IMPORTERS USA LTD',
#  'ALTITUDE SPIRITS INC',
#  'AMERICAN BEVERAGE CORPORATION',
#  'AMERICAN BEVERAGE MARKETERS',
#  'AMERICAN FIDELITY TRADING',
#  'AMERICAN VINTAGE BEVERAGE INC',
#  'ANHEUSER BUSCH INC',
#  'ARCHER ROOSE LLC',
#  'AREL GROUP WINE & SPIRITS',
#  'ARIS A ZISSIS',
#  'ARTISANS & VINES LLC',
#  'ASAHI BEER USA INC',
#  'ATLANTIC WINE & SPIRITS',
#  'ATLAS BREW WORKS LLC',
#  'AW DIRECT LLC',
#  'AZIZ SHAFI TANNIC TONGUE',
#  'BACARDI USA INC',
#  'BACCHUS IMPORTERS LTD',
#  'BACKUP BEVERAGE',
#  'BANFI PRODUCTS CORP',
#  'BANVILLE & JONES WINE MERCHANTS',
#  'BARON FRANCOIS LTD',
#  'BARREL ONE INC',
#  'BASIGNANI WINERY',
#  'BINDING BRAUEREI USA INC',
#  'BLACK ANKLE VINEYARDS LLC',
#  'BOND DISTRIBUTING CO',
#  'BOORDY VINEYARDS',
#  'BORVIN BEVERAGE',
#  'BOSTON BEER CORPORATION',
#  'BOUTIQUE VINEYARDS LLC',
#  'BRONCO WINE COMPANY',
#  'BROWN-FORMAN BEVERAGES WORLDWIDE',
#  'BUCK DISTRIBUTING COMPANY INC',
#  'BULLSHINE DISTILLERY LLC',
#  'C MONDAVI & SONS',
#  'CABERNET CORPORATION',
#  'CAFFO BEVERAGES INC',
#  'CALVERT BREWING COMPANY',
#  'CAMPARI AMERICA LLC',
#  'CANTINIERE IMPORTS & DISTRIBUTING INC',
#  'CAPE STARZ WINE LLC',
#  'CASA CHIRICO LLC',
#  'CASTLE BRANDS USA CORP',
#  'CELICAR LLC DBA TWIN VALLEY DISTILLERS',
#  'CHADDSFORD WINERY LTD',
#  'CHARLES JACQUIN ET CIE INC',
#  'CHATEAU DIANA LLC',
#  'CHEF SOUS LLC',
#  'CHEVAL QUANCARD',
#  'CLASSIC WINE IMPORTS INC',
#  'CLASSIC WINE IMPORTS INC DBA VISION WINE',
#  'CLIPPER CITY BREWING CO',
#  'COASTAL BREWING COMPANY LLC',
#  'COMETE WINES LLC',
#  'CONSTANTINE WINES INC',
#  'CONSTELLATION BRANDS',
#  'COPPER CANE LLC',
#  'CRAFT BREW ALLIANCE INC',
#  'CRAFT WINE & SPIRITS OF MARYLAND LLC',
#  'CROWN IMPORTS',
#  "D'AQUINO ITALIAN IMPORTING CO INC",
#  'DANGEROUS WINE GROUP LLC',
#  'DC BRAU BREWING LLC',
#  'DCD ENTERPRISES LLC',
#  'DELICATO FAMILY VINEYARDS',
#  'DELMAR BREWING COMPANY LLC',
#  'DESCHUTES BREWERY INC',
#  'DEUTSCH FAMILY WINE & SPIRITS',
#  'DIAGEO NORTH AMERICA INC',
#  'DIONYSOS IMPORTS INC',
#  'DISARONNO INTERNATIONAL LLC',
#  'DMV DISTRIBUTING LLC',
#  'DOGFISH HEAD CRAFT BREWERY',
#  'DOGFISH HEAD DISTILLERY LLC',
#  'DOMAINE SELECT WINE & SPIRITS LLC',
#  'DON SEBASTIANI & SONS',
#  'DOPS INC',
#  'DRAGON DISTILLERY LLC',
#  'DREYFUS ASHBY INC',
#  'DUCKHORN WINE COMPANY',
#  'DUCLAW BREWERY LLC',
#  'DUGGANS DISTILLERS PROD',
#  'DUVEL MOORTGAT USA LTD',
#  'Default',
#  'E & J GALLO WINERY',
#  'E M D SALES INC',
#  'EASTERN LIQUOR DISTRIBUTORS INC',
#  'ELITE WINES IMPORTS',
#  'ELK RUN VINEYARDS',
#  'EVEREST SPIRITS LLC',
#  'EXCELSIOR WINE COMPANY LLC',
#  'FAR NIENTE WINERY INC',
#  'FAROPIAN SPIRITS LTD',
#  'FERRARI CARANO WINERY',
#  'FETZER VINEYARDS',
#  'FIFTH GENERATION INC',
#  'FIORE WINERY',
#  'FIVE GRAPES LLC',
#  'FLAVOR SEEKERS LLC',
#  'FLYING DOG BREWERY LLLP',
#  'FN CELLARS LLC',
#  'FOLEY FAMILY WINES INC',
#  'FOWLES WINE USA INC',
#  'FRANCIS COPPOLA WINERY LLC',
#  'FRANK LIN MD',
#  'FREDERICK P WINNER LTD',
#  'FREDERICK WILDMAN & SONS',
#  'FREE RUN WINE MERCHANTS LLC',
#  'FREELANCE WINES LLC',
#  'FREIXENET USA',
#  'FRITZ IMPORTS LLC',
#  'FRONT PORCH MICRO WINERY LLC',
#  'FRUIT OF THE VINES INC',
#  'FX MATT BREWING CO',
#  'GAMBRINUS',
#  "GATOR RON'S LLC",
#  'GEORGIAN HOUSE OF GREATER WASHINGTON',
#  'GF WINES, LLC DBA GARY FARRELL WINERY',
#  'GLOBAL OCEAN AND AIR CARGO SERVICES',
#  'GOOSE RIDGE LLC',
#  'GRAIL POINT BREWERY LLC',
#  'GRAND ENCLOS DU CHATEAU DE CERONS',
#  'GRAPES & BARLEY LLC',
#  'GRAPES OF SPAIN INC',
#  'GROTH VINEYARDS & WINERY',
#  'HAMCO DC',
#  'HARVEST IMPORTING LLC',
#  'HEAVEN HILL DISTILLERIES INC',
#  'HEIMBUCH ESTATE VINEYARDS AND WINERY LLC',
#  'HEINEKEN USA',
#  'HOME BREW MART INC',
#  'HONIG VINEYARD AND WINERY',
#  'IMPERO WINE DISTRIBUTORS VIRGINIA INC',
#  'INFINIUM SPIRITS INC',
#  'INTERBALT PRODUCTS CORP',
#  'INTERNATIONAL CELLARS LLC',
#  'INTERNATIONAL SPIRITS & WINES LLC',
#  'J LOHR WINERY',
#  'JACK POUST & COMPANY INC',
#  'JACKSON FAMILY ENTERPRISES INC',
#  'JIM BEAM BRANDS CO',
#  'JOHN GIVEN WINES INC',
#  'JORDAN VINEYARD',
#  'JOS VICTORI WINES',
#  'KAHN PAPER COMPANY INC',
#  'KATCEF BROTHERS INC',
#  'KING ESTATE WINERY',
#  'KLEIN FAMILY VINTNERS',
#  'KOBRAND CORPORATION',
#  'KYSELA PERE ET FILS LTD',
#  'LA ISLA CORPORATION',
#  'LABATT USA OPERATING CO LLC',
#  'LAIRD AND COMPANY',
#  'LANTERNA DISTRIBUTORS INC',
#  'LAPHAM SALES & MARKETING DBA LAPHAM',
#  'LATITUDE BEVERAGE COMPANY',
#  'LCF WINE COMPANY LLC',
#  'LEGACY PARTNERS DISTRIBUTION LLC',
#  'LEGENDS LTD',
#  'LUNEAU USA INC',
#  'LUXCO SPIRITED BRANDS',
#  'LYON DISTILLING COMPANY LLC',
#  'MACCHU PISCO LLC',
#  'MADIDUS LLC',
#  'MAISON JOMERE LTD',
#  'MARK ANTHONY BRANDS INC',
#  'MARQUEE SELECTIONS LLC',
#  'MASS BAY BREWING CO',
#  'MAST-JAEGERMEISTER US INC',
#  'MEIOMI',
#  'MERRYVALE VINEYARDS',
#  'MEXCOR INTERNATIONAL',
#  'MHW LTD',
#  'MICHAEL R DOWNEY SELECTIONS INC',
#  'MILLER BREWING COMPANY',
#  'MOET HENNESSY USA',
#  'MONDO VINO',
#  'MONOCACY BREWING CO LLC',
#  'MONSIEUR TOUTON SELECTION',
#  'MONTEBELLO BRANDS INC',
#  'NARRAGANSETT BREWING COMPANY',
#  'NEW BELGIUM BREWING INC',
#  'NEW PARROTT & CO',
#  'NICE LEGS LLC',
#  'NICHE IMPORTERS',
#  'NICKOLAS IMPORTS LLC',
#  'NOBLE VINTNERS INC',
#  'NORTH LOCK LLC DBA PORT CITY BREWING CO',
#  'NOVELTY MD INC',
#  'OCEAN CITY BREWING CO LLC',
#  'OENOS LLC',
#  'ONE TRUE VINE',
#  'OPICI FAMILY DISTRIBUTING OF MD',
#  'ORGANIC VINTNERS INC',
#  'OSLO ENTERPRISE',
#  'PABST BREWING CO',
#  'PACIFIC RIM WINEMAKERS',
#  'PALM BAY IMPORTS',
#  'PAMPA BEVERAGES LLC DBA TRANSNATIONAL SU',
#  'PARK STREET IMPORTS LLC',
#  'PATERNO IMPORTS LTD',
#  'PERNOD RICARD USA LLC',
#  'PIPE CREEK WINES LLC',
#  'PLATA WINE PARTNERS LLC',
#  'PLUME RIDGE IRREVOCABLE TRUST',
#  'POTOMAC SELECTIONS INC',
#  'PRECEPT BRANDS LLC',
#  'PREMIUM DISTRIBUTORS OF MARYLAND',
#  'PRESTIGE BEVERAGE GROUP OF MD LLC',
#  'PRESTIGE WINE IMPORTS',
#  'PROXIMO SPIRITS INC',
#  'PUNTO VINO LLC',
#  'PWSWN INC',
#  'QUINTESSENTIAL LLC',
#  'RAPP CAPITAL LLC',
#  'RED INK IMPORTS',
#  'RED MOUNTAIN DISTILLING & SPIRITS LLC',
#  'RELIABLE CHURCHILL LLLP',
#  'REMY COINTREAU USA',
#  'REPUBLIC NATIONAL DISTRIBUTING CO',
#  'REPUBLIC RESTORATIVES',
#  'ROBERT GIRAUD',
#  'ROBERT KACHER SELECTIONS LLC',
#  'ROBERT OATLEY',
#  'ROBERT OATLEY VINEYARDS INC',
#  'ROOTS RUN DEEP LLC',
#  'ROYAL WINE CORP',
#  'RUSSIAN STANDARD VODKA (USA) INC',
#  'RUTHERFORD WINE COMPANY',
#  'RVWC LLC',
#  'SABLE RIDGE VINEYARD LLC',
#  'SAGAMORE WHISKEY LLC',
#  'SALVETO IMPORTS LLC',
#  'SAN ANTONIO WINERY INC',
#  'SANGLIER SELECTIONS LLC',
#  'SANTA MARGHERITA USA INC',
#  'SAZERAC CO',
#  'SCHEID VINEYARDS CALIFORNIA INC',
#  'SCHMITT SOHNE INC',
#  'SCHUG CARNEROS ESTATE WINERY',
#  'SCOPERTA IMPORTING COMPANY INC',
#  'SERRALLES USA LLC',
#  'SIDNEY-FRANK IMPORTING CO',
#  'SIERRA NEVADA BREWING CO',
#  'SIMON N CELLARS LLC',
#  'SINGHA NORTH AMERICA INC',
#  'SMITH-ANDERSON ENTERPRISES INC',
#  'SOKOL BLOSSER LTD',
#  'SOUTHERN GLAZERS WINE AND SPIRITS',
#  'SOUTHERN WINE & SPIRITS OF MARYLAND',
#  'SPADA ENTERPRISES INC',
#  'SPAINS BEST BEERS INC',
#  'SPLINTER GROUP NAPA LLC',
#  'ST KILLIAN IMPORTING CO INC',
#  'ST RICE WINE INC',
#  'STARR HILL BREWERY LLC',
#  'STE MICHELLE WINE ESTATES',
#  'STEFANO INCORPORATED',
#  'STELLAR IMPORTING CO LLC',
#  'STOLI GROUP (USA) LLC',
#  'SUBARASHII KUDAMONO CO INC',
#  'SUGARLOAF MOUNTAIN SUNLIGHT VINEYARD LLC',
#  'SUGARLOAF MOUNTAIN VINEYARD LLC',
#  'SURVILLE ENTERPRISES CORP',
#  'SUTTER HOME WINERY INC',
#  'SWEETWATER BREWING COMPANY LLC',
#  'TAP26MD LLC',
#  'TERRAPIN BEER COMPANY',
#  'TESTA WINES OF THE WORLD LTD',
#  'THE BROOKLYN BREWERY CORPORATION',
#  'THE EDRINGTON GROUP USA LLC',
#  'THE HESS COLLECTION',
#  'THE RIVER WINE',
#  'THE SANDY BOTTOM ENTERPRISES LLC',
#  'THE SPANISH WINE IMPORTERS LLC',
#  'THE TRITON COLLECTION',
#  'THE TRITON COLLECTION INC',
#  'THE VINERY LLC',
#  'THE WINE GROUP',
#  'THE WINE SOURCE INC',
#  'THREE HENS LLC T/A TENTH HARVEST',
#  'THREE STARS BREWING COMPANY LLC',
#  'TI BEVERAGE GROUP LTD',
#  'TRADEWINDS SPECIALTY IMPORTS LLC',
#  'TREANA WINERY LLC',
#  'TREASURY WINE ESTATES AMERICAS COMPANY',
#  'TREFETHEN VINEYARDS',
#  'TRI-VIN IMPORTS',
#  'TRICANA SHIPPERS & IMPORT',
#  'UNITED STATES BEVERAGE',
#  'UNITED STATES DISTILLED PRODUCTS',
#  'URUGUAY IMPORTS LTD',
#  'USA WINE IMPORTS',
#  'USA WINE WEST LLC',
#  'VIGNOBLES LVDH USA INC',
#  'VIN DIVINO LTD',
#  'VINIFERA DISTRIBUTING OF MARYLAND INC',
#  'VINTAGE POINT LLC',
#  'VINTAGE VIRGINIA APPLES',
#  'VINTAGE WINE ESTATES INC',
#  'VINTAGE WINES INC',
#  'VINTURE WINE COMPANY LLC',
#  'VINTUS LLC',
#  'VOLUBILIS IMPORTS INC',
#  'WAGNER WINE COMPANY LLC',
#  'WARSTEINER IMPORTERS',
#  'WASHBURN WINE CO',
#  'WEIN-BAUER INC',
#  'WESTERN SPIRITS BEVERAGE COMPANY LLC',
#  'WETTEN IMPORTERS INC',
#  'WHITE ROCK DISTILLERS INC',
#  'WI INC',
#  'WILLIAM GRANT AND SONS INC',
#  'WILLIAM HARRISON IMPORTS',
#  'WILLIAMS CORNER WINE',
#  'WILSON DANIELS LTD',
#  'WINE BRIDGE IMPORTS INC',
#  'WINEBOW INC',
#  'YOUNG WON TRADING INC',
#  'YUENGLING BREWERY',
#  'Z WINE GALLERY IMPORTS LLC',
#  'ZURENA LLC',
#  nan}

# %%
print(set(ware_reta['ITEM TYPE']))
# Out:
# {nan, 'DUNNAGE', 'WINE', 'REF', 'STR_SUPPLIES', 'LIQUOR', 'NON-ALCOHOL', 'BEER', 'KEGS'}

# %%
test2 = ware_reta[(ware_reta['ITEM TYPE']!='BEER') & (ware_reta['ITEM TYPE']!= 'DUNNAGE') & (ware_reta['ITEM TYPE']!= 'LIQUOR') & (ware_reta['ITEM TYPE']!= 'NON-ALCOHOL') & (ware_reta['ITEM TYPE']!= 'KEGS') & (ware_reta['ITEM TYPE']!= 'REF') & (ware_reta['ITEM TYPE']!= 'STR_SUPPLIES') & (ware_reta['ITEM TYPE']!= 'WINE')]
test2[['YEAR', 'MONTH', 'SUPPLIER', 'ITEM CODE', 'ITEM DESCRIPTION','ITEM TYPE','RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES']]
test2
# Out:
#        YEAR MONTH                           SUPPLIER ITEM CODE  \
# 66439  2017    10  REPUBLIC NATIONAL DISTRIBUTING CO    347939
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 66439  FONTANAFREDDA BAROLO SILVER LABEL 750 ML       NaN           0.0
#
#        RETAIL TRANSFERS  WAREHOUSE SALES
# 66439               0.0              1.0

# %%
ware_reta.loc[(ware_reta['ITEM CODE']=='347939') & (ware_reta['SUPPLIER']=='REPUBLIC NATIONAL DISTRIBUTING CO'), 'ITEM TYPE'] = 'WINE'
test3 = ware_reta.loc[(ware_reta['ITEM CODE']=='347939') & (ware_reta['SUPPLIER']=='REPUBLIC NATIONAL DISTRIBUTING CO')]
test3.head()
# Out:
#        YEAR MONTH                           SUPPLIER ITEM CODE  \
# 66439  2017    10  REPUBLIC NATIONAL DISTRIBUTING CO    347939
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 66439  FONTANAFREDDA BAROLO SILVER LABEL 750 ML      WINE           0.0
#
#        RETAIL TRANSFERS  WAREHOUSE SALES
# 66439               0.0              1.0

# %%
before = len(ware_reta)
ware_reta = ware_reta.drop_duplicates()
after = len(ware_reta)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
select_columns = ['YEAR', 'MONTH', 'SUPPLIER', 'ITEM CODE', 'ITEM DESCRIPTION','ITEM TYPE','RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES']
ware_reta = ware_reta[select_columns].drop_duplicates()
after = len(ware_reta)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
import numpy as np
import pandas as pd
#Write three tables in your local database:
#A table for the cleaned data.
#A table for the aggregate per supplier.
#A table for the aggregate per item.

# %%
agg_supplier = ware_reta.groupby(['SUPPLIER'])['RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES'].agg(['sum','mean','min','max']) 
agg_supplier.head(60)
# Out:
# /Users/Veeka/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                        RETAIL SALES                           \
#                                                 sum       mean   min     max
# SUPPLIER
# 8 VINI INC                                     2.78   0.308889  0.00    1.07
# A HARDY USA LTD                                0.40   0.133333  0.08    0.16
# A I G WINE & SPIRITS                          12.52   0.313000  0.00    1.67
# A VINTNERS SELECTIONS                       8640.57   0.991346 -1.84  104.04
# A&E INC                                       11.52   0.303158  0.08    1.41
# A&W BORDERS LLC                                0.80   0.114286  0.00    0.32
# ADAMBA IMPORTS INTL                           32.20   1.788889  0.00    5.55
# AIKO IMPORTERS INC                            11.24   0.274146  0.00    1.54
# ALLAGASH BREWING COMPANY                     304.09   2.868774  0.00   37.78
# ALLIED IMPORTERS USA LTD                       7.63   0.448824  0.00    1.86
# ALTITUDE SPIRITS INC                           5.61   0.374000  0.08    1.31
# AMERICAN BEVERAGE CORPORATION                452.40   3.866667  0.00   12.64
# AW DIRECT LLC                              0.00     0.00
# AZIZ SHAFI TANNIC TONGUE                   0.00    11.83
# BACARDI USA INC                            0.00   312.00
# BACCHUS IMPORTERS LTD                     -1.00    64.00
# BACKUP BEVERAGE                           -1.00    20.00
# BANFI PRODUCTS CORP                       -1.00    93.00
# BANVILLE & JONES WINE MERCHANTS            0.00     0.00
# BARON FRANCOIS LTD                        -1.00    18.00
# BARREL ONE INC                             1.00     3.00
# BASIGNANI WINERY                           0.00     0.00
# BINDING BRAUEREI USA INC                   0.00    86.83
# BLACK ANKLE VINEYARDS LLC                  0.00     0.00
# BOND DISTRIBUTING CO                       0.00    15.00
# BOORDY VINEYARDS                          -0.92     9.00
# BORVIN BEVERAGE                            0.00     0.00
# BOSTON BEER CORPORATION                   -6.00  1055.96
# BOUTIQUE VINEYARDS LLC                    -1.00     7.00
# BRONCO WINE COMPANY                        0.00    50.00
# BROWN-FORMAN BEVERAGES WORLDWIDE           0.00   210.00
# BUCK DISTRIBUTING COMPANY INC             -2.00   282.00
# BULLSHINE DISTILLERY LLC                   0.00     0.00
# C MONDAVI & SONS                           0.00    63.00
# CABERNET CORPORATION                       0.00    42.00
# CAFFO BEVERAGES INC                        0.00     0.00
# CALVERT BREWING COMPANY                    1.00     1.00
# CAMPARI AMERICA LLC                        0.00    22.00
# CANTINIERE IMPORTS & DISTRIBUTING INC      1.00     3.00
# CAPE STARZ WINE LLC                        0.00     9.00
# CASA CHIRICO LLC                           1.00    13.00
# CASTLE BRANDS USA CORP                     0.00   161.00
# CELICAR LLC DBA TWIN VALLEY DISTILLERS     0.00     1.00
# CHADDSFORD WINERY LTD                      0.00     0.00
# CHARLES JACQUIN ET CIE INC                 0.00     0.00
# CHATEAU DIANA LLC                          0.00     2.00
# CHEF SOUS LLC                              0.00     0.00
# CHEVAL QUANCARD                            0.00     0.00
# CLASSIC WINE IMPORTS INC                   0.00     0.00

# %%
agg_supplier = agg_supplier.to_csv('aggregateforsupplier.csv', index=False)

# %%
agg_itemtype = ware_reta.groupby(['ITEM TYPE'])['RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES'].agg(['sum'])
agg_itemtype.head(60)
# Out:
# /Users/Veeka/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#              RETAIL SALES RETAIL TRANSFERS WAREHOUSE SALES
#                       sum              sum             sum
# ITEM TYPE
# BEER            209763.11        234924.44      2437617.32
# DUNNAGE              0.00             0.00       -45331.00
# KEGS                 0.00             0.00        43558.00
# LIQUOR          309847.85        334176.41        33173.32
# NON-ALCOHOL       8109.97          9058.37         8656.72
# REF                281.34           171.92        -6754.00
# STR_SUPPLIES       995.98          3594.70            0.00
# WINE            313400.42        340710.51       433010.47

# %%
agg_itemtype = agg_itemtype.to_csv('aggregateforitemtype.csv', index=False)

# %%
ware_reta.head(60)
# Out:
#     YEAR MONTH                              SUPPLIER ITEM CODE  \
# 0   2017     4                       ROYAL WINE CORP    100200
# 1   2017     4              SANTA MARGHERITA USA INC    100749
# 2   2017     4                    JIM BEAM BRANDS CO     10103
# 3   2017     4          HEAVEN HILL DISTILLERIES INC     10120
# 1           SANTA MARGHERITA P/GRIG ALTO - 375ML          WINE           0.0
# 2          KNOB CREEK BOURBON 9YR - 100P - 375ML        LIQUOR           0.0
# 3                  J W DANT BOURBON 100P - 1.75L        LIQUOR           0.0
# 4                    RAMON CORDOVA RIOJA - 750ML          WINE           0.0
# 5           MANISCHEWITZ CREAM WH CONCORD - 1.5L          WINE           0.0
# 6                 BARKAN CLASSIC PET SYR - 750ML          WINE           0.0
# 7          KNOB CREEK BOURBON 9YR - 100P - 1.75L        LIQUOR           0.0
# 8                      CH ST MICH P/GRIS - 750ML          WINE           0.0
# 9             CH DE LA CHESNAIE MUSCADET - 750ML          WINE           0.0
# 10            OLD GRAND DAD BOURBON 100P - 750ML        LIQUOR           0.0
# 11              HILLROCK DOUBLE CASK RYE - 750ML        LIQUOR           0.0
# 12                          LA CHAYA MAL - 750ML          WINE           0.0
# 13                    LA CHAYA TORRONTES - 750ML          WINE           0.0
# 14                           FEW BOURBON - 750ML        LIQUOR           0.0
# 15                 KOPPER KETTLE WHISKEY - 750ML        LIQUOR           0.0
# 16                  ALLAGASH SAISON 6/4 NR 12.0Z          BEER           0.0
# 17                        KINSEY BOURBON - 750ML        LIQUOR           0.0
# 18                            LOT 40 RYE - 750ML        LIQUOR           0.0
# 19          TROEGS SOLID SENDER PALE ALE - 4/6NR          BEER           0.0
# 20                      GREY GOOSE VODKA - 375ML        LIQUOR           0.0
# 21             VAJRA LANGHE NEBBIOLO DOC - 750ML          WINE           0.0
# 22       BALTIMORE BEER WORKS DARK USHER - 4/6NR          BEER           0.0
# 23               PALLINI LIMONCELLO 6/CS - 750ML        LIQUOR           0.0
# 24                         FOUR BOTTLE WINE TOTE  STR_SUPPLIES           0.0
# 25        LES CHAILLOUX SANCERRE CHERRIE - 750ML          WINE           0.0
# 26                    MURPHY GOODE CHARD - 750ML          WINE           0.0
# 27                       STONE IPA 4/6 NR - 12OZ          BEER           0.0
# 28              EREDI LODALI BAROLO 6/CS - 750ML          WINE           0.0
# 29            VICTORY GOLDEN MONKEY 4/6NR - 12OZ          BEER           0.0
# 30                   LAGUNITAS IPA 4/6 NR - 12OZ          BEER           0.0
# 31         LAGUNITAS SUMPIN SUMPIN 4/6 NR - 12OZ          BEER           0.0
# 32      OSKAR BLUES DALES PALE ALE 12.OZ 4/6 CAN          BEER           0.0
# 33          CRISPIN CIDER ORIGINAL 4/6 NR - 12OZ          BEER           0.0
# 34     BRECKENRIDGE VANILLA PORTER 4/6 NR - 12OZ          BEER           0.0
# 35                CONCANNON FOUNDERS CAB - 750ML          WINE           0.0
# 36                           LOVE P/NOIR - 750ML          WINE           0.0
# 37              OLMECA ALTOS TEQ - PLATA - 750ML        LIQUOR           0.0
# 38           OLMECA ALTOS TEQ - REPOSADO - 750ML        LIQUOR           0.0
# 39       JAMESON IRISH WHISKY CASK MATES - 750ML        LIQUOR           0.0
# 40                  BRECKENRIDGE BOURBON - 750ML        LIQUOR           0.0
# 41                        SEIFRIED S/BLC - 750ML          WINE           0.0
# 42            MALIBU RUM - PASSION FRUIT - 750ML        LIQUOR           0.0
# 43         CHATEAU LAUBADE ARMAGNAC VSOP - 750ML        LIQUOR           0.0
# 44           CHATEAU LAUBADE ARMAGNAC XO - 750ML        LIQUOR           0.0
# 45          JOSE CUERVO GOLDEN MARGARITA - 1.75L        LIQUOR           0.0
# 46                        HAKUTSURU SAKE - 720ML          WINE           0.0
# 47              TROEGS HOPBACK ALE 4/6 NR - 12OZ          BEER           0.0
# 48                SIX BOTTLE WINE TOTE (NO LOGO)  STR_SUPPLIES           0.0
# 49  FIRESTONE LUPONIC DISTORTION - 4/6 CAN 12.0Z          BEER           0.0
# 50          LAGUNITAS LIL SUMPIN - 2/12 NR 12.0Z          BEER           0.0
# 51                  SMIRNOFF VODKA - CHERRY - 1L        LIQUOR           0.0
# 52                  HAKUSHU WHISKY 12 YR - 750ML        LIQUOR           0.0
# 53                    CUPCAKE PROSECCO - 187 3PK          WINE           0.0
# 54    OSKAR BLUES DEVIANT DALES - 4/6  CAN 12.OZ          BEER           0.0
# 55               SAUZA HORNITOS REPOSATO - 375ML        LIQUOR           0.0
# 56            EFFEN VODKA - BLACK CHERRY - 375ML        LIQUOR           0.0
# 57                   MAKERS MARK BOURBON - 375ML        LIQUOR           0.0
# 58           CINNABON CINNAMON CREAM LIQ - 750ML        LIQUOR           0.0
# 59               VEUVE CLICQUOT DEMI SEC - 375ML          WINE           0.0
#
#     RETAIL TRANSFERS  WAREHOUSE SALES
# 0                1.0              0.0
# 1                1.0              0.0
# 2                8.0              0.0
# 3                2.0              0.0
# 4                4.0              0.0
# 5                1.0              0.0
# 6                1.0              0.0
# 7               32.0              0.0
# 8               26.0              0.0
# 9                1.0              0.0
# 10               3.0              0.0
# 11               5.0              0.0
# 12               4.0              0.0
# 13               1.0              0.0
# 14               1.0              0.0
# 15               1.0              0.0
# 16               4.0              0.0
# 17               1.0              0.0
# 18               1.0              0.0
# 19               1.0              0.0
# 20              11.0              0.0
# 21               1.0              0.0
# 22               1.0              0.0
# 23               2.0              0.0
# 24               2.0              0.0
# 25               1.0              0.0
# 26              22.0              0.0
# 27              44.0              0.0
# 28               1.0              0.0
# 29              25.0              0.0
# 30              58.0              0.0
# 31              26.0              0.0
# 32              31.0              0.0
# 33               2.0              0.0
# 34               6.0              0.0
# 35               3.0              0.0
# 36              16.0              0.0
# 37              39.0              0.0
# 38              20.0              0.0
# 39               3.0              0.0
# 40               3.0              0.0
# 41               1.0              0.0
# 42               3.0              0.0
# 43               2.0              0.0
# 44               1.0              0.0
# 45              50.0              0.0
# 46               2.0              0.0
# 47               5.0              0.0
# 48               2.0              0.0
# 49               3.0              0.0
# 50               6.0              0.0
# 51               6.0              0.0
# 52               6.0              0.0
# 53               2.0              0.0
# 54               3.0              0.0
# 55               1.0              0.0
# 56               2.0              0.0
# 57              27.0              0.0
# 58               1.0              0.0
# 59               1.0              0.0

# %%
ware_reta = ware_reta.to_csv('Warehouse_and_Retail_Sales_cleaned.csv', index=False)
