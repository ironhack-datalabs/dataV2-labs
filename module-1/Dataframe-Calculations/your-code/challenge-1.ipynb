# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
import re

# %%
df = pd.read_csv('Pokemon.csv')

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# engine = create_engine('mysql+pymysql://student:IHisCool!@34.77.233.175:3306/')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# connection = engine.connect()

# %%
# list(pd.read_sql('SELECT * FROM information_schema.tables', engine)['TABLE_NAME'])

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %%
df['Speed'] = df['Speed']*-1
df['Defense'] = df['Defense']*-1
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col1 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col2 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col3 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col4 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col5 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col6 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col7 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col8 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow0_col9 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col0 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col2 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col3 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col5 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col6 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col8 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow1_col9 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col0 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col1 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col3 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col4 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col5 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col6 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col7 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col8 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow2_col9 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col0 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col1 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col2 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col4 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col5 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col6 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col7 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col8 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow3_col9 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col5 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col7 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow4_col9 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col0 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col1 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col2 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col3 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col4 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col6 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col7 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col8 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_034e757e_a0e1_11ea_afcd_309c2349339drow5_col9 {
#             background-color:  #efcebd;
#             color:  #000000;

# %%
df.corr(co)
# Out:
#                    #     Total        HP    Attack   Defense   Sp. Atk  \
# #           1.000000  0.119813  0.097614  0.102298  0.094786  0.088759
# Total       0.119813  1.000000  0.618748  0.736211  0.612787  0.747250
# HP          0.097614  0.618748  1.000000  0.422386  0.239622  0.362380
# Attack      0.102298  0.736211  0.422386  1.000000  0.438687  0.396362
# Defense     0.094786  0.612787  0.239622  0.438687  1.000000  0.223549
# Sp. Atk     0.088759  0.747250  0.362380  0.396362  0.223549  1.000000
# Sp. Def     0.085817  0.717609  0.378718  0.263990  0.510747  0.506121
# Speed       0.010733  0.575943  0.175952  0.381240  0.015227  0.473018
# Generation  0.982516  0.048384  0.058683  0.051451  0.042419  0.036437
# Legendary   0.153396  0.501758  0.273620  0.345408  0.246377  0.448907
#
#              Sp. Def     Speed  Generation  Legendary
# #           0.085817  0.010733    0.982516   0.153396
# Total       0.717609  0.575943    0.048384   0.501758
# HP          0.378718  0.175952    0.058683   0.273620
# Attack      0.263990  0.381240    0.051451   0.345408
# Defense     0.510747  0.015227    0.042419   0.246377
# Sp. Atk     0.506121  0.473018    0.036437   0.448907
# Sp. Def     1.000000  0.259133    0.028486   0.363937
# Speed       0.259133  1.000000   -0.023121   0.326715
# Generation  0.028486 -0.023121    1.000000   0.079794
# Legendary   0.363937  0.326715    0.079794   1.000000

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
set2 =set(df['Type 2'].unique())

# %%
set1 = set(df['Type 1'].unique())

# %%
setunion = set1.union(set2)

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
def remove_mega(names):
    pattern = re.compile('\w+Mega ')
    return re.sub(pattern, '', names)
df['Names'] = df['Name'].apply(remove_mega)
df.drop('Name', axis=1, inplace=True)

# %%
df.head()
# Out:
#    # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Grass  Poison    318  45      49       49       65       65     45
# 1  2  Grass  Poison    405  60      62       63       80       80     60
# 2  3  Grass  Poison    525  80      82       83      100      100     80
# 3  3  Grass  Poison    625  80     100      123      122      120     80
# 4  4   Fire     NaN    309  39      52       43       60       50     65
#
#    Generation  Legendary       Names
# 0           1      False   Bulbasaur
# 1           1      False     Ivysaur
# 2           1      False    Venusaur
# 3           1      False    Venusaur
# 4           1      False  Charmander

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
df['A/D Ratio'] = df['Attack']/df['Defense']

# %%
df[(df['A/D Ratio'].max()==df['A/D Ratio'])]
# Out:
#        #   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 429  386  Psychic    NaN    600  50     180       20      180       20    150
#
#      Generation  Legendary               Names  A/D Ratio
# 429           3       True  DeoxysAttack Forme        9.0

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
df[(df['A/D Ratio'].min()==df['A/D Ratio'])]
# Out:
#        # Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 230  213    Bug   Rock    505  20      10      230       10      230      5
#
#      Generation  Legendary    Names  A/D Ratio
# 230           2      False  Shuckle   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
df['Combo Type'] = df['Type 1'].fillna('') + df['Type 2'].fillna('')

# %%
df['Combo Type']
# Out:
# 0       GrassPoison
# 1       GrassPoison
# 2       GrassPoison
# 3       GrassPoison
# 4              Fire
#            ...
# 795       RockFairy
# 796       RockFairy
# 797    PsychicGhost
# 798     PsychicDark
# 799       FireWater
# Name: Combo Type, Length: 800, dtype: object

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
df.sort_values('A/D Ratio',ascending=False).head(5)
# Out:
#        #   Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 429  386  Psychic     NaN    600  50     180       20      180       20
# 347  318    Water    Dark    305  45      90       20       65       20
# 19    15      Bug  Poison    495  65     150       40       15       80
# 453  408     Rock     NaN    350  67     125       40       30       30
# 348  319    Water    Dark    460  70     120       40       95       40
#
#      Speed  Generation  Legendary               Names  A/D Ratio Combo Type
# 429    150           3       True  DeoxysAttack Forme      9.000    Psychic
# 347     65           3      False            Carvanha      4.500  WaterDark
# 19     145           1      False            Beedrill      3.750  BugPoison
# 453     58           4      False            Cranidos      3.125       Rock
# 348     95           3      False            Sharpedo      3.000  WaterDark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
combo_type_list = list(df.sort_values('A/D Ratio',ascending=False).head(5)['Combo Type'])

# %%
combo_type_list
# Out:
# ['Psychic', 'WaterDark', 'BugPoison', 'Rock', 'WaterDark']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
df[df['Combo Type'].isin(combo_type_list)].groupby('Combo Type').mean()
# Out:
#                      #       Total         HP      Attack     Defense  \
# Combo Type
# BugPoison   199.166667  347.916667  53.750000   68.333333   58.083333
# Psychic     381.973684  464.552632  72.552632   64.947368   67.236842
# Rock        410.111111  409.444444  67.111111  103.333333  107.222222
# WaterDark   347.666667  493.833333  69.166667  120.000000   65.166667
#
#               Sp. Atk    Sp. Def      Speed  Generation  Legendary  A/D Ratio
# Combo Type
# BugPoison   42.500000  59.333333  65.916667    2.333333   0.000000   1.315989
# Psychic     98.552632  82.394737  78.868421    3.342105   0.236842   1.164196
# Rock        40.555556  58.333333  32.888889    3.888889   0.111111   1.260091
# WaterDark   88.833333  63.500000  87.166667    3.166667   0.000000   2.291949
