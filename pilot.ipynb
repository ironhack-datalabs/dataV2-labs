# %%
import numpy as np
import pandas as pd
import itertools
import re
from datetime import datetime 
#importamos librerias necesarios

# %%
sharks = pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\Data_Cleaning_Sharks\attacks.csv',encoding='cp1252')
sharks
#importamos csv para generar nuesto Data Frame
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sharks.info()
sharks.columns = sharks.columns.str.strip()
sharks.columns = sharks.columns.str.replace(' ', '_')
sharks.columns
#Removi espacios de columnas y sustituimos los espacios dentro del string con _
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
null_columns = sharks.isnull().mean()*100
null_columns = null_columns[null_columns > 99]
null_columns
#obtenemos las columnas con mas de 99% de datos vacios
# Out:
# Unnamed:_22    99.996112
# Unnamed:_23    99.992225
# dtype: float64

# %%
cols_eliminate = list(null_columns.index)
cols_eliminate
#eliminamos las columnas vacias en mas del 99%
# Out:
# ['Unnamed:_22', 'Unnamed:_23']

# %%
sharks_clean= sharks.drop(cols_eliminate, axis=1)
sharks_clean
# Out:
#       Case_Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sharks.isnull().mean()*100
# Out:
# Case_Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal_(Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator_or_Source    75.566614
# pdf                       75.500525
# href_formula              75.504412
# href                      75.500525
# Case_Number.1             75.500525
# Case_Number.2             75.500525
# original_order            75.473312
# Unnamed:_22               99.996112
# Unnamed:_23               99.992225
# dtype: float64

# %%
sharks_clean2 = sharks_clean[(sharks_clean['Country'].isna()) & (sharks_clean['Area'].isna()) & (sharks_clean['Location'].isna())]
list_sharks_2 = sharks_clean2.index.values.tolist()
sharks_clean= sharks_clean.drop(list_sharks_2, axis=0)
sharks_clean
#elimine todos los renglones que tienen Country Area y Location vacios
# Out:
#      Case_Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks_clean3 = sharks_clean[(sharks_clean['Country'].isna()) & (sharks_clean['Area'].isna()) | 
                             (sharks_clean['Country'].isna()) & (sharks_clean['Location'].isna()) | 
                             (sharks_clean['Location'].isna()) & (sharks_clean['Area'].isna()) |
                             (sharks_clean['Area'].isna())]
                            

list_sharks_3 = sharks_clean3.index.values.tolist()
sharks_clean= sharks_clean.drop(list_sharks_3, axis=0)
sharks_clean

#Despues elimine todas las posibilidades donde 2 registros de Country Location y Area
#esten vacios y uno no; esto es debido a que no es posible inferir valores en esos casos
#En area decidi remover todos los valores vacios ya que es la columna mas importante para inferir otros valores
#Sin valores de area no se puede llevar a cabo la inferencia en pais
# Out:
#      Case_Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6296     ND.0006  Before 1906     0.0  Unprovoked           AUSTRALIA
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks_clean['Country'][3387] = "St Kitts & Nevis"
sharks_clean['Country'][4266] = "MADAGASCAR"
sharks_clean['Country'][4498] = "CUBA"
sharks_clean['Country'][5020] = "FRANCE"
sharks_clean['Country'][6137] = "ANGOLA"

#estas son las inferencias que se lograron hacer apartir de area y location
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\1870786524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_clean['Country'][3387] = "St Kitts & Nevis"
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\1870786524.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_clean['Country'][4266] = "MADAGASCAR"
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\1870786524.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
sharks_clean['Age'].unique()
Age_list = ['Teen','28 & 26','46 & 34','28, 23 & 30','Teens','36 & 26','Â','6Â½','21 & ?','23 & 20','7      &    31','Elderly',
'Ca. 33','>50','adult','9 & 12','? & 19','23 & 26','(adult)','33 & 37','37, 67, 35, 27,  ? & 27','21, 34,24 & 35','30 & 32',
'50 & 30','17 & 35','X','"middle-age"','34 & 19','33 & 26','2 to 3 months','MAKE LINE GREEN','"young"','17 & 16','F','young','36 & 23',
'A.M.','?    &   14','2Â½','teen','Â','\xa0 ', ' ', '  ']

index_age=[]
unique_age=[]
for i in sharks_clean['Age']:
    if i in Age_list:
        if i not in unique_age:
            index_age.append(list(sharks_clean.index[sharks_clean['Age']==i]))
        unique_age.append(i)

index_age = list(itertools.chain.from_iterable(index_age))

sharks_clean= sharks_clean.drop(index_age, axis=0)
sharks_clean
#De 'age' se visualizaron los registros unicos y se dropearon los valores contenidos en Age_list
# Out:
#      Case_Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6296     ND.0006  Before 1906     0.0  Unprovoked           AUSTRALIA
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
Age_transform={"20s" : 25, "40s" : 45,"60s": 65,"18 months": 2,"30s" : 35,"50s" : 55,"18 or 20" : 19,"12 or 13" : 13,
               "8 or 10": 9,"30 or 36" : 33,"33 or 37" : 35,"mid-30s" : 35,"60's" : 65, "16 to 18" : 17,"mid-20s" : 25,
               "21 or 26" : 24, "18 to 22" : 20,"9 months" : 1,"25 or 28" : 27,"13 or 18" : 15, "7 or 8": 8,"Both 11" : 11,
               "9 or 10" : 10,"10 or 12": 11,"31 or 33" : 32,"13 or 14" : 13,'6½': 6,' 30': 30,' 28': 28,'74 ':74, '45 ':45,
              '20 ':20, ' 43':43, '2½':2}

sharks_clean['Age'].replace(Age_transform, inplace=True)

#Despues se analizaron los registros de Age_transform y se substituyeron por valores numericos, esto 
#para obtener el total de registros de 'Age' como un numero entero; en caso que se necesiten analisis
#que requieran este tipo de datos

# %%
#sharks_clean['Age'].astype('Int64', errors= 'ignore')
#sharks_clean['Age'] = sharks_clean['Age'].astype('Int32')
sharks_clean['Age'].unique()
sharks_clean['Age'] = np.floor(pd.to_numeric(sharks_clean['Age'], errors='coerce')).astype('Int64')
sharks_clean['Age'].unique()
#se realizo el cambio a tipo integer
# Out:
# <IntegerArray>
# [  57,   11,   48, <NA>,   18,   52,   15,   12,   32,   10,   21,   34,   30,
#    60,   33,   29,   54,   41,   37,   56,   19,   25,   69,   38,   55,   35,
#    46,   45,   14,   28,   20,   24,   26,   49,   22,    7,   31,   17,   40,
#    13,   42,    3,    8,   50,   16,   82,   73,   68,   51,   39,   58,   47,
#    61,   65,   36,   66,   43,    9,   72,   59,    6,   27,   64,   23,   71,
#    44,   62,   63,   70,    2,   53,   74,    5,   86,   77,   84,   75,   87,
#    67,    1,   81,   78]
# Length: 82, dtype: Int64

# %%
sharks_clean
# Out:
#      Case_Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6296     ND.0006  Before 1906     0.0  Unprovoked           AUSTRALIA
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks_clean3 = sharks_clean[sharks_clean['Injury'].isna()]
list_sharks_3 = sharks_clean3.index.values.tolist()
sharks_clean= sharks_clean.drop(list_sharks_3, axis=0)
sharks_clean
#dropeamos valores de injury nulos, de injury inferimos si fue fatal por lo tanto datos vacios no 
#valisos.
# Out:
#      Case_Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6296     ND.0006  Before 1906     0.0  Unprovoked           AUSTRALIA
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
index_inj=[]
unique_inj=[]
for i in sharks_clean['Injury']:
    if ("FATAL" in i) or ('Fatal' in i) :
        if i not in unique_inj:
            index_inj.append(list(sharks_clean.index[sharks_clean['Injury']==i]))
        unique_inj.append(i)
        
index_inj = list(itertools.chain.from_iterable(index_inj))  

for i in index_inj:
    sharks_clean['Fatal_(Y/N)'][i] = True 

#Si los registros de Injury contenian la palabra Fatal o FATAL la comulna 'Fatal_(Y/N)' recibia
# el valore booleano True
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\1536747747.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_clean['Fatal_(Y/N)'][i] = True

# %%
Fatal_transform={"N" : False,' N':False, 'N ':False, 'Y': False}
sharks_clean['Fatal_(Y/N)'].replace(Fatal_transform, inplace=True)
sharks_clean['Fatal_(Y/N)'].unique()
# Out:
# array([False, True, nan, 'M', 'UNKNOWN', '2017'], dtype=object)

# %%
sharks_clean.reset_index(inplace=True, drop=True)
key_words =['mortem','killed','Human','human', 'death','Death','disap','Disap','drown','Drown','Missing','missing',
'recovered','Forensic','body','bodies','corpse','decap','Decap','perish','remains']

pil=[]
j=0
for word in key_words:
    j = 0
    for i in sharks_clean['Injury']:
        if word in i:
            pil.append(j)
            sharks_clean['Fatal_(Y/N)'][j] = True
        j = j + 1
#continuamos infiriendo valores booleanos para Fatal_Y/N si los registros de Injury contenian alguna
#de las palabras claves contenidas en la lita de key_words; generando valores True
        
pil_listset=list(set(pil))

Fatal_transform={'M' : False, 'UNKNOWN':False, '2017': False}
sharks_clean['Fatal_(Y/N)'].fillna(False, inplace = True)
sharks_clean['Fatal_(Y/N)'].replace(Fatal_transform, inplace=True)
      
#el resto de lo valores se asigno como False; llenando en su totalidad la celda de Fatal (Y/N)
#de valores booleanos
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\3278791387.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_clean['Fatal_(Y/N)'][j] = True

# %%
sharks_clean
# Out:
#      Case_Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 5757     ND.0006  Before 1906     0.0  Unprovoked           AUSTRALIA
# 5758     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 5759     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 5760     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 5761     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks_clean['Date2'] = sharks_clean['Date']
def cast_date(date):
    date = str(date).strip()
    date = date[:10].replace('.','-')
    if date.endswith('00'):
        date = list(date)
        date[-1] = '1'
        return  "".join(date)
    return date
    

sharks_clean['Date'] = sharks_clean['Case_Number'].apply(cast_date)

#Creamos un Date2 solo para preservar informacion importante ya que Date seria remplazada con otro formato
#A partir de Case_Number obtuvimos valores correctos de Date remplazando . por -

# %%
index_list = list(sharks_clean[sharks_clean['Case_Number'].str.contains('ND', na=False)].index)


for i in index_list:
    if any(chr.isdigit() for chr in sharks_clean['Date2'][i] )== False:
        sharks_clean['Date2'][i] = None
    
    else:   
         sharks_clean['Date2'][i] = re.findall(r'[0-9]{4}',sharks_clean['Date2'][i])[0]
        
#Existian regsitros en Case_Number que no tenian la fecha completa y comenzaban con ND obtuvimos una lista con los index
#Estos registros solo contenian el año; en el ciclo for obtuvimos el año contenido en los registros desordenados de Case_Number
#Lo colocamos en Date2
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\1322319039.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_clean['Date2'][i] = re.findall(r'[0-9]{4}',sharks_clean['Date2'][i])[0]
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\1322319039.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_clean['Date2'][i] = None

# %%
#sharks_clean.to_csv('comparacion.csv')
sharks_clean3 = sharks_clean[sharks_clean['Date2'].isna()]
list_sharks_3 = sharks_clean3.index.values.tolist()
sharks_clean= sharks_clean.drop(list_sharks_3, axis=0)
sharks_clean

#Dropeamos registros vacios en Date2
# Out:
#      Case_Number        Date    Year        Type             Country  \
# 0     2018.06.25  2018-06-25  2018.0     Boating                 USA
# 1     2018.06.18  2018-06-18  2018.0  Unprovoked                 USA
# 2     2018.06.09  2018-06-09  2018.0     Invalid                 USA
# 3     2018.06.08  2018-06-08  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  2018-06-04  2018.0    Provoked              MEXICO
# ...          ...         ...     ...         ...                 ...
# 5757     ND.0006     ND-0006     0.0  Unprovoked           AUSTRALIA
# 5758     ND.0005     ND-0005     0.0  Unprovoked           AUSTRALIA
# 5759     ND.0004     ND-0004     0.0  Unprovoked           AUSTRALIA
# 5760     ND.0003     ND-0003     0.0  Unprovoked                 USA
# 5761     ND.0001     ND-0001     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks_clean[(sharks_clean['Date'].str.startswith('000')) | 
                             (sharks_clean['Date'] == 'nan')]
    
index_list = list(sharks_clean[(sharks_clean['Date'].str.startswith('000')) | 
                             (sharks_clean['Date'] == 'nan')].index)

sharks_clean= sharks_clean.drop(index_list, axis=0)
sharks_clean

#Analizamos valores en Date (nuestra celda original) y eliminamos celdas vacias o que comenzaan con 000
#ya que no ofrecian informacion relevante para asignar fechas
# Out:
#      Case_Number        Date    Year        Type             Country  \
# 0     2018.06.25  2018-06-25  2018.0     Boating                 USA
# 1     2018.06.18  2018-06-18  2018.0  Unprovoked                 USA
# 2     2018.06.09  2018-06-09  2018.0     Invalid                 USA
# 3     2018.06.08  2018-06-08  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  2018-06-04  2018.0    Provoked              MEXICO
# ...          ...         ...     ...         ...                 ...
# 5757     ND.0006     ND-0006     0.0  Unprovoked           AUSTRALIA
# 5758     ND.0005     ND-0005     0.0  Unprovoked           AUSTRALIA
# 5759     ND.0004     ND-0004     0.0  Unprovoked           AUSTRALIA
# 5760     ND.0003     ND-0003     0.0  Unprovoked                 USA
# 5761     ND.0001     ND-0001     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks_clean.reset_index(inplace=True , drop=True)
indice=[]
j = 0
for i in sharks_clean['Date']:
    if (i[5] == '0') and (i[6] == '0'):
        list_i = list(i)
        list_i[6] = "1"
        sharks_clean['Date'][j] = "".join(list_i)
        indice.append(j)
    j = j +1


        
#en date teniamos registros string con mes igual a 00; encontramos los indices y lo remplazamos con 1
#esto dara informacion del mes de enero sin embargo preserva de manera correcta el año y se puede manipular
#con el formato correcto; ademas la cantidad de registros no afecta en gran medida las estadisticas
#de año
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\3839560187.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_clean['Date'][j] = "".join(list_i)

# %%
index_list = list(sharks_clean[sharks_clean['Case_Number'].str.contains('ND', na=False)].index)
for i in index_list:
    sharks_clean['Date'][i] = sharks_clean['Date2'][i]
#Obtuvimos los indices de los Case_Number que comenzaban en ND como lo comentamos en celdas anteriores.
#Para estos indices hicimos las transformaciones correspondientes en Date2 /ver comentarios anteriores/
#Ahora la info se asigna a la celda original
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\1766491865.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_clean['Date'][i] = sharks_clean['Date2'][i]

# %%
sharks_clean['Date']=sharks_clean['Date'].str.replace(',', '-')
#cambiamos , por - para poder dar el formato correcto

# %%
sharks_clean['Date'] = pd.to_datetime(sharks_clean['Date'], errors ='coerce')
sharks_clean[sharks_clean['Date'].isna()].index
sharks_clean= sharks_clean.drop(sharks_clean[sharks_clean['Date'].isna()].index, axis=0)
#cambios el formato de date a date time

# %%
sharks_clean
# Out:
#      Case_Number       Date    Year        Type             Country  \
# 0     2018.06.25 2018-06-25  2018.0     Boating                 USA
# 1     2018.06.18 2018-06-18  2018.0  Unprovoked                 USA
# 2     2018.06.09 2018-06-09  2018.0     Invalid                 USA
# 3     2018.06.08 2018-06-08  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04 2018-06-04  2018.0    Provoked              MEXICO
# ...          ...        ...     ...         ...                 ...
# 5744     ND.0006 1906-01-01     0.0  Unprovoked           AUSTRALIA
# 5745     ND.0005 1903-01-01     0.0  Unprovoked           AUSTRALIA
# 5746     ND.0004 1903-01-01     0.0  Unprovoked           AUSTRALIA
# 5747     ND.0003 1900-01-01     0.0  Unprovoked                 USA
# 5748     ND.0001 1845-01-01     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5745 entries, 0 to 5748
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case_Number             5745 non-null   object
#  1   Date                    5745 non-null   datetime64[ns]
#  2   Year                    5743 non-null   float64
#  3   Type                    5743 non-null   object
#  4   Country                 5745 non-null   object
#  5   Area                    5745 non-null   object
#  6   Location                5463 non-null   object
#  7   Activity                5298 non-null   object
#  8   Name                    5582 non-null   object
#  9   Sex                     5261 non-null   object
#  10  Age                     3295 non-null   Int64
#  11  Injury                  5745 non-null   object
#  12  Fatal_(Y/N)             5745 non-null   bool
#  13  Time                    2852 non-null   object
# ...

# %%
col_names = ['Case_Number.1','Case_Number.2','Case_Number','Year','original_order','Date2', 'Time']
sharks_clean.drop(col_names, inplace = True, axis = 1)
#dropeamos columnas innecesarias

# %%
#sharks_clean.to_csv('comparacion.csv')

# %%
sharks_clean['Name'] = sharks_clean['Name'].fillna('Anonymous')
#en name los valores vacios se llenaron con anonimo

# %%
sharks_clean['Sex'] = sharks_clean['Sex'].str.strip()
sharks_clean['Sex'].unique()

#Ahora comenzamos con el tratamiento de la columna 'Sex'
# Out:
# array(['F', 'M', nan, 'lli', 'N', '.'], dtype=object)

# %%
Gender_transform = {'N' : 'UNKNOWN', '.':'UNKNOWN', 'lli': 'UNKNOWN'}
sharks_clean['Sex'].fillna('UNKNOWN', inplace = True)
sharks_clean['Sex'].replace(Gender_transform, inplace=True)
#Valores vacios y celdas en Gender_transform se remplazaron por string UNKNOWN

# %%
sharks_clean['Sex'].unique()
# Out:
# array(['F', 'M', 'UNKNOWN'], dtype=object)

# %%
#sharks_clean.to_csv('comparacion.csv')

# %%
sharks_clean.drop([4826, 3627], axis=0, inplace=True) #valores atipicos
sharks_clean['Investigator_or_Source'].fillna('No_Source', inplace = True)
sharks_clean
#Con la celda de Investigador se remplazaron vacios por No_Source
# Out:
#            Date        Type             Country               Area  \
# 0    2018-06-25     Boating                 USA         California
# 1    2018-06-18  Unprovoked                 USA            Georgia
# 2    2018-06-09     Invalid                 USA             Hawaii
# 3    2018-06-08  Unprovoked           AUSTRALIA    New South Wales
# 4    2018-06-04    Provoked              MEXICO             Colima
# ...         ...         ...                 ...                ...
# 5744 1906-01-01  Unprovoked           AUSTRALIA    New South Wales
# 5745 1903-01-01  Unprovoked           AUSTRALIA  Western Australia
# 5746 1903-01-01  Unprovoked           AUSTRALIA  Western Australia
# 5747 1900-01-01  Unprovoked                 USA     North Carolina
# 5748 1845-01-01  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 0             Oceanside, San Diego County      Paddling
# ...

# %%
sharks_clean.reset_index(inplace=True , drop=True)
j = 0
for i in sharks_clean['Activity']:
    i = str(i)
    if 'ing' in i:
        re_list = (re.findall(r"[A-Za-z]+(?:ing)" , i))
        sharks_clean['Activity'][j] = re_list[-1]
    j = j + 1
    


    
#Obtenemos en el ciclo for los verbos gerundios en la columna de 'Activity'
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_7212\1179997966.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks_clean['Activity'][j] = re_list[-1]

# %%
sharks_clean.to_csv('comparacion.csv')

# %%
sharks_clean['Species'].fillna('Unidentified',inplace = True)
#Colocamos especies no identificadas para valores vacios

# %%
sharks_clean
# Out:
#            Date        Type             Country               Area  \
# 0    2018-06-25     Boating                 USA         California
# 1    2018-06-18  Unprovoked                 USA            Georgia
# 2    2018-06-09     Invalid                 USA             Hawaii
# 3    2018-06-08  Unprovoked           AUSTRALIA    New South Wales
# 4    2018-06-04    Provoked              MEXICO             Colima
# ...         ...         ...                 ...                ...
# 5738 1906-01-01  Unprovoked           AUSTRALIA    New South Wales
# 5739 1903-01-01  Unprovoked           AUSTRALIA  Western Australia
# 5740 1903-01-01  Unprovoked           AUSTRALIA  Western Australia
# 5741 1900-01-01  Unprovoked                 USA     North Carolina
# 5742 1845-01-01  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location  Activity                   Name  \
# 0             Oceanside, San Diego County  Paddling            Julie Wolfe
# ...

# %%
sharks_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5743 entries, 0 to 5742
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    5743 non-null   datetime64[ns]
#  1   Type                    5741 non-null   object
#  2   Country                 5743 non-null   object
#  3   Area                    5743 non-null   object
#  4   Location                5461 non-null   object
#  5   Activity                5296 non-null   object
#  6   Name                    5743 non-null   object
#  7   Sex                     5743 non-null   object
#  8   Age                     3295 non-null   Int64
#  9   Injury                  5743 non-null   object
#  10  Fatal_(Y/N)             5743 non-null   bool
#  11  Species                 5743 non-null   object
#  12  Investigator_or_Source  5743 non-null   object
#  13  pdf                     5743 non-null   object
# ...

# %%
#El resultado final es el csv comparacion que esta comprendido en la carpeta
#la base de datos utilizo criterios propios y los presentados en las instrucciones del lab
#pasos siguientes:
#borrar codigo no necesario y visualizaciones
#crear funciones e instrucciones para dichas funciones y orientarlo a objetos
