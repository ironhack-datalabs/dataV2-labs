# %% [markdown]
# # Project 3 Data Cleaning: Sharks attacks

# %% [markdown]
# ## Modules used

# %%
import pandas as pd
import numpy as np
import re
import itertools

# %% [markdown]
# ## Dataset import and exploration

# %%
df = pd.read_csv('./attacks.csv', encoding='ISO-8859-1')
df_clean = df.copy()
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
def check_nulls():
    return df_clean.isnull().mean() * 100
check_nulls()
# Out:
# Case Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal (Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator or Source    75.566614
# pdf                       75.500525
# href formula              75.504412
# href                      75.500525
# Case Number.1             75.500525
# Case Number.2             75.500525
# original order            75.473312
# Unnamed: 22               99.996112
# Unnamed: 23               99.992225
# dtype: float64

# %% [markdown]
# ## Changes on columns name to avoid whitespaces.

# %%
df_clean.columns = df_clean.columns.str.strip().str.lower()
df_clean.columns = df_clean.columns.str.replace(" ","_")
df_clean.columns
# Out:
# Index(['case_number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'injury', 'fatal_(y/n)', 'time',
#        'species', 'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number.1', 'case_number.2', 'original_order', 'unnamed:_22',
#        'unnamed:_23'],
#       dtype='object')

# %% [markdown]
# ## Nulls columns cleanse:
# ### Since  the dataset have columns Unnamed:22 and Unnamed: 23 with almost entirely null values, they are ment to be dropped.

# %%
null_columns = df_clean.isnull().mean() * 100
null_columns = null_columns[null_columns > 99]
null_columns_eliminate = list(null_columns.index)
df_clean = df_clean.drop(null_columns_eliminate, axis=1)

# %% [markdown]
# ### Due to country, area and location columns have a large portion of null data. The efforts to reduce data were aimed in reduce as many rows as possible with null data

# %%
df_clean[['country','area', 'location']].isna()
# Out:
#        country   area  location
# 0        False  False     False
# 1        False  False     False
# 2        False  False     False
# 3        False  False     False
# 4        False  False     False
# ...        ...    ...       ...
# 25718     True   True      True
# 25719     True   True      True
# 25720     True   True      True
# 25721     True   True      True
# 25722     True   True      True
#
# [25723 rows x 3 columns]

# %%
cleaning_country_area_location = df_clean[(df_clean['country'].isna()) & (df_clean['area'].isna()) & (df_clean['location'].isna())].index
df_clean = df_clean.drop(cleaning_country_area_location, axis=0)

# %%
only_area = (df_clean['location'].isna()) & (df_clean['country'].isna())
only_country = (df_clean['location'].isna()) & (df_clean['area'].isna())
only_location = (df_clean['country'].isna()) & (df_clean['area'].isna())
excluding_area = (df_clean['area'].isna())
filter_cleaned = df_clean[(only_area) | (only_country) | (only_location) | (excluding_area) ].index

df_clean = df_clean.drop(filter_cleaned, axis=0)
df_clean[df_clean['country'].isna()]
# Out:
#        case_number                  date    year          type country  \
# 3387    1970.08.02           02-Aug-1970  1970.0       Invalid     NaN
# 4266  1956.00.00.g                  1956  1956.0  Sea Disaster     NaN
# 4498  1949.12.00.b              Dec-1949  1949.0  Sea Disaster     NaN
# 5020  1931.04.27.R  Reported 27-Apr-1931  1931.0    Unprovoked     NaN
# 6137    1787.07.05           05-Jul-1787  1787.0    Unprovoked     NaN
#
#                               area                     location  \
# 3387                 Caribbean Sea    Between St. Kitts & Nevis
# 4266  Between Comores & Madagascar                  Geyser Bank
# 4498                 Caribbean Sea  Between  Cuba  & Costa Rica
# 5020   French Southern Territories               Île Saint-Paul
# 6137                     St Helena                Landing Place
#
#                                             activity  \
# 3387     Sea Disaster Sinking of ferryboat Christina
# 4266                                       Shipwreck
# 4498  Sea Disaster, sinking of the motorship Wingate
# 5020                          Fishing, boat capsized
# 6137                                        Swimming
#
#                                                   name  sex  ... fatal_(y/n)  \
# 3387                                               NaN  NaN  ...         NaN
# 4266  Captain Eric Hunt, the cook & a French passenger    M  ...           Y
# 4498               Albert Battles, James Dean & 4 crew    M  ...           Y
# 5020                                         Quillezic    M  ...           Y
# 6137                            Private Isaac Hicksled    M  ...           Y
#
#            time                                            species  \
# 3387  Afternoon  Shark involvement prior to death was not confi...
# 4266        NaN                                                NaN
# 4498        NaN                    Shark involvement not confirmed
# 5020        NaN                                                NaN
# 6137        NaN                                                NaN
#
#                                  investigator_or_source  \
# 3387                        Rome News Tribune, 8/3/1970
# 4266                                       dinofish.com
# 4498                           Canberra Times, 1/6/1950
# 5020                       Los Angeles Times, 4/27/1931
# 6137  H.R. Janisch (1885), Extracts from the St. Hel...
#
#                                      pdf  \
# 3387  1970.08.02-Christina-ferryboat.pdf
# 4266          1956.00.00.g-Capt-Hunt.pdf
# 4498            1949.12.00.b-Wingate.pdf
# 5020          1931.04.27.R-Quillezic.pdf
# 6137             1787.07.05-Hicksled.pdf
#
#                                            href_formula  \
# 3387  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4266  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4498  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5020  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6137  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number.1  \
# 3387  http://sharkattackfile.net/spreadsheets/pdf_di...    1970.08.02
# 4266  http://sharkattackfile.net/spreadsheets/pdf_di...  1956.00.00.g
# 4498  http://sharkattackfile.net/spreadsheets/pdf_di...  1949.12.00.b
# 5020  http://sharkattackfile.net/spreadsheets/pdf_di...  1931.04.27.R
# 6137  http://sharkattackfile.net/spreadsheets/pdf_di...    1787.07.05
#
#      case_number.2 original_order
# 3387    1970.08.02         2916.0
# 4266  1956.00.00.g         2037.0
# 4498  1949.12.00.b         1805.0
# 5020  1931.04.27.R         1283.0
# 6137    1787.07.05          166.0
#
# [5 rows x 22 columns]

# %%
countries = {3387:'St. Kitts Nevis', 4266:'Madagascar', 4498:'Cuba', 5020:'France', 6137:'Cabo Verde'}

# dataframe.at[index,'column-name']='new value'


for key,country in countries.items():
    df_clean['country'][key] = country

df_clean[df_clean['country'].isna()]
# Out:
# /var/folders/dm/mxz6j4h90psdrp7fypj_85vm0000gn/T/ipykernel_2154/2591626311.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['country'][key] = country
# Empty DataFrame
# Columns: [case_number, date, year, type, country, area, location, activity, name, sex, age, injury, fatal_(y/n), time, species, investigator_or_source, pdf, href_formula, href, case_number.1, case_number.2, original_order]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_clean['age'].unique()
Age_list = ['Teen','28 & 26','46 & 34','28, 23 & 30','Teens','36 & 26','Â','6Â½','21 & ?','23 & 20','7      &    31','Elderly',
'Ca. 33','>50','adult','9 & 12','? & 19','23 & 26','(adult)','33 & 37','37, 67, 35, 27,  ? & 27','21, 34,24 & 35','30 & 32',
'50 & 30','17 & 35','X','"middle-age"','34 & 19','33 & 26','2 to 3 months','MAKE LINE GREEN','"young"','17 & 16','F','young','36 & 23',
'A.M.','?    &   14','2Â½','teen','Â','\xa0 ', ' ', '  ']

index_age=[]
unique_age=[]
for i in df_clean['age']:
    if i in Age_list:
        if i not in unique_age:
            index_age.append(list(df_clean.index[df_clean['age']==i]))
        unique_age.append(i)

index_age = list(itertools.chain.from_iterable(index_age))

df_clean= df_clean.drop(index_age, axis=0)
df_clean
# Out:
#      case_number         date    year        type             country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6296     ND.0006  Before 1906     0.0  Unprovoked           AUSTRALIA
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6296    New South Wales                                           Swimming
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        name sex  ... fatal_(y/n)           time  \
# 0               Julie Wolfe   F  ...           N          18h00
# 1           Adyson McNeely    F  ...           N  14h00  -15h00
# 2               John Denges   M  ...           N          07h45
# 3                      male   M  ...           N            NaN
# 4            Gustavo Ramos    M  ...           N            NaN
# ...                     ...  ..  ...         ...            ...
# 6296               Arab boy   M  ...           Y            NaN
# 6297                   male   M  ...           Y            NaN
# 6298                  Ahmun   M  ...           Y            NaN
# 6299  Coast Guard personnel   M  ...           Y            NaN
# 6301                   male   M  ...           Y            NaN
#
#                                                 species  \
# 0                                           White shark
# 1                                                   NaN
# 2                                                   NaN
# 3                                             2 m shark
# 4                                       Tiger shark, 3m
# ...                                                 ...
# 6296  Said to involve a grey nurse shark that leapt ...
# 6297                                                NaN
# 6298                                                NaN
# 6299                                                NaN
# 6301                                                NaN
#
#                                  investigator_or_source  \
# 0                                      R. Collier, GSAF
# 1                        K.McMurray, TrackingSharks.com
# 2                        K.McMurray, TrackingSharks.com
# 3                                        B. Myatt, GSAF
# 4                                             A .Kipper
# ...                                                 ...
# 6296  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 6297                   H. Taunton; N. Bartlett,  p. 234
# 6298              H. Taunton; N. Bartlett,  pp. 233-234
# 6299               F. Schwartz, p.23; C. Creswell, GSAF
# 6301                                         S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6296    ND-0006-ArabBoy-Prymount.pdf
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6296  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6296  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0006
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      case_number.2 original_order
# 0       2018.06.25         6303.0
# 1       2018.06.18         6302.0
# 2       2018.06.09         6301.0
# 3       2018.06.08         6300.0
# 4       2018.06.04         6299.0
# ...            ...            ...
# 6296       ND.0006            7.0
# 6297       ND.0005            6.0
# 6298       ND.0004            5.0
# 6299       ND.0003            4.0
# 6301       ND.0001            2.0
#
# [5784 rows x 22 columns]

# %%
age_dict={"20s" : 25, "40s" : 45,"60s": 65,"18 months": 2,"30s" : 35,"50s" : 55,"18 or 20" : 19,"12 or 13" : 13,
               "8 or 10": 9,"30 or 36" : 33,"33 or 37" : 35,"mid-30s" : 35,"60's" : 65, "16 to 18" : 17,"mid-20s" : 25,
               "21 or 26" : 24, "18 to 22" : 20,"9 months" : 1,"25 or 28" : 27,"13 or 18" : 15, "7 or 8": 8,"Both 11" : 11,
               "9 or 10" : 10,"10 or 12": 11,"31 or 33" : 32,"13 or 14" : 13,'6½': 6,' 30': 30,' 28': 28,'74 ':74, '45 ':45,
              '20 ':20, ' 43':43, '2½':2}

df_clean['age'].replace(age_dict, inplace=True)

# %%
df_clean['age'].unique()
df_clean['age'] = np.floor(pd.to_numeric(df_clean['age'], errors='coerce')).astype('Int64')
df_clean['age'].unique()
# Out:
# <IntegerArray>
# [  57,   11,   48, <NA>,   18,   52,   15,   12,   32,   10,   21,   34,   30,
#    60,   33,   29,   54,   41,   37,   56,   19,   25,   69,   38,   55,   35,
#    46,   45,   14,   28,   20,   24,   26,   49,   22,    7,   31,   17,   40,
#    13,   42,    3,    8,   50,   16,   82,   73,   68,   51,   39,   58,   47,
#    61,   65,   36,   66,   43,    9,   72,   59,    6,   27,   64,   23,   71,
#    44,   62,   63,   70,    2,   53,   74,    5,   86,   77,   84,   75,   87,
#    67,    1,   81,   78]
# Length: 82, dtype: Int64

# %%
injuried_cleaned = df_clean[df_clean['injury'].isna()]
index_list = injuried_cleaned.index.values.tolist()
df_clean= df_clean.drop(index_list, axis=0)
df_clean
# Out:
#      case_number         date    year        type             country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6296     ND.0006  Before 1906     0.0  Unprovoked           AUSTRALIA
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6296    New South Wales                                           Swimming
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        name sex  ...  fatal_(y/n)           time  \
# 0               Julie Wolfe   F  ...            N          18h00
# 1           Adyson McNeely    F  ...            N  14h00  -15h00
# 2               John Denges   M  ...            N          07h45
# 3                      male   M  ...            N            NaN
# 4            Gustavo Ramos    M  ...            N            NaN
# ...                     ...  ..  ...          ...            ...
# 6296               Arab boy   M  ...            Y            NaN
# 6297                   male   M  ...            Y            NaN
# 6298                  Ahmun   M  ...            Y            NaN
# 6299  Coast Guard personnel   M  ...            Y            NaN
# 6301                   male   M  ...            Y            NaN
#
#                                                 species  \
# 0                                           White shark
# 1                                                   NaN
# 2                                                   NaN
# 3                                             2 m shark
# 4                                       Tiger shark, 3m
# ...                                                 ...
# 6296  Said to involve a grey nurse shark that leapt ...
# 6297                                                NaN
# 6298                                                NaN
# 6299                                                NaN
# 6301                                                NaN
#
#                                  investigator_or_source  \
# 0                                      R. Collier, GSAF
# 1                        K.McMurray, TrackingSharks.com
# 2                        K.McMurray, TrackingSharks.com
# 3                                        B. Myatt, GSAF
# 4                                             A .Kipper
# ...                                                 ...
# 6296  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 6297                   H. Taunton; N. Bartlett,  p. 234
# 6298              H. Taunton; N. Bartlett,  pp. 233-234
# 6299               F. Schwartz, p.23; C. Creswell, GSAF
# 6301                                         S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6296    ND-0006-ArabBoy-Prymount.pdf
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6296  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6296  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0006
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      case_number.2 original_order
# 0       2018.06.25         6303.0
# 1       2018.06.18         6302.0
# 2       2018.06.09         6301.0
# 3       2018.06.08         6300.0
# 4       2018.06.04         6299.0
# ...            ...            ...
# 6296       ND.0006            7.0
# 6297       ND.0005            6.0
# 6298       ND.0004            5.0
# 6299       ND.0003            4.0
# 6301       ND.0001            2.0
#
# [5762 rows x 22 columns]

# %%
df_clean['fatal_(y/n)'][df_clean['fatal_(y/n)'] == 'Y'] = True 
df_clean['fatal_(y/n)'][(df_clean['injury'] == 'Fatal') | (df_clean['injury'] == 'Fatal')] = False 
df_clean['fatal_(y/n)'][(df_clean['fatal_(y/n)']  == 'N') | (df_clean['fatal_(y/n)']  == ' N') | (df_clean['fatal_(y/n)'] == 'N ')] = False
df_clean['fatal_(y/n)'].unique()
# Out:
# /var/folders/dm/mxz6j4h90psdrp7fypj_85vm0000gn/T/ipykernel_2154/3993754127.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['fatal_(y/n)'][df_clean['fatal_(y/n)'] == 'Y'] = True
# /var/folders/dm/mxz6j4h90psdrp7fypj_85vm0000gn/T/ipykernel_2154/3993754127.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['fatal_(y/n)'][(df_clean['injury'] == 'Fatal') | (df_clean['injury'] == 'Fatal')] = False
# /var/folders/dm/mxz6j4h90psdrp7fypj_85vm0000gn/T/ipykernel_2154/3993754127.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['fatal_(y/n)'][(df_clean['fatal_(y/n)']  == 'N') | (df_clean['fatal_(y/n)']  == ' N') | (df_clean['fatal_(y/n)'] == 'N ')] = False
# array([False, True, nan, 'M', 'UNKNOWN', '2017'], dtype=object)

# %%
df_clean.reset_index(inplace=True, drop=True)
key_words =['mortem','killed','Human','human', 'death','Death','disap','Disap','drown','Drown','Missing','missing',
'recovered','Forensic','body','bodies','corpse','decap','Decap','perish','remains']

pil=[]
j=0
for word in key_words:
    j = 0
    for i in df_clean['injury']:
        if word in i:
            pil.append(j)
            df_clean['fatal_(y/n)'][j] = True
        j = j + 1
        
pil_listset=list(set(pil))

fatal_dict={'M' : False, 'UNKNOWN':False, '2017': False}
df_clean['fatal_(y/n)'].fillna(False, inplace = True)
df_clean['fatal_(y/n)'].replace(fatal_dict, inplace=True)
# Out:
# /var/folders/dm/mxz6j4h90psdrp7fypj_85vm0000gn/T/ipykernel_2154/19689481.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['fatal_(y/n)'][j] = True

# %%
# dates = df_clean['Date'].str.replace('Before','').replace('Reported','').replace('--','-',regex=True).replace('190Feb-2010', '19-Feb-2010',regex=True).replace('Late', '', regex=True).replace('Fall', '', regex=True).replace('Summer-2008')
# df_clean['Date'] = dates
# pd.to_datetime(df_clean['Date'])
df_clean['date2'] = df_clean['date']
df_clean['date3'] = df_clean['case_number']

def cast_date(date):
    date = str(date).strip()
    date = date[:10].replace('.','-')
    if date.endswith('00'):
        date = list(date)
        date[-1] = '1'
        return  "".join(date)
    return date
    

df_clean['date'] = df_clean['case_number'].apply(cast_date)


df_clean.to_csv('comp.csv')
# df_clean[df_clean['Date2'].str.contains('ND-00')]


# date_cleaned=df_clean['Date'].str.replace('.', '-')
# df_clean['Date'] = date_cleaned
# df_clean[['Date', 'Case_Number']].head(50)

# %%
df_clean

check_nulls()
# Out:
# case_number                0.017355
# date                       0.000000
# year                       0.034710
# type                       0.034710
# country                    0.000000
# area                       0.000000
# location                   4.946199
# activity                   7.775078
# name                       2.846234
# sex                        8.399861
# age                       42.814995
# injury                     0.000000
# fatal_(y/n)                0.000000
# time                      50.503297
# species                   43.387713
# investigator_or_source     0.242971
# pdf                        0.000000
# href_formula               0.017355
# href                       0.000000
# case_number.1              0.000000
# case_number.2              0.000000
# original_order             0.000000
# date2                      0.000000
# date3                      0.017355
# dtype: float64

# %%
## Warning 
nd_values = df_clean[df_clean['case_number'].str.contains('ND', na=False)]
index = df_clean[df_clean['case_number'].str.contains('ND', na=False)].index
index = list(index)
nd_values

for i in index:
    if any(chr.isdigit() for chr in df_clean['date2'][i] )== False:
        df_clean['date2'][i] = None
    
    else:   
         df_clean['date2'][i] = re.findall(r'[0-9]{4}',df_clean['date2'][i])[0]
# Out:
# /var/folders/dm/mxz6j4h90psdrp7fypj_85vm0000gn/T/ipykernel_2154/4131220797.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['date2'][i] = re.findall(r'[0-9]{4}',df_clean['date2'][i])[0]
# /var/folders/dm/mxz6j4h90psdrp7fypj_85vm0000gn/T/ipykernel_2154/4131220797.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['date2'][i] = None

# %%
df_clean[df_clean['date2'].isna()].index
df_clean = df_clean.drop(df_clean[df_clean['date2'].isna()].index, axis=0)
df_clean[df_clean['date2'].isna()].index
df_clean
# Out:
#      case_number        date    year        type             country  \
# 0     2018.06.25  2018-06-25  2018.0     Boating                 USA
# 1     2018.06.18  2018-06-18  2018.0  Unprovoked                 USA
# 2     2018.06.09  2018-06-09  2018.0     Invalid                 USA
# 3     2018.06.08  2018-06-08  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  2018-06-04  2018.0    Provoked              MEXICO
# ...          ...         ...     ...         ...                 ...
# 5757     ND.0006     ND-0006     0.0  Unprovoked           AUSTRALIA
# 5758     ND.0005     ND-0005     0.0  Unprovoked           AUSTRALIA
# 5759     ND.0004     ND-0004     0.0  Unprovoked           AUSTRALIA
# 5760     ND.0003     ND-0003     0.0  Unprovoked                 USA
# 5761     ND.0001     ND-0001     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 5757    New South Wales                                           Swimming
# 5758  Western Australia                          Roebuck Bay        Diving
# 5759  Western Australia                                  NaN  Pearl diving
# 5760     North Carolina                       Ocracoke Inlet      Swimming
# 5761   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        name sex  ...  \
# 0               Julie Wolfe   F  ...
# 1           Adyson McNeely    F  ...
# 2               John Denges   M  ...
# 3                      male   M  ...
# 4            Gustavo Ramos    M  ...
# ...                     ...  ..  ...
# 5757               Arab boy   M  ...
# 5758                   male   M  ...
# 5759                  Ahmun   M  ...
# 5760  Coast Guard personnel   M  ...
# 5761                   male   M  ...
#
#                                                 species  \
# 0                                           White shark
# 1                                                   NaN
# 2                                                   NaN
# 3                                             2 m shark
# 4                                       Tiger shark, 3m
# ...                                                 ...
# 5757  Said to involve a grey nurse shark that leapt ...
# 5758                                                NaN
# 5759                                                NaN
# 5760                                                NaN
# 5761                                                NaN
#
#                                  investigator_or_source  \
# 0                                      R. Collier, GSAF
# 1                        K.McMurray, TrackingSharks.com
# 2                        K.McMurray, TrackingSharks.com
# 3                                        B. Myatt, GSAF
# 4                                             A .Kipper
# ...                                                 ...
# 5757  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 5758                   H. Taunton; N. Bartlett,  p. 234
# 5759              H. Taunton; N. Bartlett,  pp. 233-234
# 5760               F. Schwartz, p.23; C. Creswell, GSAF
# 5761                                         S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 5757    ND-0006-ArabBoy-Prymount.pdf
# 5758          ND-0005-RoebuckBay.pdf
# 5759               ND-0004-Ahmun.pdf
# 5760  ND-0003-Ocracoke_1900-1905.pdf
# 5761              ND-0001-Ceylon.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5757  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5758  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5759  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5760  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5761  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 5757  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0006
# 5758  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 5759  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 5760  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 5761  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      case_number.2 original_order        date2       date3
# 0       2018.06.25         6303.0  25-Jun-2018  2018.06.25
# 1       2018.06.18         6302.0  18-Jun-2018  2018.06.18
# 2       2018.06.09         6301.0  09-Jun-2018  2018.06.09
# 3       2018.06.08         6300.0  08-Jun-2018  2018.06.08
# 4       2018.06.04         6299.0  04-Jun-2018  2018.06.04
# ...            ...            ...          ...         ...
# 5757       ND.0006            7.0         1906     ND.0006
# 5758       ND.0005            6.0         1903     ND.0005
# 5759       ND.0004            5.0         1903     ND.0004
# 5760       ND.0003            4.0         1900     ND.0003
# 5761       ND.0001            2.0         1845     ND.0001
#
# [5754 rows x 24 columns]

# %%
df_clean.to_csv('comp.csv')

# %%
biased_elder_ages = df_clean[(df_clean['date'].str.startswith('000')) | (df_clean['date'] == 'nan')].index
print(biased_elder_ages)

df_clean = df_clean.drop(biased_elder_ages, axis=0)
df_clean
# Out:
# Int64Index([5109, 5664, 5665, 5666, 5667], dtype='int64')
#      case_number        date    year        type             country  \
# 0     2018.06.25  2018-06-25  2018.0     Boating                 USA
# 1     2018.06.18  2018-06-18  2018.0  Unprovoked                 USA
# 2     2018.06.09  2018-06-09  2018.0     Invalid                 USA
# 3     2018.06.08  2018-06-08  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  2018-06-04  2018.0    Provoked              MEXICO
# ...          ...         ...     ...         ...                 ...
# 5757     ND.0006     ND-0006     0.0  Unprovoked           AUSTRALIA
# 5758     ND.0005     ND-0005     0.0  Unprovoked           AUSTRALIA
# 5759     ND.0004     ND-0004     0.0  Unprovoked           AUSTRALIA
# 5760     ND.0003     ND-0003     0.0  Unprovoked                 USA
# 5761     ND.0001     ND-0001     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 5757    New South Wales                                           Swimming
# 5758  Western Australia                          Roebuck Bay        Diving
# 5759  Western Australia                                  NaN  Pearl diving
# 5760     North Carolina                       Ocracoke Inlet      Swimming
# 5761   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        name sex  ...  \
# 0               Julie Wolfe   F  ...
# 1           Adyson McNeely    F  ...
# 2               John Denges   M  ...
# 3                      male   M  ...
# 4            Gustavo Ramos    M  ...
# ...                     ...  ..  ...
# 5757               Arab boy   M  ...
# 5758                   male   M  ...
# 5759                  Ahmun   M  ...
# 5760  Coast Guard personnel   M  ...
# 5761                   male   M  ...
#
#                                                 species  \
# 0                                           White shark
# 1                                                   NaN
# 2                                                   NaN
# 3                                             2 m shark
# 4                                       Tiger shark, 3m
# ...                                                 ...
# 5757  Said to involve a grey nurse shark that leapt ...
# 5758                                                NaN
# 5759                                                NaN
# 5760                                                NaN
# 5761                                                NaN
#
#                                  investigator_or_source  \
# 0                                      R. Collier, GSAF
# 1                        K.McMurray, TrackingSharks.com
# 2                        K.McMurray, TrackingSharks.com
# 3                                        B. Myatt, GSAF
# 4                                             A .Kipper
# ...                                                 ...
# 5757  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 5758                   H. Taunton; N. Bartlett,  p. 234
# 5759              H. Taunton; N. Bartlett,  pp. 233-234
# 5760               F. Schwartz, p.23; C. Creswell, GSAF
# 5761                                         S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 5757    ND-0006-ArabBoy-Prymount.pdf
# 5758          ND-0005-RoebuckBay.pdf
# 5759               ND-0004-Ahmun.pdf
# 5760  ND-0003-Ocracoke_1900-1905.pdf
# 5761              ND-0001-Ceylon.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5757  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5758  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5759  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5760  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5761  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 5757  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0006
# 5758  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 5759  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 5760  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 5761  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      case_number.2 original_order        date2       date3
# 0       2018.06.25         6303.0  25-Jun-2018  2018.06.25
# 1       2018.06.18         6302.0  18-Jun-2018  2018.06.18
# 2       2018.06.09         6301.0  09-Jun-2018  2018.06.09
# 3       2018.06.08         6300.0  08-Jun-2018  2018.06.08
# 4       2018.06.04         6299.0  04-Jun-2018  2018.06.04
# ...            ...            ...          ...         ...
# 5757       ND.0006            7.0         1906     ND.0006
# 5758       ND.0005            6.0         1903     ND.0005
# 5759       ND.0004            5.0         1903     ND.0004
# 5760       ND.0003            4.0         1900     ND.0003
# 5761       ND.0001            2.0         1845     ND.0001
#
# [5749 rows x 24 columns]

# %%
def parse_date(row):
    row = str(row)
    if row[4:8] == '-00-':
#         print(row)
        row = list(row)
        row[6] = '1'
        print("".join(row))
        return  "".join(row)
    else:
        return row
        

df_clean['date'] = df_clean['date'].apply(parse_date)

df_clean.loc[550]
# Out:
# 2014-01-01
# 2008-01-01
# 2008-01-01
# 2004-01-01
# 2000-01-01
# 1999-01-01
# 1999-01-01
# 1998-01-01
# 1998-01-01
# 1998-01-01
# 1996-01-01
# 1996-01-01
# 1995-01-01
# 1995-01-01
# 1995-01-01
# 1994-01-01
# 1993-01-01
# 1993-01-01
# 1993-01-01
# 1993-01-01
# 1992-01-01
# 1989-01-01
# 1989-01-01
# 1988-01-01
# 1987-01-01
# 1987-01-01
# 1986-01-01
# 1985-01-01
# 1984-01-01
# 1984-01-01
# 1983-01-01
# 1983-01-01
# 1982-01-01
# 1982-01-01
# 1982-01-01
# 1981-01-01
# 1981-01-01
# 1980-01-01
# 1980-01-01
# 1980-01-01
# 1979-01-01
# 1978-01-01
# 1978-01-01
# 1976-01-01
# 1974-01-01
# 1974-01-01
# 1973-01-01
# 1973-01-01
# 1973-01-01
# 1972-01-01
# 1972-01-01
# 1971-01-01
# 1971-01-01
# 1971-01-01
# 1970-01-01
# 1970-01-01
# 1970-01-01
# 1970-01-01
# 1970-01-01
# 1970-01-01
# 1970-01-01
# 1970-01-01
# 1969-01-01
# 1968-01-01
# 1968-01-01
# 1966-01-01
# 1965-01-01
# 1965-01-01
# 1965-01-01
# 1965-01-01
# 1965-01-01
# 1963-01-01
# 1962-01-01
# 1962-01-01
# 1962-01-01
# 1961-01-01
# 1961-01-01
# 1961-01-01
# 1960-01-01
# 1960-01-01
# 1960-01-01
# 1960-01-01
# 1960-01-01
# 1960-01-01
# 1960-01-01
# 1960-01-01
# 1960-01-01
# 1959-01-01
# 1959-01-01
# 1959-01-01
# 1959-01-01
# 1959-01-01
# 1959-01-01
# 1958-01-01
# 1958-01-01
# 1958-01-01
# 1958-01-01
# 1958-01-01
# 1958-01-01
# 1958-01-01
# 1958-01-01
# 1958-01-01
# 1957-01-01
# 1957-01-01
# 1957-01-01
# 1957-01-01
# 1957-01-01
# 1957-01-01
# 1957-01-01
# 1957-01-01
# 1957-01-01
# 1957-01-01
# 1956-01-01
# 1956-01-01
# 1956-01-01
# 1956-01-01
# 1956-01-01
# 1956-01-01
# 1956-01-01
# 1956-01-01
# 1955-01-01
# 1955-01-01
# 1955-01-01
# 1955-01-01
# 1955-01-01
# 1955-01-01
# 1954-01-01
# 1954-01-01
# 1954-01-01
# 1954-01-01
# 1954-01-01
# 1954-01-01
# 1953-01-01
# 1953-01-01
# 1952-01-01
# 1952-01-01
# 1952-01-01
# 1952-01-01
# 1952-01-01
# 1951-01-01
# 1950-01-01
# 1950-01-01
# 1950-01-01
# 1950-01-01
# 1950-01-01
# 1950-01-01
# 1950-01-01
# 1950-01-01
# 1950-01-01
# 1950-01-01
# 1950-01-01
# 1949-01-01
# 1949-01-01
# 1949-01-01
# 1949-01-01
# 1949-01-01
# 1949-01-01
# 1949-01-01
# 1948-01-01
# 1948-01-01
# 1948-01-01
# 1948-01-01
# 1946-01-01
# 1946-01-01
# 1946-01-01
# 1945-01-01
# 1945-01-01
# 1945-01-01
# 1944-01-01
# 1944-01-01
# 1943-01-01
# 1943-01-01
# 1943-01-01
# 1943-01-01
# 1942-01-01
# 1942-01-01
# 1942-01-01
# 1942-01-01
# 1942-01-01
# 1942-01-01
# 1942-01-01
# 1942-01-01
# 1941-01-01
# 1941-01-01
# 1941-01-01
# 1941-01-01
# 1941-01-01
# 1941-01-01
# 1940-01-01
# 1940-01-01
# 1940-01-01
# 1940-01-01
# 1940-01-01
# 1940-01-01
# 1939-01-01
# 1939-01-01
# 1939-01-01
# 1939-01-01
# 1938-01-01
# 1938-01-01
# 1938-01-01
# 1938-01-01
# 1937-01-01
# 1936-01-01
# 1932-01-01
# 1931-01-01
# 1930-01-01
# 1929-01-01
# 1929-01-01
# 1929-01-01
# 1929-01-01
# 1929-01-01
# 1928-01-01
# 1927-01-01
# 1927-01-01
# 1926-01-01
# 1926-01-01
# 1926-01-01
# 1925-01-01
# 1923-01-01
# 1923-01-01
# 1923-01-01
# 1923-01-01
# 1920-01-01
# 1920-01-01
# 1920-01-01
# 1919-01-01
# 1918-01-01
# 1917-01-01
# 1915-01-01
# 1914-01-01
# 1913-01-01
# 1913-01-01
# 1913-01-01
# 1912-01-01
# 1911-01-01
# 1911-01-01
# 1910-01-01
# 1910-01-01
# 1909-01-01
# 1907-01-01
# 1907-01-01
# 1905-01-01
# 1904-01-01
# 1904-01-01
# 1903-01-01
# 1901-01-01
# 1900-01-01
# 1900-01-01
# 1899-01-01
# 1899-01-01
# 1899-01-01
# 1898-01-01
# 1898-01-01
# 1898-01-01
# 1898-01-01
# 1898-01-01
# 1898-01-01
# 1898-01-01
# 1897-01-01
# 1896-01-01
# 1896-01-01
# 1895-01-01
# 1893-01-01
# 1892-01-01
# 1890-01-01
# 1890-01-01
# 1890-01-01
# 1890-01-01
# 1890-01-01
# 1888-01-01
# 1887-01-01
# 1886-01-01
# 1883-01-01
# 1883-01-01
# 1883-01-01
# 1882-01-01
# 1882-01-01
# 1881-01-01
# 1880-01-01
# 1880-01-01
# 1880-01-01
# 1879-01-01
# 1878-01-01
# 1877-01-01
# 1876-01-01
# 1876-01-01
# 1876-01-01
# 1876-01-01
# 1875-01-01
# 1873-01-01
# 1872-01-01
# 1871-01-01
# 1871-01-01
# 1871-01-01
# 1870-01-01
# 1868-01-01
# 1868-01-01
# 1867-01-01
# 1865-01-01
# 1864-01-01
# 1864-01-01
# 1863-01-01
# 1862-01-01
# 1862-01-01
# 1855-01-01
# 1853-01-01
# 1853-01-01
# 1853-01-01
# 1853-01-01
# 1852-01-01
# 1851-01-01
# 1850-01-01
# 1847-01-01
# 1847-01-01
# 1847-01-01
# 1842-01-01
# 1842-01-01
# 1839-01-01
# 1839-01-01
# 1837-01-01
# 1836-01-01
# 1828-01-01
# 1825-01-01
# 1825-01-01
# 1800-01-01
# 1791-01-01
# 1767-01-01
# 1749-01-01
# 1748-01-01
# 1733-01-01
# 1700-01-01
# 1642-01-01
# 1595-01-01
# 1543-01-01
# case_number                                                    2014.00.00.b
# date                                                             2014-01-01
# year                                                                 2014.0
# type                                                             Unprovoked
# country                                                                 USA
# area                                                                 Hawaii
# location                                                                NaN
# activity                           Free diving / Photographing pilot whales
# name                                                                   male
# sex                                                                       M
# age                                                                    <NA>
# injury                                       "Minor laceration to shoulder"
# fatal_(y/n)                                                           False
# time                                                                    NaN
# species                                              Oceanic whitetip shark
# investigator_or_source                                             You Tube
# pdf                                        2014.00.00.b-OceanicWhitetip.pdf
# href_formula              http://sharkattackfile.net/spreadsheets/pdf_di...
# href                      http://sharkattackfile.net/spreadsheets/pdf_di...
# case_number.1                                                  2014.00.00.b
# case_number.2                                                  2014.00.00.b
# original_order                                                       5715.0
# date2                                                                  2014
# date3                                                          2014.00.00.b
# Name: 550, dtype: object

# %%
df_clean.reset_index(inplace=True, drop=True)

# %%
index = df_clean[df_clean['case_number'].str.contains('ND', na=False)].index
index = list(index)
for i in index:
    df_clean['date'][i] = df_clean['date2'][i]
# Out:
# /var/folders/dm/mxz6j4h90psdrp7fypj_85vm0000gn/T/ipykernel_2154/3189577804.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['date'][i] = df_clean['date2'][i]

# %%
df_clean['date'] = df_clean['date'].str.replace(',', '-')

# %%
df_clean['date'] = pd.to_datetime(df_clean['date'], errors='coerce')

dates_index = df_clean[df_clean['date'].isna()].index
df_clean = df_clean.drop(dates_index, axis=0)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5745 entries, 0 to 5748
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             5745 non-null   object
#  1   date                    5745 non-null   datetime64[ns]
#  2   year                    5743 non-null   float64
#  3   type                    5743 non-null   object
#  4   country                 5745 non-null   object
#  5   area                    5745 non-null   object
#  6   location                5463 non-null   object
#  7   activity                5298 non-null   object
#  8   name                    5582 non-null   object
#  9   sex                     5261 non-null   object
#  10  age                     3295 non-null   Int64
#  11  injury                  5745 non-null   object
#  12  fatal_(y/n)             5745 non-null   bool
#  13  time                    2852 non-null   object
#  14  species                 3261 non-null   object
#  15  investigator_or_source  5731 non-null   object
#  16  pdf                     5745 non-null   object
#  17  href_formula            5744 non-null   object
#  18  href                    5745 non-null   object
#  19  case_number.1           5745 non-null   object
#  20  case_number.2           5745 non-null   object
#  21  original_order          5745 non-null   float64
#  22  date2                   5745 non-null   object
#  23  date3                   5745 non-null   object
# dtypes: Int64(1), bool(1), datetime64[ns](1), float64(2), object(19)
# memory usage: 1.1+ MB

# %%
df_clean.drop(["case_number.1", "case_number.2", "case_number", "year", "original_order", "date2", "date3", "time"], axis=1, inplace=True)

# %%
df_clean[df_clean['name'].isna()]
# Out:
#            date        type       country                   area  \
# 80   2017-09-14     Boating     AUSTRALIA      Westerm Australia
# 116  2017-07-02     Invalid       COMOROS                Anjouan
# 144  2017-04-17  Unprovoked           USA                Florida
# 173  2017-01-13  Unprovoked     AUSTRALIA             Queensland
# 527  2014-05-04  Unprovoked  SOUTH AFRICA  Western Cape Province
# ...         ...         ...           ...                    ...
# 5649 1785-09-26  Unprovoked       ENGLAND                 Sussex
# 5656 1733-01-01     Invalid       ICELAND            Bardestrand
# 5666 1934-01-01  Unprovoked       URUGUAY                  Rocha
# 5674 2012-01-01  Unprovoked         SPAIN         Canary Islands
# 5733 1918-01-01  Unprovoked       REUNION            Saint-Denis
#
#                            location     activity name  sex   age  \
# 80                        Esperance      Fishing  NaN  NaN  <NA>
# 116                            Moya      Fishing  NaN  NaN  <NA>
# 144   Daytona Beach, Volusia County          NaN  NaN  NaN  <NA>
# 173                       Clairview     Swimming  NaN    M    57
# 527                      Simonstown       Diving  NaN  NaN  <NA>
# ...                             ...          ...  ...  ...   ...
# 5649                       Brighton          NaN  NaN    M  <NA>
# 5656                   Talkknefiord          NaN  NaN  NaN  <NA>
# 5666          Isla Chica, La Paloma     Swimming  NaN  NaN  <NA>
# 5674                       Tenerife  Skin diving  NaN  NaN  <NA>
# 5733                      Barachois     Swimming  NaN  NaN  <NA>
#
#                                                  injury  fatal_(y/n)  \
# 80          sharks rammed boats, no injury to occupants        False
# 116   Skull found in shark, a probable drowning & sc...         True
# 144                              Minor bite to the foot        False
# 173                                      Injury to hand        False
# 527                            4-inch laceration to arm        False
# ...                                                 ...          ...
# 5649                 Human remains recovered from shark         True
# 5656  Partial hominid remains recovered from shark, ...         True
# 5666                                        Foot bitten        False
# 5674                        Injury required 16 stitches        False
# 5733                                              FATAL         True
#
#                                              species  \
# 80                                 White shark, 3.5m
# 116   Shark involvement prior to death not confirmed
# 144                                              NaN
# 173                                              NaN
# 527                                        Cow shark
# ...                                              ...
# 5649                                    Tiger shark?
# 5656    Shark involvement prior to death unconfirmed
# 5666                                             NaN
# 5674                                             NaN
# 5733                                             NaN
#
#                      investigator_or_source                            pdf  \
# 80                           B. Myatt, GSAF  2017.09.14-EsperanceBoats.pdf
# 116                         Linfo, 7/3/2017         2017.07.02-Comoros.pdf
# 144   Daytona Beach News-Journal, 4/17/2017       2017.04.17.b-Volusia.pdf
# 173                Brisbane Times,1/13/2017     2017.01.13.b-Clairview.pdf
# 527                  Sunday Times, 5/5/2014        2015.05.04-CowShark.pdf
# ...                                     ...                            ...
# 5649                         C. Moore, GSAF      1785.09.26.R-Brighton.pdf
# 5656                             E. Olafsen         1733.00.00-Iceland.pdf
# 5666                        Di Candia, 2004            ND-0150-Uruguay.pdf
# 5674                         C. Moore, GSAF           ND-0129-Tenerife.pdf
# 5733                     G. Van Grevelynghe  ND-0024-Barachois-Reunion.pdf
#
#                                            href_formula  \
# 80    http://sharkattackfile.net/spreadsheets/pdf_di...
# 116   http://sharkattackfile.net/spreadsheets/pdf_di...
# 144   http://sharkattackfile.net/spreadsheets/pdf_di...
# 173   http://sharkattackfile.net/spreadsheets/pdf_di...
# 527   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5649  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5656  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5666  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5674  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5733  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href
# 80    http://sharkattackfile.net/spreadsheets/pdf_di...
# 116   http://sharkattackfile.net/spreadsheets/pdf_di...
# 144   http://sharkattackfile.net/spreadsheets/pdf_di...
# 173   http://sharkattackfile.net/spreadsheets/pdf_di...
# 527   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5649  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5656  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5666  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5674  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5733  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [163 rows x 16 columns]

# %%
df_clean['name'] = df_clean['name'].fillna('Anonymous')

# %%
df_clean['sex'] = df_clean['sex'].str.strip()
df_clean['sex'].unique()
df_clean['sex'].value_counts()
# Out:
# M      4649
# F       609
# lli       1
# N         1
# .         1
# Name: sex, dtype: int64

# %%
df_clean['sex'] = df_clean['sex'].fillna('Unknown')

def gender_identifier(row):
    identifiers = ['M', 'F', 'Unknown']
    if row not in identifiers:
        row = 'Unknown'
        return row
    else:
        return row


df_clean['sex'] = df_clean['sex'].apply(gender_identifier)

df_clean['sex'].value_counts()
# Out:
# M          4649
# F           609
# Unknown     487
# Name: sex, dtype: int64

# %%
df_clean['investigator_or_source']
# Out:
# 0                                        R. Collier, GSAF
# 1                          K.McMurray, TrackingSharks.com
# 2                          K.McMurray, TrackingSharks.com
# 3                                          B. Myatt, GSAF
# 4                                               A .Kipper
#                               ...
# 5744    L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 5745                     H. Taunton; N. Bartlett,  p. 234
# 5746                H. Taunton; N. Bartlett,  pp. 233-234
# 5747                 F. Schwartz, p.23; C. Creswell, GSAF
# 5748                                           S.W. Baker
# Name: investigator_or_source, Length: 5745, dtype: object

# %%
df_clean.drop([4826, 3627], axis=0, inplace=True)

# %%
df_clean['investigator_or_source'].fillna('no_source', inplace=True)

# %%
def finding_verbs_gerund(string):
    string = str(string)
    if 'ing' in string:
        new_word = re.findall(r"[A-Za-z]+(?:ing)", string)
        if len(new_word) > 1:
            return new_word[-1]
        else: 
            return ''.join(new_word)
    else:
        return string
    
df_clean['activity'] = df_clean['activity'].apply(finding_verbs_gerund)

# %%
df_clean['species'].fillna('Unidentified', inplace=True)

# %%
check_nulls()
# Out:
# date                       0.000000
# type                       0.034825
# country                    0.000000
# area                       0.000000
# location                   4.910326
# activity                   0.000000
# name                       0.000000
# sex                        0.000000
# age                       42.625805
# injury                     0.000000
# fatal_(y/n)                0.000000
# species                    0.000000
# investigator_or_source     0.000000
# pdf                        0.000000
# href_formula               0.017413
# href                       0.000000
# dtype: float64

# %%
df_clean
# Out:
#            date        type             country               area  \
# 0    2018-06-25     Boating                 USA         California
# 1    2018-06-18  Unprovoked                 USA            Georgia
# 2    2018-06-09     Invalid                 USA             Hawaii
# 3    2018-06-08  Unprovoked           AUSTRALIA    New South Wales
# 4    2018-06-04    Provoked              MEXICO             Colima
# ...         ...         ...                 ...                ...
# 5744 1906-01-01  Unprovoked           AUSTRALIA    New South Wales
# 5745 1903-01-01  Unprovoked           AUSTRALIA  Western Australia
# 5746 1903-01-01  Unprovoked           AUSTRALIA  Western Australia
# 5747 1900-01-01  Unprovoked                 USA     North Carolina
# 5748 1845-01-01  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  location  activity                   name  \
# 0             Oceanside, San Diego County  Paddling            Julie Wolfe
# 1          St. Simon Island, Glynn County  Standing        Adyson McNeely
# 2                            Habush, Oahu   Surfing            John Denges
# 3                      Arrawarra Headland   Surfing                   male
# 4                                La Ticla    diving         Gustavo Ramos
# ...                                   ...       ...                    ...
# 5744                                       Swimming               Arab boy
# 5745                          Roebuck Bay    Diving                   male
# 5746                                  NaN    diving                  Ahmun
# 5747                       Ocracoke Inlet  Swimming  Coast Guard personnel
# 5748  Below the English fort, Trincomalee  Swimming                   male
#
#      sex   age                                             injury  \
# 0      F    57  No injury to occupant, outrigger canoe and pad...
# 1      F    11                         Minor injury to left thigh
# 2      M    48       Injury to left lower leg from surfboard skeg
# 3      M  <NA>                          Minor injury to lower leg
# 4      M  <NA>  Lacerations to leg & hand shark PROVOKED INCIDENT
# ...   ..   ...                                                ...
# 5744   M  <NA>                                              FATAL
# 5745   M  <NA>                                              FATAL
# 5746   M  <NA>                                              FATAL
# 5747   M  <NA>                                              FATAL
# 5748   M    15  FATAL. "Shark bit him in half, carrying away t...
#
#       fatal_(y/n)                                            species  \
# 0           False                                        White shark
# 1           False                                       Unidentified
# 2           False                                       Unidentified
# 3           False                                          2 m shark
# 4           False                                    Tiger shark, 3m
# ...           ...                                                ...
# 5744         True  Said to involve a grey nurse shark that leapt ...
# 5745         True                                       Unidentified
# 5746         True                                       Unidentified
# 5747         True                                       Unidentified
# 5748         True                                       Unidentified
#
#                                  investigator_or_source  \
# 0                                      R. Collier, GSAF
# 1                        K.McMurray, TrackingSharks.com
# 2                        K.McMurray, TrackingSharks.com
# 3                                        B. Myatt, GSAF
# 4                                             A .Kipper
# ...                                                 ...
# 5744  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 5745                   H. Taunton; N. Bartlett,  p. 234
# 5746              H. Taunton; N. Bartlett,  pp. 233-234
# 5747               F. Schwartz, p.23; C. Creswell, GSAF
# 5748                                         S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 5744    ND-0006-ArabBoy-Prymount.pdf
# 5745          ND-0005-RoebuckBay.pdf
# 5746               ND-0004-Ahmun.pdf
# 5747  ND-0003-Ocracoke_1900-1905.pdf
# 5748              ND-0001-Ceylon.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5744  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5745  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5746  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5747  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5748  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5744  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5745  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5746  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5747  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5748  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [5743 rows x 16 columns]

# %%
check_nulls()
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5743 entries, 0 to 5748
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    5743 non-null   datetime64[ns]
#  1   type                    5741 non-null   object
#  2   country                 5743 non-null   object
#  3   area                    5743 non-null   object
#  4   location                5461 non-null   object
#  5   activity                5743 non-null   object
#  6   name                    5743 non-null   object
#  7   sex                     5743 non-null   object
#  8   age                     3295 non-null   Int64
#  9   injury                  5743 non-null   object
#  10  fatal_(y/n)             5743 non-null   bool
#  11  species                 5743 non-null   object
#  12  investigator_or_source  5743 non-null   object
#  13  pdf                     5743 non-null   object
#  14  href_formula            5742 non-null   object
#  15  href                    5743 non-null   object
# dtypes: Int64(1), bool(1), datetime64[ns](1), object(13)
# memory usage: 729.1+ KB
