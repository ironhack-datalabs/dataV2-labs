# %% [markdown]
# # Understanding Over & Underfitting
# ## Predicting Boston Housing Prices

# %% [markdown]
# ## Getting Started
# In this project, you will use the Boston Housing Prices dataset to build several models to predict the prices of homes with particular qualities from the suburbs of Boston, MA.
# We will build models with several different parameters, which will change the goodness of fit for each.

# %% [markdown]
# ---
# ## Data Exploration
# Since we want to predict the value of houses, the **target variable**, `'MEDV'`, will be the variable we seek to predict.

# %% [markdown]
# ### Import and explore the data. Clean the data for outliers and missing values.

# %%
import pandas as pd
df = pd.read_csv("../data/boston_data.csv")
df
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis   rad    tax  \
# 0     0.15876   0.0  10.81   0.0  0.413  5.961   17.5  5.2873   4.0  305.0
# 1     0.10328  25.0   5.13   0.0  0.453  5.927   47.2  6.9320   8.0  284.0
# 2     0.34940   0.0   9.90   0.0  0.544  5.972   76.7  3.1025   4.0  304.0
# 3     2.73397   0.0  19.58   0.0  0.871  5.597   94.9  1.5257   5.0  403.0
# 4     0.04337  21.0   5.64   0.0  0.439  6.115   63.0  6.8147   4.0  243.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 399   9.32909   0.0  18.10   0.0  0.713  6.185   98.7  2.2616  24.0  666.0
# 400  51.13580   0.0  18.10   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 401   0.01501  90.0   1.21   1.0  0.401  7.923   24.8  5.8850   1.0  198.0
# 402   0.02055  85.0   0.74   0.0  0.410  6.383   35.7  9.1876   2.0  313.0
# 403   0.08244  30.0   4.93   0.0  0.428  6.481   18.5  6.1899   6.0  300.0
#
#      ptratio   black  lstat  medv
# 0       19.2  376.94   9.88  21.7
# 1       19.7  396.90   9.22  19.6
# 2       18.4  396.24   9.97  20.3
# 3       14.7  351.85  21.45  15.4
# 4       16.8  393.97   9.43  20.5
# ..       ...     ...    ...   ...
# 399     20.2  396.90  18.13  14.1
# 400     20.2    2.60  10.11  15.0
# 401     13.6  395.52   3.16  50.0
# 402     17.3  396.90   5.77  24.7
# 403     16.6  379.41   6.36  23.7
#
# [404 rows x 14 columns]

# %% [markdown]
# ### Next, we want to explore the data. Pick several varibables you think will be most correlated with the prices of homes in Boston, and create plots that show the data dispersion as well as the regression line of best fit.

# %%
df.corr()
#I pick rm, lstat (as it is highly correlated in absolute terms) and tax (same reasoning as for Istat)
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.194770  0.404249 -0.060688  0.405290 -0.172226  0.349288
# zn      -0.194770  1.000000 -0.532268 -0.037290 -0.497114  0.302404 -0.546587
# indus    0.404249 -0.532268  1.000000  0.059928  0.760913 -0.353589  0.630048
# chas    -0.060688 -0.037290  0.059928  1.000000  0.100650  0.090146  0.084852
# nox      0.405290 -0.497114  0.760913  0.100650  1.000000 -0.266114  0.728882
# rm      -0.172226  0.302404 -0.353589  0.090146 -0.266114  1.000000 -0.210589
# age      0.349288 -0.546587  0.630048  0.084852  0.728882 -0.210589  1.000000
# dis     -0.376493  0.659018 -0.702583 -0.103124 -0.762469  0.178700 -0.734915
# rad      0.603044 -0.311313  0.616375 -0.022561  0.612115 -0.173222  0.467341
# tax      0.565047 -0.289332  0.722828 -0.043708  0.660607 -0.241733  0.503830
# ptratio  0.292092 -0.371315  0.356549 -0.121835  0.166715 -0.323330  0.231820
# black   -0.377436  0.176350 -0.378189  0.042580 -0.393876  0.128410 -0.276469
# lstat    0.428940 -0.412075  0.608309 -0.041061  0.587573 -0.578025  0.602001
# medv    -0.400956  0.355608 -0.501698  0.141400 -0.439225  0.683541 -0.390863
#
#               dis       rad       tax   ptratio     black     lstat      medv
# crim    -0.376493  0.603044  0.565047  0.292092 -0.377436  0.428940 -0.400956
# zn       0.659018 -0.311313 -0.289332 -0.371315  0.176350 -0.412075  0.355608
# indus   -0.702583  0.616375  0.722828  0.356549 -0.378189  0.608309 -0.501698
# chas    -0.103124 -0.022561 -0.043708 -0.121835  0.042580 -0.041061  0.141400
# nox     -0.762469  0.612115  0.660607  0.166715 -0.393876  0.587573 -0.439225
# rm       0.178700 -0.173222 -0.241733 -0.323330  0.128410 -0.578025  0.683541
# age     -0.734915  0.467341  0.503830  0.231820 -0.276469  0.602001 -0.390863
# dis      1.000000 -0.503471 -0.526938 -0.206016  0.306445 -0.500912  0.264876
# rad     -0.503471  1.000000  0.917344  0.487733 -0.468700  0.499279 -0.423508
# tax     -0.526938  0.917344  1.000000  0.465997 -0.462250  0.542732 -0.495792
# ptratio -0.206016  0.487733  0.465997  1.000000 -0.194891  0.351408 -0.506313
# black    0.306445 -0.468700 -0.462250 -0.194891  1.000000 -0.388913  0.360071
# lstat   -0.500912  0.499279  0.542732  0.351408 -0.388913  1.000000 -0.742695
# medv     0.264876 -0.423508 -0.495792 -0.506313  0.360071 -0.742695  1.000000

# %%
import seaborn as sns

sns.lmplot(x='lstat',y='medv', data=df ,fit_reg=True)
sns.lmplot(x='rm',y='medv', data=df ,fit_reg=True)
sns.lmplot(x='tax',y='medv', data=df ,fit_reg=True)

# %% [markdown]
# ### What do these plots tell you about the relationships between these variables and the prices of homes in Boston? Are these the relationships you expected to see in these variables?

# %%
#yes, they are as expected

# %% [markdown]
# ### Make a heatmap of the remaining variables. Are there any variables that you did not consider that have very high correlations? What are they?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = df.corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(18, 12))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, annot=True, vmax=1, vmin=-1, center=0,
square=True, linewidths=.5, cbar_kws={"shrink": .5})
# fix for mpl bug that cuts off top/bottom of seaborn viz
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.tight_layout()
plt.show() # ta-da!

# %%
#no actually, I considered the important variables. Of course there are others that are high too (ptratio for example)

# %% [markdown]
# ### Calculate Statistics
# Calculate descriptive statistics for housing price. Include the minimum, maximum, mean, median, and standard deviation.

# %%
df["medv"].describe()
# Out:
# count    404.000000
# mean      22.312376
# std        8.837019
# min        5.000000
# 25%       17.100000
# 50%       21.400000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %% [markdown]
# ----
#
# ## Developing a Model

# %% [markdown]
# ### Implementation: Define a Performance Metric
# What is the performance meteric with which you will determine the performance of your model? Create a function that calculates this performance metric, and then returns the score.

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    # Your code here:
    r2 = r2_score(y_true, y_predict)
    return r2

# %% [markdown]
# ### Implementation: Shuffle and Split Data
# Split the data into the testing and training datasets. Shuffle the data as well to remove any bias in selecting the traing and test.

# %%
from sklearn.model_selection import train_test_split

X = df[df.columns.difference(["medv"])] #columns.difference gives us all columns despite 
                                                                #for the specified one(s)
y = df["medv"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
display(X)
display(y)
# Out:
#        age   black  chas      crim     dis  indus  lstat    nox  ptratio  \
# 0     17.5  376.94   0.0   0.15876  5.2873  10.81   9.88  0.413     19.2
# 1     47.2  396.90   0.0   0.10328  6.9320   5.13   9.22  0.453     19.7
# 2     76.7  396.24   0.0   0.34940  3.1025   9.90   9.97  0.544     18.4
# 3     94.9  351.85   0.0   2.73397  1.5257  19.58  21.45  0.871     14.7
# 4     63.0  393.97   0.0   0.04337  6.8147   5.64   9.43  0.439     16.8
# ..     ...     ...   ...       ...     ...    ...    ...    ...      ...
# 399   98.7  396.90   0.0   9.32909  2.2616  18.10  18.13  0.713     20.2
# 400  100.0    2.60   0.0  51.13580  1.4130  18.10  10.11  0.597     20.2
# 401   24.8  395.52   1.0   0.01501  5.8850   1.21   3.16  0.401     13.6
# 402   35.7  396.90   0.0   0.02055  9.1876   0.74   5.77  0.410     17.3
# 403   18.5  379.41   0.0   0.08244  6.1899   4.93   6.36  0.428     16.6
#
#       rad     rm    tax    zn
# 0     4.0  5.961  305.0   0.0
# 1     8.0  5.927  284.0  25.0
# 2     4.0  5.972  304.0   0.0
# 3     5.0  5.597  403.0   0.0
# 4     4.0  6.115  243.0  21.0
# ..    ...    ...    ...   ...
# 399  24.0  6.185  666.0   0.0
# 400  24.0  5.757  666.0   0.0
# 401   1.0  7.923  198.0  90.0
# 402   2.0  6.383  313.0  85.0
# 403   6.0  6.481  300.0  30.0
#
# [404 rows x 13 columns]
# 0      21.7
# 1      19.6
# 2      20.3
# 3      15.4
# 4      20.5
#        ...
# 399    14.1
# 400    15.0
# 401    50.0
# 402    24.7
# 403    23.7
# Name: medv, Length: 404, dtype: float64

# %% [markdown]
# ----
#
# ## Analyzing Model Performance
# Next, we are going to build a Random Forest Regressor, and test its performance with several different parameter settings.

# %% [markdown]
# ### Learning Curves
# Lets build the different models. Set the max_depth parameter to 2, 4, 6, 8, and 10 respectively.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#calculating scores for train:
depths = [2,4,6,8,10]
score_train = []
score_test = []

for x in depths:
    rf = RandomForestRegressor(n_estimators=100, max_depth=x)
    rf.fit(X_train, y_train)
    y_train_pred = rf.predict(X_train)
    score_train_n = r2_score(y_train, y_train_pred)
    score_train.append(score_train_n)

score_train
# Out:
# [0.7791174844941419,
#  0.9130686286779064,
#  0.954292479227248,
#  0.9689893654837076,
#  0.9759638167301139]

# %%
#calculating scores for test:
depths = [2,4,6,8,10]
score_test = []

for x in depths:
    rf = RandomForestRegressor(n_estimators=100, max_depth=x)
    rf.fit(X_test, y_test)
    y_test_pred = rf.predict(X_test)
    score_test_n = r2_score(y_test, y_test_pred)
    score_test.append(score_test_n)
    
score_test
# Out:
# [0.8326015850518764,
#  0.9350879667007418,
#  0.962029805126764,
#  0.9593292672057305,
#  0.9669597470893804]

# %% [markdown]
# Now, plot the score for each tree on the training set and on the testing set.

# %%
#plotting
df = pd.DataFrame({'score_train': score_train,
                  'score_test': score_test}, index=depths)
ax = df.plot.bar()

# %% [markdown]
# What do these results tell you about the effect of the depth of the trees on the performance of the model?

# %%
# higher depth leads to a hgiher accuracy

# %% [markdown]
# ### Bias-Variance Tradeoff
# When the model is trained with a maximum depth of 1, does the model suffer from high bias or from high variance? How about when the model is trained with a maximum depth of 10?

# %%
#maxdepth=1: high bias, low variance
#maxdepth=10_ low bias, high variance

# %% [markdown]
# ### Best-Guess Optimal Model
# What is the max_depth parameter that you think would optimize the model? Run your model and explain its performance.

# %%
#I would say the optimum lies where score-train and score_test have almost the same r^2 score. As while on the one 
#hand r^2 score of the training data must be slightly higher, while on the other hand it shouldn't be too high
#compared to the test_set due to overfitting
#thus, my answer would be 7

rf = RandomForestRegressor(n_estimators=100, max_depth=7)
rf.fit(X_train, y_train)
y_train_pred = rf.predict(X_train)
score_train_n = r2_score(y_train, y_train_pred)

rf = RandomForestRegressor(n_estimators=100, max_depth=7)
rf.fit(X_test, y_test)
y_test_pred = rf.predict(X_test)
score_test_n = r2_score(y_test, y_test_pred)

# %%
print(score_train_n, score_test_n)
# Out:
# 0.9654662438925699 0.9569357840035283

# %% [markdown]
# ### Applicability
# *In a few sentences, discuss whether the constructed model should or should not be used in a real-world setting.*
# **Hint:** Some questions to answering:
# - *How relevant today is data that was collected from 1978?*
# - *Are the features present in the data sufficient to describe a home?*
# - *Is the model robust enough to make consistent predictions?*
# - *Would data collected in an urban city like Boston be applicable in a rural city?*

# %%
# the data is almost not relevant anymore. From a look at the codebook we can see that medv shall stand for 
# the price in thousands which is these days way higher.
#also the location might be due to better transport systems nowadays less relevant. Many socio-economic factors 
#have changed that influence the effect that feature have on the housing price
