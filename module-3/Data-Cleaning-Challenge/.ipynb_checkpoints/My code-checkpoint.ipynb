# %%
import pandas as pd
import numpy as np
import seaborn as ans
import matplotlib

# %%
iris = pd.read_csv(r"C:\Users\CLAUDIOCLEMENTE\Bootcamp\dataV2-labs\module-3\Data-Cleaning-Challenge\iris-data.csv")

# %%
iris
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
iris.dtypes
# Out:
# sepal_length_cm    float64
# sepal_width_cm     float64
# petal_length_cm    float64
# petal_width_cm     float64
# class               object
# dtype: object

# %%
iris.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
iris.isna().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     5
# class              0
# dtype: int64

# %%
iris.duplicated().sum()
# Out:
# 2

# %%
iris = iris.drop_duplicates(keep='last')

# %%
iris["sepal_length_cm"].hist(bins=150)

# %%
iris = iris.loc[iris["sepal_length_cm"]>=1]

# %%
iris["sepal_width_cm"].hist(bins=150)

# %%
iris["petal_length_cm"].hist(bins=150)

# %%
iris["petal_width_cm"].hist(bins=150)

# %%
iris["petal_width_cm"] = iris["petal_width_cm"].interpolate()

# %%
iris.isna().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     0
# class              0
# dtype: int64

# %%
iris["class"].hist()

# %%
iris["class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'versicolor',
#        'Iris-virginica'], dtype=object)

# %%
iris["class"] = np.where(iris["class"]=="Iris-setossa","Iris-setosa",\
                         np.where(iris["class"]=="versicolor","Iris-versicolor",iris["class"]))

# %%
iris["class"].hist()

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
g = sns.pairplot(iris)

# %%
g = sns.pairplot(iris, hue="class")

# %%
cleaned_iris = iris

# %%
cleaned_iris.to_csv(r"C:\Users\CLAUDIOCLEMENTE\Bootcamp\dataV2-labs\module-3\Data-Cleaning-Challenge\cleaned-iris-data.csv")
