# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("iris-data.csv", index_col=0)

# %%
iris.isna().sum()
# Out:
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     5
# class              0
# dtype: int64

# %%
iris.dtypes
# Out:
# sepal_width_cm     float64
# petal_length_cm    float64
# petal_width_cm     float64
# class               object
# dtype: object

# %%
iris["petal_width_cm"].mean()
# Out:
# 1.2365517241379318

# %%
iris["class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'versicolor',
#        'Iris-virginica'], dtype=object)

# %%
iris[iris["class"] == "Iris-virginica"].isna().sum()
# Out:
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     0
# class              0
# dtype: int64

# %%
my_list = []
for flower in iris["class"].unique(): 
    print(flower)
    temporary_df = iris[iris["class"] == flower]
    my_list.append(temporary_df.fillna(temporary_df["petal_width_cm"].mean()))
# Out:
# Iris-setosa
# Iris-setossa
# Iris-versicolor
# versicolor
# Iris-virginica

# %%
iris = pd.concat(my_list)
iris
# Out:
#                  sepal_width_cm  petal_length_cm  petal_width_cm  \
# sepal_length_cm
# 5.1                         3.5              1.4             0.2
# 4.9                         3.0              1.4             0.2
# 4.7                         3.2              1.3             0.2
# 4.6                         3.1              1.5             0.2
# 5.0                         3.6              1.4             0.2
# ...                         ...              ...             ...
# 6.7                         3.0              5.2             2.3
# 6.3                         2.5              5.0             2.3
# 6.5                         3.0              5.2             2.0
# 6.2                         3.4              5.4             2.3
# 5.9                         3.0              5.1             1.8
#
#                           class
# sepal_length_cm
# 5.1                 Iris-setosa
# 4.9                 Iris-setosa
# 4.7                 Iris-setosa
# ...

# %%
iris.plot.box()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib as plt

sns.pairplot(iris, hue = 'class')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.drop(["class"],axis=1), iris["class"],random_state = 0, test_size = 0.20)

# %%
y_test.shape
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn
# Out:
# KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(X_test)
y_predict
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa'], dtype=object)

# %%
y_test
# Out:
# sepal_length_cm
# 5.80     Iris-virginica
# 6.00    Iris-versicolor
# 4.90        Iris-setosa
# 7.30     Iris-virginica
# 5.00        Iris-setosa
# 6.30     Iris-virginica
# 4.50        Iris-setosa
# 6.70    Iris-versicolor
# 6.80    Iris-versicolor
# 6.10    Iris-versicolor
# 6.10     Iris-virginica
# 6.40    Iris-versicolor
# 6.10    Iris-versicolor
# 6.50    Iris-versicolor
# 6.10    Iris-versicolor
# 4.40        Iris-setosa
# 0.06    Iris-versicolor
# 5.50    Iris-versicolor
# 5.10        Iris-setosa
# 5.40        Iris-setosa
# 5.60     Iris-virginica
# 5.60    Iris-versicolor
# 5.00        Iris-setosa
# 4.40        Iris-setosa
# 6.20     Iris-virginica
# 5.10        Iris-setosa
# 4.80        Iris-setosa
# 6.20         versicolor
# 5.00    Iris-versicolor
# 5.20        Iris-setosa
# Name: class, dtype: object

# %%
knn.score(X_test, y_test)
# Out:
# 0.9666666666666667
