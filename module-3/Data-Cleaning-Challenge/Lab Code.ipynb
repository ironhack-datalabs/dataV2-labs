# %%
import pandas as pd

# %%
iris = pd.read_csv('iris-data.csv')
iris
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
##check the data is encoded/formatted properly
iris.dtypes

#they are all float which is what we wanted - so yes
# Out:
# sepal_length_cm    float64
# sepal_width_cm     float64
# petal_length_cm    float64
# petal_width_cm     float64
# class               object
# dtype: object

# %%
#Find any null values
iris.isna().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     5
# class              0
# dtype: int64

# %%
#we can see that petal_width_cm has null values which I have chosen to replace with the mean

#So finding the mean

iris["petal_width_cm"].mean()
# Out:
# 1.2365517241379318

# %%
iris.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
iris['petal_width_cm'].groupby(iris['class']).mean()
# Out:
# class
# Iris-setosa        0.250000
# Iris-setossa       0.300000
# Iris-versicolor    1.335556
# Iris-virginica     2.034000
# versicolor         1.240000
# Name: petal_width_cm, dtype: float64

# %%
#replacing null values with the mean of the class
iris['petal_width_cm'].fillna(iris['petal_width_cm'].groupby(iris['class']).mean())
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    2.3
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal_width_cm, Length: 150, dtype: float64

# %%
#check it's worked - null values are filled
iris.isna().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     0
# class              0
# dtype: int64

# %%
#We can see from the box plot that there are outliers/ they do not all fall within the expected mean? 
#I think pls confirm if this is correct or not?

iris.plot.box()

# %%
#visualise the data 

iris.hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000275D9D39370>,
# ...
#       dtype=object)

# %%
import seaborn as sns

sns.pairplot(iris, hue = 'class')
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\chris\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\chris\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\chris\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\chris\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
