# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located in the lab directory named `Sentiment140.csv.zip`. You need to unzip it into a `.csv` file. Then in the cell below, load and explore the data.
#
# *Notes:*
#
# * The dataset was downloaded from [Kaggle](https://www.kaggle.com/kazanova/sentiment140). We made a slight change on the original data so that each column has a label.
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer 
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/erinberardi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/erinberardi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/erinberardi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# your code here
sent = pd.read_csv('/Users/erinberardi/Downloads/Sentiment140.csv')
sample=sent.sample(n=10000, axis=0)
sample.shape
# Out:
# (10000, 6)

# %%
def clean_up(s):
    s = re.sub(r'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))', ' ', s)
    s = s.translate ({ord(c): " " for c in """!@#$%^&*()[]{}'";:,./<>?\|`-~=_+"""})
    s = re.sub('\d+',' ',s)
    s = s.lower()

    return s

# %%
def tokenize(s):
    tokens = word_tokenize(s)
    return tokens

# %%
def stem_and_lemmatize(l):
    l_stem_lem = []
    ps = PorterStemmer() 
    lm = WordNetLemmatizer()
    for w in l: 
        w=ps.stem(w)
        w=lm.lemmatize(w)
        l_stem_lem.append(w)
    return l_stem_lem

# %%
def remove_stopwords(l):
    stop_words = set(stopwords.words('english')) 
    return [word for word in l if word not in stop_words]

# %%
sample.head()
# Out:
#          target         ids                          date      flag  \
# 252885        0  1983850596  Sun May 31 13:57:34 PDT 2009  NO_QUERY
# 1470795       4  2065104078  Sun Jun 07 07:54:08 PDT 2009  NO_QUERY
# 1560163       4  2186271031  Mon Jun 15 18:36:00 PDT 2009  NO_QUERY
# 604888        0  2222086320  Thu Jun 18 06:28:33 PDT 2009  NO_QUERY
# 476257        0  2177831378  Mon Jun 15 06:46:27 PDT 2009  NO_QUERY
#
#                   user                                               text
# 252885        karen898                           Not feeling good at all
# 1470795       meggie19  getting ready for church  and soccer later. cl...
# 1560163     watchittay  @ohhkayla do ittt  i actually enjoyed this epi...
# 604888          franhr  PLEASE VOTE!  http://tweeterwall.mallplace.com...
# 476257   Mzpurrfection  @essenceshamari and sometimes my cheek, I hate...

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
sample5=sent.sample(n=5, axis=0)
sample5
# Out:
#          target         ids                          date      flag  \
# 390358        0  2054657458  Sat Jun 06 07:49:26 PDT 2009  NO_QUERY
# 876101        4  1680993123  Sat May 02 12:58:14 PDT 2009  NO_QUERY
# 1028593       4  1932639966  Tue May 26 21:53:28 PDT 2009  NO_QUERY
# 222273        0  1976987509  Sat May 30 19:47:34 PDT 2009  NO_QUERY
# 194562        0  1970315744  Sat May 30 03:21:23 PDT 2009  NO_QUERY
#
#                  user                                               text
# 390358   Rach_McCoyle  @beckym1985 nah im not im afraid, i can't get ...
# 876101         NeyeKA                             At the lake with kels
# 1028593   marimbamiss  To bed. Finished the portfolio. Hurray!.. Now ...
# 222273   KaTiE_Jcharm              okay on my way to LA...bye bye SoDak
# 194562       jcecilie        @lindaeriksen I don't like the rain either

# %%
# your code here
# apply(clean_up)
# apply(tokenize)
# apply(stem_and_lemmatize)
# apply(remove_stopwords)
#creating new column with cleaned,tokenized, stemmed and lemmed, no stopwords

sample["text_processed"]=sample["text"].apply(clean_up)
print('1 done')
sample["text_processed"]=sample["text_processed"].apply(tokenize)
print('2 done')
sample["text_processed"]=sample["text_processed"].apply(stem_and_lemmatize)
print('3 done')
sample["text_processed"]=sample["text_processed"].apply(remove_stopwords)

sample.head()
# Out:
# 1 done
# 2 done
# 3 done
#          target         ids                          date      flag  \
# 1379201       4  2052097942  Fri Jun 05 23:39:21 PDT 2009  NO_QUERY
# 1482218       4  2067218548  Sun Jun 07 11:57:44 PDT 2009  NO_QUERY
# 1242493       4  1994251837  Mon Jun 01 11:38:57 PDT 2009  NO_QUERY
# 272670        0  1990255784  Mon Jun 01 04:21:04 PDT 2009  NO_QUERY
# 1041630       4  1957100902  Thu May 28 23:31:13 PDT 2009  NO_QUERY
#
#                     user                                               text  \
# 1379201   letssayafriend     @stefrabago OURS GOT MOVED TO THE 16! YAAAAY!
# 1482218     KatieSayWhat                                 @justineoday ROFL
# 1242493  AndrewKungPhoto  @nickrkey Same result, just in a fancy differe...
# 272670       whereislena  @missgiggly Really?! OMG! A vent?! Obviously p...
# 1041630   NeverSayNicole  @jessicaatran @NeverSayNicole Hahaha!! That's ...
#
#                                             text_processed
# 1379201                    [stefrabago, got, move, yaaaay]
# 1482218                                [justineoday, rofl]
# 1242493            [nickrkey, result, fanci, differ, form]
# 272670   [missgiggli, realli, omg, vent, obvious, plan,...
# 1041630  [jessicaatran, neversaynicol, hahaha, hilari, ...

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
from nltk.probability import FreqDist

# %%
# your code here

# List of list of all words
list_of_words = sample["text_processed"].tolist()
list_of_words

# Create one list of all words
bow = []
for lists in list_of_words:
    for word in lists:
        bow.append(word)
bow

# Create frequency with words
freq_dist = FreqDist(bow)
top_5000 = freq_dist.most_common(5000)

# %%
#top_5000

# %%
# separating list of words and frequency
word_features, freq = [[x for x,y in top_5000],
      [y for x,y in top_5000]]

# List of just words
word_features
# Out:
# ['go',
#  'day',
#  'get',
#  'wa',
#  'good',
#  'thi',
#  'work',
#  'love',
#  'like',
#  'quot',
#  'today',
#  'got',
#  'time',
#  'u',
#  'miss',
#  'thank',
#  'lol',
#  'back',
#  'know',
#  'feel',
#  'one',
#  'im',
#  'want',
#  'realli',
#  'see',
#  'think',
#  'amp',
#  'hope',
#  'watch',
#  'well',
#  'make',
#  'still',
#  'night',
#  'much',
#  'ha',
#  'new',
#  'need',
#  'tomorrow',
#  'na',
#  'home',
#  'oh',
#  'look',
#  'sleep',
#  'last',
#  'come',
#  'wish',
#  'sad',
#  'great',
#  'twitter',
#  'morn',
#  'wait',
#  'tri',
#  'veri',
#  'happi',
#  'fun',
#  'whi',
#  'would',
#  'right',
#  'better',
#  'thing',
#  'haha',
#  'tonight',
#  'onli',
#  'sorri',
#  'though',
#  'week',
#  'way',
#  'bed',
#  'bad',
#  'school',
#  'follow',
#  'hate',
#  'nice',
#  'hour',
#  'gon',
#  'even',
#  'hi',
#  'take',
#  'weekend',
#  'say',
#  'yeah',
#  'show',
#  'play',
#  'friend',
#  'everyon',
#  'could',
#  'start',
#  'cant',
#  'ye',
#  'tweet',
#  'hey',
#  'final',
#  'ok',
#  'soon',
#  'awesom',
#  'never',
#  'use',
#  'lt',
#  'sick',
#  'peopl',
#  'tire',
#  'guy',
#  'first',
#  'dont',
#  'long',
#  'next',
#  'becaus',
#  'wan',
#  'talk',
#  'lot',
#  'sure',
#  'bore',
#  'littl',
#  'help',
#  'rain',
#  'x',
#  'plea',
#  'best',
#  'alway',
#  'let',
#  'ani',
#  'phone',
#  'hous',
#  'suck',
#  'eat',
#  'live',
#  'cool',
#  'find',
#  'read',
#  'song',
#  'man',
#  'year',
#  'alreadi',
#  'movi',
#  'girl',
#  'keep',
#  'head',
#  'readi',
#  'went',
#  'thought',
#  'life',
#  'call',
#  'hurt',
#  'anoth',
#  'excit',
#  'bit',
#  'leav',
#  'damn',
#  'guess',
#  'amaz',
#  'yay',
#  'late',
#  'omg',
#  'tell',
#  'stop',
#  'also',
#  'ever',
#  'away',
#  'made',
#  'done',
#  'n',
#  'two',
#  'b',
#  'yet',
#  'glad',
#  'old',
#  'pretti',
#  'actual',
#  'monday',
#  'updat',
#  'finish',
#  'befor',
#  'mayb',
#  'summer',
#  'hard',
#  'run',
#  'noth',
#  'put',
#  'w',
#  'someth',
#  'parti',
#  'listen',
#  'ur',
#  'end',
#  'enjoy',
#  'car',
#  'check',
#  'plan',
#  'left',
#  'birthday',
#  'someon',
#  'sound',
#  'doe',
#  'sun',
#  'sunday',
#  'mean',
#  'earli',
#  'r',
#  'kid',
#  'big',
#  'exam',
#  'ya',
#  'luck',
#  'stuff',
#  'pic',
#  'game',
#  'give',
#  'mani',
#  'hear',
#  'p',
#  'babi',
#  'wow',
#  'post',
#  'lost',
#  'friday',
#  'later',
#  'weather',
#  'video',
#  'shop',
#  'said',
#  'die',
#  'fuck',
#  'seem',
#  'stay',
#  'sinc',
#  'mom',
#  'dad',
#  'onc',
#  'around',
#  'may',
#  'aww',
#  'cri',
#  'anyth',
#  'win',
#  'famili',
#  'till',
#  'food',
#  'might',
#  'drive',
#  'wonder',
#  'yesterday',
#  'move',
#  'write',
#  'studi',
#  'gt',
#  'tho',
#  'book',
#  'found',
#  'okay',
#  'without',
#  'iphon',
#  'everi',
#  'ugh',
#  'almost',
#  'funni',
#  'wake',
#  'anyon',
#  'th',
#  'boy',
#  'probabl',
#  'buy',
#  'cute',
#  'believ',
#  'cold',
#  'didnt',
#  'free',
#  'ta',
#  'poor',
#  'woke',
#  'dinner',
#  'pictur',
#  'fail',
#  'beauti',
#  'mine',
#  'close',
#  'shit',
#  'open',
#  'outsid',
#  'everyth',
#  'welcom',
#  'forward',
#  'must',
#  'god',
#  'class',
#  'lunch',
#  'tv',
#  'hot',
#  'job',
#  'anymor',
#  'world',
#  'room',
#  'happen',
#  'turn',
#  'true',
#  'send',
#  'least',
#  'gone',
#  'rememb',
#  'fan',
#  'total',
#  'music',
#  'caus',
#  'part',
#  'c',
#  'dream',
#  'meet',
#  'chang',
#  'saw',
#  'hair',
#  'laugh',
#  'bring',
#  'came',
#  'goodnight',
#  'ask',
#  'bye',
#  'busi',
#  'coffe',
#  'sit',
#  'pm',
#  'wrong',
#  'kinda',
#  'real',
#  'abl',
#  'far',
#  'pain',
#  'hang',
#  'enough',
#  'word',
#  'awww',
#  'news',
#  'e',
#  'headach',
#  'interest',
#  'comput',
#  'rock',
#  'month',
#  'ah',
#  'xx',
#  'k',
#  'sooo',
#  'sweet',
#  'tea',
#  'minut',
#  'place',
#  'problem',
#  'name',
#  'eye',
#  'saturday',
#  'smile',
#  'hit',
#  'cuz',
#  'el',
#  'pick',
#  'super',
#  'hug',
#  'pay',
#  'boo',
#  'mind',
#  'repli',
#  'sister',
#  'clean',
#  'st',
#  'sometim',
#  'face',
#  'person',
#  'heart',
#  'text',
#  'kind',
#  'hello',
#  'rest',
#  'worth',
#  'fix',
#  'dog',
#  'break',
#  'awak',
#  'crazi',
#  'idea',
#  'train',
#  'beach',
#  'full',
#  'g',
#  'cat',
#  'hahaha',
#  'annoy',
#  'stupid',
#  'brother',
#  'pas',
#  'mad',
#  'wont',
#  'blog',
#  'homework',
#  'breakfast',
#  'spend',
#  'aw',
#  'cours',
#  'hand',
#  'reason',
#  'sing',
#  'drink',
#  'ticket',
#  'site',
#  'hell',
#  'english',
#  'wear',
#  'onlin',
#  'second',
#  'favorit',
#  'fine',
#  'catch',
#  'whole',
#  'kill',
#  'ice',
#  'set',
#  'hehe',
#  'messag',
#  'high',
#  'trip',
#  'soo',
#  'add',
#  'cut',
#  'anyway',
#  'worri',
#  'danc',
#  'lucki',
#  'either',
#  'walk',
#  'ill',
#  'com',
#  'goin',
#  'side',
#  'mother',
#  'dude',
#  'money',
#  'seen',
#  'agre',
#  'instead',
#  'scare',
#  'btw',
#  'photo',
#  'link',
#  'foot',
#  'star',
#  'alon',
#  'jealou',
#  'f',
#  'half',
#  'tast',
#  'test',
#  'understand',
#  'goe',
#  'guitar',
#  'ladi',
#  'hungri',
#  'drop',
#  'heard',
#  'june',
#  'short',
#  'til',
#  'nap',
#  'graduat',
#  'le',
#  'unfortun',
#  'afternoon',
#  'xd',
#  'visit',
#  'broke',
#  'london',
#  'church',
#  'v',
#  'season',
#  'lie',
#  'serious',
#  'care',
#  'swim',
#  'broken',
#  'cook',
#  'vote',
#  'lay',
#  'finger',
#  'bought',
#  'cup',
#  'weird',
#  'order',
#  'offic',
#  'fb',
#  'top',
#  'took',
#  'film',
#  'download',
#  'page',
#  'mood',
#  'save',
#  'suppos',
#  'sunshin',
#  'lmao',
#  'list',
#  'youtub',
#  'upload',
#  'shirt',
#  'bu',
#  'ipod',
#  'internet',
#  'ago',
#  'share',
#  'la',
#  'award',
#  'chat',
#  'sign',
#  'david',
#  'congrat',
#  'fair',
#  'bday',
#  'holiday',
#  'told',
#  'l',
#  'xxx',
#  'hr',
#  'differ',
#  'shout',
#  'quit',
#  'realiz',
#  'sleepi',
#  'facebook',
#  'pool',
#  'date',
#  'joke',
#  'followfriday',
#  'chill',
#  'hmm',
#  'pull',
#  'sigh',
#  'fall',
#  'ahh',
#  'laptop',
#  'point',
#  'store',
#  'j',
#  'lil',
#  'co',
#  'depress',
#  'album',
#  'stuck',
#  'mr',
#  'bet',
#  'hubbi',
#  'uk',
#  'team',
#  'gave',
#  'email',
#  'due',
#  'offici',
#  'nd',
#  'forgot',
#  'relax',
#  'learn',
#  'kick',
#  'appreci',
#  'twilight',
#  'pray',
#  'ppl',
#  'tour',
#  'shoe',
#  'ate',
#  'water',
#  'appar',
#  'figur',
#  'cream',
#  'rather',
#  'togeth',
#  'air',
#  'band',
#  'ddlovato',
#  'safe',
#  'account',
#  'app',
#  'jona',
#  'speak',
#  'worst',
#  'sore',
#  'nick',
#  'thx',
#  'sent',
#  'answer',
#  'ahhh',
#  'moment',
#  'past',
#  'pack',
#  'nite',
#  'stomach',
#  'hmmm',
#  'park',
#  'three',
#  'stori',
#  'definit',
#  'notic',
#  'voic',
#  'soooo',
#  'chocol',
#  'join',
#  'websit',
#  'crap',
#  'complet',
#  'sunni',
#  'upset',
#  'raini',
#  'spent',
#  'black',
#  'everybodi',
#  'bless',
#  'flu',
#  'meant',
#  'asleep',
#  'juli',
#  'vacat',
#  'shot',
#  'fli',
#  'mac',
#  'absolut',
#  'yea',
#  'town',
#  'matter',
#  'bike',
#  'perfect',
#  'moon',
#  'record',
#  'white',
#  'coupl',
#  'throat',
#  'fast',
#  'dm',
#  'bbq',
#  'mommi',
#  'parent',
#  'wtf',
#  'number',
#  'googl',
#  'forget',
#  'bout',
#  'doctor',
#  'cloth',
#  'celebr',
#  'posit',
#  'bitch',
#  'jonasbroth',
#  'usual',
#  'shall',
#  'h',
#  'thursday',
#  'sort',
#  'horribl',
#  'leg',
#  'woman',
#  'age',
#  'citi',
#  'bro',
#  'min',
#  'lazi',
#  'wed',
#  'load',
#  'normal',
#  'exactli',
#  'sat',
#  'line',
#  'expect',
#  'chanc',
#  'slow',
#  'via',
#  'mileycyru',
#  'pc',
#  'cover',
#  'dead',
#  'insid',
#  'kiss',
#  'myspac',
#  'light',
#  'tuesday',
#  'goodby',
#  'mtv',
#  'radio',
#  'lose',
#  'sen',
#  'arriv',
#  'hahah',
#  'gorgeou',
#  'shine',
#  'havent',
#  'ju',
#  'flight',
#  'blue',
#  'red',
#  'laker',
#  'case',
#  'nope',
#  'box',
#  'surpris',
#  'wash',
#  'instal',
#  'chicken',
#  'decid',
#  'joy',
#  'ride',
#  'green',
#  'offer',
#  'beer',
#  'club',
#  'appl',
#  'yup',
#  'result',
#  'cake',
#  'miley',
#  'lame',
#  'mum',
#  'wit',
#  'count',
#  'garden',
#  'dear',
#  'cheer',
#  'yr',
#  'mail',
#  'near',
#  'bum',
#  'bodi',
#  'aint',
#  'support',
#  'ff',
#  'peac',
#  'airport',
#  'small',
#  'ohh',
#  'shower',
#  'practic',
#  'hold',
#  'tommcfli',
#  'knew',
#  'mmm',
#  'bag',
#  'memori',
#  'includ',
#  'proud',
#  'hill',
#  'cancel',
#  'dr',
#  'tan',
#  'luv',
#  'crash',
#  'fit',
#  'servic',
#  'arm',
#  'storm',
#  'stress',
#  'wine',
#  'awwww',
#  'angel',
#  'compani',
#  'gettin',
#  'contact',
#  'window',
#  'huge',
#  'ive',
#  'drunk',
#  'dure',
#  '�',
#  'sadli',
#  'interview',
#  'math',
#  'power',
#  'son',
#  'wast',
#  'alright',
#  'warm',
#  'mess',
#  'gym',
#  'build',
#  'tweep',
#  'pink',
#  'block',
#  'bummer',
#  'studio',
#  'fam',
#  'dvd',
#  'colleg',
#  'batteri',
#  'sky',
#  'special',
#  'bill',
#  'taylor',
#  'invit',
#  'door',
#  'mark',
#  'perform',
#  'plu',
#  'fat',
#  'revis',
#  'design',
#  'father',
#  'hangov',
#  'idk',
#  'puppi',
#  'card',
#  'smell',
#  'brain',
#  'msn',
#  'middl',
#  'front',
#  'wife',
#  'fight',
#  'fantast',
#  'earlier',
#  'death',
#  'round',
#  'shame',
#  'xoxo',
#  'concert',
#  'random',
#  'men',
#  'chees',
#  'canada',
#  'king',
#  'ad',
#  'race',
#  'comment',
#  'question',
#  'vip',
#  'current',
#  'manag',
#  'type',
#  'act',
#  'tom',
#  'dress',
#  'continu',
#  'smoke',
#  'especi',
#  'bug',
#  'slept',
#  'babe',
#  'doesnt',
#  'yep',
#  'burn',
#  'empti',
#  'deal',
#  'seriou',
#  'joe',
#  'yum',
#  'grow',
#  'tear',
#  'apart',
#  'sim',
#  'mix',
#  'track',
#  'becom',
#  'blow',
#  'cross',
#  'wednesday',
#  'art',
#  'confus',
#  'stand',
#  'mobil',
#  'singl',
#  'ignor',
#  'note',
#  'web',
#  'travel',
#  'vega',
#  'state',
#  'touch',
#  'histori',
#  'woo',
#  'present',
#  'import',
#  'issu',
#  'prepar',
#  'topic',
#  'along',
#  'edit',
#  'rob',
#  'si',
#  'french',
#  'shake',
#  'mi',
#  'doubl',
#  'boyfriend',
#  'grandma',
#  'sport',
#  'em',
#  'extra',
#  'met',
#  'bite',
#  'cousin',
#  'fill',
#  'thanx',
#  'mention',
#  'caught',
#  'blast',
#  'mous',
#  'troubl',
#  'rd',
#  'info',
#  'nail',
#  'breath',
#  'jon',
#  'beat',
#  'sexi',
#  'prob',
#  'buddi',
#  'quiet',
#  'pizza',
#  'anim',
#  'behind',
#  'paint',
#  'texa',
#  'promis',
#  'drama',
#  'addict',
#  'view',
#  'gut',
#  'san',
#  'teach',
#  'bc',
#  'begin',
#  'major',
#  'chri',
#  'couldnt',
#  'sum',
#  'lake',
#  'yummi',
#  'releas',
#  'fell',
#  'spot',
#  'episod',
#  'pour',
#  'wii',
#  'eh',
#  'adam',
#  'fml',
#  'project',
#  'truli',
#  'sex',
#  'cell',
#  'daughter',
#  'non',
#  'alot',
#  'click',
#  'ahead',
#  'scari',
#  'gotten',
#  'tight',
#  '♫',
#  'somebodi',
#  'ouch',
#  'itun',
#  'model',
#  'forev',
#  'road',
#  'workout',
#  'al',
#  'prom',
#  'swear',
#  'nearli',
#  'disappoint',
#  'child',
#  'outta',
#  'inde',
#  'mornin',
#  'lone',
#  'except',
#  'attack',
#  'sale',
#  'land',
#  'rip',
#  'piss',
#  'machin',
#  'daddi',
#  'ed',
#  'stick',
#  'allow',
#  'upgrad',
#  'ball',
#  'ach',
#  'longer',
#  'franc',
#  'uh',
#  'product',
#  'er',
#  'aliv',
#  'chillin',
#  'although',
#  'control',
#  'quick',
#  'matt',
#  'frustrat',
#  'aim',
#  'thru',
#  'log',
#  'traffic',
#  'ear',
#  'exhaust',
#  'candi',
#  'gay',
#  'peep',
#  'experi',
#  ...]

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here
word_features=list(bow.index)
### First running for sample of 10000 rows
def find_features(lst, bow):
    word_features=list(bow.index)
    words = set(lst)
    features = {}
    for w in word_features:
        features[w] = (w in words)
    return features
word_features
features=[]
for i,l in enumerate(sample["text_processed"]):
    s=[find_features(l,bow),sample["sentiment"].iloc[i]]
    z=tuple(s)
    features.append(z)
features

# %%
def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

word_features

# %%
#featuresets = [(find_features(rev), category) for (rev, category) in documents]

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
