# %% [markdown]
# # Inbalanced Classes
# ## In this lab, we are going to explore a case of imbalanced classes.
#
#
# Like we disussed in class, when we have noisy data, if we are not careful, we can end up fitting our model to the noise in the data and not the 'signal'-- the factors that actually determine the outcome. This is called overfitting, and results in good results in training, and in bad results when the model is applied to real data. Similarly, we could have a model that is too simplistic to accurately model the signal. This produces a model that doesnt work well (ever).

# %% [markdown]
# ### First, download the data from: https://www.kaggle.com/ntnu-testimon/paysim1. Import the dataset and provide some discriptive statistics and plots. What do you think will be the important features in determining the outcome?

# %%
import pandas as pd

# %%
df = pd.read_csv("../../../../Ironhack/Data_Module3/Financial_Dataset_for_Fraud_Detection.csv")
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
#create shortened df
#taking appr. 1%
df = df.sample(n = 63626)
df
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 1463646   140  CASH_OUT  120881.26   C994405504         1001.0
# 3580066   261  CASH_OUT   90017.52  C1871082562        52140.0
# 5650776   396   CASH_IN  170824.17  C1117044366       102315.0
# 792677     40   CASH_IN   39732.35  C1882479424         5415.0
# 6089496   522  CASH_OUT   61249.99  C1234041577            0.0
# ...       ...       ...        ...          ...            ...
# 934086     43   CASH_IN  237171.02  C1948700288       753112.0
# 5312457   373   CASH_IN   75348.98   C120254954        12742.0
# 1689233   159   PAYMENT     203.93  C2134557524       177294.2
# 3818120   281  CASH_OUT  183741.65   C923941491        51147.0
# 5185839   360  CASH_OUT   95287.10   C153146866            0.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 1463646            0.00   C864462325            0.00       120881.26        0
# ...

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  63626.000000  6.362600e+04   6.362600e+04    6.362600e+04
# mean     242.980448  1.800847e+05   8.270032e+05    8.477675e+05
# std      142.527520  6.181280e+05   2.850346e+06    2.885479e+06
# min        1.000000  4.500000e-01   0.000000e+00    0.000000e+00
# 25%      155.000000  1.331094e+04   0.000000e+00    0.000000e+00
# 50%      239.000000  7.621817e+04   1.453200e+04    0.000000e+00
# 75%      335.000000  2.088518e+05   1.060798e+05    1.431285e+05
# max      728.000000  5.625500e+07   3.537580e+07    3.575571e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362600e+04    6.362600e+04  63626.000000    63626.000000
# mean     1.098105e+06    1.221881e+06      0.001477        0.000016
# std      3.460156e+06    3.720724e+06      0.038409        0.003964
# min      0.000000e+00    0.000000e+00      0.000000        0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63626 entries, 1463646 to 5185839
# Data columns (total 11 columns):
# step              63626 non-null int64
# type              63626 non-null object
# amount            63626 non-null float64
# nameOrig          63626 non-null object
# oldbalanceOrg     63626 non-null float64
# newbalanceOrig    63626 non-null float64
# nameDest          63626 non-null object
# oldbalanceDest    63626 non-null float64
# newbalanceDest    63626 non-null float64
# isFraud           63626 non-null int64
# isFlaggedFraud    63626 non-null int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 5.8+ MB

# %%
df.corr()
# Out:
#                     step    amount  oldbalanceOrg  newbalanceOrig  \
# step            1.000000  0.021653      -0.001344       -0.001376
# amount          0.021653  1.000000      -0.000602       -0.006403
# oldbalanceOrg  -0.001344 -0.000602       1.000000        0.998726
# newbalanceOrig -0.001376 -0.006403       0.998726        1.000000
# oldbalanceDest  0.027085  0.288481       0.067749        0.069273
# newbalanceDest  0.025301  0.451877       0.043549        0.043537
# isFraud         0.037226  0.075442       0.012837       -0.006102
# isFlaggedFraud  0.011210  0.001404       0.013314        0.013123
#
#                 oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud
# step                  0.027085        0.025301  0.037226        0.011210
# amount                0.288481        0.451877  0.075442        0.001404
# oldbalanceOrg         0.067749        0.043549  0.012837        0.013314
# newbalanceOrig        0.069273        0.043537 -0.006102        0.013123
# ...

# %%
#plot isFraud and amount as there seems to be a positive relationship between them
#Problem: due to the huge difference in the scales I have to change the kind of diagram

# %%
df[["isFraud","amount"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117d60050>,
# ...
#       dtype=object)

# %%
#df[["isFraud","amount"]].plot(kind='barh')

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119a68a90>,
# ...
#       dtype=object)

# %%
"""kind — ‘bar’,’barh’,’pie’,’scatter’,’kde’ etc which can be found in the docs.
color — Which accepts and array of hex codes corresponding sequential to each data series / column.
linestyle — ‘solid’, ‘dotted’, ‘dashed’ (applies to line graphs only)
xlim, ylim — specify a tuple (lower limit, upper limit) for which the plot will be drawn
legend— a boolean value to display or hide the legend
labels — a list corresponding to the number of columns in the dataframe, a descriptive name can be provided here for the legend
title — The string title of the plot"""
# Out:
# 'kind — ‘bar’,’barh’,’pie’,’scatter’,’kde’ etc which can be found in the docs.\ncolor — Which accepts and array of hex codes corresponding sequential to each data series / column.\nlinestyle — ‘solid’, ‘dotted’, ‘dashed’ (applies to line graphs only)\nxlim, ylim — specify a tuple (lower limit, upper limit) for which the plot will be drawn\nlegend— a boolean value to display or hide the legend\nlabels — a list corresponding to the number of columns in the dataframe, a descriptive name can be provided here for the legend\ntitle — The string title of the plot'

# %% [markdown]
# ### What is the distribution of the outcome?

# %%
df.isFraud.value_counts()
# Out:
# 0    63532
# 1       94
# Name: isFraud, dtype: int64

# %% [markdown]
# ### Clean the dataset. How are you going to integrate the time variable? Do you think the step (integer) coding in which it is given is appropriate?

# %%
#change type to dumiy variables
df[['CASH_OUT', 'DEBIT', 'PAYMENT', 'TRANSFER']] = pd.get_dummies(df["type"], prefix=["type"], drop_first=True)
#drop type
df = df.drop("type", axis=1)
df
# Out:
#          step     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 1463646   140  120881.26   C994405504         1001.0            0.00
# 3580066   261   90017.52  C1871082562        52140.0            0.00
# 5650776   396  170824.17  C1117044366       102315.0       273139.17
# 792677     40   39732.35  C1882479424         5415.0        45147.35
# 6089496   522   61249.99  C1234041577            0.0            0.00
# ...       ...        ...          ...            ...             ...
# 934086     43  237171.02  C1948700288       753112.0       990283.02
# 5312457   373   75348.98   C120254954        12742.0        88090.98
# 1689233   159     203.93  C2134557524       177294.2       177090.27
# 3818120   281  183741.65   C923941491        51147.0            0.00
# 5185839   360   95287.10   C153146866            0.0            0.00
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...

# %%
#drop name origin df
df = df.drop("nameOrig", axis=1)
#drop oldbalance & oldbalance_dest to avoid multicollinearity with newbalance and newbalance_dest
df = df.drop(["oldbalanceOrg", "oldbalanceDest"], axis=1)
df
# Out:
#          step     amount  newbalanceOrig     nameDest  newbalanceDest  \
# 1463646   140  120881.26            0.00   C864462325       120881.26
# 3580066   261   90017.52            0.00  C1033122873        91268.70
# 5650776   396  170824.17       273139.17   C764785779      2531600.31
# 792677     40   39732.35        45147.35   C973882694       299666.08
# 6089496   522   61249.99            0.00  C1326092597      2073849.03
# ...       ...        ...             ...          ...             ...
# 934086     43  237171.02       990283.02   C416415078      2502664.80
# 5312457   373   75348.98        88090.98   C977027938            0.00
# 1689233   159     203.93       177090.27  M1356520596            0.00
# 3818120   281  183741.65            0.00    C30770683      5022373.40
# 5185839   360   95287.10            0.00    C84544257     11088087.96
#
#          isFraud  isFlaggedFraud  CASH_OUT  DEBIT  PAYMENT  TRANSFER
# ...

# %%
df["nameDest"].value_counts()
#drop nameDest
df = df.drop(["nameDest"], axis=1)
df
# Out:
#          step     amount  newbalanceOrig  newbalanceDest  isFraud  \
# 1463646   140  120881.26            0.00       120881.26        0
# 3580066   261   90017.52            0.00        91268.70        0
# 5650776   396  170824.17       273139.17      2531600.31        0
# 792677     40   39732.35        45147.35       299666.08        0
# 6089496   522   61249.99            0.00      2073849.03        0
# ...       ...        ...             ...             ...      ...
# 934086     43  237171.02       990283.02      2502664.80        0
# 5312457   373   75348.98        88090.98            0.00        0
# 1689233   159     203.93       177090.27            0.00        0
# 3818120   281  183741.65            0.00      5022373.40        0
# 5185839   360   95287.10            0.00     11088087.96        0
#
#          isFlaggedFraud  CASH_OUT  DEBIT  PAYMENT  TRANSFER
# 1463646               0         1      0        0         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63626 entries, 1463646 to 5185839
# Data columns (total 10 columns):
# step              63626 non-null int64
# amount            63626 non-null float64
# newbalanceOrig    63626 non-null float64
# newbalanceDest    63626 non-null float64
# isFraud           63626 non-null int64
# isFlaggedFraud    63626 non-null int64
# CASH_OUT          63626 non-null uint8
# DEBIT             63626 non-null uint8
# PAYMENT           63626 non-null uint8
# TRANSFER          63626 non-null uint8
# dtypes: float64(3), int64(3), uint8(4)
# memory usage: 3.6 MB

# %% [markdown]
# ### Run a logisitc regression classifier and evaluate its accuracy.

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns='isFraud')
y = df['isFraud']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#turn our data set into something that looks more like a standard normally distributed data set

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
#import the logistic regression
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(solver='liblinear', random_state=0)
logreg.fit(scaled_X_train, y_train)

#predict using X_test
y_pred = logreg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score

# %%
display(confusion_matrix(y_test, y_pred),
        precision_score(y_test, y_pred),
        recall_score(y_test, y_pred),
        f1_score(y_test, y_pred))
# Out:
# array([[8876, 3832],
#        [   4,   14]])
# 0.003640145605824233
# 0.7777777777777778
# 0.007246376811594203

# %% [markdown]
# ### Now pick a model of your choice and evaluate its accuracy.

# %%
#I already did that above

# %% [markdown]
# ### Which model worked better and how do you know?

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# %%
#roc curves
precision, recall, _ = roc_curve(y_test, y_pred)

# plot roc curve for our model
plt.plot(precision, recall, marker='.', label="Log_Reg")
plt.title("Logistic Regression")
plt.xlabel('False Pos. Rate')
plt.ylabel('True Pos. Rate')
plt.legend()
plt.show()
