# %% [markdown]
# # Explore Correlations

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/vpavandijk/LEARNING/Ironhack/copy of google drive class AMS0520/Copy of CDD.csv', sep = '\t')
data.head()
# Out:
#   EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0       Disaster     Natural  Meteorological - Hydrological
# 1       Disaster     Natural  Meteorological - Hydrological
# 2       Disaster     Natural  Meteorological - Hydrological
# 3       Disaster     Natural                     Biological
# 4       Incident  Technology            Hazardous Chemicals
#
#                     EVENT TYPE                                 PLACE  \
# 0  Storm - Unspecified / Other                   Christmas Island NS
# 1                 Winter Storm  Nova Scotia and Prince Edward Island
# 2                        Flood             Red Earth First Nation SK
# 3                     Epidemic              Alberta and Saskatchewan
# 4         Leak / Spill Release                   Seaforth Channel BC
#
#          EVENT START DATE                                           COMMENTS  \
# 0  25/12/2016 12:00:00 AM  Christmas Island NS, December 25, 2016. Reside...
# ...

# %%
#Print the correlation matrix:

data.corr()
# Out:
#                                 FATALITIES  INJURED / INFECTED  EVACUATED  \
# FATALITIES                        1.000000            0.998728  -0.003530
# INJURED / INFECTED                0.998728            1.000000  -0.003554
# EVACUATED                        -0.003530           -0.003554   1.000000
# ESTIMATED TOTAL COST              0.027839            0.073538   0.660335
# NORMALIZED TOTAL COST             0.031352            0.080907   0.580352
# FEDERAL DFAA PAYMENTS             0.014838            0.311491   0.406679
# PROVINCIAL DFAA PAYMENTS         -0.020317            0.404215   0.083692
# PROVINCIAL DEPARTMENT PAYMENTS   -0.023630           -0.002056   0.212975
# MUNICIPAL COSTS                   0.965880            0.965286   0.514186
# OGD COSTS                         0.417442           -0.036915   0.154761
# INSURANCE PAYMENTS                0.241347            0.456924   0.825937
# NGO PAYMENTS                      0.966678            0.999639   0.838898
# ...

# %%
#Print a heat map of this correlation matrix (hint: use seaborn.heatmap())

data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# /Users/vpavandijk/opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_b8e3d620_a0e9_11ea_9cd1_600308a0272erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b8e3d620_a0e9_11ea_9cd1_600308a0272erow0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b8e3d620_a0e9_11ea_9cd1_600308a0272erow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b8e3d620_a0e9_11ea_9cd1_600308a0272erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b8e3d620_a0e9_11ea_9cd1_600308a0272erow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b8e3d620_a0e9_11ea_9cd1_600308a0272erow0_col5 {
#             background-color:  #455cce;
# ...

# %%
# Print a heat map of this correlation matrix (hint: use seaborn.heatmap())

# sns.heatmap(data.corr())

fig, ax = plt.subplots(figsize=(18,18))
sns.heatmap(data.corr(),annot=True, linewidths=.5, ax=ax)

# %%
# Find 3 pairs of columns, one pair that is highly positively correlated, one for which the correlation 
# is almost zero and one pair that is negatively correlated. In each case write down an explanation why
# we see this correlation:
'''
highly postive correlated:
"municipal costs" and "fatalities"
when the number of fatalities is high the disaster is big which gives high costs to recover.

correlation almost zero:
"provincial department payments" and "injured"
almost no correlation.. Probably the province is not involved when disasters with injuries are happening.

negative correlated:
no highly negative correlated correlations.
small negative correlation between "magnitude" and "evacuated"
The higher the magnitude of a earthquake the less people can be evacuated (not possible to get at location anymore)
'''

# %%
data.columns
# Out:
# Index(['EVENT CATEGORY', 'EVENT GROUP', 'EVENT SUBGROUP', 'EVENT TYPE',
#        'PLACE', 'EVENT START DATE', 'COMMENTS', 'FATALITIES',
#        'INJURED / INFECTED', 'EVACUATED', 'ESTIMATED TOTAL COST',
#        'NORMALIZED TOTAL COST', 'EVENT END DATE', 'FEDERAL DFAA PAYMENTS',
#        'PROVINCIAL DFAA PAYMENTS', 'PROVINCIAL DEPARTMENT PAYMENTS',
#        'MUNICIPAL COSTS', 'OGD COSTS', 'INSURANCE PAYMENTS', 'NGO PAYMENTS',
#        'UTILITY - PEOPLE AFFECTED', 'MAGNITUDE'],
#       dtype='object')

# %%
# Look up the pairplot function in Seaborn. Use it to plot the pairwise relations between the six 
# columns you selected. Does what you see confirm your ideas? Describe in a comment.

sns.pairplot(data, vars=['MUNICIPAL COSTS', 'FATALITIES', 'PROVINCIAL DEPARTMENT PAYMENTS', 'INJURED / INFECTED', 'MAGNITUDE', 'EVACUATED'], dropna = True)
plt.show()

# very difficult to interpret these plots....
# So I tried a smaller version with a very high positive correlation, but this did not made me any wiser....

# sns.pairplot(data, vars=['FATALITIES', 'INJURED / INFECTED'], dropna = True)
# import matplotlib.pyplot as plt
# plt.show()
# Out:
# /Users/vpavandijk/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/vpavandijk/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
