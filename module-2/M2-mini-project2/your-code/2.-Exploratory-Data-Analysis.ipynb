# %% [markdown]
# # Inferential statistics
# ## Part II - Exploratory Data Analysis
#
# Before starting the actual analysis it's a good idea to explore the data that we will be using, to give yourself a first idea of the questions you will be able to answer with your data, the bias you could have, other data you could need, etc.
#
# ### Libraries
# In addition to pandas we will also import matplolib and seaborn so that we will able to plot our data to better understand it.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('max_columns', 100)
# %matplotlib inline
import numpy as np
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Explore the dataset
#
# Let's load the cleaned dataset first. Import it with the name `wnba` and show the head.

# %%
df = pd.read_csv('wnba_clean.csv')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#               Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 0    Aerial Powers  DAL    F     183      71  21.200991          US
# 1      Alana Beard   LA  G/F     185      73  21.329438          US
# 2     Alex Bentley  CON    G     170      69  23.875433          US
# 3  Alex Montgomery  SAN  G/F     185      84  24.543462          US
# 4     Alexis Jones  MIN    G     175      78  25.469388          US
#
#            Birthdate  Age         College Experience  Games Played  MIN  FGM  \
# 0   January 17, 1994   23  Michigan State          2             8  173   30
# 1       May 14, 1982   35            Duke         12            30  947   90
# 2   October 27, 1990   26      Penn State          4            26  617   82
# 3  December 11, 1988   28    Georgia Tech          6            31  721   75
# 4     August 5, 1994   23          Baylor          R            24  137   16
#
#    FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  OREB  DREB  REB  AST  STL  BLK  \
# ...

# %%
df.sort_values('AST', ascending=False)
# Out:
#                          Name Team  Pos  Height  Weight        BMI  \
# 85          Layshia Clarendon  ATL    G     175      64  20.897959
# 126                  Sue Bird  SEA    G     175      68  22.204082
# 37       Courtney Vandersloot  CHI    G     173      66  22.052190
# 123      Skylar Diggins-Smith  DAL    G     175      66  21.551020
# 11              Alyssa Thomas  CON    F     188      84  23.766410
# 33               Chelsea Gray   LA    G     180      77  23.765432
# 28             Candace Parker   LA  F/C     193      79  21.208623
# 61             Jasmine Thomas  CON    G     175      66  21.551020
# 51              Erica Wheeler  IND    G     170      65  22.491349
# 116          Seimone Augustus  MIN  G/F     183      77  22.992624
# 86           Leilani Mitchell  PHO    G     165      58  21.303949
# 42          Danielle Robinson  PHO    G     175      57  18.612245
# 30           Cappie Pondexter  CHI    G     175      73  23.836735
# ...

# %% [markdown]
# **Use describe() to take an initial look at the data.**

# %%
df.describe()
df.drop(['Birthdate', 'Name', 'College'], axis=1, inplace=True)
df['Experience'].replace('R', 0, inplace=True)

# %% [markdown]
# Most of the game-related stats have a very high range of values which can be explained by the fact that the dataset contains data on both players that play the majority of games and also players that may spend almost the entirety of the season on the bench.
#
# There are also some extremes in the weight and age columns. Feel free, if you'd like, to check which are the players with a very high (or low) age/weight and do some research on them. This is useful to confirm that they are simply outliers and not errors in the data.

# %%
df[df['Weight'] > 95]
# Out:
#     Team  Pos  Height  Weight        BMI Birth_Place  Age Experience  \
# 12    NY    C     196     113  29.414827          SE   24          3
# 23   CON    F     191     104  28.507990          US   21          0
# 36   DAL    C     193     113  30.336385          US   29          7
# 41   CON  F/C     185     108  31.555880          US   28          5
# 84   SEA    C     196      96  24.989588          US   23          0
# 89   CON    C     193     104  27.920213          US   27          5
# 124  CHI    C     196      97  25.249896          US   25          3
# 130  MIN    C     198      96  24.487297          US   32         10
#
#      Games Played  MIN  FGM  FGA   FG%  3PM  3PA   3P%  FTM  FTA    FT%  OREB  \
# 12             25  133   20   53  37.7    2    8  25.0    9   12   75.0     5
# 23             19  112   14   26  53.8    0    0   0.0   16   19   84.2    11
# 36             16  217   32   57  56.1    0    0   0.0    6   12   50.0    28
# ...

# %% [markdown]
# ### Looking at the distributions of the data
# Let's take a look at the distribution of the 4 stats that describe the physical characteristics of the players.
#
# **Plot the four distributions about `height`, `weight`, `age` and `BMI`.**

# %%
fig, ax = plt.subplots(2, 2, figsize=(12,6))
ax[0,0].hist(df['Height'], bins=15)
ax[0,0].set_title('Height')
ax[0,1].hist(df['Weight'], bins=25)
ax[0,1].set_title('Weight')
ax[1,0].hist(df['Age'], bins=15)
ax[1,0].set_title('Age')
ax[1,1].hist(df['BMI'], bins=15)
ax[1,1].set_title('BMI')
plt.tight_layout()
plt.show()

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
# Most players are from the age 20-26, the majority of them are above average in Height.
# They look like a more less standard distribution
# The weight is between 60 and 90 KGs with a few BIG girls.

# %% [markdown]
# In addition to what the describe() method already told us we can see that the physical characteristics of the players (apart from the age) more or less follow a standard distribution, which is expected when looking at the distribution of values that arise from a lot of factors that are independent from each other as is the case for many physical quantities.
#
# The height distribution looks like a bimodal. This may be due to the fact that players in basketball fall under two main categories (please note that this is a very gross generalization): shorter and more agile, and taller and less agile. Therefore there are less "average" height players since they will neither be as agile as the shorter players nor have the same impact in the paint (that is, under the basket) as a taller player.
#
# The age distribution is a bit skewed to the right which is expected since most professional players stop playing after their prime physical years come to an end.

# %% [markdown]
# We could do the same for the main game stats. They are points, assists, blocks, rebounds and steals.
#
# **Now plot the distribution of the columns `REB`, `AST`, `STL`, `PTS` and `BLK` the same way you did in the last cell.**

# %%
fig, ax = plt.subplots(3, 2, figsize=(12,6))
ax[0,0].hist(df['REB'], bins=15)
ax[0,0].set_title('REB')
ax[0,1].hist(df['AST'], bins=25)
ax[0,1].set_title('AST')
ax[1,0].hist(df['STL'], bins=15)
ax[1,0].set_title('STL')
ax[1,1].hist(df['PTS'], bins=15)
ax[1,1].set_title('PTS')
ax[2,1].hist(df['BLK'], bins=15)
ax[2,1].set_title('BLK')
plt.tight_layout()
plt.show()

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
# The Majority of players do not score too often.

# %% [markdown]
# As expected all of the above distribution are heavily skewed to the right, since most players will have very low to average stats while there will be a handful of star players whose stats peak above everyone else. It is also important to think about the fact that we are simply taking the stats as they are without considering the minutes played by each player. Even though skill plays a very important factor in determining this kind of stats we also have to consider that players that play more minutes will, on average, score more points (or blocks, assists, etc.).

# %% [markdown]
# **For the sake of it let's look at the same distributions by dividing those stats by the minutes played for each player in the dataset.**

# %%
fig, ax = plt.subplots(3, 2, figsize=(12,6))
ax[0,0].hist(df['REB']/df['MIN'])
ax[0,0].set_title('REB/MIN')
ax[0,1].hist(df['AST']/df['MIN'])
ax[0,1].set_title('AST/MIN')
ax[1,0].hist(df['STL']/df['MIN'])
ax[1,0].set_title('STL/MIN')
ax[1,1].hist(df['PTS']/df['MIN'])
ax[1,1].set_title('PTS/MIN')
ax[2,1].hist(df['BLK']/df['MIN'])
ax[2,1].set_title('BLK/MIN')
plt.tight_layout()
plt.show()

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
# all of them are pretty balanced, the 'outliers' are skilled players probably

# %%
#df['FTM']

# %% [markdown]
# ### Summary
#
# The main insights we obtained from this exploratory analysis are:
# - Game-related stats have a very high range of values.
# - There are some extremes in the weight and age columns.
# - The physical characteristics of the players more or less follow a standard distribution.
# - We need to take into account that our dataset contains data on both players that play the majority of games and also players that may spend almost the entirety of the season on the bench.
#
# Now, it's time to try to put an end to your family's discussions. As seen on the README, the main discussions are:
# - Your grandmother says that your sister couldn't play in a professional basketball league (not only the WNBA, but ANY professional basketball league) because she's too skinny and lacks muscle.
# - Your sister says that most female professional players fail their free throws.
# - Your brother-in-law heard on the TV that the average assists among NBA (male) and WNBA (female) players is 52 for the 2016-2017 season. He is convinced this average would be higher if we only considered the players from the WNBA.
#
# **Do you think you have all the necessary data to answer these questions?**

# %%
# Your grandmother says that your sister couldn't play in a professional basketball league (not only the WNBA, but ANY professional basketball league) because she's too skinny and lacks muscle.
# Yes, we got BMI/Weight/Height
# Your sister says that most female professional players fail their free throws.
# df['FTA']/df['FTM'] YES
# Your brother-in-law heard on the TV that the average assists among NBA (male)
# and WNBA (female) players is 52 for the 2016-2017 season.
# He is convinced this average would be higher if we only considered the players from the WNBA.
# Yes
# df['AST'].mean()

# %%
df['Age'].mean()
# Out:
# 27.112676056338028

# %%
df.corrwith(df['Age']).sort_values()
# Out:
# Height         -0.107125
# Weight         -0.049890
# FT%            -0.013643
# DD2            -0.001498
# OREB            0.009165
# BLK             0.020437
# 3P%             0.036811
# BMI             0.043729
# REB             0.082987
# FTA             0.083017
# TD3             0.089587
# FTM             0.105345
# DREB            0.109977
# FG%             0.121423
# Games Played    0.125768
# FGA             0.168012
# FGM             0.169818
# PTS             0.171281
# 3PA             0.186789
# 3PM             0.191551
# TO              0.194990
# STL             0.205229
# MIN             0.239304
# AST             0.252346
# Age             1.000000
# dtype: float64

# %%
df.corrwith(df['Weight']).sort_values()
# Out:
# AST            -0.445231
# 3PA            -0.374683
# 3PM            -0.341832
# TO             -0.280432
# STL            -0.259023
# 3P%            -0.237746
# MIN            -0.233388
# FGA            -0.231564
# Games Played   -0.214920
# FT%            -0.184566
# PTS            -0.175402
# FGM            -0.148116
# FTM            -0.117581
# FTA            -0.094195
# Age            -0.049890
# TD3             0.000162
# DREB            0.080622
# DD2             0.104744
# REB             0.134072
# BLK             0.172917
# FG%             0.214274
# OREB            0.238818
# BMI             0.752237
# Height          0.770489
# Weight          1.000000
# dtype: float64

# %%
df.corrwith(df['Height']).sort_values()
# Out:
# AST            -0.445325
# 3PA            -0.359546
# 3PM            -0.328597
# FT%            -0.274055
# 3P%            -0.255198
# TO             -0.211953
# STL            -0.181034
# FGA            -0.147097
# Games Played   -0.146742
# MIN            -0.140038
# Age            -0.107125
# PTS            -0.087219
# FTM            -0.059440
# FGM            -0.048719
# FTA            -0.027620
# TD3             0.081493
# BMI             0.163703
# DD2             0.200338
# DREB            0.221064
# FG%             0.233682
# REB             0.272597
# BLK             0.350921
# OREB            0.353680
# Weight          0.770489
# Height          1.000000
# dtype: float64

# %%
plt.scatter(df['Weight'], df['3PA'])

# %%
plt.scatter(df['Height'], df['3PA'])

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(36,20))
sns.barplot(x=df['PTS'], y=df['Age'])

# %%
df.columns
# Out:
# Index(['Team', 'Pos', 'Height', 'Weight', 'BMI', 'Birth_Place', 'Age',
#        'Experience', 'Games Played', 'MIN', 'FGM', 'FGA', 'FG%', '3PM', '3PA',
#        '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
#        'TO', 'PTS', 'DD2', 'TD3'],
#       dtype='object')

# %%
df.groupby(['Team']).mean()
# Out:
#           Height     Weight        BMI        Age  Experience  Games Played  \
# Team
# ATL   185.727273  77.909091  22.528013  26.909091    5.181818     26.636364
# CHI   186.181818  79.454545  22.836069  27.090909    4.000000     22.545455
# CON   184.750000  84.750000  24.699827  25.000000    3.166667     24.583333
# DAL   186.583333  81.500000  23.296561  24.666667    2.583333     20.583333
# IND   184.083333  77.000000  22.672055  28.000000    5.666667     24.333333
# LA    185.833333  78.333333  22.707020  28.500000    5.916667     22.666667
# MIN   183.090909  80.272727  23.903961  30.545455    9.000000     26.454545
# NY    183.166667  80.833333  23.998705  26.000000    4.666667     24.833333
# PHO   185.583333  77.666667  22.396297  28.500000    5.000000     24.916667
# SAN   183.461538  77.000000  22.767770  26.692308    3.846154     25.923077
# SEA   184.333333  77.916667  22.839158  27.083333    4.750000     25.666667
# ...
