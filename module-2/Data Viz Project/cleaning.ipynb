# %%
#https://data.world/agriculture/crop-production
    
import pandas as pd

wheat = pd.read_csv('./agriculture-crop-production/Production_Crops_E_Europe.csv')
wheat.head()
# Out:
#    Area Code     Area  Item Code      Item  Element Code         Element  \
# 0          3  Albania        515    Apples          5312  Area harvested
# 1          3  Albania        515    Apples          5419           Yield
# 2          3  Albania        515    Apples          5510      Production
# 3          3  Albania        526  Apricots          5312  Area harvested
# 4          3  Albania        526  Apricots          5419           Yield
#
#      Unit    Y1961 Y1961F   Y1962  ...     Y2010  Y2010F     Y2011  Y2011F  \
# 0      ha      NaN      M     NaN  ...    3839.0      Im    3450.0     NaN
# 1   hg/ha      NaN    NaN     NaN  ...  142221.0      Fc  185507.0      Fc
# 2  tonnes  10004.0    NaN  8039.0  ...   54604.0     NaN   64000.0     NaN
# 3      ha      NaN      M     NaN  ...     273.0      Im     300.0     NaN
# 4   hg/ha      NaN    NaN     NaN  ...  126971.0      Fc  130000.0      Fc
#
#       Y2012  Y2012F     Y2013  Y2013F     Y2014  Y2014F
# ...

# %%
wheat.columns.values
# Out:
# array(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code',
#        'Element', 'Unit', 'Y1961', 'Y1961F', 'Y1962', 'Y1962F', 'Y1963',
#        'Y1963F', 'Y1964', 'Y1964F', 'Y1965', 'Y1965F', 'Y1966', 'Y1966F',
#        'Y1967', 'Y1967F', 'Y1968', 'Y1968F', 'Y1969', 'Y1969F', 'Y1970',
#        'Y1970F', 'Y1971', 'Y1971F', 'Y1972', 'Y1972F', 'Y1973', 'Y1973F',
#        'Y1974', 'Y1974F', 'Y1975', 'Y1975F', 'Y1976', 'Y1976F', 'Y1977',
#        'Y1977F', 'Y1978', 'Y1978F', 'Y1979', 'Y1979F', 'Y1980', 'Y1980F',
#        'Y1981', 'Y1981F', 'Y1982', 'Y1982F', 'Y1983', 'Y1983F', 'Y1984',
#        'Y1984F', 'Y1985', 'Y1985F', 'Y1986', 'Y1986F', 'Y1987', 'Y1987F',
#        'Y1988', 'Y1988F', 'Y1989', 'Y1989F', 'Y1990', 'Y1990F', 'Y1991',
#        'Y1991F', 'Y1992', 'Y1992F', 'Y1993', 'Y1993F', 'Y1994', 'Y1994F',
#        'Y1995', 'Y1995F', 'Y1996', 'Y1996F', 'Y1997', 'Y1997F', 'Y1998',
#        'Y1998F', 'Y1999', 'Y1999F', 'Y2000', 'Y2000F', 'Y2001', 'Y2001F',
# ...

# %%
wheat.shape
# Out:
# (10464, 115)

# %%
wheat_droped = wheat.drop(['Y1961F', 'Y1962F','Y1963F','Y1964F','Y1964F','Y1965F','Y1966F','Y1967F','Y1968F',
           'Y1969F','Y1970F','Y1971F','Y1972F','Y1973F','Y1974F','Y1975F','Y1976F','Y1977F','Y1978F',
           'Y1979F','Y1980F','Y1981F','Y1982F','Y1983F','Y1984F','Y1985F','Y1986F','Y1987F','Y1988F',
           'Y1989F','Y1990F','Y1991F','Y1992F','Y1993F','Y1994F','Y1995F','Y1996F','Y1997F','Y1998F',
           'Y1999F','Y2000F','Y2001F','Y2002F','Y2003F','Y2004F','Y2005F','Y2006F','Y2007F','Y2008F',
           'Y2009F','Y2010F','Y2011F','Y2012F','Y2013F','Y2014F'], axis=1)

# %%
wheat_droped[wheat_droped.isnull().any(axis=1)]
# Out:
#        Area Code          Area  Item Code                      Item  \
# 0              3       Albania        515                    Apples
# 1              3       Albania        515                    Apples
# 3              3       Albania        526                  Apricots
# 4              3       Albania        526                  Apricots
# 9              3       Albania         44                    Barley
# ...          ...           ...        ...                       ...
# 10459        248  Yugoslav SFR       1735        Vegetables Primary
# 10460        248  Yugoslav SFR       1735        Vegetables Primary
# 10461        248  Yugoslav SFR       1800  Vegetables&Melons, Total
# 10462        248  Yugoslav SFR       1800  Vegetables&Melons, Total
# 10463        248  Yugoslav SFR       1800  Vegetables&Melons, Total
#
#        Element Code         Element    Unit      Y1961      Y1962      Y1963  \
# ...

# %%
wheat_last_tenyears = wheat_droped[['Area','Item','Element','Unit','Y2004','Y2005',
                                    'Y2006','Y2007','Y2008','Y2009','Y2010','Y2011','Y2012','Y2013','Y2014']]
wheat_last_tenyears.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10464 entries, 0 to 10463
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Area     10464 non-null  object
#  1   Item     10464 non-null  object
#  2   Element  10464 non-null  object
#  3   Unit     10464 non-null  object
#  4   Y2004    8259 non-null   float64
#  5   Y2005    8296 non-null   float64
#  6   Y2006    8490 non-null   float64
#  7   Y2007    8517 non-null   float64
#  8   Y2008    8559 non-null   float64
#  9   Y2009    8603 non-null   float64
#  10  Y2010    8635 non-null   float64
#  11  Y2011    8639 non-null   float64
#  12  Y2012    8635 non-null   float64
#  13  Y2013    8642 non-null   float64
#  14  Y2014    7795 non-null   float64
# dtypes: float64(11), object(4)
# memory usage: 1.2+ MB

# %%
wheat_last_tenyears[wheat_last_tenyears.isnull().any(axis=1)]
# Out:
#                Area                      Item         Element    Unit   Y2004  \
# 9           Albania                    Barley            Seed  tonnes   450.0
# 13          Albania                Beans, dry            Seed  tonnes  3340.0
# 43          Albania                Cottonseed            Seed  tonnes   162.0
# 56          Albania         Fruit, citrus nes  Area harvested      ha     NaN
# 57          Albania         Fruit, citrus nes           Yield   hg/ha     NaN
# ...             ...                       ...             ...     ...     ...
# 10459  Yugoslav SFR        Vegetables Primary           Yield   hg/ha     NaN
# 10460  Yugoslav SFR        Vegetables Primary      Production  tonnes     NaN
# 10461  Yugoslav SFR  Vegetables&Melons, Total  Area harvested      ha     NaN
# 10462  Yugoslav SFR  Vegetables&Melons, Total           Yield   hg/ha     NaN
# 10463  Yugoslav SFR  Vegetables&Melons, Total      Production  tonnes     NaN
#
# ...

# %%
wheat_cleaned = wheat_last_tenyears.dropna()
wheat_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7193 entries, 0 to 9881
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Area     7193 non-null   object
#  1   Item     7193 non-null   object
#  2   Element  7193 non-null   object
#  3   Unit     7193 non-null   object
#  4   Y2004    7193 non-null   float64
#  5   Y2005    7193 non-null   float64
#  6   Y2006    7193 non-null   float64
#  7   Y2007    7193 non-null   float64
#  8   Y2008    7193 non-null   float64
#  9   Y2009    7193 non-null   float64
#  10  Y2010    7193 non-null   float64
#  11  Y2011    7193 non-null   float64
#  12  Y2012    7193 non-null   float64
#  13  Y2013    7193 non-null   float64
#  14  Y2014    7193 non-null   float64
# dtypes: float64(11), object(4)
# memory usage: 899.1+ KB

# %%
wheat_cleaned[wheat_cleaned.Unit == 'tonnes'].to_csv('european_wheat_cleaned.csv', index=False)
