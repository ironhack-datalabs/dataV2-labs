# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1
#
# #### Read the `employees` dataset from Ironhack's database:
# * db: `employees`
# * table: `employees`
#
# Save your data in a variable called `employees`.

# %%
employees = pd.read_csv("../Employees.csv")
employees
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %% [markdown]
# #### What's the mean `Salary` by `Department`?
# **Tip**: There are 2 ways to do it: with or without pivot tables. Do it both ways.

# %%
employees.pivot_table(index=["Department"])
# Out:
#                Salary     Years
# Department
# Admin       76.325203  7.642276
# HR          74.237705  7.172131
# IT          70.671642  8.141791
# Sales       73.132231  7.206612

# %%
employees.groupby("Department").mean()
# Out:
#                Years     Salary
# Department
# Admin       7.642276  76.325203
# HR          7.172131  74.237705
# IT          8.141791  70.671642
# Sales       7.206612  73.132231

# %% [markdown]
# #### Now, group the data by more than one column. Use Pandas pivot table function to select the mean `Salary` by `Department` and `Title`.

# %%
employees.pivot_table(index=["Department", "Title"])
# Out:
#                          Salary     Years
# Department Title
# Admin      Analyst    77.736842  7.684211
#            VP         75.571429  8.142857
#            associate  75.813953  7.116279
# HR         Analyst    71.404762  7.761905
#            VP         75.441176  5.823529
#            associate  75.934783  7.630435
# IT         Analyst    69.600000  7.688889
#            VP         74.000000  8.702128
#            associate  68.095238  8.000000
# Sales      Analyst    76.074074  8.166667
#            VP         66.675000  7.325000
#            associate  76.814815  5.111111

# %%
employees.groupby(["Department", "Title"]).mean()
# Out:
#                          Years     Salary
# Department Title
# Admin      Analyst    7.684211  77.736842
#            VP         8.142857  75.571429
#            associate  7.116279  75.813953
# HR         Analyst    7.761905  71.404762
#            VP         5.823529  75.441176
#            associate  7.630435  75.934783
# IT         Analyst    7.688889  69.600000
#            VP         8.702128  74.000000
#            associate  8.000000  68.095238
# Sales      Analyst    8.166667  76.074074
#            VP         7.325000  66.675000
#            associate  5.111111  76.814815

# %% [markdown]
# #### Display the number of `Years` of work experience and the `Salary` for each `Title`. Add `Years` as a column in your pivot table.
# **Hint**: Use Pandas documentation to explore the [pivot table](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) function.

# %%
employees.pivot_table(index=["Title"], values=["Years", "Salary"])
# Out:
#               Salary     Years
# Title
# Analyst    73.703911  7.849162
# VP         72.907975  7.619632
# associate  73.968354  7.158228

# %% [markdown]
# #### Find the mean `Salary` and number of employees in each `Department` and for each job `Title`.

# %%
employees.pivot_table(index=["Department", "Title"], values=["Salary"])
# Out:
#                          Salary
# Department Title
# Admin      Analyst    77.736842
#            VP         75.571429
#            associate  75.813953
# HR         Analyst    71.404762
#            VP         75.441176
#            associate  75.934783
# IT         Analyst    69.600000
#            VP         74.000000
#            associate  68.095238
# Sales      Analyst    76.074074
#            VP         66.675000
#            associate  76.814815

# %% [markdown]
# #### For each `Department` and each job `Title`, find the `Salary` median, minimum, maximum and standard deviation. Comment your results.

# %%
employees.pivot_table(index=["Department", "Title"], values=["Salary"], aggfunc=[np.mean,np.median, np.max, np.min])
# Out:
#                            mean median   amax   amin
#                          Salary Salary Salary Salary
# Department Title
# Admin      Analyst    77.736842   80.5    120     33
#            VP         75.571429   75.5    120     31
#            associate  75.813953   79.0    119     30
# HR         Analyst    71.404762   72.5    119     31
#            VP         75.441176   76.5    119     32
#            associate  75.934783   76.0    119     30
# IT         Analyst    69.600000   69.0    119     30
#            VP         74.000000   71.0    120     31
#            associate  68.095238   59.5    117     33
# Sales      Analyst    76.074074   72.0    120     30
#            VP         66.675000   60.0    119     30
#            associate  76.814815   79.0    120     31

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
#there are no missing values

# %% [markdown]
# #### The stake holders want to know, for each `Department`, the number of employees and how much money is spent on salaries. Could you provide that information?

# %%
employees.pivot_table(index=["Department"], values=["Salary"], aggfunc=[np.mean, np.count_nonzero])
# Out:
#                  mean count_nonzero
#                Salary        Salary
# Department
# Admin       76.325203           123
# HR          74.237705           122
# IT          70.671642           134
# Sales       73.132231           121

# %% [markdown]
# #### For each `Department` and `Title`, find the the total years of work experience and the mean `Salary`.

# %%
employees.pivot_table(index=["Department", "Title"], values=["Years","Salary"], aggfunc=[np.sum, np.mean])
# Out:
#                         sum             mean
#                      Salary Years     Salary     Years
# Department Title
# Admin      Analyst     2954   292  77.736842  7.684211
#            VP          3174   342  75.571429  8.142857
#            associate   3260   306  75.813953  7.116279
# HR         Analyst     2999   326  71.404762  7.761905
#            VP          2565   198  75.441176  5.823529
#            associate   3493   351  75.934783  7.630435
# IT         Analyst     3132   346  69.600000  7.688889
#            VP          3478   409  74.000000  8.702128
#            associate   2860   336  68.095238  8.000000
# Sales      Analyst     4108   441  76.074074  8.166667
#            VP          2667   293  66.675000  7.325000
#            associate   2074   138  76.814815  5.111111

# %% [markdown]
# ## Bonus Challenge 1
#
# #### Compute the mean `Salary` after removing the maximum `Salary` for each `Department`. Create the appropriate pivot table.
# **Hint**: Write a custom function.

# %%
# your code here

# %% [markdown]
# # Challenge 2
#
# #### Read the `fitbit` dataset from Ironhack's database:
# * db: `fitbit`
# * table: `fitbit`
#
# Save your data in a variable called `fitbit`.

# %%
fitbit = pd.read_csv("../Fitbit2.csv")
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics.
# **Hint**: Use Pandas functions from previous lectures.

# %%
fitbit.describe()
# Out:
#        Calorie burned         Steps    Distance      Floors  \
# count      367.000000    367.000000  367.000000  367.000000
# mean      2741.501362  10121.588556    8.549128   11.724796
# std        916.307036   5594.836225    3.409881   10.337370
# min        179.000000      0.000000    0.000000    0.000000
# 25%       2698.000000   6730.500000    6.155000    5.000000
# 50%       2974.000000  10413.000000    8.290000   11.000000
# 75%       3233.000000  13916.500000   10.560000   16.000000
# max       4351.000000  26444.000000   20.450000  101.000000
#
#        Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# count         367.000000              367.000000             367.000000
# mean          563.934482              236.405995              26.163488
# std           294.793145               86.531376              20.319456
# min             1.002000                0.000000               0.000000
# ...

# %%
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
# Date                          367 non-null object
# Calorie burned                367 non-null int64
# Steps                         367 non-null int64
# Distance                      367 non-null float64
# Floors                        367 non-null int64
# Minutes Sedentary             367 non-null float64
# Minutes Lightly Active        367 non-null int64
# Minutes Fairly Active         367 non-null int64
# Minutes Very Active           367 non-null int64
# Activity Calories             367 non-null int64
# MinutesOfSleep                367 non-null int64
# MinutesOfBeingAwake           367 non-null int64
# NumberOfAwakings              367 non-null int64
# LengthOfRestInMinutes         367 non-null int64
# Distance_miles                367 non-null float64
# Days                          367 non-null object
# Days_encoded                  367 non-null float64
# ...

# %% [markdown]
# #### You suspect that there must be a linear relationship between the `Minutes Very Active` and the `Steps`. Compute the correlation between these variables.

# %%
fitbit.corr() #0.571452
# Out:
#                             Calorie burned     Steps  Distance    Floors  \
# Calorie burned                    1.000000  0.255305  0.292790  0.130757
# Steps                             0.255305  1.000000  0.779678  0.306511
# Distance                          0.292790  0.779678  1.000000  0.382940
# Floors                            0.130757  0.306511  0.382940  1.000000
# Minutes Sedentary                 0.125353  0.076906  0.160632  0.057812
# Minutes Lightly Active            0.209540  0.393010  0.455272 -0.085992
# Minutes Fairly Active             0.188256  0.303244  0.348113  0.278408
# Minutes Very Active               0.197881  0.571452  0.759310  0.399503
# Activity Calories                -0.130758 -0.160568 -0.246853 -0.155532
# MinutesOfSleep                    0.011485  0.130986  0.129442  0.069464
# MinutesOfBeingAwake               0.041999  0.124846  0.130447  0.064587
# NumberOfAwakings                  0.030490  0.106591  0.091095  0.043459
# ...

# %% [markdown]
# #### Use matplotlib to visually plot `Minutes Very active` vs `Steps`. We'll work with matplotlib next week. As a first introduction, uncomment and complete the following code. You need to replace the # symbol for the correct function arguments.

# %%
import matplotlib.pyplot as plt;

# %%
plt.scatter(fitbit["Minutes Very Active"], fitbit["Steps"])
plt.title("Correlation1")
plt.xlabel("Minutes Avtice")
plt.ylabel("Steps")
# Out:
# Text(0, 0.5, 'Steps')

# %% [markdown]
# #### What can you say about `Minutes Very Active` and `Steps`? Write a comment below.

# %%
#there is a positive correlation

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the `Minutes Sedentary` and the `Steps`. Compute the correlation between these variables.

# %%
fitbit["Minutes Sedentary"].corr(fitbit["Steps"])
# Out:
# 0.07690608062990091

# %% [markdown]
# #### Use matplotlib to visually plot `Minutes Sedentary` vs `Steps`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
plt.scatter(fitbit["Minutes Sedentary"], fitbit["Steps"])
plt.title("Correlation2")
plt.xlabel("Minutes Sedentary")
plt.ylabel("Steps")
plt.show()

# %%
#there is a positive correlation but its rather weak. Not even sure if it significant

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the `MinutesOfSleep` and the `Steps`. Compute the correlation between these variables.

# %%
fitbit["MinutesOfSleep"].corr(fitbit["Steps"])
# Out:
# 0.1309856595083638

# %% [markdown]
# #### Use matplotlib to visually plot `MinutesOfSleep` vs `Steps`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
plt.scatter(fitbit["MinutesOfSleep"], fitbit["Steps"])
plt.title("Correlation3")
plt.xlabel("Minutes of Sleep")
plt.ylabel("Steps")
# Out:
# Text(0, 0.5, 'Steps')

# %%
# there seems to be a weak psoitive relationship
# i.e. people that sleep longer actually move more, even though they technically would have less time than a 
# person sleeping less. However, they might have more energy or care about their health more in general
# or the reason why some people sleep less is that they have to work a lot which also prevents them from going 
# longer distances. However, the correlation is rather weak.

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`.

# %%
columns = ['Calorie burned', 'Steps', 'Floors', 'Minutes Sedentary', 'Minutes Very Active', 'MinutesOfSleep']

# %%
subset =fitbit[columns]
subset
# Out:
#      Calorie burned  Steps  Floors  Minutes Sedentary  Minutes Very Active  \
# 0              1934    905       0              1.355                    0
# 1              3631  18925       4            611.000                   60
# 2              3204  14228       1            602.000                   77
# 3              2673   6756       8            749.000                    4
# 4              2495    502       1            876.000                    0
# ..              ...    ...     ...                ...                  ...
# 362            3796  18588      16            599.000                   79
# 363            3525  16382      16            684.000                   55
# 364            3649  21913      19            701.000                   90
# 365            3539  19023      15            575.000                   85
# 366             304   9526       2            564.000                   10
#
#      MinutesOfSleep
# 0               384
# 1               454
# ...

# %%
subset_corr = subset.corr()
subset_corr
# Out:
#                      Calorie burned     Steps    Floors  Minutes Sedentary  \
# Calorie burned             1.000000  0.255305  0.130757           0.125353
# Steps                      0.255305  1.000000  0.306511           0.076906
# Floors                     0.130757  0.306511  1.000000           0.057812
# Minutes Sedentary          0.125353  0.076906  0.057812           1.000000
# Minutes Very Active        0.197881  0.571452  0.399503           0.105963
# MinutesOfSleep             0.011485  0.130986  0.069464           0.204242
#
#                      Minutes Very Active  MinutesOfSleep
# Calorie burned                  0.197881        0.011485
# Steps                           0.571452        0.130986
# Floors                          0.399503        0.069464
# Minutes Sedentary               0.105963        0.204242
# Minutes Very Active             1.000000        0.108018
# MinutesOfSleep                  0.108018        1.000000

# %% [markdown]
# #### Based on the result of the correlation matrix, which of the features are highly correlated with variable `Steps`?
# **Hint**: sort the correlations of `Steps` vs the rest of the features in descending order. You can use Pandas `sort_values`.

# %%
subset_corr.sort_values("Steps")
# Out:
#                      Calorie burned     Steps    Floors  Minutes Sedentary  \
# Minutes Sedentary          0.125353  0.076906  0.057812           1.000000
# MinutesOfSleep             0.011485  0.130986  0.069464           0.204242
# Calorie burned             1.000000  0.255305  0.130757           0.125353
# Floors                     0.130757  0.306511  1.000000           0.057812
# Minutes Very Active        0.197881  0.571452  0.399503           0.105963
# Steps                      0.255305  1.000000  0.306511           0.076906
#
#                      Minutes Very Active  MinutesOfSleep
# Minutes Sedentary               0.105963        0.204242
# MinutesOfSleep                  0.108018        1.000000
# Calorie burned                  0.197881        0.011485
# Floors                          0.399503        0.069464
# Minutes Very Active             1.000000        0.108018
# Steps                           0.571452        0.130986

# %% [markdown]
# # Challenge 3
#
# #### Read the `time_grades` dataset from Ironhack's database:
# * db: `time_grades`
# * table: `time_grades`
#
# Save your data in a variable called `time_grades`.

# %%
time_grades = pd.read_csv("../student-por.csv", sep=";")
time_grades
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# #### Show visually the frequency distribution of the `time_grades` dataset.

# %%
time_grades.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f1f35d0>,
# ...
#       dtype=object)

# %%
# %matplotlib inline

time_grades.boxplot()

# %% [markdown]
# #### Is there a correlation between `Study time` and `Grade`? Use both Pearson and Spearman correlations and comment your results.

# %%
time_grades.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.107832 -0.121050    0.034490  -0.008415  0.319968
# Medu       -0.107832  1.000000  0.647477   -0.265079   0.097006 -0.172210
# Fedu       -0.121050  0.647477  1.000000   -0.208288   0.050400 -0.165915
# traveltime  0.034490 -0.265079 -0.208288    1.000000  -0.063154  0.097730
# studytime  -0.008415  0.097006  0.050400   -0.063154   1.000000 -0.147441
# failures    0.319968 -0.172210 -0.165915    0.097730  -0.147441  1.000000
# famrel     -0.020559  0.024421  0.020256   -0.009521  -0.004127 -0.062645
# freetime   -0.004910 -0.019686  0.006841    0.000937  -0.068829  0.108995
# goout       0.112805  0.009536  0.027690    0.057454  -0.075442  0.045078
# Dalc        0.134768 -0.007018  0.000061    0.092824  -0.137585  0.105949
# Walc        0.086357 -0.019766  0.038445    0.057007  -0.214925  0.082266
# health     -0.008750  0.004614  0.044910   -0.048261  -0.056433  0.035588
# ...

# %%
time_grades.studytime.corr(time_grades.G1, method="spearman")
# Out:
# 0.27141154061500294

# %%
time_grades.studytime.corr(time_grades.G1, method="pearson")
# Out:
# 0.26087538031319013

# %% [markdown]
# #### Use matplotlib to visually plot `Study time` vs `Grade`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
plt.scatter(time_grades["studytime"], time_grades["G1"])
plt.title("Correlation3")
plt.xlabel("Minutes of Sleep")
plt.ylabel("Steps")
# Out:
# Text(0, 0.5, 'Steps')

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlations?

# %%
"""
Internet Research: 
The Pearson correlation evaluates the linear relationship between two continuous variables. A relationship is 
linear when a change in one variable is associated with a proportional change in the other variable.

The Spearman correlation evaluates the monotonic relationship between two continuous or ordinal variables. In a 
monotonic relationship, the variables tend to change together, but not necessarily at a constant rate. The 
Spearman correlation coefficient is based on the ranked values for each variable rather than the raw data.

Retrieved from https://support.minitab.com/en-us/minitab-express/1/help-and-how-to/modeling-statistics/regression/
supporting-topics/basics/a-comparison-of-the-pearson-and-spearman-correlation-methods/
"""
# Out:
# '\nyour commments here\n'
