# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import os

# %%
data = pd.read_csv('/Users/vpavandijk/LEARNING/Ironhack/week 7 project/DATA/FAOSTAT/Prices_E_All_Data/Prices_E_All_Data.csv', encoding='latin1')
data.head()
# Out:
#    Area Code         Area  Item Code                              Item  \
# 0          2  Afghanistan        221               Almonds, with shell
# 1          2  Afghanistan        221               Almonds, with shell
# 2          2  Afghanistan        221               Almonds, with shell
# 3          2  Afghanistan        711  Anise, badian, fennel, coriander
# 4          2  Afghanistan        515                            Apples
#
#    Element Code                                 Element  Months Code  \
# 0          5530              Producer Price (LCU/tonne)         7021
# 1          5531              Producer Price (SLC/tonne)         7021
# 2          5539  Producer Price Index (2014-2016 = 100)         7021
# 3          5539  Producer Price Index (2014-2016 = 100)         7021
# 4          5530              Producer Price (LCU/tonne)         7021
#
#          Months Unit  Y1991 Y1991F  Y1992 Y1992F     Y1993 Y1993F     Y1994  \
# ...

# %%
data.describe().transpose()
data.shape
# Out:
# (89034, 65)

# %%
item = data['Item']
item_set = set(item)
len(item_set)
# Out:
# 235

# %%
data_apples = data[data['Item'] == 'Apples']
data_apples
# Out:
#        Area Code         Area  Item Code    Item  Element Code  \
# 4              2  Afghanistan        515  Apples          5530
# 5              2  Afghanistan        515  Apples          5531
# 6              2  Afghanistan        515  Apples          5539
# 108            3      Albania        515  Apples          5530
# 109            3      Albania        515  Apples          5530
# ...          ...          ...        ...     ...           ...
# 88316        181     Zimbabwe        515  Apples          5530
# 88317        181     Zimbabwe        515  Apples          5530
# 88318        181     Zimbabwe        515  Apples          5531
# 88319        181     Zimbabwe        515  Apples          5532
# 88320        181     Zimbabwe        515  Apples          5539
#
#                                       Element  Months Code        Months Unit  \
# 4                  Producer Price (LCU/tonne)         7021  Annual value  LCU
# ...

# %%
data_norm = pd.read_csv('/Users/vpavandijk/LEARNING/Ironhack/week 7 project/DATA/FAOSTAT/Prices_E_All_Data_(Normalized)/Prices_E_All_Data_(Normalized).csv', encoding='latin1')
data_norm.head(60)
# Out:
#     Area Code         Area  Item Code                              Item  \
# 0           2  Afghanistan        221               Almonds, with shell
# 1           2  Afghanistan        221               Almonds, with shell
# 2           2  Afghanistan        221               Almonds, with shell
# 3           2  Afghanistan        221               Almonds, with shell
# 4           2  Afghanistan        221               Almonds, with shell
# 5           2  Afghanistan        221               Almonds, with shell
# 6           2  Afghanistan        221               Almonds, with shell
# 7           2  Afghanistan        221               Almonds, with shell
# 8           2  Afghanistan        221               Almonds, with shell
# 9           2  Afghanistan        221               Almonds, with shell
# 10          2  Afghanistan        221               Almonds, with shell
# 11          2  Afghanistan        221               Almonds, with shell
# ...

# %%
data_norm.shape
# Out:
# (979720, 13)

# %%
data_norm_apples = data_norm[data_norm['Item'] == 'Apples']
data_norm_apples
# Out:
#         Area Code         Area  Item Code    Item  Element Code  \
# 78              2  Afghanistan        515  Apples          5530
# 79              2  Afghanistan        515  Apples          5530
# 80              2  Afghanistan        515  Apples          5530
# 81              2  Afghanistan        515  Apples          5530
# 82              2  Afghanistan        515  Apples          5530
# ...           ...          ...        ...     ...           ...
# 976583        181     Zimbabwe        515  Apples          5539
# 976584        181     Zimbabwe        515  Apples          5539
# 976585        181     Zimbabwe        515  Apples          5539
# 976586        181     Zimbabwe        515  Apples          5539
# 976587        181     Zimbabwe        515  Apples          5539
#
#                                        Element  Year Code  Year  Months Code  \
# 78                  Producer Price (LCU/tonne)       1993  1993         7021
# ...

# %%
data_eu_test = pd.read_csv('/Users/vpavandijk/LEARNING/Ironhack/week 7 project/DATA/EUROSTAT/Extra-EU28 trade, by Member State, total product(tet00055).tsv', sep='\t')
data_eu_test_2 = data_eu_test.drop(data_eu_test.index[[0,1,2,3]])
data_eu_test_2
# Out:
#     indic_et,sitc06,partner,geo\time     2008      2009      2010      2011   \
# 4      CONT_EXP_EU,TOTAL,EXT_EU28,CZ       1.1       1.1       1.2       1.3
# 5      CONT_EXP_EU,TOTAL,EXT_EU28,DE      27.3      27.4      27.8      27.6
# 6      CONT_EXP_EU,TOTAL,EXT_EU28,DK       1.8       2.0       1.8       1.8
# 7      CONT_EXP_EU,TOTAL,EXT_EU28,EE       0.2       0.2       0.2       0.3
# 8      CONT_EXP_EU,TOTAL,EXT_EU28,EL       0.6       0.7       0.7       0.7
# ..                               ...       ...       ...       ...       ...
# 140    MIO_IMP_VAL,TOTAL,EXT_EU28,RO   17259.3   10430.9   12822.6   14924.5
# 141    MIO_IMP_VAL,TOTAL,EXT_EU28,SE   35305.6   27516.7   36995.1   40451.3
# 142    MIO_IMP_VAL,TOTAL,EXT_EU28,SI    6194.5    4708.4    6242.0    7103.6
# 143    MIO_IMP_VAL,TOTAL,EXT_EU28,SK   13483.3    9970.3   13781.2   15365.2
# 144    MIO_IMP_VAL,TOTAL,EXT_EU28,UK  217529.3  188181.9  226954.0  252696.4
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:@localhost:3306/IH_week7_project')

test = pd.read_sql_table('data_norm_eu28', engine)
test
# Out:
#         index  Area Code     Area  Item Code          Item  Element Code  \
# 0       43463         11  Austria        515        Apples          5530
# 1       43464         11  Austria        515        Apples          5530
# 2       43465         11  Austria        515        Apples          5530
# 3       43466         11  Austria        515        Apples          5530
# 4       43467         11  Austria        515        Apples          5530
# ...       ...        ...      ...        ...           ...           ...
# 36481  849844        210   Sweden        987  Wool, greasy          5530
# 36482  849845        210   Sweden        987  Wool, greasy          5530
# 36483  849846        210   Sweden        987  Wool, greasy          5530
# 36484  849847        210   Sweden        987  Wool, greasy          5530
# 36485  849848        210   Sweden        987  Wool, greasy          5530
#
#                           Element  Year Code  Year  Months Code        Months  \
# ...
