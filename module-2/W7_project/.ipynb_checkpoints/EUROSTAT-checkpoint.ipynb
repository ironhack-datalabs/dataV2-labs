# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_eu_extra = pd.read_csv('/Users/vpavandijk/LEARNING/Ironhack/week 7 project/DATA/EUROSTAT/Extra-EU28 trade, by Member State, total product(tet00055).tsv', sep='\t')
data_eu_extra
# Out:
#     indic_et,sitc06,partner,geo\time     2008      2009      2010      2011   \
# 0      CONT_EXP_EU,TOTAL,EXT_EU28,AT       2.5       2.4       2.4       2.3
# 1      CONT_EXP_EU,TOTAL,EXT_EU28,BE       5.6       5.9       6.1       6.2
# 2      CONT_EXP_EU,TOTAL,EXT_EU28,BG       0.5       0.4       0.4       0.5
# 3      CONT_EXP_EU,TOTAL,EXT_EU28,CY       0.0       0.0       0.0       0.0
# 4      CONT_EXP_EU,TOTAL,EXT_EU28,CZ       1.1       1.1       1.2       1.3
# ..                               ...       ...       ...       ...       ...
# 140    MIO_IMP_VAL,TOTAL,EXT_EU28,RO   17259.3   10430.9   12822.6   14924.5
# 141    MIO_IMP_VAL,TOTAL,EXT_EU28,SE   35305.6   27516.7   36995.1   40451.3
# 142    MIO_IMP_VAL,TOTAL,EXT_EU28,SI    6194.5    4708.4    6242.0    7103.6
# 143    MIO_IMP_VAL,TOTAL,EXT_EU28,SK   13483.3    9970.3   13781.2   15365.2
# 144    MIO_IMP_VAL,TOTAL,EXT_EU28,UK  217529.3  188181.9  226954.0  252696.4
#
# ...

# %%
data_eu_extra.columns
data_eu_extra = data_eu_extra.rename({'indic_et,sitc06,partner,geo\\time': 'original_name'}, axis=1)
data_eu_extra

data_eu_extra['Country'] = data_eu_extra['original_name'].str[-2:]
data_eu_extra
data_eu_extra = data_eu_extra[['original_name', 'Country', '2008 ', '2009 ', '2010 ', '2011 ','2012 ', '2013 ', '2014 ', '2015 ', '2016 ', '2017 ', '2018 ', '2019 ']]
data_eu_extra

data_eu_extra_numbers = data_eu_extra.loc[np.r_[58:87]]
data_eu_extra_numbers
# data_eu_extra_numbers.to_csv('data_eu_extra_numbers.csv')
# data_eu_extra_numbers_NL = data_eu_extra_numbers[data_eu_extra_numbers['Country'] == 'NL']
# data_eu_extra_numbers_NL
# data_eu_extra_numbers_all = data_eu_extra_numbers[data_eu_extra_numbers['Country'] == '28']
# data_eu_extra_numbers_all
# Out:
#                       original_name Country     2008      2009      2010   \
# 58    MIO_BAL_VAL,TOTAL,EXT_EU28,AT      AT    5935.8    4556.6    5491.8
# 59    MIO_BAL_VAL,TOTAL,EXT_EU28,BE      BE  -21443.7  -10693.6   -8179.7
# 60    MIO_BAL_VAL,TOTAL,EXT_EU28,BG      BG   -4842.7   -2686.2   -1942.8
# 61    MIO_BAL_VAL,TOTAL,EXT_EU28,CY      CY   -1973.2   -1245.7   -1553.3
# 62    MIO_BAL_VAL,TOTAL,EXT_EU28,CZ      CZ   -7642.8   -4434.8   -8201.5
# 63    MIO_BAL_VAL,TOTAL,EXT_EU28,DE      DE   65462.9   65411.1   84616.0
# 64    MIO_BAL_VAL,TOTAL,EXT_EU28,DK      DK    2820.6    3859.2    6091.1
# 65    MIO_BAL_VAL,TOTAL,EXT_EU28,EE      EE     332.5     549.8     872.6
# 66    MIO_BAL_VAL,TOTAL,EXT_EU28,EL      EL  -20501.2  -15005.6  -12675.6
# 67    MIO_BAL_VAL,TOTAL,EXT_EU28,ES      ES  -58506.1  -30122.6  -41136.1
# 68  MIO_BAL_VAL,TOTAL,EXT_EU28,EU28      28 -276280.9 -142114.5 -175134.6
# 69    MIO_BAL_VAL,TOTAL,EXT_EU28,FI      FI    5174.4    4712.0    5320.6
# ...

# %%
data_eu_intra = pd.read_csv('/Users/vpavandijk/LEARNING/Ironhack/week 7 project/DATA/EUROSTAT/Intra-EU28 trade, by Member State, total product(tet00047).tsv', sep='\t')
data_eu_intra
# Out:
#     indic_et,sitc06,partner,geo\time     2008      2009      2010      2011   \
# 0          CONT_EXP_EU,TOTAL,EU28,AT       3.3       3.2       3.3       3.2
# 1          CONT_EXP_EU,TOTAL,EU28,BE       9.0       9.1       8.8       8.7
# 2          CONT_EXP_EU,TOTAL,EU28,BG       0.3       0.3       0.4       0.4
# 3          CONT_EXP_EU,TOTAL,EU28,CY       0.0       0.0       0.0       0.0
# 4          CONT_EXP_EU,TOTAL,EU28,CZ       3.1       3.1       3.3       3.5
# ..                               ...       ...       ...       ...       ...
# 140        MIO_IMP_VAL,TOTAL,EU28,RO   39888.6   28516.7   34027.1   40018.3
# 141        MIO_IMP_VAL,TOTAL,EU28,SE   79259.6   58428.2   75357.3   86722.4
# 142        MIO_IMP_VAL,TOTAL,EU28,SI   18985.2   14344.4   16477.6   18421.9
# 143        MIO_IMP_VAL,TOTAL,EU28,SK   36769.4   29927.7   36474.1   42236.5
# 144        MIO_IMP_VAL,TOTAL,EU28,UK  229698.5  184398.9  218337.4  235545.7
#
# ...

# %%
data_eu_intra.columns
data_eu_intra = data_eu_intra.rename({'indic_et,sitc06,partner,geo\\time': 'original_name'}, axis=1)
data_eu_intra

data_eu_intra['Country'] = data_eu_intra['original_name'].str[-2:]
data_eu_intra
data_eu_intra = data_eu_intra[['original_name', 'Country', '2008 ', '2009 ', '2010 ', '2011 ','2012 ', '2013 ', '2014 ', '2015 ', '2016 ', '2017 ', '2018 ', '2019 ']]
data_eu_intra

data_eu_intra_numbers = data_eu_intra.loc[np.r_[58:87]]
data_eu_intra_numbers

# data_eu_intra_numbers.to_csv('data_eu_intra_numbers.csv')

# data_eu_intra_numbers_NL = data_eu_intra_numbers[data_eu_intra_numbers['Country'] == 'NL']
# data_eu_intra_numbers_NL
# data_eu_intra_numbers_all = data_eu_intra_numbers[data_eu_intra_numbers['Country'] == '28']
# new_version = data_eu_intra_numbers_all.transpose()
# new_version = new_version.drop(['Country', '2019 '])
# new_version = new_version.rename(columns=new_version.iloc[0])
# new_version = new_version.drop(['original_name'])
# new_version = new_version.set_axis(['Balance', 'Export_Value', 'Import_Value'], axis=1, inplace=False)
# new_version
# Out:
#                   original_name Country     2008      2009      2010   \
# 58    MIO_BAL_VAL,TOTAL,EU28,AT      AT   -7978.4   -8912.0  -10356.7
# 59    MIO_BAL_VAL,TOTAL,EU28,BE      BE   25205.5   22312.3   20637.5
# 60    MIO_BAL_VAL,TOTAL,EU28,BG      BG   -5047.1   -2490.3   -1740.8
# 61    MIO_BAL_VAL,TOTAL,EU28,CY      CY   -4153.0   -3470.1   -3852.8
# 62    MIO_BAL_VAL,TOTAL,EU28,CZ      CZ   10880.0   10104.0   12976.0
# 63    MIO_BAL_VAL,TOTAL,EU28,DE      DE  112062.6   73457.2   69347.9
# 64    MIO_BAL_VAL,TOTAL,EU28,DK      DK    2319.7    3920.4    4007.8
# 65    MIO_BAL_VAL,TOTAL,EU28,EE      EE   -2758.8   -1332.8   -1397.9
# 66    MIO_BAL_VAL,TOTAL,EU28,EL      EL  -23800.5  -20117.4  -15811.6
# 67    MIO_BAL_VAL,TOTAL,EU28,ES      ES  -36211.0  -17109.5  -13625.9
# 68  MIO_BAL_VAL,TOTAL,EU28,EU28      28   74176.7   65796.7   70557.1
# 69    MIO_BAL_VAL,TOTAL,EU28,FI      FI   -1996.6   -3303.2   -4781.4
# ...

# %%
data_eu_total = data_eu_extra_numbers + data_eu_intra_numbers
data_eu_total['Country'] = data_eu_total['original_name'].str[-2:]
data_eu_total_final = data_eu_total.drop('2019 ', axis=1)
data_eu_total_final
data_eu_total_final_transpose = data_eu_total_final.transpose()
data_eu_total_final_transpose
data_eu_total_final_transpose.columns = data_eu_total_final_transpose.iloc[1]
data_eu_total_final_transpose = data_eu_total_final_transpose.drop(['original_name', 'Country'])
data_eu_total_final_transpose
# data_eu_total_final_transpose.to_csv('data_eu_total.csv')
# Out:
# Country       AT       BE      BG      CY       CZ      DE       DK      EE  \
# 2008     -2042.6   3761.8 -9889.8 -6126.2   3237.2  177526   5140.3 -2426.3
# 2009     -4355.4  11618.7 -5176.5 -4715.8   5669.2  138868   7779.6    -783
# 2010     -4864.9  12457.8 -3683.6 -5406.1   4774.5  153964  10098.9  -525.3
# 2011    -10050.2   6270.8 -3141.9 -4927.8   7768.8  157411  11638.5  -539.2
# 2012     -9263.9   5301.1   -4689 -4324.3  12164.5  191672  11882.7 -1555.8
# 2013     -6115.2  12862.8 -3556.7 -3233.6  13564.1  198655  10240.6 -1614.5
# 2014     -2828.6  13860.9 -4074.7 -3641.5  15596.2  216460   8941.1 -1693.3
# 2015     -2942.4    19202 -3469.1 -3377.6  14882.8  248196   8887.1 -1521.4
# 2016     -5102.1    16926 -2136.9 -4396.5  17710.9  251728   8844.6 -1617.9
# 2017     -6819.9  18522.7 -2433.3 -5244.7  16731.2  252294   8510.7 -1893.1
# 2018     -7578.8  11640.7 -3587.6 -4914.7  14802.7  233301   6111.9 -1796.2
#
# ...

# %%
data_eu_total_final_transpose_EU_all = data_eu_total_final_transpose['28']
data_eu_total_final_transpose_EU_all
# Out:
# 2008     -202104
# 2009    -76317.8
# 2010     -104578
# 2011     -108044
# 2012    -45094.2
# 2013      116556
# 2014     90579.7
# 2015      138610
# 2016      108539
# 2017     92296.8
# 2018     49362.4
# Name: 28, dtype: object
