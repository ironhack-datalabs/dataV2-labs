# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv(r"..\M2-mini-project1\diamonds_clean.csv")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53930   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53931   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53932   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53933   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53934   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        clarity_num  color_num  cut_num
# 0                2          5        5
# 1                3          5        4
# 2                5          5        2
# 3                4          1        4
# 4                2          0        2
# ...            ...        ...      ...
# 53930            3          6        5
# 53931            3          6        2
# 53932            3          6        3
# 53933            2          2        4
# 53934            2          6        5
#
# [53935 rows x 13 columns]

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53935.000000  53935.000000  53935.000000  53935.000000  53927.000000
# mean       0.797717     61.749326     57.457134   3931.939557      5.731716
# std        0.473186      1.432434      2.234505   3988.204703      1.119137
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        4.130000     79.000000     95.000000  18823.000000     10.020000
#
#                   y             z   clarity_num     color_num       cut_num
# count  53928.000000  53928.000000  53935.000000  53935.000000  53935.000000
# mean       5.733549      3.539953      4.051210      3.405970      3.904181
# std        1.111006      0.702039      1.647026      1.701001      1.116501
# min        3.680000      1.070000      1.000000      0.000000      1.000000
# 25%        4.720000      2.910000      3.000000      2.000000      3.000000
# 50%        5.710000      3.530000      4.000000      3.000000      4.000000
# 75%        6.540000      4.040000      5.000000      5.000000      5.000000
# max        9.940000     31.800000      8.000000      6.000000      5.000000

# %%
#Price variability seems very high (std > mean) and high range (18823 - 326)

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#carat, size(depth,table), cut and clarity and color are likely to positevely affect the price.

#carat is usually used  as a direct measure of the weight of a jewel

#the bigger the size of the diamond the higher the value

#cut and clarity measure the quality of the diamond

#color probably has to do with the "pureness" of the diamond

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
diamonds.groupby(["color_num"]).mean()
# Out:
#               carat      depth      table        price         x         y  \
# color_num
# 0          1.159576  61.884533  57.811903  5314.587313  6.516511  6.515374
# 1          1.026377  61.846541  57.576646  5090.006087  6.222103  6.222014
# 2          0.911668  61.837203  57.517873  4485.739010  5.984522  5.979882
# 3          0.771190  61.757111  57.288629  3999.135671  5.678549  5.681198
# 4          0.736538  61.694582  57.433536  3724.886397  5.616727  5.620634
# 5          0.657882  61.662076  57.491456  3076.854737  5.411607  5.416336
# 6          0.657795  61.698125  57.404590  3169.954096  5.417851  5.421928
#
#                   z  clarity_num   cut_num
# color_num
# 0          4.031244     3.778332  3.733785
# 1          3.845940     3.964582  3.874562
# 2          3.698622     3.933879  3.876912
# 3          3.507966     4.463425  3.991233
# 4          3.465788     4.133934  3.885559
# 5          3.340507     3.969784  3.894243
# 6          3.343320     3.691513  3.927380

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
# there is a negative relationship between color and price
# Out:
#                  price
# color_num
# 0          5314.587313
# 1          5090.006087
# 2          4485.739010
# 3          3999.135671
# 4          3724.886397
# 5          3076.854737
# 6          3169.954096

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
diamonds.groupby(["color_num"]).agg({"color_num":"count"})
# Out:
#            color_num
# color_num
# 0               2806
# 1               5421
# 2               8303
# 3              11292
# 4               9542
# 5               9796
# 6               6775

# %%
#your code here
diamonds.groupby(["color_num"]).agg({"color_num":"count"}).plot()

# %%
# the nb diamonds grows from type 1 to 3 (the largest group), it then decreases from 3 to 6 (the smallest category)

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby(["carat"]).mean()
# Out:
#            depth      table         price          x         y         z  \
# carat
# 0.20   61.100000  59.333333    365.166667   3.786667  3.753333  2.303333
# 0.21   60.511111  58.444444    380.222222   3.874444  3.837778  2.332222
# 0.22   61.620000  60.400000    391.400000   3.898000  3.848000  2.386000
# 0.23   61.426621  58.034130    486.143345   3.946382  3.973379  2.431468
# 0.24   61.599213  57.488189    505.185039   3.990157  4.019331  2.465591
# ...          ...        ...           ...        ...       ...       ...
# 3.65   67.100000  53.000000  11668.000000   9.530000  9.480000  6.380000
# 3.67   62.400000  56.000000  16193.000000   9.860000  9.810000  6.130000
# 4.00   63.300000  58.000000  15984.000000  10.010000  9.940000  6.310000
# 4.01   62.500000  62.000000  15223.000000  10.020000  9.940000  6.240000
# 4.13   64.800000  61.000000  17329.000000  10.000000  9.850000  6.430000
#
#        clarity_num  color_num   cut_num
# carat
# 0.20      3.833333   5.166667  4.166667
# 0.21      3.666667   5.444444  3.888889
# 0.22      3.600000   4.800000  3.400000
# 0.23      5.901024   4.518771  3.255973
# 0.24      5.972441   4.185039  3.555118
# ...            ...        ...       ...
# 3.65      1.000000   2.000000  1.000000
# 3.67      1.000000   1.000000  4.000000
# 4.00      1.000000   1.000000  3.000000
# 4.01      1.000000   0.000000  4.000000
# 4.13      1.000000   2.000000  1.000000
#
# [271 rows x 9 columns]

# %%
# carat has a direct positive correlation with price

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
diamonds.groupby(["carat"]).agg({"carat":"count"}).plot()

#there is a frequency of diamonds with carats between 0 - 1.5

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby(["table"]).mean()
# Out:
#         carat  depth    price      x      y      z  clarity_num  color_num  \
# table
# 43.0   1.0400  62.90   4997.0  6.450  6.410  4.040         5.00        1.0
# 44.0   0.2900  62.80    474.0  4.200  4.240  2.650         5.00        5.0
# 49.0   0.6500  64.25   2290.5  5.355  5.320  3.425         4.00        3.0
# 50.0   1.5100  61.50   8995.5  7.380  7.295  4.510         3.00        3.0
# 50.1   0.9400  66.00   3353.0  6.130  6.170  4.060         2.00        2.0
# ...       ...    ...      ...    ...    ...    ...          ...        ...
# 71.0   0.6800  58.00   1633.0  5.850  5.700  3.350         3.00        3.0
# 73.0   0.6025  68.90   2406.5  5.520  5.465  3.745         4.25        4.5
# 76.0   0.7900  65.30   2362.0  5.520  5.130  3.350         3.00        3.0
# 79.0   0.8100  68.80   2301.0  5.260  5.200  3.580         2.00        4.0
# 95.0   2.0100  58.60  13387.0  8.320  8.310  4.870         3.00        4.0
#
#        cut_num
# table
# 43.0       5.0
# 44.0       3.0
# 49.0       1.0
# 50.0       1.0
# 50.1       1.0
# ...        ...
# 71.0       1.0
# 73.0       1.0
# 76.0       1.0
# 79.0       1.0
# 95.0       1.0
#
# [127 rows x 9 columns]

# %%
# the is no clear linear relationship between table and price

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
diamonds.groupby(["clarity_num"]).mean()
# Out:
#                 carat      depth      table        price         x         y  \
# clarity_num
# 1            1.270745  62.728726  58.299593  3869.968835  6.746423  6.694919
# 2            1.077548  61.772479  57.927282  5062.251169  6.403973  6.394201
# 3            0.850482  61.853042  57.662541  3996.001148  5.888383  5.888256
# 4            0.763935  61.724417  57.417401  3924.989395  5.658633  5.659782
# 5            0.727185  61.667442  57.315435  3839.671359  5.572912  5.579302
# 6            0.596202  61.663778  57.024990  3283.737071  5.218454  5.232118
# 7            0.503321  61.624651  56.884460  2523.114637  4.961721  4.976437
# 8            0.505123  61.510615  56.507207  2864.839106  4.968402  4.989827
#
#                     z  color_num   cut_num
# clarity_num
# 1            4.214937   2.979675  2.978320
# 2            3.951987   3.470140  3.666920
# 3            3.640636   3.448450  3.747264
# 4            3.492788   3.494208  3.978871
# 5            3.441223   3.161567  4.000857
# 6            3.221465   3.569483  4.116857
# 7            3.062132   3.351573  4.228454
# 8            3.061659   3.101676  4.432961

# %%
# there seems to be a sightly negative relationship between price and clarity, however given the mean in category 2, 
# the results do not seem conclusive

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here
# carat and color are likely to affect prices, though in opposite directions. Clarity may infuence price too

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8500789922841188

# %% [markdown]
# **What do you think?**

# %%
diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z', 'clarity_num', 'color_num', 'cut_num'],
#       dtype='object')

# %%
import statsmodels.api as sm

factors = diamonds[['carat','depth', 'table','clarity_num', 'color_num', 'cut_num']]
price = diamonds[['price']]

X = factors
y = price


model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.952
# Model:                            OLS   Adj. R-squared (uncentered):              0.952
# Method:                 Least Squares   F-statistic:                          1.780e+05
# Date:                Thu, 12 Mar 2020   Prob (F-statistic):                        0.00
# Time:                        15:01:37   Log-Likelihood:                     -4.6017e+05
# No. Observations:               53935   AIC:                                  9.204e+05
# Df Residuals:                   53929   BIC:                                  9.204e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# carat        8812.1475     12.725    692.527      0.000    8787.207    8837.088
# depth         -69.5395      1.799    -38.653      0.000     -73.066     -66.013
# table         -41.4310      1.863    -22.237      0.000     -45.083     -37.779
# clarity_num   519.8879      3.493    148.835      0.000     513.042     526.734
# color_num     316.8326      3.277     96.685      0.000     310.410     323.255
# cut_num       100.4194      4.815     20.857      0.000      90.983     109.856
# ==============================================================================
# Omnibus:                    10666.848   Durbin-Watson:                   0.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           177294.604
# Skew:                           0.492   Prob(JB):                         0.00
# Kurtosis:                      11.827   Cond. No.                         205.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#your thoughts here

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
