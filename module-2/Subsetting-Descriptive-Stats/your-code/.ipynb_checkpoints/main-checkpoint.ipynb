# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd
import seaborn as sns

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here
temp = pd.read_csv('..\data\Temp_states.csv')

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
"""
City = catgorical - Str
State = catgorical - Str
State = numerical - Float
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
temp.loc[temp["State"] == "New York"]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
temp.loc[temp["State"] == "New York"].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
temp.loc[temp["Temperature"] > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
temp[["City","Temperature"]].loc[temp["Temperature"] > 15]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
condition = (temp["Temperature"] > 15) & (temp["Temperature"] < 20)
temp[["City","Temperature"]].loc[condition]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here
temp.groupby("State").agg({"Temperature":["mean","std"]})
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees = pd.read_csv('..\data\Employee.csv')

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %%
"""
Name = catgorical - Str
Department = catgorical - Str
Education = catgorical - Str
Gender = catgorical - Str
Title = catgorical - Str
Years = numerical - Int
Salry = numerical - Int
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
employees["Salary"].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employees["Salary"].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
employees["Salary"].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
employees[["Name","Salary"]].sort_values(by="Salary").iloc[0:5]
# Out:
#      Name  Salary
# 1   Maria      30
# 2   David      30
# 0    Jose      35
# 3   Sonia      35
# 4  Samuel      55

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees.loc[employees["Name"]=="David"]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees["Salary"].loc[employees["Name"]=="David"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
employees.loc[employees["Title"]=="associate"]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employees.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# Method 2
# your code here
employees.loc[0:2]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees.loc[(employees["Title"]=="associate")&(employees["Salary"]>55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees.groupby("Years").mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees.groupby("Title").agg({"Salary":"mean"})
# Out:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here
employees.Salary.quantile([0.25,0.5,0.75,1])
# Out:
# 0.25    35.0
# 0.50    55.0
# 0.75    60.0
# 1.00    70.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here
employees.groupby("Gender").agg({"Salary":"mean"})
# Out:
#         Salary
# Gender
# F         47.5
# M         50.0

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
employees.groupby("Department").agg(["mean","min","max"])
# Out:
#                Years         Salary
#                 mean min max   mean min max
# Department
# HR          4.666667   2   8  45.00  30  70
# IT          4.500000   1   8  48.75  30  70
# Sales       2.500000   2   3  55.00  55  55

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders = pd.read_csv('..\data\Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %%
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
orders["UnitPrice"].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
orders[["UnitPrice"]].agg(["max","min"])
# Out:
#      UnitPrice
# max    8142.75
# min       0.00

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
orders.loc[orders["Country"]=="Spain"]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
orders.loc[orders["Country"]=="Spain"].agg({"CustomerID":"nunique"})
# Out:
# CustomerID    30
# dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
customers = orders.groupby("CustomerID").agg({"Quantity":"sum"})
customers.loc[(customers["Quantity"] > 50)]

#can you make it in one line????
# Out:
#             Quantity
# CustomerID
# 12346          74215
# 12347           2458
# 12348           2341
# 12349            631
# 12350            197
# ...              ...
# 18278             66
# 18281             54
# 18282            103
# 18283           1397
# 18287           1586
#
# [4091 rows x 1 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
orders_spain = orders.loc[orders["Country"]=="Spain"].groupby("InvoiceNo").agg({"Quantity":"sum"})
orders_spain.loc[orders_spain["Quantity"]>50]
# Out:
#            Quantity
# InvoiceNo
# 536944          400
# 538095           67
# 538525          300
# 539351          100
# 540469          630
# ...             ...
# 578321          920
# 578339           77
# 579503          117
# 580955          182
# 581193           92
#
# [80 rows x 1 columns]

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
orders_spent = orders.groupby("InvoiceNo").agg({"amount_spent":"sum"})
orders_spent.loc[orders_spent["amount_spent"]==0]
# Out:
#            amount_spent
# InvoiceNo
# 543599              0.0
# 564651              0.0
# 568384              0.0
# 578841              0.0

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
orders_descr = orders.groupby("InvoiceNo").agg({"Description":"first"})
orders_descr[orders_descr["Description"].str.startswith("lunch bag")]
# Out:
#                              Description
# InvoiceNo
# 536412               lunch bag cars blue
# 536542        lunch bag spaceboy design
# 536577           lunch bag red retrospot
# 536842                lunch bag woodland
# 536944           lunch bag suki  design
# ...                                  ...
# 581027          lunch bag paisley park
# 581131            lunch bag suki design
# 581223            lunch bag apple design
# 581413     lunch bag vintage leaf design
# 581583           lunch bag red retrospot
#
# [368 rows x 1 columns]

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
orders[orders["Description"].str.startswith("lunch bag")].loc[orders["year"]==2011]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here
orders["amount_spent"].loc[orders["Country"]=="Spain"].hist()

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
orders.loc[orders["month"]==8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
orders.loc[orders["month"]==8].groupby("Country").agg({"InvoiceNo":"nunique"})
# Out:
#                  InvoiceNo
# Country
# Australia                2
# Austria                  2
# Belgium                  9
# Canada                   1
# Channel Islands          5
# Denmark                  1
# EIRE                    17
# Finland                  3
# France                  28
# Germany                 39
# Iceland                  1
# Israel                   1
# Italy                    4
# Malta                    2
# Netherlands              8
# Norway                   2
# Poland                   2
# Portugal                 1
# Spain                   10
# Sweden                   5
# Switzerland              3
# United Kingdom        1133
# Unspecified              2

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders.groupby("Country").agg({"amount_spent":"mean"})
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
orders.groupby("StockCode").agg({"UnitPrice":"max"})
# Out:
#            UnitPrice
# StockCode
# 10002          0.850
# 10080          0.850
# 10120          0.210
# 10123C         0.650
# 10124A         0.420
# ...              ...
# C2           150.000
# DOT         1599.260
# M           4161.060
# PADS           0.001
# POST        8142.750
#
# [3665 rows x 1 columns]

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders.groupby("year").agg({"amount_spent":"mean"})
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
