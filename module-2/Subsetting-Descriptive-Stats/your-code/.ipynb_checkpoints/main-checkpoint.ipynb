# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd
import math

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here

# %% [markdown]
# #### Print `temp`.

# %%
# your code here

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees = pd.read_csv('../data/employees.csv')

# %%
employees
# Out:
#      employ_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  2003-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  2006-01-03
# 4          104      Bruce     Ernst    BERNST  590.423.4568  2007-05-21
# ..         ...        ...       ...       ...           ...         ...
# 102        202        Pat       Fay      PFAY  603.123.6666  2005-08-17
# 103        203      Susan    Mavris   SMAVRIS  515.123.7777  2002-06-07
# 104        204    Hermann      Baer     HBAER  515.123.8888  2002-06-07
# 105        205    Shelley   Higgins  SHIGGINS  515.123.8080  2002-06-07
# 106        206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
#
#          job_id  salary  commission_pct  manager_id  department_id
# ...

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.astype
# Out:
# <bound method NDFrame.astype of      employ_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  2003-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  2006-01-03
# 4          104      Bruce     Ernst    BERNST  590.423.4568  2007-05-21
# ..         ...        ...       ...       ...           ...         ...
# 102        202        Pat       Fay      PFAY  603.123.6666  2005-08-17
# 103        203      Susan    Mavris   SMAVRIS  515.123.7777  2002-06-07
# 104        204    Hermann      Baer     HBAER  515.123.8888  2002-06-07
# 105        205    Shelley   Higgins  SHIGGINS  515.123.8080  2002-06-07
# 106        206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
#
#          job_id  salary  commission_pct  manager_id  department_id
# ...

# %%
"""
your comments here
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
employees.salary.mean()
# Out:
# 6461.682242990654

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employees.salary.max()
# Out:
# 24000

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
min_salary = employees.salary.min()
min_salary
# Out:
# 2100

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
#employees.loc[min_salary,"employ_id"]
employees[employees.salary == min_salary][["employ_id","first_name","last_name"]]
# Out:
#     employ_id first_name last_name
# 32        132         TJ     Olson

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees[employees.first_name == 'David']
# Out:
#     employ_id first_name  last_name     email        phone_number   hire_date  \
# 5         105      David     Austin   DAUSTIN        590.423.4569  2005-06-25
# 51        151      David  Bernstein  DBERNSTE  011.44.1344.345268  2005-03-24
# 65        165      David        Lee      DLEE  011.44.1346.529268  2008-02-23
#
#      job_id  salary  commission_pct  manager_id  department_id
# 5   IT_PROG    4800             NaN       103.0           60.0
# 51   SA_REP    9500            0.25       145.0           80.0
# 65   SA_REP    6800            0.10       147.0           80.0

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees[employees.first_name == 'David']['salary']
# Out:
# 5     4800
# 51    9500
# 65    6800
# Name: salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here

# %%
departments = pd.read_csv('../data/departements.csv')
departments
# Out:
#     department_id       department_name  manager_id  location_id
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
employees_departments = pd.merge(employees,departments, on='department_id')
employees_departments
# Out:
#      employ_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  2003-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  2006-01-03
# 4          104      Bruce     Ernst    BERNST  590.423.4568  2007-05-21
# ..         ...        ...       ...       ...           ...         ...
# 101        202        Pat       Fay      PFAY  603.123.6666  2005-08-17
# 102        203      Susan    Mavris   SMAVRIS  515.123.7777  2002-06-07
# 103        204    Hermann      Baer     HBAER  515.123.8888  2002-06-07
# 104        205    Shelley   Higgins  SHIGGINS  515.123.8080  2002-06-07
# 105        206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
#
#          job_id  salary  commission_pct  manager_id_x  department_id  \
# ...

# %%
employees_departments[employees_departments.department_name == 'Executive']
# Out:
#    employ_id first_name last_name     email  phone_number   hire_date  \
# 0        100     Steven      King     SKING  515.123.4567  2003-06-17
# 1        101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2        102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
#
#     job_id  salary  commission_pct  manager_id_x  department_id  \
# 0  AD_PRES   24000             NaN           NaN           90.0
# 1    AD_VP   17000             NaN         100.0           90.0
# 2    AD_VP   17000             NaN         100.0           90.0
#
#   department_name  manager_id_y  location_id
# 0       Executive         100.0         1700
# 1       Executive         100.0         1700
# 2       Executive         100.0         1700

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employees_departments.iloc[:3]
# Out:
#    employ_id first_name last_name     email  phone_number   hire_date  \
# 0        100     Steven      King     SKING  515.123.4567  2003-06-17
# 1        101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2        102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
#
#     job_id  salary  commission_pct  manager_id_x  department_id  \
# 0  AD_PRES   24000             NaN           NaN           90.0
# 1    AD_VP   17000             NaN         100.0           90.0
# 2    AD_VP   17000             NaN         100.0           90.0
#
#   department_name  manager_id_y  location_id
# 0       Executive         100.0         1700
# 1       Executive         100.0         1700
# 2       Executive         100.0         1700

# %%
# Method 2
# your code here
employees_departments.head(3)
# Out:
#    employ_id first_name last_name     email  phone_number   hire_date  \
# 0        100     Steven      King     SKING  515.123.4567  2003-06-17
# 1        101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2        102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
#
#     job_id  salary  commission_pct  manager_id_x  department_id  \
# 0  AD_PRES   24000             NaN           NaN           90.0
# 1    AD_VP   17000             NaN         100.0           90.0
# 2    AD_VP   17000             NaN         100.0           90.0
#
#   department_name  manager_id_y  location_id
# 0       Executive         100.0         1700
# 1       Executive         100.0         1700
# 2       Executive         100.0         1700

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees_departments[employees.salary >=10000]
# Out:
# <ipython-input-55-ccb3c1438096>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   employees_departments[employees.salary >=10000]
#      employ_id first_name  last_name     email        phone_number  \
# 0          100     Steven       King     SKING        515.123.4567
# 1          101      Neena    Kochhar  NKOCHHAR        515.123.4568
# 2          102        Lex    De Haan   LDEHAAN        515.123.4569
# 8          108      Nancy  Greenberg  NGREENBE        515.124.4569
# 14         114        Den   Raphaely  DRAPHEAL        515.127.4561
# 45         180    Winston     Taylor   WTAYLOR        650.507.9876
# 46         181       Jean     Fleaur   JFLEAUR        650.507.9877
# 47         182     Martha   Sullivan  MSULLIVA        650.507.9878
# 48         183     Girard      Geoni    GGEONI        650.507.9879
# 49         184    Nandita   Sarchand  NSARCHAN        650.509.1876
# 50         185     Alexis       Bull     ABULL        650.509.2876
# ...

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
#date_min = employees_departments.hire_date.min()
#date_max = employees_departments.hire_date.max()

employees_departments['hire_year'] = [date[:4] for date in employees_departments.hire_date]
employees_departments[['hire_year','salary']].groupby('hire_year').mean()
# Out:
#                  salary
# hire_year
# 2001       17000.000000
# 2002        9828.571429
# 2003        7750.000000
# 2004        8600.000000
# 2005        6824.137931
# 2006        5045.833333
# 2007        4883.333333
# 2008        5381.818182

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees_departments[['department_name','salary']].groupby('department_name').mean()
# Out:
#                         salary
# department_name
# Accounting        10150.000000
# Administration     4400.000000
# Executive         19333.333333
# Finance            8600.000000
# Human Resources    6500.000000
# IT                 5760.000000
# Marketing          9500.000000
# Public Relations  10000.000000
# Purchasing         4150.000000
# Sales              8955.882353
# Shipping           3475.555556

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here
employees_departments.salary.describe()
# Out:
# count      106.000000
# mean      6456.603774
# std       3927.583017
# min       2100.000000
# 25%       3100.000000
# 50%       6150.000000
# 75%       8950.000000
# max      24000.000000
# Name: salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here
employees_departments[['department_name', 'salary']].groupby('department_name').mean()
# Out:
#                         salary
# department_name
# Accounting        10150.000000
# Administration     4400.000000
# Executive         19333.333333
# Finance            8600.000000
# Human Resources    6500.000000
# IT                 5760.000000
# Marketing          9500.000000
# Public Relations  10000.000000
# Purchasing         4150.000000
# Sales              8955.882353
# Shipping           3475.555556

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
employees_departments_num = employees_departments.numeric
employees_departments_num.groupby(department_name).describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-46f219c0c6b9> in <module>
#       1 # your code here
# ----> 2 employees_departments_num = employees_departments.numeric
#       3 employees_departments_num.groupby(department_name).describe()
#
# /usr/local/Cellar/jupyterlab/2.1.1/libexec/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'numeric'

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here

# %% [markdown]
# #### Select all free orders.

# %%
# your code here

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
