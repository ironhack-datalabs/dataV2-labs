# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y, 'go--', label='linear', linewidth=2, markersize=6)
plt.plot(x,z, label='quadratic', color='blue', marker='x', linestyle='dashed', markersize=4)

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("linear vs quadratic plot")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,y)
ax1.set_title('linear')
ax1.set_xlabel('x label')
ax1.set_ylabel('y label')

ax2.plot(x,z)
ax2.set_title('quadratric')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(15,7))
ax1.plot(x,y)
ax1.set_title('linear')
ax1.set_xlabel('x label')
ax1.set_ylabel('y label', fontsize='15')

ax2.plot(x,z)
ax2.set_title('quadratric')
ax2.set_xlabel('x label', fontweight='bold')
ax2.set_ylabel('y label')

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
#
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
import math

x = np.arange(0,100)
y = x*2
z = np.exp(x)

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('x')
ax1.set_ylabel('x²', color=color)
lns1 = ax1.plot(x, y, color=color,  marker='o', label = 'square(x)')
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('exp(x)', color=color)  # we already handled the x-label with ax1
lns2 = ax2.plot(x, z, color=color,  marker='x', label = 'exp(x)')
ax2.set_yscale('log')
ax2.tick_params(axis='y', labelcolor=color)

#Combine 2 labels
lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=0, shadow=True)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
import pandas as pd
fitbit = pd.read_csv('Fitbit2.csv')

# %%
fitbit.head(100)
# Out:
#           Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0   2015-05-08            1934    905      0.65       0              1.355
# 1   2015-05-09            3631  18925     14.11       4            611.000
# 2   2015-05-10            3204  14228     10.57       1            602.000
# 3   2015-05-11            2673   6756      5.02       8            749.000
# 4   2015-05-12            2495    502      3.73       1            876.000
# ..         ...             ...    ...       ...     ...                ...
# 95  2015-08-11            2857  13535     10.08       7              1.348
# 96  2015-08-12            2055   1883      1.40       1              1.370
# 97  2015-08-13            3218  11354      8.44       8            694.000
# 98  2015-08-14             301  11532      8.57       4            572.000
# 99  2015-08-15            2813   6129      4.55       3            635.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
plt.hist(fitbit.groupby('Work_or_Weekend').median()[['Steps']])
plt.xlabel('Work_or_Weekend')
plt.show()

# %%
fitbit.groupby('Work_or_Weekend').median()[['Steps']]
# Out:
#                    Steps
# Work_or_Weekend
# 0                 9998.0
# 1                10445.5

# %%
# MEDIAN STEPS BY WORK_OR_WEEKEND
plt.plot(fitbit.groupby('Months_encoded').median()[['Steps']])

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
x = fitbit['Minutes Lightly Active']
y = fitbit['Steps']
z = fitbit['Minutes Very Active']
w = fitbit['Minutes Sedentary']

data = [[x,y,'Minutes Lightly Active vs Steps'], [x,z,'Minutes Very Active vs Steps'], [x,w,'Minutes Sedentary vs Steps']]
axes = [ax1, ax2, ax3]
fig, axes = plt.subplots(1,3, figsize=(15,7))
for index in range(len(axes)):
    axes[index].scatter(data[index][0],data[index][1])
    axes[index].set_title(data[index][2])
    axes[index].set_xlabel('Minutes')
    axes[index].set_ylabel('Steps', fontsize='15')
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name  Gender        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  23.926502
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(exclude=['object'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(12,6)})

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.hist(titanic.Age)
plt.xlabel('Age')
plt.ylabel('Nb')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, [ax1, ax2, ax3] = plt.subplots(1,3, figsize=(15,7))
ax1.hist(titanic.Age, bins=10)
ax1.set_title('bins=10')
ax2.hist(titanic.Age, bins=20)
ax2.set_title('bins=20')
ax3.hist(titanic.Age, bins=50)
ax3.set_title('bins=50')
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
If bins is an integer, it defines the number of equal-width bins in the range.
If bins is a sequence, it defines the bin edges, including the left edge of 
the first bin and the right edge of the last bin; in this case, bins may be unequally spaced.
All but the last (righthand-most) bin is half-open.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.displot(titanic.Age, kde=True)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.hist(titanic.Gender)
plt.xlabel('Gender')
plt.ylabel('Nb')
plt.show()

# %%
# Method 2 - seaborn
sns.countplot(x = titanic.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x = titanic.Pclass)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
print(titanic.Age.describe())
ax = sns.boxplot(x=titanic.Age)
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
There are a few outliers after 60
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
#Creating figure composed of two matplotlib Axes objects
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={'height_ratios': (.15, .85)})

#assigning a graph to each ax
sns.boxplot(x=titanic.Age, ax=ax_box)
sns.histplot(x=titanic.Age, ax= ax_hist)

plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
The count of each age range
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic.Age, titanic.Fare)
plt.show()

# %%
titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name Gender   Age  SibSp  \
# 0            1       0.0       3  Braund, Mr. Owen Harris   male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25    U0        S

# %%
# Method 2 - seaborn
sns.scatterplot(data=titanic, x="Age", y="Fare")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
#Compute the correlation matrix
corr = titanic.corr()

#Mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

#Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11,9))

#Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
PClass 1, 2, 3 = Passenger class
sibsp = nb of siblings/spouses aboard
parch = nb of parents/children aboard
There is a correlation bewteen Fare and survived and Parch and SibSp
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
titanic.groupby(['Pclass'])['Age'].describe()
# Out:
#         count       mean        std   min        25%        50%      75%   max
# Pclass
# 1       323.0  39.555048  13.863639  0.92  30.000000  40.000000  49.0000  80.0
# 2       277.0  29.977433  13.563141  0.67  22.948773  29.000000  36.5000  70.0
# 3       709.0  25.432757  10.605975  0.17  20.000000  25.315435  31.4561  74.0

# %%
ax = sns.boxplot(x= 'Pclass', y='Age', data=titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col = 'Gender')
g.map(plt.hist, 'Age')
plt.show()
