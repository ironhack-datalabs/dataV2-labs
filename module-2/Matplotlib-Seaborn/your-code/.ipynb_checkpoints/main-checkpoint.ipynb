# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set
import math
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, label='(x,y)')
plt.plot(x, z, label='(x,z)')

plt.xlabel('x label')
plt.ylabel('y/z label')

plt.title("(x,y) and (x,z)")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,y)
ax1.set_title('(x,y)')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x,z)
ax2.set_title('(x,z)')
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1,2,figsize=(10,5))
ax1.plot(x,y)
ax1.set_title('(x,y)')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x,z)
ax2.set_title('(x,z)')
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,x**2)
ax1.set_title('(x,y)')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')
ax1.set_xscale("linear")
ax1.set_yscale("linear")

ax2.plot(x,np.exp(x))
ax2.set_title('(x,y)')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')
ax2.set_xscale("log")
ax2.set_yscale("log")


plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,x**2,label="linear")
ax1.set_title('(x,y)')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')
ax1.set_xscale("linear")
ax1.set_yscale("linear")
ax1.legend(loc="upper right")

ax2.plot(x,np.exp(x),label="log")
ax2.set_title('(x,y)')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')
ax2.set_xscale("log")
ax2.set_yscale("log")
ax1.legend(loc="upper right")

plt.legend()
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv(r"..\data\Fitbit2.csv")
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

x1 = fitbit["Months_encoded"].unique()
y1 = fitbit.groupby(["Months_encoded"])["Steps"].median()

x2 = fitbit["Work_or_Weekend"].unique()
y2 = fitbit.groupby(["Work_or_Weekend"])["Steps"].median()


fig, [ax1, ax2] = plt.subplots(1,2,figsize=(12,4))
ax1.bar(x1 , y1, label="steps")
ax1.set_title('median steps by month')   
ax1.set_xlabel('months')     
ax1.set_ylabel('median steps')
ax1.legend(loc="upper right")

# MEDIAN STEPS BY WORK_OR_WEEKEND

ax2.bar(x2,y2,label="log")
ax2.set_title('median steps on workday vs weekend')
ax2.set_xlabel('workday/weekend')
ax2.set_ylabel('steps')
ax1.legend(loc="upper right")

plt.legend()
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
lst = ["Minutes Lightly Active", "Minutes Fairly Active","Minutes Very Active"]
x = fitbit["Steps"]

for i in lst:
    plt.scatter(x, fitbit[i])
    plt.xlabel('Steps')
    plt.ylabel(i)
    plt.title("{} vs steps".format(i))
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv(r"..\data\titanic.csv")
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
#age
#fare
#Pclass
# your code here

# %%
# CATEGORICAL VARIABLES

#Name
#Sex
#Siblings/Spouses Aboard
#Parents/Children Aboard 
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic["Age"].hist()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
x = titanic["Age"]

fig, [ax1, ax2, ax3] = plt.subplots(1,3,figsize=(12,4))
ax1.hist(x, bins=10)
ax1.set_title('Age distribution')   
ax1.set_xlabel('Age')     
ax1.set_ylabel('Frequency')

ax2.hist(x, bins=20)
ax2.set_title('Age distribution')   
ax2.set_xlabel('Age')     
ax2.set_ylabel('Frequency')

ax3.hist(x, bins=50)
ax3.set_title('Age distribution')   
ax3.set_xlabel('Age')     
ax3.set_ylabel('Frequency')


plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The larger the bin sie the less concentrated the distribution
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic["Age"])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
labels = titanic["Sex"].unique()
x = titanic.groupby(["Sex"])["Sex"].count()

plt.pie(x,labels=labels)
plt.ylabel('Frequency')
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.barplot(x=x,y=labels)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
x = titanic["Pclass"].unique()
y = titanic.groupby(["Pclass"])["Pclass"].count()

sns.barplot(x=x,y=y)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.pairplot(titanic, x_vars=titanic.columns, y_vars="Age", diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
There is no clear relationship between age and fare
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic["Age"], titanic["Fare"])
plt.xlabel('Age')
plt.ylabel("Fare")
plt.title("Age vs fare")
plt.show()

# %%
# Method 2 - seaborn
# your code here
ax = sns.scatterplot(x=titanic["Age"], y=titanic["Fare"])

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
plt.figure(figsize=(10,10))
sns.heatmap(titanic.corr(),annot = True, vmin=-1, vmax=1, center= 0)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.pairplot(titanic, x_vars="Pclass", y_vars="Age", diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
titanic = sns.load_dataset("titanic")
x = sns.FacetGrid(titanic, col="Age",  row="Sex")
x = x.map(plt.hist,"Name")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-fa8f7469bb13> in <module>
#       1 # your code here
# ...
