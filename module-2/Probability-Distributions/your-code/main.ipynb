# %% [markdown]
# # Before your start:
# - Read the README.md file.
# - Comment as much as you can and use the resources (README.md file).
# - Happy learning!

# %% [markdown]
# # Challenge 1 - Generate and Plot Normal Distributions
# #### Step 1: Generate samples and test normal distribution.
#
# Use mean=50, standard_deviation=5, and sample_size=[10, 50, 500, 5000] to generate 4 random samples that are normally distributed.
#
# **Hint**: Read the documentation for `scipy.stats.norm.rvs`. The function will help you create the normal random samples.

# %%
from scipy.stats import norm
from scipy.stats import poisson
from scipy.stats import binom
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
import numpy as np
# %matplotlib inline
import seaborn as sns 
import pandas as pd
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sample_mean = 50
sample_std = 5
sample_sizes = [10,50,500,5000]

# %%
sample10 = pd.DataFrame(np.random.normal(sample_mean, sample_std, size=10))
sample50 = pd.DataFrame(np.random.normal(sample_mean, sample_std, size=50))
sample500 = pd.DataFrame(np.random.normal(sample_mean, sample_std, size=500))
sample5000 = pd.DataFrame(np.random.normal(sample_mean, sample_std, size=5000))

# %%
data = []
for s in sample_sizes:
    d = pd.DataFrame(np.random.normal(sample_mean, sample_std, size=s))
    data.append(d)

# %%
sample10.hist()
sample50.hist()
sample500.hist()
sample5000.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FFCCEBA828>]],
#       dtype=object)

# %% [markdown]
# #### Step 2: Plot normal distributions.
#
# To check the shape of the samples you have just created, you can use matplotlib. For example, you can use it to plot a histogram of each sample.
#
# If you did, your outputs would be really similar to the ones below:
#
# ![normal distributions with different sample sizes](../images/ch-1.png)

# %% [markdown]
# #### Compare the distributions above. What do you observe? Explain with the Central Limit Theorem.

# %%
"""
As we add more and more samples, the distribution begins to look like a normal distribution.

given a population for which we do not know the distribution (such as the heights of all data students, globally), as we draw more samples from the population, the distribution of the sample means approaches a normal distribution, and converges to the theoretical values of the underlying population distribution.

"""
# Out:
# '\nAs we add more and more samples, the distribution begins to look like a normal distribution.\n\ngiven a population for which we do not know the distribution (such as the heights of all data students, globally), as we draw more samples from the population, the distribution of the sample means approaches a normal distribution, and converges to the theoretical values of the underlying population distribution.\n\n'

# %% [markdown]
# #### Bonus: Plot normal distributions.
#
# Even though you still don't know how to use matplotlib, as a bonus challenge, you can try to reproduce the plot above using the samples you have created. This plotting library will be introduced later this week, so don't worry if you don't manage to get the results you want now: you can always come back to solve this challenge later.

# %%
fig, axes = plt.subplots(2, 2, figsize=(12,6))

sample10.hist(bins=100, ax=axes[0,0])
sample50.hist(bins=100, ax=axes[0,1])
sample500.hist(bins=100, ax=axes[1,0])
sample5000.hist(bins=100, ax=axes[1,1])
plt.show()

# %% [markdown]
# # Challenge 2 - Plot Probability Mass Function (PMF)

# %% [markdown]
# ### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# ### Challenge
#
# We assume that the probability of clicking an advertisement in a Youtube video is 0.15. We have a sample of 5 people who watched the video and we want to plot the PMF for a binomial distribution.
#
# #### Step 1: Create the binomial distribution mentioned above. Store the result in a variable called `dist`.
# **Hint**: use binom from `scipy.stats.binom`. This object takes *n* and *p* as shape parameters, where *n* is the number of independent experiments and *p* the probability of success of the experiment.

# %%
import scipy
n = 5
p = 0.15
k = 2

# n is our sample_size
# p is our probability
# k is the number of successful event happening in a ROW

#result = 


dist = scipy.stats.binom.pmf(n=n, p=p, k=k)
print(dist)
# Out:
# 0.13817812499999998

# %% [markdown]
# #### Step 2: Plot the PMF of the distribution.
# To do it, run the code in the cell below.
#
# **Hint**: Your output should look like the one below:
#
# ![binom 10](../images/ch-2.png)

# %%
# run this code
n = 5
p = 0.15
k = range(n)

fig, ax = plt.subplots(1, 1)

plt.plot(k, scipy.stats.binom.pmf(n=n,p=p, k=k))

plt.show()

# %% [markdown]
# #### Step 3: Explain what you observe from the plot above.

# %%
"""
X is the number of successive clicks in a row
Y is the probability of the success

If we only want one click out of 5 person with 15% chance then we have 40% chance this to happen.
IF we want to have two clicks out of 5 people with 15% percen, then we have 13% chance this to happen...

"""
# Out:
# '\nX is the number of successive clicks in a row\nY is the probability of the success\n\nIf we only want one click out of 5 person with 15% chance then we have 40% chance this to happen.\nIF we want to have two clicks out of 5 people with 15% percen, then we have 13% chance this to happen...\n\n'

# %% [markdown]
# #### Step 4: Now plot PMF with 50, 500, and 5000 visitors.
# To plot the PMF, you can copy the code given above and replace variable `dist` for the name of the variables where you have stored the new binomial objects for 50, 500 and 5000 visitors.

# %%
fig, ax = plt.subplots(1,3,figsize=(12,6))
n = 50
p = 0.15
k = range(n)

ax[0].plot(k, scipy.stats.binom.pmf(n=n,p=p, k=k))
ax[0].set_xlabel('number of successive events in a row')
ax[0].set_ylabel(f'probability of successive events K=={k} times in a row')

n = 500
k = range(n)

ax[1].plot(k, scipy.stats.binom.pmf(n=n,p=p, k=k))
ax[1].set_xlabel('number of successive events in a row')
ax[0].set_ylabel(f'probability of successive events K=={k} times in a row')
n = 5000
k = range(n)

ax[2].plot(k, scipy.stats.binom.pmf(n=n,p=p, k=k))
ax[2].set_xlabel('number of successive events in a row')
ax[0].set_ylabel(f'probability of successive events K=={k} times in a row')

plt.tight_layout()

plt.show()



#X is the number of successive events in a row
#Y is the probability of the success

# %% [markdown]
# #### Step 5: What did you notice from the distribution plots? Comment your findings.

# %%
"""
If K value is too high or too low then the probability is becoming zero, because we will have either HIGHER K or lower.

"""
# Out:
# '\nIf K value is too high or too low then the probability is becoming zero, because we will have either HIGHER K or lower.\n\n'

# %% [markdown]
# # Challenge 3
# #### Step 1: Research the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %%
"""
Deals iwth the frequency with which an event occurs in a specific interval
Need to know how often it occurs for a specific period of time.
If x happens y times in z seconds how many times it happens i times in j seconds.


"""
# Out:
# '\nDeals iwth the frequency with which an event occurs in a specific interval\nNeed to know how often it occurs for a specific period of time.\nIf x happens y times in z seconds how many times it happens i times in j seconds.\n\n\n'

# %% [markdown]
# #### Step 2: A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# **Hint**: use `scipy.stats.poisson.pmf`.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
#Calculate a few first moments:


mu = 300
mean, var, skew, kurt = poisson.stats(mu, moments='mvsk')
#Display the probability mass function (pmf):


x = np.arange(poisson.ppf(0.01, mu), poisson.ppf(0.99, mu))
ax.plot(x, poisson.pmf(x, mu), 'bo', ms=8, label='poisson pmf')
ax.vlines(x, 0, poisson.pmf(x, mu), colors='b', lw=5, alpha=0.3)
#Alternatively, the distribution object can be called (as a function) to fix the shape and location. This returns a “frozen” RV object holding the given parameters fixed.

#Freeze the distribution and display the frozen pmf:


rv = poisson(mu)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
        label='frozen pmf')
ax.legend(loc='best', frameon=False)
plt.show()

# %%
poisson.pmf(mu=300, k=320)
# Out:
# 0.011612348610402475

# %% [markdown]
# #### Step 3: What is the probability of getting 60 visits?

# %%
poisson.pmf(mu=300, k=320)
# Out:
# 0.011612348610402475

# %% [markdown]
# #### Step 4: Create a list to store the Poisson distribution probabilities for 0 to 1000 visitors. Store your list in a variable called `arr`.

# %%
arr = [poisson.pmf(300, k) for k in range(1000)]

# %% [markdown]
# #### Step 5: Plot the probabilities.
# To do it, run the code in the cell below. Your plot should look like the one below:
#
# ![poisson distribution](../images/ch-3.png)

# %%
# run this code
plt.plot(arr)
plt.show()

# %% [markdown]
# # Challenge 4 - Central Limit Theorem
#
# A delivery company needs 35 minutes to deliver a package, with a standard deviation of 8 minutes. Suppose that in one day, they deliver 200 packages.
#
# **Hint**: `stats.norm.cdf` can help you find the answers.
#
# #### Step 1: What is the probability that the mean delivery time today is between 30 and 35 minutes?

# %%
from scipy.stats import norm
norm(35,8).cdf(35)
# IF it takes 35 minutes to deliver a package
# with a standard deviation of 8
# what is the chance that the delivery will be 35 minutes
norm(35,8).cdf(35)
# IF it takes 35 minutes to deliver a package 
# with a standard deviation of 8, 
# what is the chance that the delivery will be 30 minutes


# We need to subtract because we are looking for the inner chance 
norm(35,8).cdf(35) - norm(35,8).cdf(30)
# Chance to be 35 minute - chance to be 30 minute
# Out:
# 0.23401447095129946

# %% [markdown]
# #### Step 2: What is the probability that in total, it takes more than 115 hours to deliver all 200 packages?

# %%
# IF it takes 115hours*60minutes/200 minutes to deliver a package
# with a standard deviation of 8
# what is the chance that the delivery will be more than 35 minutes
# Out:
# 0.5249176690292472

# %% [markdown]
# # Challenge 5 - Normal Variables
# The value (in thousands) of the monthly sales of a publishing company follows a normal distribution with a mean equal to 200 and a standard deviation equal to 40.
#
# <div align="center">$X → N(200,40)$</div>
#
# **Hint**: `stats.norm.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that the monthly sales are more than 300.

# %%
1-norm(200,40).cdf(300)
# Out:
# 0.006209665325776159

# %% [markdown]
# #### Step 2: Find the probability that the monthly sales fall between 160 and 240.

# %%
norm(200,40).cdf(240)-norm(200,40).cdf(160)
# Out:
# 0.6826894921370859

# %% [markdown]
# #### Step 3: Find the probability that the monthly sales do not exceed 150.

# %%
norm(200,40).cdf(150)
# Out:
# 0.10564977366685535

# %% [markdown]
# #### Step 4: Find the probability that the monthly sales exceed 3000.

# %%
1-norm(200,40).cdf(3000)
# Out:
# 0.0

# %% [markdown]
# # Challenge 6 - Poisson distribution
# The mean number of violent robberies per month that are registered in a particular barrio is 4.
#
# **Hint**: `stats.poisson.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that in a particular month there is no violent robbery.

# %%
poisson.pmf(mu=4, k=0)
# Out:
# 0.01831563888873418

# %% [markdown]
# #### Step 2: Find the probability that there are at least 1 robbery in a given month.

# %%
poisson.pmf(mu=4, k=1)
# Out:
# 0.07326255555493673

# %% [markdown]
# #### Step 3: Find the probability that there are between 2 and 6 (inclusive) robberies in a given month.

# %%
(1-poisson.pmf(mu=4, k=6))- (1-poisson.pmf(mu=4, k=2))
# Out:
# 0.04232947654285246

# %% [markdown]
# #### Step 4: Find the probability that there are more than 2 robberies in 15 days.

# %%
poisson.pmf(mu=2, k=2)
# Out:
# 0.2706705664732254
